# %% [markdown]
# # Real-time Adaptive PID Control for DC Motor Speed Regulation using Neural Network-based Self-tuning
#
# **Machine Learning (CS-5841/EE-5841) Project**
# *Mbadiwe S. Benyeogor, Mark-Anthony Agbanu, Kepha Barasa, and Joseph Alfred Sonne*
#
#
# **Instructor: Professor Sujan Kumar Roy**

# %% [markdown]
# # Introduction
# This software documentation describes the functionality of a real-time Artificial Neural Network (ANN)-tuned PID motor speed control system implemented in Python. The system uses a Proportional-Integral-Derivative (PID) controller initially, and after 20% of the total runtime, the ANN dynamically adjusts the PID gains for improved performance. The control loop is executed in real-time, interfacing with an Arduino via serial communication.
#
# # System Overview
# The system consists of:
# - A PID controller for initial motor speed regulation.
# - An ANN for self-tuning of PID gains after 20% of the runtime.
# - A serial communication interface to receive speed measurements and send control signals.
# - A CSV logging mechanism for data storage.
# - Real-time visualization of system performance using Matplotlib.
#
#
# # Experimental Setup
#
# The experimental setup displayed in Figure 1 is essential for implementing and testing the Python code provided below. Each device in the setup is a critical component of the control loop, ensuring the system operates as intended. The experiment primarily investigates the performance of an ANN-enhanced PID control system, comparing it with that of a classical PID control algorithm. This approach evaluates the advantages of integrating machine learning into traditional control methods for improved system efficiency.
#
# ![Experimental Setup](Device2.png)
#
# *Figure 1: Experimental setup showing the components of the real-time ANN-enabled PID motor speed control system.*
#
# ---
#
# ^1 The devices in the experimental setup are required for the Python code below to function correctly.

# %% [markdown]
# # Classical PID Control program without ANN-enabled Self-tuning:

# %%
import serial
import time
import csv
import matplotlib.pyplot as plt
from datetime import datetime
from matplotlib.ticker import ScalarFormatter

# PID Parameters (Tune as needed)
Kp = 1.6
Ki = 0.05
Kd = 0.5

# User Inputs
desired_speed = float(input("Enter desired motor speed (RPM): "))
runtime = float(input("Enter duration for PID control (seconds): "))

# Initialize Serial Communication (Update COM port if necessary)
ser = serial.Serial('COM3', 115200, timeout=0.2)  # Ensure COM port matches your system

# PID Variables
previous_error = 0
integral = 0

# Anti-Windup Limits
integral_min = -255
integral_max = 255

# Data Logging
times, speeds, errors, pwm_outputs = [], [], [], []
kp_values, ki_values, kd_values = [], [], []
start_time = time.time()

# Generate dynamic filenames with timestamp
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"PID_motor_data_{current_time}.csv"
pdf_filename_speed = f"PID_motor_plot_speed_{current_time}.pdf"
pdf_filename_gains = f"PID_motor_plot_gains_{current_time}.pdf"

# CSV File Setup
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Time (s)", "Desired Speed (RPM)", "Measured Speed (RPM)", "Error (RPM)", "PWM Output", "Kp", "Ki", "Kd"])  # CSV Header

def pid_control(measured_speed):
    """Compute PID control signal."""
    global previous_error, integral

    # PID computation
    error = desired_speed - measured_speed
    integral += error
    integral = max(min(integral, integral_max), integral_min)  # Anti-windup
    derivative = error - previous_error
    control_signal = (Kp * error) + (Ki * integral) + (Kd * derivative)
    previous_error = error

    return control_signal

# Main Control Loop
while time.time() - start_time < runtime:  # Run for user-defined duration
    response = ser.readline().decode().strip()
    if response:
        try:
            measured_speed = float(response)  # Measured speed in RPM
            elapsed_time = time.time() - start_time

            # Compute PID control output
            pwm_output = pid_control(measured_speed)
            ser.write(f"{pwm_output}\n".encode())  # Send PWM to Arduino

            # Store data
            times.append(elapsed_time)
            speeds.append(measured_speed)
            errors.append(desired_speed - measured_speed)
            pwm_outputs.append(pwm_output)
            kp_values.append(Kp)
            ki_values.append(Ki)
            kd_values.append(Kd)

            # Print output with current parameters
            print(f"Time: {elapsed_time:.2f}s | Desired: {desired_speed:.2f} RPM | "
                  f"Measured: {measured_speed:.2f} RPM | Error: {errors[-1]:.2f} RPM | "
                  f"PWM: {pwm_output} | Kp: {Kp} | Ki: {Ki} | Kd: {Kd}")

            # Save data to CSV
            with open(csv_filename, mode="a", newline="") as file:
                writer = csv.writer(file)
                writer.writerow([elapsed_time, desired_speed, measured_speed, errors[-1], pwm_output, Kp, Ki, Kd])

        except ValueError:
            print("Invalid data received.")

ser.close()

# Compute Settling Time (Ts)
settling_threshold = desired_speed * 0.05  # 5% threshold in RPM
Ts = next((t for t, e in zip(times, errors) if abs(e) <= settling_threshold), times[-1])

# Generate and Save Measured Speed & Error Plot
plt.figure(figsize=(7, 6))
plt.plot(times, speeds, label="Measured Speed", color="b", linewidth=2)
plt.plot(times, errors, label="Error", color="r", linewidth=2)
plt.plot(times, [desired_speed] * len(times), label="Desired Speed", color="g", linestyle="--", linewidth=2)

# Add shaded threshold region
threshold_lower = desired_speed * 0.95  # Lower bound of ±5% threshold
threshold_upper = desired_speed * 1.05  # Upper bound of ±5% threshold
plt.fill_between(times, threshold_lower, threshold_upper, color="gray", alpha=0.3, label="±5% Threshold")

# Add settling time marker
if Ts:
    plt.axvline(Ts, color="black", linestyle="--", linewidth=2, label=f"Settling Time: {Ts:.2f}s")
    #plt.text(Ts, desired_speed, f"  Ts = {Ts:.2f}s", fontsize=12, color="black", va="bottom")

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Speed (RPM)", fontsize=16)
#plt.title("Measured Speed and Error for PID Control without ANN", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Y-axis scientific notation
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)

# Add legend
plt.legend(fontsize=14)

# Save as PDF
plt.tight_layout()
plt.savefig(pdf_filename_speed, format="pdf")
plt.show()

# Generate and Save PID Gains Plot
plt.figure(figsize=(7, 6))
plt.plot(times, kp_values, label="Kp", color="m", linewidth=2)
plt.plot(times, ki_values, label="Ki", color="c", linewidth=2, alpha=0.6)
plt.plot(times, kd_values, label="Kd", color="y", linewidth=2, alpha=0.6)
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("PID Gains", fontsize=16)
#plt.title("Constant PID Gains Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(fontsize=14)

# Save as PDF
plt.tight_layout()
plt.savefig(pdf_filename_gains, format="pdf")
plt.show()

# Final Report
print(f"Data saved to {csv_filename}")
print(f"Speed plot saved to {pdf_filename_speed}")
print(f"PID gains plot saved to {pdf_filename_gains}")
# Out:
# Enter desired motor speed (RPM): 4000
# Enter duration for PID control (seconds): 8000
# Time: 1.90s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 2.93s | Desired: 4000.00 RPM | Measured: 3035.00 RPM | Error: 965.00 RPM | PWM: 39.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 3.97s | Desired: 4000.00 RPM | Measured: 3715.00 RPM | Error: 285.00 RPM | PWM: 128.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 5.01s | Desired: 4000.00 RPM | Measured: 3747.00 RPM | Error: 253.00 RPM | PWM: 401.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 6.04s | Desired: 4000.00 RPM | Measured: 3766.00 RPM | Error: 234.00 RPM | PWM: 377.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7.08s | Desired: 4000.00 RPM | Measured: 3605.00 RPM | Error: 395.00 RPM | PWM: 725.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 8.10s | Desired: 4000.00 RPM | Measured: 3682.00 RPM | Error: 318.00 RPM | PWM: 483.04999999999995 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 9.15s | Desired: 4000.00 RPM | Measured: 3052.00 RPM | Error: 948.00 RPM | PWM: 1844.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 10.18s | Desired: 4000.00 RPM | Measured: 3770.00 RPM | Error: 230.00 RPM | PWM: 21.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 11.22s | Desired: 4000.00 RPM | Measured: 3745.00 RPM | Error: 255.00 RPM | PWM: 433.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 12.25s | Desired: 4000.00 RPM | Measured: 3718.00 RPM | Error: 282.00 RPM | PWM: 477.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 13.29s | Desired: 4000.00 RPM | Measured: 3827.00 RPM | Error: 173.00 RPM | PWM: 235.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 14.32s | Desired: 4000.00 RPM | Measured: 3725.00 RPM | Error: 275.00 RPM | PWM: 503.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 15.35s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 526.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 16.39s | Desired: 4000.00 RPM | Measured: 3703.00 RPM | Error: 297.00 RPM | PWM: 481.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 17.42s | Desired: 4000.00 RPM | Measured: 3854.00 RPM | Error: 146.00 RPM | PWM: 170.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 18.45s | Desired: 4000.00 RPM | Measured: 3100.00 RPM | Error: 900.00 RPM | PWM: 1829.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 19.48s | Desired: 4000.00 RPM | Measured: 3605.00 RPM | Error: 395.00 RPM | PWM: 392.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 20.53s | Desired: 4000.00 RPM | Measured: 3732.00 RPM | Error: 268.00 RPM | PWM: 378.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 21.56s | Desired: 4000.00 RPM | Measured: 3714.00 RPM | Error: 286.00 RPM | PWM: 479.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 22.59s | Desired: 4000.00 RPM | Measured: 3713.00 RPM | Error: 287.00 RPM | PWM: 472.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 23.63s | Desired: 4000.00 RPM | Measured: 3829.00 RPM | Error: 171.00 RPM | PWM: 228.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 24.65s | Desired: 4000.00 RPM | Measured: 3378.00 RPM | Error: 622.00 RPM | PWM: 1233.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 25.68s | Desired: 4000.00 RPM | Measured: 3625.00 RPM | Error: 375.00 RPM | PWM: 489.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 26.73s | Desired: 4000.00 RPM | Measured: 3734.00 RPM | Error: 266.00 RPM | PWM: 383.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 27.76s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 448.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 28.79s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 528.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 29.83s | Desired: 4000.00 RPM | Measured: 3692.00 RPM | Error: 308.00 RPM | PWM: 504.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 30.87s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 509.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 31.90s | Desired: 4000.00 RPM | Measured: 3679.00 RPM | Error: 321.00 RPM | PWM: 531.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 32.93s | Desired: 4000.00 RPM | Measured: 3707.00 RPM | Error: 293.00 RPM | PWM: 467.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 33.97s | Desired: 4000.00 RPM | Measured: 3724.00 RPM | Error: 276.00 RPM | PWM: 445.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 35.01s | Desired: 4000.00 RPM | Measured: 3692.00 RPM | Error: 308.00 RPM | PWM: 521.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 36.04s | Desired: 4000.00 RPM | Measured: 3655.00 RPM | Error: 345.00 RPM | PWM: 583.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 37.08s | Desired: 4000.00 RPM | Measured: 3679.00 RPM | Error: 321.00 RPM | PWM: 514.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 38.10s | Desired: 4000.00 RPM | Measured: 3666.00 RPM | Error: 334.00 RPM | PWM: 553.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 39.15s | Desired: 4000.00 RPM | Measured: 3585.00 RPM | Error: 415.00 RPM | PWM: 717.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 40.18s | Desired: 4000.00 RPM | Measured: 3624.00 RPM | Error: 376.00 RPM | PWM: 594.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 41.22s | Desired: 4000.00 RPM | Measured: 3637.00 RPM | Error: 363.00 RPM | PWM: 587.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 42.25s | Desired: 4000.00 RPM | Measured: 3832.00 RPM | Error: 168.00 RPM | PWM: 184.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 43.28s | Desired: 4000.00 RPM | Measured: 3704.00 RPM | Error: 296.00 RPM | PWM: 550.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 44.32s | Desired: 4000.00 RPM | Measured: 3715.00 RPM | Error: 285.00 RPM | PWM: 463.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 45.35s | Desired: 4000.00 RPM | Measured: 3733.00 RPM | Error: 267.00 RPM | PWM: 430.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 46.39s | Desired: 4000.00 RPM | Measured: 3845.00 RPM | Error: 155.00 RPM | PWM: 204.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 47.42s | Desired: 4000.00 RPM | Measured: 3759.00 RPM | Error: 241.00 RPM | PWM: 441.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 48.45s | Desired: 4000.00 RPM | Measured: 3716.00 RPM | Error: 284.00 RPM | PWM: 488.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 49.48s | Desired: 4000.00 RPM | Measured: 3549.00 RPM | Error: 451.00 RPM | PWM: 817.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 50.51s | Desired: 4000.00 RPM | Measured: 3708.00 RPM | Error: 292.00 RPM | PWM: 400.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 51.56s | Desired: 4000.00 RPM | Measured: 3889.00 RPM | Error: 111.00 RPM | PWM: 99.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 52.59s | Desired: 4000.00 RPM | Measured: 3193.00 RPM | Error: 807.00 RPM | PWM: 1651.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 53.63s | Desired: 4000.00 RPM | Measured: 3616.00 RPM | Error: 384.00 RPM | PWM: 415.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 54.66s | Desired: 4000.00 RPM | Measured: 3892.00 RPM | Error: 108.00 RPM | PWM: 47.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 55.68s | Desired: 4000.00 RPM | Measured: 2804.00 RPM | Error: 1196.00 RPM | PWM: 2470.3500000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 56.73s | Desired: 4000.00 RPM | Measured: 3722.00 RPM | Error: 278.00 RPM | PWM: -1.4499999999999886 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 57.76s | Desired: 4000.00 RPM | Measured: 3260.00 RPM | Error: 740.00 RPM | PWM: 1427.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 58.79s | Desired: 4000.00 RPM | Measured: 3667.00 RPM | Error: 333.00 RPM | PWM: 342.05000000000007 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 59.82s | Desired: 4000.00 RPM | Measured: 3137.00 RPM | Error: 863.00 RPM | PWM: 1658.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 60.87s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 36.950000000000045 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 61.89s | Desired: 4000.00 RPM | Measured: 2991.00 RPM | Error: 1009.00 RPM | PWM: 2023.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 62.93s | Desired: 4000.00 RPM | Measured: 3659.00 RPM | Error: 341.00 RPM | PWM: 224.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 63.97s | Desired: 4000.00 RPM | Measured: 3425.00 RPM | Error: 575.00 RPM | PWM: 1049.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 65.00s | Desired: 4000.00 RPM | Measured: 3719.00 RPM | Error: 281.00 RPM | PWM: 315.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 66.03s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 327.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 67.06s | Desired: 4000.00 RPM | Measured: 3912.00 RPM | Error: 88.00 RPM | PWM: 89.05000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 68.10s | Desired: 4000.00 RPM | Measured: 3129.00 RPM | Error: 871.00 RPM | PWM: 1797.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 69.14s | Desired: 4000.00 RPM | Measured: 3592.00 RPM | Error: 408.00 RPM | PWM: 434.05000000000007 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 70.17s | Desired: 4000.00 RPM | Measured: 3164.00 RPM | Error: 836.00 RPM | PWM: 1564.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 71.20s | Desired: 4000.00 RPM | Measured: 3804.00 RPM | Error: 196.00 RPM | PWM: 6.350000000000023 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 72.23s | Desired: 4000.00 RPM | Measured: 3941.00 RPM | Error: 59.00 RPM | PWM: 38.650000000000006 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 73.28s | Desired: 4000.00 RPM | Measured: 3913.00 RPM | Error: 87.00 RPM | PWM: 165.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 74.30s | Desired: 4000.00 RPM | Measured: 3969.00 RPM | Error: 31.00 RPM | PWM: 34.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 75.34s | Desired: 4000.00 RPM | Measured: 3778.00 RPM | Error: 222.00 RPM | PWM: 463.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 76.38s | Desired: 4000.00 RPM | Measured: 3886.00 RPM | Error: 114.00 RPM | PWM: 141.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 77.41s | Desired: 4000.00 RPM | Measured: 3770.00 RPM | Error: 230.00 RPM | PWM: 438.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 78.45s | Desired: 4000.00 RPM | Measured: 3724.00 RPM | Error: 276.00 RPM | PWM: 477.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 79.47s | Desired: 4000.00 RPM | Measured: 3736.00 RPM | Error: 264.00 RPM | PWM: 429.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 80.50s | Desired: 4000.00 RPM | Measured: 3884.00 RPM | Error: 116.00 RPM | PWM: 124.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 81.55s | Desired: 4000.00 RPM | Measured: 3403.00 RPM | Error: 597.00 RPM | PWM: 1208.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 82.59s | Desired: 4000.00 RPM | Measured: 3677.00 RPM | Error: 323.00 RPM | PWM: 392.55000000000007 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 83.62s | Desired: 4000.00 RPM | Measured: 2741.00 RPM | Error: 1259.00 RPM | PWM: 2495.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 84.65s | Desired: 4000.00 RPM | Measured: 3549.00 RPM | Error: 451.00 RPM | PWM: 330.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 85.69s | Desired: 4000.00 RPM | Measured: 3672.00 RPM | Error: 328.00 RPM | PWM: 476.05000000000007 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 86.72s | Desired: 4000.00 RPM | Measured: 3106.00 RPM | Error: 894.00 RPM | PWM: 1726.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 87.75s | Desired: 4000.00 RPM | Measured: 3574.00 RPM | Error: 426.00 RPM | PWM: 460.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 88.78s | Desired: 4000.00 RPM | Measured: 3701.00 RPM | Error: 299.00 RPM | PWM: 427.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 89.83s | Desired: 4000.00 RPM | Measured: 3614.00 RPM | Error: 386.00 RPM | PWM: 673.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 90.85s | Desired: 4000.00 RPM | Measured: 3770.00 RPM | Error: 230.00 RPM | PWM: 302.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 91.90s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 345.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 92.92s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 376.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 93.96s | Desired: 4000.00 RPM | Measured: 3634.00 RPM | Error: 366.00 RPM | PWM: 669.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 94.99s | Desired: 4000.00 RPM | Measured: 3749.00 RPM | Error: 251.00 RPM | PWM: 356.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 96.03s | Desired: 4000.00 RPM | Measured: 3757.00 RPM | Error: 243.00 RPM | PWM: 397.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 97.06s | Desired: 4000.00 RPM | Measured: 3770.00 RPM | Error: 230.00 RPM | PWM: 374.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 98.09s | Desired: 4000.00 RPM | Measured: 3760.00 RPM | Error: 240.00 RPM | PWM: 401.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 99.12s | Desired: 4000.00 RPM | Measured: 3760.00 RPM | Error: 240.00 RPM | PWM: 396.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 100.17s | Desired: 4000.00 RPM | Measured: 3771.00 RPM | Error: 229.00 RPM | PWM: 373.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 101.20s | Desired: 4000.00 RPM | Measured: 3647.00 RPM | Error: 353.00 RPM | PWM: 639.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 102.22s | Desired: 4000.00 RPM | Measured: 3878.00 RPM | Error: 122.00 RPM | PWM: 92.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 103.26s | Desired: 4000.00 RPM | Measured: 3885.00 RPM | Error: 115.00 RPM | PWM: 193.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 104.30s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 528.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 105.33s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 392.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 106.37s | Desired: 4000.00 RPM | Measured: 3774.00 RPM | Error: 226.00 RPM | PWM: 364.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 107.40s | Desired: 4000.00 RPM | Measured: 3802.00 RPM | Error: 198.00 RPM | PWM: 315.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 108.44s | Desired: 4000.00 RPM | Measured: 3810.00 RPM | Error: 190.00 RPM | PWM: 312.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 109.48s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 365.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 110.51s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 376.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 111.55s | Desired: 4000.00 RPM | Measured: 3620.00 RPM | Error: 380.00 RPM | PWM: 698.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 112.57s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 391.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 113.62s | Desired: 4000.00 RPM | Measured: 3772.00 RPM | Error: 228.00 RPM | PWM: 356.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 114.64s | Desired: 4000.00 RPM | Measured: 3757.00 RPM | Error: 243.00 RPM | PWM: 409.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 115.68s | Desired: 4000.00 RPM | Measured: 3775.00 RPM | Error: 225.00 RPM | PWM: 363.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 116.71s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 358.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 117.75s | Desired: 4000.00 RPM | Measured: 3772.00 RPM | Error: 228.00 RPM | PWM: 382.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 118.77s | Desired: 4000.00 RPM | Measured: 3774.00 RPM | Error: 226.00 RPM | PWM: 373.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 119.81s | Desired: 4000.00 RPM | Measured: 3777.00 RPM | Error: 223.00 RPM | PWM: 368.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 120.86s | Desired: 4000.00 RPM | Measured: 3790.00 RPM | Error: 210.00 RPM | PWM: 342.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 121.89s | Desired: 4000.00 RPM | Measured: 3765.00 RPM | Error: 235.00 RPM | PWM: 401.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 122.92s | Desired: 4000.00 RPM | Measured: 3766.00 RPM | Error: 234.00 RPM | PWM: 386.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 123.95s | Desired: 4000.00 RPM | Measured: 3592.00 RPM | Error: 408.00 RPM | PWM: 752.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 124.98s | Desired: 4000.00 RPM | Measured: 3861.00 RPM | Error: 139.00 RPM | PWM: 100.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 126.03s | Desired: 4000.00 RPM | Measured: 3768.00 RPM | Error: 232.00 RPM | PWM: 430.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 127.06s | Desired: 4000.00 RPM | Measured: 3894.00 RPM | Error: 106.00 RPM | PWM: 119.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 128.09s | Desired: 4000.00 RPM | Measured: 3413.00 RPM | Error: 587.00 RPM | PWM: 1192.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 129.12s | Desired: 4000.00 RPM | Measured: 3640.00 RPM | Error: 360.00 RPM | PWM: 475.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 130.17s | Desired: 4000.00 RPM | Measured: 3715.00 RPM | Error: 285.00 RPM | PWM: 431.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 131.20s | Desired: 4000.00 RPM | Measured: 3711.00 RPM | Error: 289.00 RPM | PWM: 477.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 132.23s | Desired: 4000.00 RPM | Measured: 3841.00 RPM | Error: 159.00 RPM | PWM: 202.14999999999998 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 133.26s | Desired: 4000.00 RPM | Measured: 3876.00 RPM | Error: 124.00 RPM | PWM: 193.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 134.30s | Desired: 4000.00 RPM | Measured: 3763.00 RPM | Error: 237.00 RPM | PWM: 448.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 135.34s | Desired: 4000.00 RPM | Measured: 3873.00 RPM | Error: 127.00 RPM | PWM: 160.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 136.37s | Desired: 4000.00 RPM | Measured: 3900.00 RPM | Error: 100.00 RPM | PWM: 159.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 137.41s | Desired: 4000.00 RPM | Measured: 3743.00 RPM | Error: 257.00 RPM | PWM: 502.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 138.43s | Desired: 4000.00 RPM | Measured: 3866.00 RPM | Error: 134.00 RPM | PWM: 165.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 139.47s | Desired: 4000.00 RPM | Measured: 3765.00 RPM | Error: 235.00 RPM | PWM: 439.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 140.50s | Desired: 4000.00 RPM | Measured: 3733.00 RPM | Error: 267.00 RPM | PWM: 455.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 141.55s | Desired: 4000.00 RPM | Measured: 3870.00 RPM | Error: 130.00 RPM | PWM: 152.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 142.57s | Desired: 4000.00 RPM | Measured: 3745.00 RPM | Error: 255.00 RPM | PWM: 483.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 143.62s | Desired: 4000.00 RPM | Measured: 3718.00 RPM | Error: 282.00 RPM | PWM: 477.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 144.65s | Desired: 4000.00 RPM | Measured: 3859.00 RPM | Error: 141.00 RPM | PWM: 167.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 145.67s | Desired: 4000.00 RPM | Measured: 3145.00 RPM | Error: 855.00 RPM | PWM: 1737.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 146.71s | Desired: 4000.00 RPM | Measured: 3638.00 RPM | Error: 362.00 RPM | PWM: 345.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 147.73s | Desired: 4000.00 RPM | Measured: 3890.00 RPM | Error: 110.00 RPM | PWM: 62.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 148.77s | Desired: 4000.00 RPM | Measured: 3789.00 RPM | Error: 211.00 RPM | PWM: 400.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 149.80s | Desired: 4000.00 RPM | Measured: 3774.00 RPM | Error: 226.00 RPM | PWM: 381.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 150.84s | Desired: 4000.00 RPM | Measured: 3770.00 RPM | Error: 230.00 RPM | PWM: 382.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 151.87s | Desired: 4000.00 RPM | Measured: 3774.00 RPM | Error: 226.00 RPM | PWM: 372.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 152.90s | Desired: 4000.00 RPM | Measured: 3774.00 RPM | Error: 226.00 RPM | PWM: 374.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 153.93s | Desired: 4000.00 RPM | Measured: 3752.00 RPM | Error: 248.00 RPM | PWM: 420.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 154.97s | Desired: 4000.00 RPM | Measured: 3792.00 RPM | Error: 208.00 RPM | PWM: 325.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 156.00s | Desired: 4000.00 RPM | Measured: 3762.00 RPM | Error: 238.00 RPM | PWM: 408.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 157.04s | Desired: 4000.00 RPM | Measured: 3771.00 RPM | Error: 229.00 RPM | PWM: 374.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 158.07s | Desired: 4000.00 RPM | Measured: 3622.00 RPM | Error: 378.00 RPM | PWM: 692.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 159.10s | Desired: 4000.00 RPM | Measured: 3903.00 RPM | Error: 97.00 RPM | PWM: 27.450000000000017 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 160.15s | Desired: 4000.00 RPM | Measured: 3572.00 RPM | Error: 428.00 RPM | PWM: 863.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 161.18s | Desired: 4000.00 RPM | Measured: 3886.00 RPM | Error: 114.00 RPM | PWM: 38.150000000000006 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 162.22s | Desired: 4000.00 RPM | Measured: 3009.00 RPM | Error: 991.00 RPM | PWM: 2036.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 163.24s | Desired: 4000.00 RPM | Measured: 3522.00 RPM | Error: 478.00 RPM | PWM: 521.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 164.29s | Desired: 4000.00 RPM | Measured: 3885.00 RPM | Error: 115.00 RPM | PWM: 15.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 165.31s | Desired: 4000.00 RPM | Measured: 3804.00 RPM | Error: 196.00 RPM | PWM: 366.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 166.36s | Desired: 4000.00 RPM | Measured: 3793.00 RPM | Error: 207.00 RPM | PWM: 349.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 167.39s | Desired: 4000.00 RPM | Measured: 3942.00 RPM | Error: 58.00 RPM | PWM: 31.05000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 168.41s | Desired: 4000.00 RPM | Measured: 3205.00 RPM | Error: 795.00 RPM | PWM: 1653.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 169.45s | Desired: 4000.00 RPM | Measured: 3696.00 RPM | Error: 304.00 RPM | PWM: 253.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 170.50s | Desired: 4000.00 RPM | Measured: 3630.00 RPM | Error: 370.00 RPM | PWM: 637.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 171.53s | Desired: 4000.00 RPM | Measured: 3767.00 RPM | Error: 233.00 RPM | PWM: 317.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 172.55s | Desired: 4000.00 RPM | Measured: 3757.00 RPM | Error: 243.00 RPM | PWM: 406.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 173.59s | Desired: 4000.00 RPM | Measured: 3748.00 RPM | Error: 252.00 RPM | PWM: 420.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 174.63s | Desired: 4000.00 RPM | Measured: 3893.00 RPM | Error: 107.00 RPM | PWM: 111.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 175.66s | Desired: 4000.00 RPM | Measured: 3940.00 RPM | Error: 60.00 RPM | PWM: 85.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 176.69s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 440.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 177.73s | Desired: 4000.00 RPM | Measured: 3784.00 RPM | Error: 216.00 RPM | PWM: 357.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 178.76s | Desired: 4000.00 RPM | Measured: 3800.00 RPM | Error: 200.00 RPM | PWM: 324.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 179.80s | Desired: 4000.00 RPM | Measured: 3813.00 RPM | Error: 187.00 RPM | PWM: 305.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 180.82s | Desired: 4000.00 RPM | Measured: 3755.00 RPM | Error: 245.00 RPM | PWM: 433.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 181.86s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 541.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 182.89s | Desired: 4000.00 RPM | Measured: 3683.00 RPM | Error: 317.00 RPM | PWM: 523.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 183.92s | Desired: 4000.00 RPM | Measured: 3733.00 RPM | Error: 267.00 RPM | PWM: 414.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 184.95s | Desired: 4000.00 RPM | Measured: 3908.00 RPM | Error: 92.00 RPM | PWM: 72.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 185.99s | Desired: 4000.00 RPM | Measured: 3927.00 RPM | Error: 73.00 RPM | PWM: 120.05000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 187.03s | Desired: 4000.00 RPM | Measured: 3169.00 RPM | Error: 831.00 RPM | PWM: 1721.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 188.07s | Desired: 4000.00 RPM | Measured: 3794.00 RPM | Error: 206.00 RPM | PWM: 29.850000000000023 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 189.10s | Desired: 4000.00 RPM | Measured: 3584.00 RPM | Error: 416.00 RPM | PWM: 783.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 190.13s | Desired: 4000.00 RPM | Measured: 3760.00 RPM | Error: 240.00 RPM | PWM: 308.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 191.16s | Desired: 4000.00 RPM | Measured: 3777.00 RPM | Error: 223.00 RPM | PWM: 361.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 192.20s | Desired: 4000.00 RPM | Measured: 3807.00 RPM | Error: 193.00 RPM | PWM: 306.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 193.22s | Desired: 4000.00 RPM | Measured: 3804.00 RPM | Error: 196.00 RPM | PWM: 327.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 194.27s | Desired: 4000.00 RPM | Measured: 3805.00 RPM | Error: 195.00 RPM | PWM: 324.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 195.30s | Desired: 4000.00 RPM | Measured: 3815.00 RPM | Error: 185.00 RPM | PWM: 303.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 196.34s | Desired: 4000.00 RPM | Measured: 3813.00 RPM | Error: 187.00 RPM | PWM: 312.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 197.37s | Desired: 4000.00 RPM | Measured: 3835.00 RPM | Error: 165.00 RPM | PWM: 265.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 198.40s | Desired: 4000.00 RPM | Measured: 3838.00 RPM | Error: 162.00 RPM | PWM: 270.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 199.44s | Desired: 4000.00 RPM | Measured: 3828.00 RPM | Error: 172.00 RPM | PWM: 292.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 200.47s | Desired: 4000.00 RPM | Measured: 3848.00 RPM | Error: 152.00 RPM | PWM: 245.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 201.50s | Desired: 4000.00 RPM | Measured: 3964.00 RPM | Error: 36.00 RPM | PWM: 12.349999999999994 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 202.54s | Desired: 4000.00 RPM | Measured: 3978.00 RPM | Error: 22.00 RPM | PWM: 40.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 203.57s | Desired: 4000.00 RPM | Measured: 3826.00 RPM | Error: 174.00 RPM | PWM: 367.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 204.61s | Desired: 4000.00 RPM | Measured: 3929.00 RPM | Error: 71.00 RPM | PWM: 74.85000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 205.64s | Desired: 4000.00 RPM | Measured: 3213.00 RPM | Error: 787.00 RPM | PWM: 1629.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 206.68s | Desired: 4000.00 RPM | Measured: 3738.00 RPM | Error: 262.00 RPM | PWM: 169.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 207.72s | Desired: 4000.00 RPM | Measured: 3992.00 RPM | Error: 8.00 RPM | PWM: -101.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 208.75s | Desired: 4000.00 RPM | Measured: 3819.00 RPM | Error: 181.00 RPM | PWM: 388.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 209.78s | Desired: 4000.00 RPM | Measured: 3287.00 RPM | Error: 713.00 RPM | PWM: 1419.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 210.81s | Desired: 4000.00 RPM | Measured: 3860.00 RPM | Error: 140.00 RPM | PWM: -49.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 211.85s | Desired: 4000.00 RPM | Measured: 3851.00 RPM | Error: 149.00 RPM | PWM: 255.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 212.89s | Desired: 4000.00 RPM | Measured: 3847.00 RPM | Error: 153.00 RPM | PWM: 259.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 213.92s | Desired: 4000.00 RPM | Measured: 3849.00 RPM | Error: 151.00 RPM | PWM: 253.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 214.95s | Desired: 4000.00 RPM | Measured: 3646.00 RPM | Error: 354.00 RPM | PWM: 680.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 215.98s | Desired: 4000.00 RPM | Measured: 3762.00 RPM | Error: 238.00 RPM | PWM: 335.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 217.01s | Desired: 4000.00 RPM | Measured: 3816.00 RPM | Error: 184.00 RPM | PWM: 280.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 218.06s | Desired: 4000.00 RPM | Measured: 3942.00 RPM | Error: 58.00 RPM | PWM: 42.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 219.09s | Desired: 4000.00 RPM | Measured: 2825.00 RPM | Error: 1175.00 RPM | PWM: 2451.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 220.12s | Desired: 4000.00 RPM | Measured: 3634.00 RPM | Error: 366.00 RPM | PWM: 193.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 221.16s | Desired: 4000.00 RPM | Measured: 3209.00 RPM | Error: 791.00 RPM | PWM: 1490.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 222.18s | Desired: 4000.00 RPM | Measured: 3561.00 RPM | Error: 439.00 RPM | PWM: 539.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 223.22s | Desired: 4000.00 RPM | Measured: 3940.00 RPM | Error: 60.00 RPM | PWM: -80.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 224.26s | Desired: 4000.00 RPM | Measured: 3857.00 RPM | Error: 143.00 RPM | PWM: 283.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 225.29s | Desired: 4000.00 RPM | Measured: 3855.00 RPM | Error: 145.00 RPM | PWM: 245.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 226.32s | Desired: 4000.00 RPM | Measured: 3827.00 RPM | Error: 173.00 RPM | PWM: 303.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 227.36s | Desired: 4000.00 RPM | Measured: 3798.00 RPM | Error: 202.00 RPM | PWM: 350.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 228.40s | Desired: 4000.00 RPM | Measured: 3955.00 RPM | Error: 45.00 RPM | PWM: 6.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 229.44s | Desired: 4000.00 RPM | Measured: 3805.00 RPM | Error: 195.00 RPM | PWM: 399.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 230.46s | Desired: 4000.00 RPM | Measured: 3786.00 RPM | Error: 214.00 RPM | PWM: 364.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 231.50s | Desired: 4000.00 RPM | Measured: 3660.00 RPM | Error: 340.00 RPM | PWM: 619.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 232.52s | Desired: 4000.00 RPM | Measured: 3793.00 RPM | Error: 207.00 RPM | PWM: 277.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 233.57s | Desired: 4000.00 RPM | Measured: 3954.00 RPM | Error: 46.00 RPM | PWM: 5.8500000000000085 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 234.59s | Desired: 4000.00 RPM | Measured: 3326.00 RPM | Error: 674.00 RPM | PWM: 1405.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 235.64s | Desired: 4000.00 RPM | Measured: 3722.00 RPM | Error: 278.00 RPM | PWM: 259.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 236.67s | Desired: 4000.00 RPM | Measured: 3854.00 RPM | Error: 146.00 RPM | PWM: 180.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 237.70s | Desired: 4000.00 RPM | Measured: 3511.00 RPM | Error: 489.00 RPM | PWM: 966.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 238.74s | Desired: 4000.00 RPM | Measured: 3933.00 RPM | Error: 67.00 RPM | PWM: -91.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 239.77s | Desired: 4000.00 RPM | Measured: 3854.00 RPM | Error: 146.00 RPM | PWM: 285.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 240.81s | Desired: 4000.00 RPM | Measured: 3848.00 RPM | Error: 152.00 RPM | PWM: 258.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 241.84s | Desired: 4000.00 RPM | Measured: 3969.00 RPM | Error: 31.00 RPM | PWM: 1.8500000000000014 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 242.87s | Desired: 4000.00 RPM | Measured: 3294.00 RPM | Error: 706.00 RPM | PWM: 1479.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 243.91s | Desired: 4000.00 RPM | Measured: 3565.00 RPM | Error: 435.00 RPM | PWM: 573.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 244.95s | Desired: 4000.00 RPM | Measured: 3768.00 RPM | Error: 232.00 RPM | PWM: 282.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 245.99s | Desired: 4000.00 RPM | Measured: 3903.00 RPM | Error: 97.00 RPM | PWM: 100.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 247.02s | Desired: 4000.00 RPM | Measured: 3897.00 RPM | Error: 103.00 RPM | PWM: 180.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 248.05s | Desired: 4000.00 RPM | Measured: 3771.00 RPM | Error: 229.00 RPM | PWM: 442.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 249.09s | Desired: 4000.00 RPM | Measured: 3893.00 RPM | Error: 107.00 RPM | PWM: 122.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 250.12s | Desired: 4000.00 RPM | Measured: 3947.00 RPM | Error: 53.00 RPM | PWM: 70.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 251.15s | Desired: 4000.00 RPM | Measured: 2848.00 RPM | Error: 1152.00 RPM | PWM: 2405.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 252.18s | Desired: 4000.00 RPM | Measured: 3681.00 RPM | Error: 319.00 RPM | PWM: 106.65000000000009 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 253.22s | Desired: 4000.00 RPM | Measured: 3649.00 RPM | Error: 351.00 RPM | PWM: 590.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 254.26s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 284.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 255.29s | Desired: 4000.00 RPM | Measured: 3773.00 RPM | Error: 227.00 RPM | PWM: 382.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 256.32s | Desired: 4000.00 RPM | Measured: 3900.00 RPM | Error: 100.00 RPM | PWM: 109.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 257.36s | Desired: 4000.00 RPM | Measured: 3819.00 RPM | Error: 181.00 RPM | PWM: 342.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 258.40s | Desired: 4000.00 RPM | Measured: 3812.00 RPM | Error: 188.00 RPM | PWM: 317.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 259.44s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 435.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 260.45s | Desired: 4000.00 RPM | Measured: 3732.00 RPM | Error: 268.00 RPM | PWM: 452.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 261.49s | Desired: 4000.00 RPM | Measured: 3752.00 RPM | Error: 248.00 RPM | PWM: 399.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 262.54s | Desired: 4000.00 RPM | Measured: 3723.00 RPM | Error: 277.00 RPM | PWM: 470.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 263.57s | Desired: 4000.00 RPM | Measured: 3862.00 RPM | Error: 138.00 RPM | PWM: 164.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 264.61s | Desired: 4000.00 RPM | Measured: 3760.00 RPM | Error: 240.00 RPM | PWM: 447.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 265.64s | Desired: 4000.00 RPM | Measured: 3767.00 RPM | Error: 233.00 RPM | PWM: 382.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 266.67s | Desired: 4000.00 RPM | Measured: 3751.00 RPM | Error: 249.00 RPM | PWM: 419.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 267.71s | Desired: 4000.00 RPM | Measured: 3866.00 RPM | Error: 134.00 RPM | PWM: 169.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 268.73s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 470.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 269.77s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 421.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 270.81s | Desired: 4000.00 RPM | Measured: 3887.00 RPM | Error: 113.00 RPM | PWM: 123.05000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 271.84s | Desired: 4000.00 RPM | Measured: 3199.00 RPM | Error: 801.00 RPM | PWM: 1638.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 272.87s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 82.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 273.90s | Desired: 4000.00 RPM | Measured: 3652.00 RPM | Error: 348.00 RPM | PWM: 631.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 274.95s | Desired: 4000.00 RPM | Measured: 3945.00 RPM | Error: 55.00 RPM | PWM: -45.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 275.99s | Desired: 4000.00 RPM | Measured: 3861.00 RPM | Error: 139.00 RPM | PWM: 277.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 277.02s | Desired: 4000.00 RPM | Measured: 3850.00 RPM | Error: 150.00 RPM | PWM: 258.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 278.05s | Desired: 4000.00 RPM | Measured: 3873.00 RPM | Error: 127.00 RPM | PWM: 204.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 279.09s | Desired: 4000.00 RPM | Measured: 4006.00 RPM | Error: -6.00 RPM | PWM: -63.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 280.12s | Desired: 4000.00 RPM | Measured: 3883.00 RPM | Error: 117.00 RPM | PWM: 261.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 281.16s | Desired: 4000.00 RPM | Measured: 3988.00 RPM | Error: 12.00 RPM | PWM: -20.549999999999997 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 282.19s | Desired: 4000.00 RPM | Measured: 3060.00 RPM | Error: 940.00 RPM | PWM: 1980.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 283.22s | Desired: 4000.00 RPM | Measured: 3633.00 RPM | Error: 367.00 RPM | PWM: 313.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 284.26s | Desired: 4000.00 RPM | Measured: 3971.00 RPM | Error: 29.00 RPM | PWM: -109.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 285.28s | Desired: 4000.00 RPM | Measured: 3851.00 RPM | Error: 149.00 RPM | PWM: 311.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 286.32s | Desired: 4000.00 RPM | Measured: 3817.00 RPM | Error: 183.00 RPM | PWM: 322.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 287.36s | Desired: 4000.00 RPM | Measured: 3837.00 RPM | Error: 163.00 RPM | PWM: 263.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 288.39s | Desired: 4000.00 RPM | Measured: 3847.00 RPM | Error: 153.00 RPM | PWM: 252.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 289.42s | Desired: 4000.00 RPM | Measured: 3853.00 RPM | Error: 147.00 RPM | PWM: 244.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 290.45s | Desired: 4000.00 RPM | Measured: 3964.00 RPM | Error: 36.00 RPM | PWM: 14.849999999999994 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 291.49s | Desired: 4000.00 RPM | Measured: 3596.00 RPM | Error: 404.00 RPM | PWM: 843.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 292.52s | Desired: 4000.00 RPM | Measured: 3903.00 RPM | Error: 97.00 RPM | PWM: 14.450000000000017 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 293.56s | Desired: 4000.00 RPM | Measured: 3588.00 RPM | Error: 412.00 RPM | PWM: 829.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 294.59s | Desired: 4000.00 RPM | Measured: 3793.00 RPM | Error: 207.00 RPM | PWM: 241.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 295.63s | Desired: 4000.00 RPM | Measured: 3895.00 RPM | Error: 105.00 RPM | PWM: 129.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 296.66s | Desired: 4000.00 RPM | Measured: 3764.00 RPM | Error: 236.00 RPM | PWM: 455.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 297.69s | Desired: 4000.00 RPM | Measured: 3702.00 RPM | Error: 298.00 RPM | PWM: 520.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 298.73s | Desired: 4000.00 RPM | Measured: 3730.00 RPM | Error: 270.00 RPM | PWM: 430.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 299.76s | Desired: 4000.00 RPM | Measured: 3747.00 RPM | Error: 253.00 RPM | PWM: 409.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 300.80s | Desired: 4000.00 RPM | Measured: 3735.00 RPM | Error: 265.00 RPM | PWM: 442.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 301.84s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 388.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 302.87s | Desired: 4000.00 RPM | Measured: 3878.00 RPM | Error: 122.00 RPM | PWM: 147.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 303.90s | Desired: 4000.00 RPM | Measured: 3907.00 RPM | Error: 93.00 RPM | PWM: 147.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 304.94s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 417.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 305.97s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 413.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 307.01s | Desired: 4000.00 RPM | Measured: 3883.00 RPM | Error: 117.00 RPM | PWM: 137.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 308.03s | Desired: 4000.00 RPM | Measured: 3912.00 RPM | Error: 88.00 RPM | PWM: 139.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 309.07s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 439.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 310.11s | Desired: 4000.00 RPM | Measured: 3878.00 RPM | Error: 122.00 RPM | PWM: 156.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 311.14s | Desired: 4000.00 RPM | Measured: 3900.00 RPM | Error: 100.00 RPM | PWM: 161.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 312.17s | Desired: 4000.00 RPM | Measured: 3771.00 RPM | Error: 229.00 RPM | PWM: 443.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 313.20s | Desired: 4000.00 RPM | Measured: 3575.00 RPM | Error: 425.00 RPM | PWM: 790.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 314.25s | Desired: 4000.00 RPM | Measured: 3735.00 RPM | Error: 265.00 RPM | PWM: 356.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 315.28s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 449.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 316.32s | Desired: 4000.00 RPM | Measured: 3752.00 RPM | Error: 248.00 RPM | PWM: 398.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 317.36s | Desired: 4000.00 RPM | Measured: 3742.00 RPM | Error: 258.00 RPM | PWM: 430.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 318.39s | Desired: 4000.00 RPM | Measured: 3772.00 RPM | Error: 228.00 RPM | PWM: 362.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 319.42s | Desired: 4000.00 RPM | Measured: 3795.00 RPM | Error: 205.00 RPM | PWM: 329.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 320.46s | Desired: 4000.00 RPM | Measured: 3788.00 RPM | Error: 212.00 RPM | PWM: 355.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 321.49s | Desired: 4000.00 RPM | Measured: 3908.00 RPM | Error: 92.00 RPM | PWM: 99.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 322.54s | Desired: 4000.00 RPM | Measured: 3936.00 RPM | Error: 64.00 RPM | PWM: 101.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 323.57s | Desired: 4000.00 RPM | Measured: 3806.00 RPM | Error: 194.00 RPM | PWM: 388.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 324.60s | Desired: 4000.00 RPM | Measured: 3909.00 RPM | Error: 91.00 RPM | PWM: 106.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 325.64s | Desired: 4000.00 RPM | Measured: 3804.00 RPM | Error: 196.00 RPM | PWM: 378.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 326.67s | Desired: 4000.00 RPM | Measured: 3791.00 RPM | Error: 209.00 RPM | PWM: 353.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 327.71s | Desired: 4000.00 RPM | Measured: 3625.00 RPM | Error: 375.00 RPM | PWM: 695.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 328.73s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 341.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 329.77s | Desired: 4000.00 RPM | Measured: 3800.00 RPM | Error: 200.00 RPM | PWM: 309.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 330.81s | Desired: 4000.00 RPM | Measured: 3786.00 RPM | Error: 214.00 RPM | PWM: 362.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 331.84s | Desired: 4000.00 RPM | Measured: 3910.00 RPM | Error: 90.00 RPM | PWM: 94.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 332.87s | Desired: 4000.00 RPM | Measured: 3798.00 RPM | Error: 202.00 RPM | PWM: 391.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 333.90s | Desired: 4000.00 RPM | Measured: 3892.00 RPM | Error: 108.00 RPM | PWM: 138.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 334.93s | Desired: 4000.00 RPM | Measured: 3802.00 RPM | Error: 198.00 RPM | PWM: 374.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 335.98s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 361.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 337.00s | Desired: 4000.00 RPM | Measured: 3773.00 RPM | Error: 227.00 RPM | PWM: 382.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 338.05s | Desired: 4000.00 RPM | Measured: 3893.00 RPM | Error: 107.00 RPM | PWM: 123.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 339.08s | Desired: 4000.00 RPM | Measured: 3919.00 RPM | Error: 81.00 RPM | PWM: 129.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 340.11s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 419.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 341.14s | Desired: 4000.00 RPM | Measured: 3767.00 RPM | Error: 233.00 RPM | PWM: 395.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 342.17s | Desired: 4000.00 RPM | Measured: 3786.00 RPM | Error: 214.00 RPM | PWM: 345.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 343.22s | Desired: 4000.00 RPM | Measured: 3614.00 RPM | Error: 386.00 RPM | PWM: 716.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 344.25s | Desired: 4000.00 RPM | Measured: 3762.00 RPM | Error: 238.00 RPM | PWM: 319.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 345.28s | Desired: 4000.00 RPM | Measured: 3777.00 RPM | Error: 223.00 RPM | PWM: 362.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 346.31s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 371.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 347.34s | Desired: 4000.00 RPM | Measured: 3607.00 RPM | Error: 393.00 RPM | PWM: 726.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 348.39s | Desired: 4000.00 RPM | Measured: 3858.00 RPM | Error: 142.00 RPM | PWM: 114.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 349.42s | Desired: 4000.00 RPM | Measured: 3936.00 RPM | Error: 64.00 RPM | PWM: 76.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 350.46s | Desired: 4000.00 RPM | Measured: 3795.00 RPM | Error: 205.00 RPM | PWM: 411.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 351.49s | Desired: 4000.00 RPM | Measured: 3797.00 RPM | Error: 203.00 RPM | PWM: 336.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 352.52s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 366.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 353.56s | Desired: 4000.00 RPM | Measured: 3921.00 RPM | Error: 79.00 RPM | PWM: 70.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 354.59s | Desired: 4000.00 RPM | Measured: 3835.00 RPM | Error: 165.00 RPM | PWM: 319.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 355.63s | Desired: 4000.00 RPM | Measured: 3814.00 RPM | Error: 186.00 RPM | PWM: 320.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 356.65s | Desired: 4000.00 RPM | Measured: 3826.00 RPM | Error: 174.00 RPM | PWM: 285.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 357.69s | Desired: 4000.00 RPM | Measured: 3976.00 RPM | Error: 24.00 RPM | PWM: -23.849999999999994 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 358.72s | Desired: 4000.00 RPM | Measured: 3612.00 RPM | Error: 388.00 RPM | PWM: 815.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 359.75s | Desired: 4000.00 RPM | Measured: 3952.00 RPM | Error: 48.00 RPM | PWM: -80.44999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 360.78s | Desired: 4000.00 RPM | Measured: 4013.00 RPM | Error: -13.00 RPM | PWM: -39.2 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 361.82s | Desired: 4000.00 RPM | Measured: 3878.00 RPM | Error: 122.00 RPM | PWM: 275.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 362.86s | Desired: 4000.00 RPM | Measured: 4003.00 RPM | Error: -3.00 RPM | PWM: -54.7 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 363.89s | Desired: 4000.00 RPM | Measured: 3910.00 RPM | Error: 90.00 RPM | PWM: 203.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 364.92s | Desired: 4000.00 RPM | Measured: 3843.00 RPM | Error: 157.00 RPM | PWM: 297.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 365.96s | Desired: 4000.00 RPM | Measured: 3968.00 RPM | Error: 32.00 RPM | PWM: 1.4500000000000028 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 367.00s | Desired: 4000.00 RPM | Measured: 3318.00 RPM | Error: 682.00 RPM | PWM: 1428.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 368.03s | Desired: 4000.00 RPM | Measured: 3706.00 RPM | Error: 294.00 RPM | PWM: 289.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 369.07s | Desired: 4000.00 RPM | Measured: 3899.00 RPM | Error: 101.00 RPM | PWM: 77.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 370.11s | Desired: 4000.00 RPM | Measured: 3172.00 RPM | Error: 828.00 RPM | PWM: 1701.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 371.14s | Desired: 4000.00 RPM | Measured: 3846.00 RPM | Error: 154.00 RPM | PWM: -77.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 372.17s | Desired: 4000.00 RPM | Measured: 3147.00 RPM | Error: 853.00 RPM | PWM: 1727.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 373.21s | Desired: 4000.00 RPM | Measured: 3824.00 RPM | Error: 176.00 RPM | PWM: -44.14999999999998 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 374.24s | Desired: 4000.00 RPM | Measured: 3940.00 RPM | Error: 60.00 RPM | PWM: 50.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 375.28s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 507.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 376.31s | Desired: 4000.00 RPM | Measured: 3743.00 RPM | Error: 257.00 RPM | PWM: 427.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 377.34s | Desired: 4000.00 RPM | Measured: 3894.00 RPM | Error: 106.00 RPM | PWM: 106.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 378.39s | Desired: 4000.00 RPM | Measured: 3132.00 RPM | Error: 868.00 RPM | PWM: 1782.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 379.42s | Desired: 4000.00 RPM | Measured: 3853.00 RPM | Error: 147.00 RPM | PWM: -112.54999999999998 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 380.45s | Desired: 4000.00 RPM | Measured: 2869.00 RPM | Error: 1131.00 RPM | PWM: 2314.3500000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# ...
# Time: 7876.84s | Desired: 4000.00 RPM | Measured: 3836.00 RPM | Error: 164.00 RPM | PWM: 147.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7877.86s | Desired: 4000.00 RPM | Measured: 3933.00 RPM | Error: 67.00 RPM | PWM: 71.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7878.90s | Desired: 4000.00 RPM | Measured: 3720.00 RPM | Error: 280.00 RPM | PWM: 567.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7879.94s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 380.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7880.97s | Desired: 4000.00 RPM | Measured: 3929.00 RPM | Error: 71.00 RPM | PWM: 40.85000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7882.00s | Desired: 4000.00 RPM | Measured: 3223.00 RPM | Error: 777.00 RPM | PWM: 1608.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7883.04s | Desired: 4000.00 RPM | Measured: 3654.00 RPM | Error: 346.00 RPM | PWM: 350.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7884.07s | Desired: 4000.00 RPM | Measured: 3819.00 RPM | Error: 181.00 RPM | PWM: 219.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7885.11s | Desired: 4000.00 RPM | Measured: 3211.00 RPM | Error: 789.00 RPM | PWM: 1579.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7886.13s | Desired: 4000.00 RPM | Measured: 3723.00 RPM | Error: 277.00 RPM | PWM: 199.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7887.17s | Desired: 4000.00 RPM | Measured: 3962.00 RPM | Error: 38.00 RPM | PWM: -45.94999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7888.21s | Desired: 4000.00 RPM | Measured: 3965.00 RPM | Error: 35.00 RPM | PWM: 67.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7889.24s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 446.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7890.28s | Desired: 4000.00 RPM | Measured: 3795.00 RPM | Error: 205.00 RPM | PWM: 335.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7891.31s | Desired: 4000.00 RPM | Measured: 3790.00 RPM | Error: 210.00 RPM | PWM: 351.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7892.34s | Desired: 4000.00 RPM | Measured: 3786.00 RPM | Error: 214.00 RPM | PWM: 357.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7893.37s | Desired: 4000.00 RPM | Measured: 3938.00 RPM | Error: 62.00 RPM | PWM: 35.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7894.41s | Desired: 4000.00 RPM | Measured: 3814.00 RPM | Error: 186.00 RPM | PWM: 372.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7895.43s | Desired: 4000.00 RPM | Measured: 3784.00 RPM | Error: 216.00 RPM | PWM: 373.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7896.47s | Desired: 4000.00 RPM | Measured: 3722.00 RPM | Error: 278.00 RPM | PWM: 488.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7897.50s | Desired: 4000.00 RPM | Measured: 3714.00 RPM | Error: 286.00 RPM | PWM: 474.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7898.54s | Desired: 4000.00 RPM | Measured: 3737.00 RPM | Error: 263.00 RPM | PWM: 422.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7899.57s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 397.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7900.61s | Desired: 4000.00 RPM | Measured: 3734.00 RPM | Error: 266.00 RPM | PWM: 448.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7901.64s | Desired: 4000.00 RPM | Measured: 3738.00 RPM | Error: 262.00 RPM | PWM: 429.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7902.67s | Desired: 4000.00 RPM | Measured: 3855.00 RPM | Error: 145.00 RPM | PWM: 186.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7903.71s | Desired: 4000.00 RPM | Measured: 3777.00 RPM | Error: 223.00 RPM | PWM: 408.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7904.74s | Desired: 4000.00 RPM | Measured: 3778.00 RPM | Error: 222.00 RPM | PWM: 367.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7905.78s | Desired: 4000.00 RPM | Measured: 3904.00 RPM | Error: 96.00 RPM | PWM: 103.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7906.80s | Desired: 4000.00 RPM | Measured: 3408.00 RPM | Error: 592.00 RPM | PWM: 1207.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7907.85s | Desired: 4000.00 RPM | Measured: 3672.00 RPM | Error: 328.00 RPM | PWM: 405.55000000000007 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7908.87s | Desired: 4000.00 RPM | Measured: 2765.00 RPM | Error: 1235.00 RPM | PWM: 2442.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7909.92s | Desired: 4000.00 RPM | Measured: 3599.00 RPM | Error: 401.00 RPM | PWM: 237.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7910.94s | Desired: 4000.00 RPM | Measured: 3398.00 RPM | Error: 602.00 RPM | PWM: 1076.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7911.97s | Desired: 4000.00 RPM | Measured: 3686.00 RPM | Error: 314.00 RPM | PWM: 371.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7913.02s | Desired: 4000.00 RPM | Measured: 3878.00 RPM | Error: 122.00 RPM | PWM: 111.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7914.05s | Desired: 4000.00 RPM | Measured: 3963.00 RPM | Error: 37.00 RPM | PWM: 29.450000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7915.08s | Desired: 4000.00 RPM | Measured: 3562.00 RPM | Error: 438.00 RPM | PWM: 914.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7916.10s | Desired: 4000.00 RPM | Measured: 3898.00 RPM | Error: 102.00 RPM | PWM: 7.950000000000017 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7917.15s | Desired: 4000.00 RPM | Measured: 3005.00 RPM | Error: 995.00 RPM | PWM: 2051.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7918.17s | Desired: 4000.00 RPM | Measured: 3610.00 RPM | Error: 390.00 RPM | PWM: 334.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7919.22s | Desired: 4000.00 RPM | Measured: 3726.00 RPM | Error: 274.00 RPM | PWM: 393.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7920.25s | Desired: 4000.00 RPM | Measured: 3915.00 RPM | Error: 85.00 RPM | PWM: 54.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7921.28s | Desired: 4000.00 RPM | Measured: 3793.00 RPM | Error: 207.00 RPM | PWM: 404.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7922.31s | Desired: 4000.00 RPM | Measured: 3943.00 RPM | Error: 57.00 RPM | PWM: 28.950000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7923.36s | Desired: 4000.00 RPM | Measured: 3076.00 RPM | Error: 924.00 RPM | PWM: 1924.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7924.38s | Desired: 4000.00 RPM | Measured: 3628.00 RPM | Error: 372.00 RPM | PWM: 331.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7925.42s | Desired: 4000.00 RPM | Measured: 3930.00 RPM | Error: 70.00 RPM | PWM: -26.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7926.45s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 511.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7927.50s | Desired: 4000.00 RPM | Measured: 3851.00 RPM | Error: 149.00 RPM | PWM: 198.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7928.52s | Desired: 4000.00 RPM | Measured: 3730.00 RPM | Error: 270.00 RPM | PWM: 505.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7929.56s | Desired: 4000.00 RPM | Measured: 3625.00 RPM | Error: 375.00 RPM | PWM: 665.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7930.59s | Desired: 4000.00 RPM | Measured: 3693.00 RPM | Error: 307.00 RPM | PWM: 469.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7931.62s | Desired: 4000.00 RPM | Measured: 3907.00 RPM | Error: 93.00 RPM | PWM: 54.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7932.66s | Desired: 4000.00 RPM | Measured: 2799.00 RPM | Error: 1201.00 RPM | PWM: 2488.3500000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7933.69s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: -79.54999999999995 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7934.72s | Desired: 4000.00 RPM | Measured: 2810.00 RPM | Error: 1190.00 RPM | PWM: 2390.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7935.76s | Desired: 4000.00 RPM | Measured: 3549.00 RPM | Error: 451.00 RPM | PWM: 364.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7936.79s | Desired: 4000.00 RPM | Measured: 3719.00 RPM | Error: 281.00 RPM | PWM: 377.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7937.82s | Desired: 4000.00 RPM | Measured: 3732.00 RPM | Error: 268.00 RPM | PWM: 435.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7938.85s | Desired: 4000.00 RPM | Measured: 3702.00 RPM | Error: 298.00 RPM | PWM: 504.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7939.88s | Desired: 4000.00 RPM | Measured: 3737.00 RPM | Error: 263.00 RPM | PWM: 416.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7940.92s | Desired: 4000.00 RPM | Measured: 3714.00 RPM | Error: 286.00 RPM | PWM: 481.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7941.96s | Desired: 4000.00 RPM | Measured: 3706.00 RPM | Error: 294.00 RPM | PWM: 487.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7942.99s | Desired: 4000.00 RPM | Measured: 3869.00 RPM | Error: 131.00 RPM | PWM: 140.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7944.03s | Desired: 4000.00 RPM | Measured: 3134.00 RPM | Error: 866.00 RPM | PWM: 1765.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7945.06s | Desired: 4000.00 RPM | Measured: 3489.00 RPM | Error: 511.00 RPM | PWM: 652.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7946.09s | Desired: 4000.00 RPM | Measured: 3649.00 RPM | Error: 351.00 RPM | PWM: 494.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7947.13s | Desired: 4000.00 RPM | Measured: 3645.00 RPM | Error: 355.00 RPM | PWM: 582.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7948.16s | Desired: 4000.00 RPM | Measured: 3646.00 RPM | Error: 354.00 RPM | PWM: 578.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7949.20s | Desired: 4000.00 RPM | Measured: 3670.00 RPM | Error: 330.00 RPM | PWM: 528.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7950.22s | Desired: 4000.00 RPM | Measured: 3723.00 RPM | Error: 277.00 RPM | PWM: 429.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7951.27s | Desired: 4000.00 RPM | Measured: 3885.00 RPM | Error: 115.00 RPM | PWM: 115.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7952.29s | Desired: 4000.00 RPM | Measured: 3695.00 RPM | Error: 305.00 RPM | PWM: 595.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7953.32s | Desired: 4000.00 RPM | Measured: 3660.00 RPM | Error: 340.00 RPM | PWM: 574.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7954.37s | Desired: 4000.00 RPM | Measured: 3610.00 RPM | Error: 390.00 RPM | PWM: 661.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7955.40s | Desired: 4000.00 RPM | Measured: 3581.00 RPM | Error: 419.00 RPM | PWM: 697.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7956.43s | Desired: 4000.00 RPM | Measured: 3738.00 RPM | Error: 262.00 RPM | PWM: 353.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7957.47s | Desired: 4000.00 RPM | Measured: 3775.00 RPM | Error: 225.00 RPM | PWM: 354.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7958.50s | Desired: 4000.00 RPM | Measured: 3599.00 RPM | Error: 401.00 RPM | PWM: 742.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7959.54s | Desired: 4000.00 RPM | Measured: 3560.00 RPM | Error: 440.00 RPM | PWM: 736.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7960.56s | Desired: 4000.00 RPM | Measured: 3550.00 RPM | Error: 450.00 RPM | PWM: 737.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7961.59s | Desired: 4000.00 RPM | Measured: 3622.00 RPM | Error: 378.00 RPM | PWM: 581.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7962.63s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 357.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7963.67s | Desired: 4000.00 RPM | Measured: 3748.00 RPM | Error: 252.00 RPM | PWM: 414.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7964.69s | Desired: 4000.00 RPM | Measured: 3748.00 RPM | Error: 252.00 RPM | PWM: 415.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7965.74s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 403.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7966.77s | Desired: 4000.00 RPM | Measured: 3616.00 RPM | Error: 384.00 RPM | PWM: 696.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7967.79s | Desired: 4000.00 RPM | Measured: 3749.00 RPM | Error: 251.00 RPM | PWM: 347.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7968.84s | Desired: 4000.00 RPM | Measured: 3633.00 RPM | Error: 367.00 RPM | PWM: 657.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7969.87s | Desired: 4000.00 RPM | Measured: 3635.00 RPM | Error: 365.00 RPM | PWM: 595.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7970.91s | Desired: 4000.00 RPM | Measured: 3635.00 RPM | Error: 365.00 RPM | PWM: 596.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7971.93s | Desired: 4000.00 RPM | Measured: 3633.00 RPM | Error: 367.00 RPM | PWM: 600.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7972.97s | Desired: 4000.00 RPM | Measured: 3671.00 RPM | Error: 329.00 RPM | PWM: 520.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7974.00s | Desired: 4000.00 RPM | Measured: 3666.00 RPM | Error: 334.00 RPM | PWM: 549.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7975.04s | Desired: 4000.00 RPM | Measured: 3604.00 RPM | Error: 396.00 RPM | PWM: 677.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7976.07s | Desired: 4000.00 RPM | Measured: 3581.00 RPM | Error: 419.00 RPM | PWM: 694.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7977.12s | Desired: 4000.00 RPM | Measured: 3756.00 RPM | Error: 244.00 RPM | PWM: 315.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7978.15s | Desired: 4000.00 RPM | Measured: 3508.00 RPM | Error: 492.00 RPM | PWM: 923.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7979.18s | Desired: 4000.00 RPM | Measured: 3631.00 RPM | Error: 369.00 RPM | PWM: 541.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7980.22s | Desired: 4000.00 RPM | Measured: 3648.00 RPM | Error: 352.00 RPM | PWM: 567.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7981.26s | Desired: 4000.00 RPM | Measured: 3635.00 RPM | Error: 365.00 RPM | PWM: 603.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7982.29s | Desired: 4000.00 RPM | Measured: 3646.00 RPM | Error: 354.00 RPM | PWM: 573.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7983.31s | Desired: 4000.00 RPM | Measured: 3634.00 RPM | Error: 366.00 RPM | PWM: 604.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7984.35s | Desired: 4000.00 RPM | Measured: 3621.00 RPM | Error: 379.00 RPM | PWM: 625.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7985.38s | Desired: 4000.00 RPM | Measured: 3613.00 RPM | Error: 387.00 RPM | PWM: 635.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7986.43s | Desired: 4000.00 RPM | Measured: 3643.00 RPM | Error: 357.00 RPM | PWM: 568.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7987.45s | Desired: 4000.00 RPM | Measured: 3659.00 RPM | Error: 341.00 RPM | PWM: 550.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7988.49s | Desired: 4000.00 RPM | Measured: 3622.00 RPM | Error: 378.00 RPM | PWM: 636.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7989.52s | Desired: 4000.00 RPM | Measured: 3789.00 RPM | Error: 211.00 RPM | PWM: 266.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7990.56s | Desired: 4000.00 RPM | Measured: 3655.00 RPM | Error: 345.00 RPM | PWM: 631.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7991.59s | Desired: 4000.00 RPM | Measured: 3664.00 RPM | Error: 336.00 RPM | PWM: 545.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7992.61s | Desired: 4000.00 RPM | Measured: 3636.00 RPM | Error: 364.00 RPM | PWM: 609.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7993.65s | Desired: 4000.00 RPM | Measured: 3638.00 RPM | Error: 362.00 RPM | PWM: 590.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7994.69s | Desired: 4000.00 RPM | Measured: 3662.00 RPM | Error: 338.00 RPM | PWM: 541.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7995.72s | Desired: 4000.00 RPM | Measured: 3799.00 RPM | Error: 201.00 RPM | PWM: 265.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7996.75s | Desired: 4000.00 RPM | Measured: 3677.00 RPM | Error: 323.00 RPM | PWM: 590.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7997.78s | Desired: 4000.00 RPM | Measured: 3801.00 RPM | Error: 199.00 RPM | PWM: 269.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7998.82s | Desired: 4000.00 RPM | Measured: 3837.00 RPM | Error: 163.00 RPM | PWM: 255.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7999.87s | Desired: 4000.00 RPM | Measured: 3722.00 RPM | Error: 278.00 RPM | PWM: 515.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Data saved to PID_motor_data_20250405_002719.csv
# Speed plot saved to PID_motor_plot_speed_20250405_002719.pdf
# PID gains plot saved to PID_motor_plot_gains_20250405_002719.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime
import uuid  # Import UUID for unique filenames

import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

# Define whether ANN is enabled or not
ANN_enabled = True  # Set to True if ANN is used, False otherwise

# Convert lists to NumPy arrays for performance calculations
time_stamps = np.array(times)  # Recorded time points
error = np.array(errors)
setpoints = np.array([desired_speed] * len(times))  # Setpoints stored as an array
speeds = np.array(speeds)

# Compute Performance Metrics
rmse = np.sqrt(np.mean(error ** 2))  # Root Mean Square Error
mae = np.mean(np.abs(error))  # Mean Absolute Error
SSE = error[-1]  # Last recorded steady-state error
max_speed = max(speeds)  # Maximum speed recorded
overshoot = max(0, ((max_speed - desired_speed) / desired_speed) * 100)  # Percentage overshoot

# Settling Time (Ts)
within_tolerance = np.abs(error) < (0.05 * desired_speed)  # Define ±5% tolerance band
Ts_index = np.argmax(within_tolerance) if np.any(within_tolerance) else -1
Ts = time_stamps[Ts_index] if Ts_index != -1 else None  # First time where error is within ±5%

# Print Summary of Performance Metrics
print("Performance Metrics:")
print(f"Root Mean Square Error (RMSE): {rmse:.2f} RPM")
print(f"Mean Absolute Error (MAE): {mae:.2f} RPM")
print(f"Steady-State Error (SSE): {SSE:.2f} RPM")
print(f"Maximum Speed: {max_speed:.2f} RPM")
print(f"Overshoot: {overshoot:.2f}%")
print(f"Settling Time (Ts): {Ts:.2f} seconds" if Ts else "Settling Time (Ts): Not achieved within the runtime.")

# Generate Performance Plots and Save with explicit names
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")  # Format: YYYYMMDD_HHMMSS
identifier = "With_ANN" if ANN_enabled else "No_ANN"  # Condition-based identifier
unique_id = uuid.uuid4().hex[:8]  # Generates an 8-character unique ID

# 1. Histogram of Errors
hist_filename = f"Histogram_Errors_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.hist(error, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Error (RPM)", fontsize=16)
plt.ylabel("Frequency", fontsize=16)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(hist_filename, format="pdf", bbox_inches="tight")
plt.show()

# 2. RMSE & MAE Comparison
rmse_mae_filename = f"RMSE_MAE_Comparison_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["RMSE", "MAE"], [rmse, mae], color=['red', 'orange'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(rmse_mae_filename, format="pdf", bbox_inches="tight")
plt.show()

# 3. Overshoot & Steady-State Error
overshoot_sse_filename = f"Overshoot_SSE_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["Overshoot (%)", "SSE"], [overshoot, SSE], color=['purple', 'green'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)

# Apply Scientific Notation for the Y-axis
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)
plt.savefig(overshoot_sse_filename, format="pdf", bbox_inches="tight")
plt.show()

# Print saved filenames
print(f"Histogram of Errors saved as {hist_filename}")
print(f"RMSE & MAE Comparison saved as {rmse_mae_filename}")
print(f"Overshoot & Steady-State Error saved as {overshoot_sse_filename}")
# Out:
# Performance Metrics:
# Root Mean Square Error (RMSE): 342.16 RPM
# Mean Absolute Error (MAE): 261.99 RPM
# Steady-State Error (SSE): 278.00 RPM
# Maximum Speed: 4238.00 RPM
# Overshoot: 5.95%
# Settling Time (Ts): 13.29 seconds
# Histogram of Errors saved as Histogram_Errors_With_ANN_20250405_031255_594bdd48.pdf
# RMSE & MAE Comparison saved as RMSE_MAE_Comparison_With_ANN_20250405_031255_594bdd48.pdf
# Overshoot & Steady-State Error saved as Overshoot_SSE_With_ANN_20250405_031255_594bdd48.pdf

# %% [markdown]
# # Enhanced PID Control program with ANN-enabled Self-tuning:

# %%
import serial
import time
import csv
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime

# Initialize Serial Communication (Update COM Port)
ser = serial.Serial('COM3', 115200, timeout=0.1)

# PID Initial Parameters
Kp, Ki, Kd = 1.0, 0.05, 0.5
desired_speed = float(input("Enter desired motor speed (RPM): "))
runtime = float(input("Enter duration for PID control (seconds): "))
ann_start_time = runtime * 0.2  # ANN starts optimizing after 20% of runtime

# Define ANN Model (PyTorch)
class PIDANN(nn.Module):
    def __init__(self):
        super(PIDANN, self).__init__()
        self.fc1 = nn.Linear(5, 16)  # 5 Inputs -> 16 Neurons
        self.fc2 = nn.Linear(16, 16)  # Hidden layer
        self.fc3 = nn.Linear(16, 3)  # 3 Outputs (Kp, Ki, Kd)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)  # No activation (raw values)
        return x

# Initialize ANN Model
model = PIDANN()
optimizer = optim.Adam(model.parameters(), lr=0.01)
loss_function = nn.MSELoss()

# Data Logging
times, speeds, errors, pwm_outputs = [], [], [], []
kp_values, ki_values, kd_values, loss_values = [], [], [], []
start_time = time.time()
history = []  # Training Buffer
history_size = int(runtime * 0.1)  # Keep last nth data points for ANN training--10% size of run time

# Generate dynamic filenames for CSV and PDF
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"motor_speed_data_ANN_{current_datetime}.csv"
pdf_filename_speed = f"motor_speed_plot_speed_ANN_{current_datetime}.pdf"
pdf_filename_gains = f"motor_speed_plot_gains_ANN_{current_datetime}.pdf"
pdf_filename_loss = f"motor_speed_plot_loss_ANN_{current_datetime}.pdf"

# CSV File Setup
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Time (s)", "Desired Speed (RPM)", "Measured Speed (RPM)", "Error (RPM)", 
                     "PWM Output", "Kp", "Ki", "Kd", "Loss"])  # CSV Header

def pid_control(measured_speed, elapsed_time):
    """Compute PID control signal."""
    global Kp, Ki, Kd, history

    error = desired_speed - measured_speed
    delta_error = error - errors[-1] if errors else 0
    control_signal = (Kp * error) + (Ki * sum(errors[-history_size:])) + (Kd * delta_error)

    # ANN Optimization only after 20% runtime
    if elapsed_time >= ann_start_time and len(history) > 10:
        inputs = np.array([len(errors), desired_speed, measured_speed, error, control_signal], dtype=np.float32)
        inputs_tensor = torch.tensor(inputs, dtype=torch.float32)

        with torch.no_grad():
            output_tensor = model(inputs_tensor)

        Kp, Ki, Kd = output_tensor.numpy()

        # Apply constraints
        Kp = max(0.0, min(Kp, 50.0))
        Ki = max(0.0, min(Ki, 25.0))
        Kd = max(0.0, min(Kd, 25.0))

    # Train the ANN Online only after given runtime (e.g., 20% runtime)
    if elapsed_time >= ann_start_time:
        history.append([len(errors), desired_speed, measured_speed, error, control_signal, Kp, Ki, Kd])
        if len(history) > history_size:
            history.pop(0)

        x_train = torch.tensor([h[:-3] for h in history], dtype=torch.float32)
        y_train = torch.tensor([h[-3:] for h in history], dtype=torch.float32)

        optimizer.zero_grad()
        prediction = model(x_train)
        loss = loss_function(prediction, y_train)
        loss.backward()
        optimizer.step()

        loss_value = loss.item()
        loss_values.append(loss_value)
    else:
        loss_value = 0  # Before 20% runtime, no ANN training

    return control_signal, loss_value

# Main Control Loop
while time.time() - start_time < runtime:
    response = ser.readline().decode().strip()
    if response:
        measured_speed = float(response)  # Measured speed in RPM
        elapsed_time = time.time() - start_time
        
        # Compute PID output with ANN tuning only after 20% runtime
        pwm_output, loss_value = pid_control(measured_speed, elapsed_time)
        ser.write(f"{pwm_output}\n".encode())  # Send PWM to Arduino

        # Store Data
        times.append(elapsed_time)
        speeds.append(measured_speed)
        errors.append(desired_speed - measured_speed)
        pwm_outputs.append(pwm_output)
        kp_values.append(Kp)
        ki_values.append(Ki)
        kd_values.append(Kd)

        # Save to CSV
        with open(csv_filename, mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([elapsed_time, desired_speed, measured_speed, errors[-1], pwm_output, 
                             Kp, Ki, Kd, loss_value])

        # Print data in real-time
        print(f"Time: {elapsed_time:.2f}s | Desired: {desired_speed:.2f} RPM | Measured: {measured_speed:.2f} RPM | "
              f"Error: {errors[-1]:.2f} RPM | PWM: {pwm_output} | Kp: {Kp:.3f} | Ki: {Ki:.3f} | "
              f"Kd: {Kd:.3f} | Loss: {loss_value:.6f}")

ser.close()

# Generate Measured Speed & Error Plot
plt.figure(figsize=(7, 6))
plt.plot(times, speeds, label="Measured Speed (RPM)", color="b", linewidth=2)
plt.plot(times, errors, label="Error", color="r", linewidth=2)
plt.plot(times, [desired_speed] * len(times), label="Desired Speed (RPM)", color="g", linestyle="--", linewidth=2)

# Add shaded threshold region
threshold_lower = desired_speed * 0.95  # Lower bound of ±5% threshold
threshold_upper = desired_speed * 1.05  # Upper bound of ±5% threshold
plt.fill_between(times, threshold_lower, threshold_upper, color="gray", alpha=0.3, label="±5% Threshold")

# Add settling time marker
if Ts:
    plt.axvline(Ts, color="black", linestyle="--", linewidth=2, label=f"Settling Time: {Ts:.2f}s")
    #plt.text(Ts, desired_speed, f"  Ts = {Ts:.2f}s", fontsize=12, color="black", va="bottom")

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Speed (RPM)", fontsize=16)
#plt.title("Measured Speed and Error for PID Control with ANN", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_speed, format="pdf")
plt.show()

# Generate PID Gains Plot
plt.figure(figsize=(7, 6))
plt.plot(times, kp_values, label="Kp", color="m", linewidth=2)
plt.plot(times, ki_values, label="Ki", color="c", linewidth=2, alpha=0.6)
plt.plot(times, kd_values, label="Kd", color="y", linewidth=2, alpha=0.6)

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("PID Gains", fontsize=16)
#plt.title("ANN-PID Gains Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_gains, format="pdf")
plt.show()

# Generate Loss Plot
plt.figure(figsize=(7, 6))
plt.plot(times[:len(loss_values)], loss_values, label="Loss (MSE)", color="orange", linewidth=2)

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Loss (MSE)", fontsize=16)
#plt.title("ANN Training Loss Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_loss, format="pdf")
plt.show()

# Final Outputs
print(f"Data saved to {csv_filename}")
print(f"Measured Speed plot saved to {pdf_filename_speed}")
print(f"PID Gains plot saved to {pdf_filename_gains}")
print(f"Loss plot saved to {pdf_filename_loss}")
# Out:
# Enter desired motor speed (RPM): 4000
# Enter duration for PID control (seconds): 8000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 9000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 9200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 1.21s | Desired: 4000.00 RPM | Measured: 3256.00 RPM | Error: 744.00 RPM | PWM: 4516.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 2.24s | Desired: 4000.00 RPM | Measured: 3716.00 RPM | Error: 284.00 RPM | PWM: 5491.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 3.29s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 5636.400000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 4.32s | Desired: 4000.00 RPM | Measured: 3788.00 RPM | Error: 212.00 RPM | PWM: 5671.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 5.34s | Desired: 4000.00 RPM | Measured: 3572.00 RPM | Error: 428.00 RPM | PWM: 6008.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 6.39s | Desired: 4000.00 RPM | Measured: 3271.00 RPM | Error: 729.00 RPM | PWM: 6373.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 7.41s | Desired: 4000.00 RPM | Measured: 3503.00 RPM | Error: 497.00 RPM | PWM: 5911.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 8.44s | Desired: 4000.00 RPM | Measured: 3553.00 RPM | Error: 447.00 RPM | PWM: 5977.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 9.48s | Desired: 4000.00 RPM | Measured: 3605.00 RPM | Error: 395.00 RPM | PWM: 5946.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 10.51s | Desired: 4000.00 RPM | Measured: 3757.00 RPM | Error: 243.00 RPM | PWM: 5764.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 11.56s | Desired: 4000.00 RPM | Measured: 2912.00 RPM | Error: 1088.00 RPM | PWM: 7120.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 12.59s | Desired: 4000.00 RPM | Measured: 3468.00 RPM | Error: 532.00 RPM | PWM: 5918.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 13.62s | Desired: 4000.00 RPM | Measured: 3590.00 RPM | Error: 410.00 RPM | PWM: 6039.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 14.65s | Desired: 4000.00 RPM | Measured: 3615.00 RPM | Error: 385.00 RPM | PWM: 6083.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 15.69s | Desired: 4000.00 RPM | Measured: 3586.00 RPM | Error: 414.00 RPM | PWM: 6159.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 16.72s | Desired: 4000.00 RPM | Measured: 3629.00 RPM | Error: 371.00 RPM | PWM: 6100.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 17.76s | Desired: 4000.00 RPM | Measured: 3621.00 RPM | Error: 379.00 RPM | PWM: 6152.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 18.79s | Desired: 4000.00 RPM | Measured: 3604.00 RPM | Error: 396.00 RPM | PWM: 6193.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 19.83s | Desired: 4000.00 RPM | Measured: 3633.00 RPM | Error: 367.00 RPM | PWM: 6161.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 20.86s | Desired: 4000.00 RPM | Measured: 3711.00 RPM | Error: 289.00 RPM | PWM: 6076.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 21.89s | Desired: 4000.00 RPM | Measured: 3866.00 RPM | Error: 134.00 RPM | PWM: 5897.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 22.93s | Desired: 4000.00 RPM | Measured: 3431.00 RPM | Error: 569.00 RPM | PWM: 6634.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 23.96s | Desired: 4000.00 RPM | Measured: 3579.00 RPM | Error: 421.00 RPM | PWM: 6223.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 24.99s | Desired: 4000.00 RPM | Measured: 3688.00 RPM | Error: 312.00 RPM | PWM: 6155.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 26.03s | Desired: 4000.00 RPM | Measured: 3627.00 RPM | Error: 373.00 RPM | PWM: 6316.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 27.06s | Desired: 4000.00 RPM | Measured: 2887.00 RPM | Error: 1113.00 RPM | PWM: 7414.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 28.11s | Desired: 4000.00 RPM | Measured: 3506.00 RPM | Error: 494.00 RPM | PWM: 6172.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 29.14s | Desired: 4000.00 RPM | Measured: 3759.00 RPM | Error: 241.00 RPM | PWM: 6126.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 30.18s | Desired: 4000.00 RPM | Measured: 2919.00 RPM | Error: 1081.00 RPM | PWM: 7525.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 31.21s | Desired: 4000.00 RPM | Measured: 3475.00 RPM | Error: 525.00 RPM | PWM: 6325.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 32.25s | Desired: 4000.00 RPM | Measured: 3611.00 RPM | Error: 389.00 RPM | PWM: 6425.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 33.27s | Desired: 4000.00 RPM | Measured: 3653.00 RPM | Error: 347.00 RPM | PWM: 6450.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 34.32s | Desired: 4000.00 RPM | Measured: 3768.00 RPM | Error: 232.00 RPM | PWM: 6315.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 35.35s | Desired: 4000.00 RPM | Measured: 3608.00 RPM | Error: 392.00 RPM | PWM: 6624.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 36.39s | Desired: 4000.00 RPM | Measured: 3744.00 RPM | Error: 256.00 RPM | PWM: 6360.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 37.43s | Desired: 4000.00 RPM | Measured: 3636.00 RPM | Error: 364.00 RPM | PWM: 6603.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 38.46s | Desired: 4000.00 RPM | Measured: 3636.00 RPM | Error: 364.00 RPM | PWM: 6567.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 39.48s | Desired: 4000.00 RPM | Measured: 3624.00 RPM | Error: 376.00 RPM | PWM: 6603.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 40.53s | Desired: 4000.00 RPM | Measured: 3588.00 RPM | Error: 412.00 RPM | PWM: 6670.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 41.56s | Desired: 4000.00 RPM | Measured: 3615.00 RPM | Error: 385.00 RPM | PWM: 6632.650000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 42.60s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 6413.400000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 43.63s | Desired: 4000.00 RPM | Measured: 3775.00 RPM | Error: 225.00 RPM | PWM: 6520.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 44.66s | Desired: 4000.00 RPM | Measured: 3616.00 RPM | Error: 384.00 RPM | PWM: 6766.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 45.70s | Desired: 4000.00 RPM | Measured: 3751.00 RPM | Error: 249.00 RPM | PWM: 6503.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 46.73s | Desired: 4000.00 RPM | Measured: 3800.00 RPM | Error: 200.00 RPM | PWM: 6509.650000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 47.76s | Desired: 4000.00 RPM | Measured: 3771.00 RPM | Error: 229.00 RPM | PWM: 6587.650000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 48.80s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 6647.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 49.83s | Desired: 4000.00 RPM | Measured: 3567.00 RPM | Error: 433.00 RPM | PWM: 6883.150000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 50.87s | Desired: 4000.00 RPM | Measured: 2821.00 RPM | Error: 1179.00 RPM | PWM: 7942.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 51.90s | Desired: 4000.00 RPM | Measured: 3405.00 RPM | Error: 595.00 RPM | PWM: 6752.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 52.94s | Desired: 4000.00 RPM | Measured: 3536.00 RPM | Error: 464.00 RPM | PWM: 6878.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 53.97s | Desired: 4000.00 RPM | Measured: 3751.00 RPM | Error: 249.00 RPM | PWM: 6644.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 55.00s | Desired: 4000.00 RPM | Measured: 3804.00 RPM | Error: 196.00 RPM | PWM: 6684.650000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 56.04s | Desired: 4000.00 RPM | Measured: 3836.00 RPM | Error: 164.00 RPM | PWM: 6672.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 57.07s | Desired: 4000.00 RPM | Measured: 3790.00 RPM | Error: 210.00 RPM | PWM: 6766.150000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 58.11s | Desired: 4000.00 RPM | Measured: 2898.00 RPM | Error: 1102.00 RPM | PWM: 8091.650000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 59.14s | Desired: 4000.00 RPM | Measured: 3709.00 RPM | Error: 291.00 RPM | PWM: 6484.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 60.17s | Desired: 4000.00 RPM | Measured: 3655.00 RPM | Error: 345.00 RPM | PWM: 6985.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 61.21s | Desired: 4000.00 RPM | Measured: 3657.00 RPM | Error: 343.00 RPM | PWM: 6972.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 62.24s | Desired: 4000.00 RPM | Measured: 3659.00 RPM | Error: 341.00 RPM | PWM: 6987.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 63.27s | Desired: 4000.00 RPM | Measured: 2975.00 RPM | Error: 1025.00 RPM | PWM: 8031.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 64.31s | Desired: 4000.00 RPM | Measured: 3530.00 RPM | Error: 470.00 RPM | PWM: 6908.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 65.34s | Desired: 4000.00 RPM | Measured: 3695.00 RPM | Error: 305.00 RPM | PWM: 6962.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 66.38s | Desired: 4000.00 RPM | Measured: 3864.00 RPM | Error: 136.00 RPM | PWM: 6806.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 67.41s | Desired: 4000.00 RPM | Measured: 3679.00 RPM | Error: 321.00 RPM | PWM: 7175.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 68.44s | Desired: 4000.00 RPM | Measured: 3708.00 RPM | Error: 292.00 RPM | PWM: 7055.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 69.48s | Desired: 4000.00 RPM | Measured: 3712.00 RPM | Error: 288.00 RPM | PWM: 7078.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 70.51s | Desired: 4000.00 RPM | Measured: 3868.00 RPM | Error: 132.00 RPM | PWM: 6860.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 71.55s | Desired: 4000.00 RPM | Measured: 3722.00 RPM | Error: 278.00 RPM | PWM: 7164.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 72.59s | Desired: 4000.00 RPM | Measured: 3850.00 RPM | Error: 150.00 RPM | PWM: 6913.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 73.62s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 7169.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 74.64s | Desired: 4000.00 RPM | Measured: 3687.00 RPM | Error: 313.00 RPM | PWM: 7181.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 75.67s | Desired: 4000.00 RPM | Measured: 3669.00 RPM | Error: 331.00 RPM | PWM: 7203.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 76.72s | Desired: 4000.00 RPM | Measured: 3394.00 RPM | Error: 606.00 RPM | PWM: 7623.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 77.76s | Desired: 4000.00 RPM | Measured: 3827.00 RPM | Error: 173.00 RPM | PWM: 6867.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 78.79s | Desired: 4000.00 RPM | Measured: 3741.00 RPM | Error: 259.00 RPM | PWM: 7221.400000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 79.81s | Desired: 4000.00 RPM | Measured: 3857.00 RPM | Error: 143.00 RPM | PWM: 7017.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 80.85s | Desired: 4000.00 RPM | Measured: 3707.00 RPM | Error: 293.00 RPM | PWM: 7307.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 81.89s | Desired: 4000.00 RPM | Measured: 3699.00 RPM | Error: 301.00 RPM | PWM: 7259.150000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 82.91s | Desired: 4000.00 RPM | Measured: 2952.00 RPM | Error: 1048.00 RPM | PWM: 8390.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 83.96s | Desired: 4000.00 RPM | Measured: 3507.00 RPM | Error: 493.00 RPM | PWM: 7237.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 84.99s | Desired: 4000.00 RPM | Measured: 3665.00 RPM | Error: 335.00 RPM | PWM: 7302.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 86.03s | Desired: 4000.00 RPM | Measured: 3680.00 RPM | Error: 320.00 RPM | PWM: 7375.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 87.06s | Desired: 4000.00 RPM | Measured: 3658.00 RPM | Error: 342.00 RPM | PWM: 7432.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 88.09s | Desired: 4000.00 RPM | Measured: 3806.00 RPM | Error: 194.00 RPM | PWM: 7216.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 89.12s | Desired: 4000.00 RPM | Measured: 3682.00 RPM | Error: 318.00 RPM | PWM: 7485.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 90.15s | Desired: 4000.00 RPM | Measured: 3650.00 RPM | Error: 350.00 RPM | PWM: 7487.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 91.19s | Desired: 4000.00 RPM | Measured: 2933.00 RPM | Error: 1067.00 RPM | PWM: 8564.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 92.22s | Desired: 4000.00 RPM | Measured: 3526.00 RPM | Error: 474.00 RPM | PWM: 7370.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 93.26s | Desired: 4000.00 RPM | Measured: 3630.00 RPM | Error: 370.00 RPM | PWM: 7534.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 94.30s | Desired: 4000.00 RPM | Measured: 3673.00 RPM | Error: 327.00 RPM | PWM: 7540.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 95.33s | Desired: 4000.00 RPM | Measured: 3712.00 RPM | Error: 288.00 RPM | PWM: 7519.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 96.36s | Desired: 4000.00 RPM | Measured: 3675.00 RPM | Error: 325.00 RPM | PWM: 7609.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 97.39s | Desired: 4000.00 RPM | Measured: 3826.00 RPM | Error: 174.00 RPM | PWM: 7380.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 98.43s | Desired: 4000.00 RPM | Measured: 3675.00 RPM | Error: 325.00 RPM | PWM: 7690.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 99.46s | Desired: 4000.00 RPM | Measured: 3802.00 RPM | Error: 198.00 RPM | PWM: 7441.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 100.51s | Desired: 4000.00 RPM | Measured: 3841.00 RPM | Error: 159.00 RPM | PWM: 7456.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 101.53s | Desired: 4000.00 RPM | Measured: 3692.00 RPM | Error: 308.00 RPM | PWM: 7707.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 102.57s | Desired: 4000.00 RPM | Measured: 3634.00 RPM | Error: 366.00 RPM | PWM: 7734.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 103.60s | Desired: 4000.00 RPM | Measured: 3824.00 RPM | Error: 176.00 RPM | PWM: 7439.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 104.65s | Desired: 4000.00 RPM | Measured: 3682.00 RPM | Error: 318.00 RPM | PWM: 7756.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 105.66s | Desired: 4000.00 RPM | Measured: 3625.00 RPM | Error: 375.00 RPM | PWM: 7786.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 106.71s | Desired: 4000.00 RPM | Measured: 3538.00 RPM | Error: 462.00 RPM | PWM: 7907.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 107.75s | Desired: 4000.00 RPM | Measured: 3830.00 RPM | Error: 170.00 RPM | PWM: 7448.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 108.78s | Desired: 4000.00 RPM | Measured: 3697.00 RPM | Error: 303.00 RPM | PWM: 7802.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 109.81s | Desired: 4000.00 RPM | Measured: 3665.00 RPM | Error: 335.00 RPM | PWM: 7799.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 110.84s | Desired: 4000.00 RPM | Measured: 3551.00 RPM | Error: 449.00 RPM | PWM: 7971.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 111.88s | Desired: 4000.00 RPM | Measured: 3859.00 RPM | Error: 141.00 RPM | PWM: 7474.650000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 112.91s | Desired: 4000.00 RPM | Measured: 3913.00 RPM | Error: 87.00 RPM | PWM: 7554.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 113.94s | Desired: 4000.00 RPM | Measured: 3016.00 RPM | Error: 984.00 RPM | PWM: 8931.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 114.97s | Desired: 4000.00 RPM | Measured: 3600.00 RPM | Error: 400.00 RPM | PWM: 7656.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 116.01s | Desired: 4000.00 RPM | Measured: 3725.00 RPM | Error: 275.00 RPM | PWM: 7780.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 117.05s | Desired: 4000.00 RPM | Measured: 3763.00 RPM | Error: 237.00 RPM | PWM: 7800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 118.08s | Desired: 4000.00 RPM | Measured: 3930.00 RPM | Error: 70.00 RPM | PWM: 7580.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 119.11s | Desired: 4000.00 RPM | Measured: 3846.00 RPM | Error: 154.00 RPM | PWM: 7793.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 120.15s | Desired: 4000.00 RPM | Measured: 3791.00 RPM | Error: 209.00 RPM | PWM: 7841.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 121.17s | Desired: 4000.00 RPM | Measured: 3734.00 RPM | Error: 266.00 RPM | PWM: 7910.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 122.21s | Desired: 4000.00 RPM | Measured: 3892.00 RPM | Error: 108.00 RPM | PWM: 7657.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 123.24s | Desired: 4000.00 RPM | Measured: 3715.00 RPM | Error: 285.00 RPM | PWM: 8007.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 124.28s | Desired: 4000.00 RPM | Measured: 2926.00 RPM | Error: 1074.00 RPM | PWM: 9116.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 125.30s | Desired: 4000.00 RPM | Measured: 3582.00 RPM | Error: 418.00 RPM | PWM: 7792.150000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 126.34s | Desired: 4000.00 RPM | Measured: 2958.00 RPM | Error: 1042.00 RPM | PWM: 9077.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 127.37s | Desired: 4000.00 RPM | Measured: 3553.00 RPM | Error: 447.00 RPM | PWM: 7924.6500000000015 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 128.41s | Desired: 4000.00 RPM | Measured: 3871.00 RPM | Error: 129.00 RPM | PWM: 7767.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 129.44s | Desired: 4000.00 RPM | Measured: 3741.00 RPM | Error: 259.00 RPM | PWM: 8127.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 130.48s | Desired: 4000.00 RPM | Measured: 3898.00 RPM | Error: 102.00 RPM | PWM: 7840.400000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 131.51s | Desired: 4000.00 RPM | Measured: 3965.00 RPM | Error: 35.00 RPM | PWM: 7823.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 132.55s | Desired: 4000.00 RPM | Measured: 3731.00 RPM | Error: 269.00 RPM | PWM: 8209.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 133.58s | Desired: 4000.00 RPM | Measured: 3697.00 RPM | Error: 303.00 RPM | PWM: 8157.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 134.61s | Desired: 4000.00 RPM | Measured: 3888.00 RPM | Error: 112.00 RPM | PWM: 7868.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 135.64s | Desired: 4000.00 RPM | Measured: 3730.00 RPM | Error: 270.00 RPM | PWM: 8206.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 136.68s | Desired: 4000.00 RPM | Measured: 3685.00 RPM | Error: 315.00 RPM | PWM: 8208.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 137.72s | Desired: 4000.00 RPM | Measured: 3673.00 RPM | Error: 327.00 RPM | PWM: 8220.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 138.75s | Desired: 4000.00 RPM | Measured: 3622.00 RPM | Error: 378.00 RPM | PWM: 8307.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 139.78s | Desired: 4000.00 RPM | Measured: 3693.00 RPM | Error: 307.00 RPM | PWM: 8193.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 140.81s | Desired: 4000.00 RPM | Measured: 3728.00 RPM | Error: 272.00 RPM | PWM: 8192.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 141.85s | Desired: 4000.00 RPM | Measured: 3720.00 RPM | Error: 280.00 RPM | PWM: 8235.400000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 142.89s | Desired: 4000.00 RPM | Measured: 3845.00 RPM | Error: 155.00 RPM | PWM: 8057.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 143.92s | Desired: 4000.00 RPM | Measured: 3413.00 RPM | Error: 587.00 RPM | PWM: 8776.150000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 144.96s | Desired: 4000.00 RPM | Measured: 2873.00 RPM | Error: 1127.00 RPM | PWM: 9399.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 145.99s | Desired: 4000.00 RPM | Measured: 3541.00 RPM | Error: 459.00 RPM | PWM: 8183.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 147.02s | Desired: 4000.00 RPM | Measured: 3715.00 RPM | Error: 285.00 RPM | PWM: 8279.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 148.04s | Desired: 4000.00 RPM | Measured: 3702.00 RPM | Error: 298.00 RPM | PWM: 8400.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 149.09s | Desired: 4000.00 RPM | Measured: 3710.00 RPM | Error: 290.00 RPM | PWM: 8396.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 150.12s | Desired: 4000.00 RPM | Measured: 3701.00 RPM | Error: 299.00 RPM | PWM: 8428.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 151.16s | Desired: 4000.00 RPM | Measured: 3744.00 RPM | Error: 256.00 RPM | PWM: 8374.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 152.19s | Desired: 4000.00 RPM | Measured: 3413.00 RPM | Error: 587.00 RPM | PWM: 8905.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 153.22s | Desired: 4000.00 RPM | Measured: 3676.00 RPM | Error: 324.00 RPM | PWM: 8375.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 154.26s | Desired: 4000.00 RPM | Measured: 3723.00 RPM | Error: 277.00 RPM | PWM: 8452.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 155.30s | Desired: 4000.00 RPM | Measured: 3724.00 RPM | Error: 276.00 RPM | PWM: 8488.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 156.32s | Desired: 4000.00 RPM | Measured: 3734.00 RPM | Error: 266.00 RPM | PWM: 8487.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 157.36s | Desired: 4000.00 RPM | Measured: 3725.00 RPM | Error: 275.00 RPM | PWM: 8519.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 158.40s | Desired: 4000.00 RPM | Measured: 3685.00 RPM | Error: 315.00 RPM | PWM: 8588.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 159.42s | Desired: 4000.00 RPM | Measured: 3717.00 RPM | Error: 283.00 RPM | PWM: 8536.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 160.45s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 8551.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 161.50s | Desired: 4000.00 RPM | Measured: 3717.00 RPM | Error: 283.00 RPM | PWM: 8585.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 162.53s | Desired: 4000.00 RPM | Measured: 3901.00 RPM | Error: 99.00 RPM | PWM: 8318.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 163.56s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 8641.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 164.59s | Desired: 4000.00 RPM | Measured: 3739.00 RPM | Error: 261.00 RPM | PWM: 8595.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 165.62s | Desired: 4000.00 RPM | Measured: 3704.00 RPM | Error: 296.00 RPM | PWM: 8655.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 166.66s | Desired: 4000.00 RPM | Measured: 3747.00 RPM | Error: 253.00 RPM | PWM: 8587.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 167.69s | Desired: 4000.00 RPM | Measured: 3717.00 RPM | Error: 283.00 RPM | PWM: 8667.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 168.73s | Desired: 4000.00 RPM | Measured: 3701.00 RPM | Error: 299.00 RPM | PWM: 8690.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 169.77s | Desired: 4000.00 RPM | Measured: 3723.00 RPM | Error: 277.00 RPM | PWM: 8664.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 170.81s | Desired: 4000.00 RPM | Measured: 3707.00 RPM | Error: 293.00 RPM | PWM: 8713.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 171.84s | Desired: 4000.00 RPM | Measured: 2713.00 RPM | Error: 1287.00 RPM | PWM: 10210.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 172.88s | Desired: 4000.00 RPM | Measured: 3583.00 RPM | Error: 417.00 RPM | PWM: 8473.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 173.91s | Desired: 4000.00 RPM | Measured: 2756.00 RPM | Error: 1244.00 RPM | PWM: 10169.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 174.93s | Desired: 4000.00 RPM | Measured: 3527.00 RPM | Error: 473.00 RPM | PWM: 8661.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 175.97s | Desired: 4000.00 RPM | Measured: 3698.00 RPM | Error: 302.00 RPM | PWM: 8814.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 177.01s | Desired: 4000.00 RPM | Measured: 3687.00 RPM | Error: 313.00 RPM | PWM: 8931.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 178.04s | Desired: 4000.00 RPM | Measured: 3733.00 RPM | Error: 267.00 RPM | PWM: 8872.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 179.08s | Desired: 4000.00 RPM | Measured: 3765.00 RPM | Error: 235.00 RPM | PWM: 8860.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 180.12s | Desired: 4000.00 RPM | Measured: 3814.00 RPM | Error: 186.00 RPM | PWM: 8815.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 181.14s | Desired: 4000.00 RPM | Measured: 3747.00 RPM | Error: 253.00 RPM | PWM: 8949.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 182.18s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 8958.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 183.21s | Desired: 4000.00 RPM | Measured: 3907.00 RPM | Error: 93.00 RPM | PWM: 8692.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 184.24s | Desired: 4000.00 RPM | Measured: 3770.00 RPM | Error: 230.00 RPM | PWM: 8992.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 185.28s | Desired: 4000.00 RPM | Measured: 3730.00 RPM | Error: 270.00 RPM | PWM: 8995.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 186.32s | Desired: 4000.00 RPM | Measured: 3733.00 RPM | Error: 267.00 RPM | PWM: 8984.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 187.35s | Desired: 4000.00 RPM | Measured: 3707.00 RPM | Error: 293.00 RPM | PWM: 9038.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 188.38s | Desired: 4000.00 RPM | Measured: 3723.00 RPM | Error: 277.00 RPM | PWM: 9015.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 189.42s | Desired: 4000.00 RPM | Measured: 3745.00 RPM | Error: 255.00 RPM | PWM: 9004.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 190.45s | Desired: 4000.00 RPM | Measured: 3730.00 RPM | Error: 270.00 RPM | PWM: 9050.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 191.48s | Desired: 4000.00 RPM | Measured: 3713.00 RPM | Error: 287.00 RPM | PWM: 9082.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 192.53s | Desired: 4000.00 RPM | Measured: 3734.00 RPM | Error: 266.00 RPM | PWM: 9056.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 193.56s | Desired: 4000.00 RPM | Measured: 3291.00 RPM | Error: 709.00 RPM | PWM: 9745.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 194.59s | Desired: 4000.00 RPM | Measured: 3643.00 RPM | Error: 357.00 RPM | PWM: 9031.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 195.63s | Desired: 4000.00 RPM | Measured: 2791.00 RPM | Error: 1209.00 RPM | PWM: 10502.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 196.66s | Desired: 4000.00 RPM | Measured: 3609.00 RPM | Error: 391.00 RPM | PWM: 8910.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 197.70s | Desired: 4000.00 RPM | Measured: 3775.00 RPM | Error: 225.00 RPM | PWM: 9089.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 198.73s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 9169.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 199.76s | Desired: 4000.00 RPM | Measured: 3751.00 RPM | Error: 249.00 RPM | PWM: 9235.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 200.79s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 9180.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 201.83s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 9260.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 202.87s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 9255.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 203.90s | Desired: 4000.00 RPM | Measured: 3813.00 RPM | Error: 187.00 RPM | PWM: 9173.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 204.93s | Desired: 4000.00 RPM | Measured: 3824.00 RPM | Error: 176.00 RPM | PWM: 9197.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 205.96s | Desired: 4000.00 RPM | Measured: 3832.00 RPM | Error: 168.00 RPM | PWM: 9200.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 206.99s | Desired: 4000.00 RPM | Measured: 3800.00 RPM | Error: 200.00 RPM | PWM: 9260.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 208.03s | Desired: 4000.00 RPM | Measured: 3823.00 RPM | Error: 177.00 RPM | PWM: 9220.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 209.06s | Desired: 4000.00 RPM | Measured: 3842.00 RPM | Error: 158.00 RPM | PWM: 9212.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 210.10s | Desired: 4000.00 RPM | Measured: 3980.00 RPM | Error: 20.00 RPM | PWM: 9022.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 211.13s | Desired: 4000.00 RPM | Measured: 3849.00 RPM | Error: 151.00 RPM | PWM: 9288.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 212.17s | Desired: 4000.00 RPM | Measured: 3852.00 RPM | Error: 148.00 RPM | PWM: 9226.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 213.19s | Desired: 4000.00 RPM | Measured: 3805.00 RPM | Error: 195.00 RPM | PWM: 9305.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 214.23s | Desired: 4000.00 RPM | Measured: 3846.00 RPM | Error: 154.00 RPM | PWM: 9230.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 215.26s | Desired: 4000.00 RPM | Measured: 3823.00 RPM | Error: 177.00 RPM | PWM: 9293.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 216.31s | Desired: 4000.00 RPM | Measured: 3976.00 RPM | Error: 24.00 RPM | PWM: 9061.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 217.34s | Desired: 4000.00 RPM | Measured: 3864.00 RPM | Error: 136.00 RPM | PWM: 9306.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 218.37s | Desired: 4000.00 RPM | Measured: 3810.00 RPM | Error: 190.00 RPM | PWM: 9338.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 219.40s | Desired: 4000.00 RPM | Measured: 3820.00 RPM | Error: 180.00 RPM | PWM: 9306.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 220.43s | Desired: 4000.00 RPM | Measured: 3853.00 RPM | Error: 147.00 RPM | PWM: 9270.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 221.47s | Desired: 4000.00 RPM | Measured: 3861.00 RPM | Error: 139.00 RPM | PWM: 9282.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 222.51s | Desired: 4000.00 RPM | Measured: 3769.00 RPM | Error: 231.00 RPM | PWM: 9431.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 223.54s | Desired: 4000.00 RPM | Measured: 3522.00 RPM | Error: 478.00 RPM | PWM: 9767.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 224.58s | Desired: 4000.00 RPM | Measured: 3759.00 RPM | Error: 241.00 RPM | PWM: 9312.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 225.61s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 9456.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 226.65s | Desired: 4000.00 RPM | Measured: 3772.00 RPM | Error: 228.00 RPM | PWM: 9431.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 227.68s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 9486.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 228.71s | Desired: 4000.00 RPM | Measured: 3743.00 RPM | Error: 257.00 RPM | PWM: 9498.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 229.74s | Desired: 4000.00 RPM | Measured: 3688.00 RPM | Error: 312.00 RPM | PWM: 9590.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 230.78s | Desired: 4000.00 RPM | Measured: 3673.00 RPM | Error: 327.00 RPM | PWM: 9601.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 231.80s | Desired: 4000.00 RPM | Measured: 3829.00 RPM | Error: 171.00 RPM | PWM: 9376.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 232.84s | Desired: 4000.00 RPM | Measured: 3704.00 RPM | Error: 296.00 RPM | PWM: 9650.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 233.88s | Desired: 4000.00 RPM | Measured: 3771.00 RPM | Error: 229.00 RPM | PWM: 9502.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 234.91s | Desired: 4000.00 RPM | Measured: 3950.00 RPM | Error: 50.00 RPM | PWM: 9278.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 235.95s | Desired: 4000.00 RPM | Measured: 3838.00 RPM | Error: 162.00 RPM | PWM: 9538.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 236.98s | Desired: 4000.00 RPM | Measured: 3784.00 RPM | Error: 216.00 RPM | PWM: 9571.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 238.01s | Desired: 4000.00 RPM | Measured: 3976.00 RPM | Error: 24.00 RPM | PWM: 9267.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 239.04s | Desired: 4000.00 RPM | Measured: 3745.00 RPM | Error: 255.00 RPM | PWM: 9711.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 240.08s | Desired: 4000.00 RPM | Measured: 2784.00 RPM | Error: 1216.00 RPM | PWM: 11049.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 241.11s | Desired: 4000.00 RPM | Measured: 3065.00 RPM | Error: 935.00 RPM | PWM: 10208.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 242.15s | Desired: 4000.00 RPM | Measured: 3723.00 RPM | Error: 277.00 RPM | PWM: 9408.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 243.19s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 9661.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 244.22s | Desired: 4000.00 RPM | Measured: 3739.00 RPM | Error: 261.00 RPM | PWM: 9768.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 245.25s | Desired: 4000.00 RPM | Measured: 3819.00 RPM | Error: 181.00 RPM | PWM: 9639.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 246.29s | Desired: 4000.00 RPM | Measured: 3805.00 RPM | Error: 195.00 RPM | PWM: 9709.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 247.31s | Desired: 4000.00 RPM | Measured: 3793.00 RPM | Error: 207.00 RPM | PWM: 9730.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 248.35s | Desired: 4000.00 RPM | Measured: 3748.00 RPM | Error: 252.00 RPM | PWM: 9802.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 249.38s | Desired: 4000.00 RPM | Measured: 3760.00 RPM | Error: 240.00 RPM | PWM: 9774.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 250.41s | Desired: 4000.00 RPM | Measured: 3635.00 RPM | Error: 365.00 RPM | PWM: 9979.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 251.44s | Desired: 4000.00 RPM | Measured: 3662.00 RPM | Error: 338.00 RPM | PWM: 9895.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 252.49s | Desired: 4000.00 RPM | Measured: 3780.00 RPM | Error: 220.00 RPM | PWM: 9748.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 253.53s | Desired: 4000.00 RPM | Measured: 3842.00 RPM | Error: 158.00 RPM | PWM: 9725.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 254.56s | Desired: 4000.00 RPM | Measured: 3736.00 RPM | Error: 264.00 RPM | PWM: 9923.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 255.58s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 9897.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 256.61s | Desired: 4000.00 RPM | Measured: 3749.00 RPM | Error: 251.00 RPM | PWM: 9873.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 257.65s | Desired: 4000.00 RPM | Measured: 3738.00 RPM | Error: 262.00 RPM | PWM: 9913.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 258.69s | Desired: 4000.00 RPM | Measured: 3897.00 RPM | Error: 103.00 RPM | PWM: 9682.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 259.71s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 9993.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 260.75s | Desired: 4000.00 RPM | Measured: 3890.00 RPM | Error: 110.00 RPM | PWM: 9714.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 261.78s | Desired: 4000.00 RPM | Measured: 3745.00 RPM | Error: 255.00 RPM | PWM: 10009.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 262.81s | Desired: 4000.00 RPM | Measured: 3784.00 RPM | Error: 216.00 RPM | PWM: 9891.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 263.85s | Desired: 4000.00 RPM | Measured: 3741.00 RPM | Error: 259.00 RPM | PWM: 9986.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 264.89s | Desired: 4000.00 RPM | Measured: 3900.00 RPM | Error: 100.00 RPM | PWM: 9739.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 265.91s | Desired: 4000.00 RPM | Measured: 3792.00 RPM | Error: 208.00 RPM | PWM: 9985.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 266.95s | Desired: 4000.00 RPM | Measured: 3730.00 RPM | Error: 270.00 RPM | PWM: 10035.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 267.98s | Desired: 4000.00 RPM | Measured: 3744.00 RPM | Error: 256.00 RPM | PWM: 9996.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 269.01s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 10038.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 270.05s | Desired: 4000.00 RPM | Measured: 3695.00 RPM | Error: 305.00 RPM | PWM: 10096.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 271.08s | Desired: 4000.00 RPM | Measured: 3878.00 RPM | Error: 122.00 RPM | PWM: 9819.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 272.11s | Desired: 4000.00 RPM | Measured: 3812.00 RPM | Error: 188.00 RPM | PWM: 10016.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 273.15s | Desired: 4000.00 RPM | Measured: 3679.00 RPM | Error: 321.00 RPM | PWM: 10192.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 274.18s | Desired: 4000.00 RPM | Measured: 3647.00 RPM | Error: 353.00 RPM | PWM: 10189.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 275.22s | Desired: 4000.00 RPM | Measured: 3099.00 RPM | Error: 901.00 RPM | PWM: 11013.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 276.25s | Desired: 4000.00 RPM | Measured: 3505.00 RPM | Error: 495.00 RPM | PWM: 10175.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 277.29s | Desired: 4000.00 RPM | Measured: 3649.00 RPM | Error: 351.00 RPM | PWM: 10187.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 278.33s | Desired: 4000.00 RPM | Measured: 3624.00 RPM | Error: 376.00 RPM | PWM: 10314.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 279.35s | Desired: 4000.00 RPM | Measured: 3808.00 RPM | Error: 192.00 RPM | PWM: 10044.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 280.39s | Desired: 4000.00 RPM | Measured: 3637.00 RPM | Error: 363.00 RPM | PWM: 10402.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 281.43s | Desired: 4000.00 RPM | Measured: 3631.00 RPM | Error: 369.00 RPM | PWM: 10344.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 282.46s | Desired: 4000.00 RPM | Measured: 3636.00 RPM | Error: 364.00 RPM | PWM: 10352.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 283.50s | Desired: 4000.00 RPM | Measured: 3779.00 RPM | Error: 221.00 RPM | PWM: 10158.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 284.53s | Desired: 4000.00 RPM | Measured: 3659.00 RPM | Error: 341.00 RPM | PWM: 10421.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 285.57s | Desired: 4000.00 RPM | Measured: 2668.00 RPM | Error: 1332.00 RPM | PWM: 11864.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 286.60s | Desired: 4000.00 RPM | Measured: 3467.00 RPM | Error: 533.00 RPM | PWM: 10237.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 287.63s | Desired: 4000.00 RPM | Measured: 3688.00 RPM | Error: 312.00 RPM | PWM: 10331.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 288.67s | Desired: 4000.00 RPM | Measured: 3743.00 RPM | Error: 257.00 RPM | PWM: 10375.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 289.70s | Desired: 4000.00 RPM | Measured: 3723.00 RPM | Error: 277.00 RPM | PWM: 10445.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 290.74s | Desired: 4000.00 RPM | Measured: 3261.00 RPM | Error: 739.00 RPM | PWM: 11142.650000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 291.76s | Desired: 4000.00 RPM | Measured: 3833.00 RPM | Error: 167.00 RPM | PWM: 10090.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 292.80s | Desired: 4000.00 RPM | Measured: 3691.00 RPM | Error: 309.00 RPM | PWM: 10597.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 293.83s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 10543.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 294.87s | Desired: 4000.00 RPM | Measured: 3394.00 RPM | Error: 606.00 RPM | PWM: 11002.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 295.91s | Desired: 4000.00 RPM | Measured: 3366.00 RPM | Error: 634.00 RPM | PWM: 10927.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 296.94s | Desired: 4000.00 RPM | Measured: 3648.00 RPM | Error: 352.00 RPM | PWM: 10521.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 297.97s | Desired: 4000.00 RPM | Measured: 3416.00 RPM | Error: 584.00 RPM | PWM: 11028.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 299.01s | Desired: 4000.00 RPM | Measured: 3609.00 RPM | Error: 391.00 RPM | PWM: 10652.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 300.05s | Desired: 4000.00 RPM | Measured: 3689.00 RPM | Error: 311.00 RPM | PWM: 10648.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 301.07s | Desired: 4000.00 RPM | Measured: 3687.00 RPM | Error: 313.00 RPM | PWM: 10706.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# ...
# Time: 7899.09s | Desired: 4000.00 RPM | Measured: 4226.00 RPM | Error: -226.00 RPM | PWM: -38.575582612800645 | Kp: 10.221 | Ki: 2.356 | Kd: 7.889 | Loss: 0.018088
# Time: 7900.13s | Desired: 4000.00 RPM | Measured: 4206.00 RPM | Error: -206.00 RPM | PWM: 752841.8620033264 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.017579
# Time: 7901.17s | Desired: 4000.00 RPM | Measured: 3528.00 RPM | Error: 472.00 RPM | PWM: 523.9436391579657 | Kp: 8.098 | Ki: 1.846 | Kd: 6.261 | Loss: 0.017066
# Time: 7902.20s | Desired: 4000.00 RPM | Measured: 4057.00 RPM | Error: -57.00 RPM | PWM: 583954.8458068371 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.016420
# Time: 7903.25s | Desired: 4000.00 RPM | Measured: 4197.00 RPM | Error: -197.00 RPM | PWM: -76.17892303796543 | Kp: 10.530 | Ki: 2.433 | Kd: 8.128 | Loss: 0.015834
# Time: 7904.29s | Desired: 4000.00 RPM | Measured: 3058.00 RPM | Error: 942.00 RPM | PWM: 792021.3234570026 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.015253
# Time: 7905.32s | Desired: 4000.00 RPM | Measured: 4062.00 RPM | Error: -62.00 RPM | PWM: -345.53892105896375 | Kp: 12.685 | Ki: 2.954 | Kd: 9.782 | Loss: 0.014761
# Time: 7906.36s | Desired: 4000.00 RPM | Measured: 4142.00 RPM | Error: -142.00 RPM | PWM: 935719.637727499 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.014361
# Time: 7907.40s | Desired: 4000.00 RPM | Measured: 4263.00 RPM | Error: -263.00 RPM | PWM: -97.83460439019836 | Kp: 10.516 | Ki: 2.433 | Kd: 8.119 | Loss: 0.014055
# Time: 7908.44s | Desired: 4000.00 RPM | Measured: 3970.00 RPM | Error: 30.00 RPM | PWM: 773010.9718902111 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.013877
# Time: 7909.48s | Desired: 4000.00 RPM | Measured: 4177.00 RPM | Error: -177.00 RPM | PWM: -93.4047280876839 | Kp: 10.696 | Ki: 2.478 | Kd: 8.258 | Loss: 0.013768
# Time: 7910.53s | Desired: 4000.00 RPM | Measured: 3795.00 RPM | Error: 205.00 RPM | PWM: 788362.7738363743 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.013787
# Time: 7911.56s | Desired: 4000.00 RPM | Measured: 3927.00 RPM | Error: 73.00 RPM | PWM: 43.018487708002795 | Kp: 10.383 | Ki: 2.404 | Kd: 8.017 | Loss: 0.013784
# Time: 7912.60s | Desired: 4000.00 RPM | Measured: 4182.00 RPM | Error: -182.00 RPM | PWM: 754707.8004217148 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.013951
# Time: 7913.64s | Desired: 4000.00 RPM | Measured: 4212.00 RPM | Error: -212.00 RPM | PWM: -41.82627401893842 | Kp: 10.254 | Ki: 2.374 | Kd: 7.919 | Loss: 0.013995
# Time: 7914.70s | Desired: 4000.00 RPM | Measured: 3489.00 RPM | Error: 511.00 RPM | PWM: 758124.6969652176 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.014264
# Time: 7915.74s | Desired: 4000.00 RPM | Measured: 2876.00 RPM | Error: 1124.00 RPM | PWM: 780.0824272187019 | Kp: 7.961 | Ki: 1.820 | Kd: 6.159 | Loss: 0.014271
# Time: 7916.78s | Desired: 4000.00 RPM | Measured: 2845.00 RPM | Error: 1155.00 RPM | PWM: 582327.6686388254 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.014617
# Time: 7917.82s | Desired: 4000.00 RPM | Measured: 3446.00 RPM | Error: 554.00 RPM | PWM: 73.07480914890766 | Kp: 11.338 | Ki: 2.637 | Kd: 8.752 | Loss: 0.014600
# Time: 7918.86s | Desired: 4000.00 RPM | Measured: 3311.00 RPM | Error: 689.00 RPM | PWM: 842491.0153083801 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.014994
# Time: 7919.90s | Desired: 4000.00 RPM | Measured: 4083.00 RPM | Error: -83.00 RPM | PWM: -267.39381672328454 | Kp: 12.070 | Ki: 2.815 | Kd: 9.314 | Loss: 0.014980
# Time: 7920.94s | Desired: 4000.00 RPM | Measured: 4223.00 RPM | Error: -223.00 RPM | PWM: 884955.4556617737 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.015384
# Time: 7921.99s | Desired: 4000.00 RPM | Measured: 3075.00 RPM | Error: 925.00 RPM | PWM: 896.6952196860511 | Kp: 6.667 | Ki: 1.508 | Kd: 5.166 | Loss: 0.015387
# Time: 7923.02s | Desired: 4000.00 RPM | Measured: 2829.00 RPM | Error: 1171.00 RPM | PWM: 483844.8794863224 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.015731
# Time: 7924.06s | Desired: 4000.00 RPM | Measured: 4042.00 RPM | Error: -42.00 RPM | PWM: -417.1217898337636 | Kp: 13.153 | Ki: 3.077 | Kd: 10.146 | Loss: 0.015795
# Time: 7925.10s | Desired: 4000.00 RPM | Measured: 4242.00 RPM | Error: -242.00 RPM | PWM: 964861.2031154633 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.015927
# Time: 7926.15s | Desired: 4000.00 RPM | Measured: 4257.00 RPM | Error: -257.00 RPM | PWM: -56.158182865940034 | Kp: 10.179 | Ki: 2.358 | Kd: 7.863 | Loss: 0.015806
# Time: 7927.18s | Desired: 4000.00 RPM | Measured: 4263.00 RPM | Error: -263.00 RPM | PWM: 734780.0860521793 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.015641
# Time: 7928.22s | Desired: 4000.00 RPM | Measured: 4247.00 RPM | Error: -247.00 RPM | PWM: -40.58244071461377 | Kp: 10.073 | Ki: 2.332 | Kd: 7.781 | Loss: 0.015211
# Time: 7929.25s | Desired: 4000.00 RPM | Measured: 4239.00 RPM | Error: -239.00 RPM | PWM: 719851.1982040405 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.014751
# Time: 7930.30s | Desired: 4000.00 RPM | Measured: 4226.00 RPM | Error: -226.00 RPM | PWM: -33.00554137364088 | Kp: 10.036 | Ki: 2.322 | Kd: 7.753 | Loss: 0.014017
# Time: 7931.34s | Desired: 4000.00 RPM | Measured: 3838.00 RPM | Error: 162.00 RPM | PWM: 719441.8788127899 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.013425
# Time: 7932.37s | Desired: 4000.00 RPM | Measured: 3610.00 RPM | Error: 390.00 RPM | PWM: 314.6437148735131 | Kp: 9.147 | Ki: 2.106 | Kd: 7.069 | Loss: 0.012708
# Time: 7933.42s | Desired: 4000.00 RPM | Measured: 4128.00 RPM | Error: -128.00 RPM | PWM: 640942.3034996986 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.012248
# Time: 7934.46s | Desired: 4000.00 RPM | Measured: 3289.00 RPM | Error: 711.00 RPM | PWM: 685.3061973480508 | Kp: 7.379 | Ki: 1.678 | Kd: 5.711 | Loss: 0.011744
# Time: 7935.51s | Desired: 4000.00 RPM | Measured: 2786.00 RPM | Error: 1214.00 RPM | PWM: 526030.644420147 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.011568
# Time: 7936.54s | Desired: 4000.00 RPM | Measured: 3718.00 RPM | Error: 282.00 RPM | PWM: -171.93881622287154 | Kp: 12.036 | Ki: 2.800 | Kd: 9.286 | Loss: 0.011435
# Time: 7937.59s | Desired: 4000.00 RPM | Measured: 3332.00 RPM | Error: 668.00 RPM | PWM: 869266.3010947704 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.011554
# Time: 7938.63s | Desired: 4000.00 RPM | Measured: 2972.00 RPM | Error: 1028.00 RPM | PWM: 640.7869565349538 | Kp: 8.321 | Ki: 1.902 | Kd: 6.433 | Loss: 0.011753
# Time: 7939.67s | Desired: 4000.00 RPM | Measured: 4043.00 RPM | Error: -43.00 RPM | PWM: 576925.1436767578 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.012056
# Time: 7940.71s | Desired: 4000.00 RPM | Measured: 3384.00 RPM | Error: 616.00 RPM | PWM: 576.0277696491103 | Kp: 7.705 | Ki: 1.753 | Kd: 5.960 | Loss: 0.012406
# Time: 7941.75s | Desired: 4000.00 RPM | Measured: 3643.00 RPM | Error: 357.00 RPM | PWM: 537986.8167198896 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.012784
# Time: 7942.78s | Desired: 4000.00 RPM | Measured: 4186.00 RPM | Error: -186.00 RPM | PWM: -227.1232551645371 | Kp: 11.122 | Ki: 2.575 | Kd: 8.582 | Loss: 0.013194
# Time: 7943.84s | Desired: 4000.00 RPM | Measured: 4250.00 RPM | Error: -250.00 RPM | PWM: 783222.4293839931 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.013565
# Time: 7944.87s | Desired: 4000.00 RPM | Measured: 4244.00 RPM | Error: -244.00 RPM | PWM: -44.266111901801196 | Kp: 9.707 | Ki: 2.233 | Kd: 7.496 | Loss: 0.013959
# Time: 7945.91s | Desired: 4000.00 RPM | Measured: 4207.00 RPM | Error: -207.00 RPM | PWM: 678189.6906399727 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.014284
# Time: 7946.95s | Desired: 4000.00 RPM | Measured: 3476.00 RPM | Error: 524.00 RPM | PWM: 562.9592998233857 | Kp: 7.442 | Ki: 1.687 | Kd: 5.758 | Loss: 0.014658
# Time: 7947.99s | Desired: 4000.00 RPM | Measured: 4071.00 RPM | Error: -71.00 RPM | PWM: 509967.8262588978 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.014942
# Time: 7949.03s | Desired: 4000.00 RPM | Measured: 3929.00 RPM | Error: 71.00 RPM | PWM: 143.54162575793453 | Kp: 9.135 | Ki: 2.094 | Kd: 7.056 | Loss: 0.015316
# Time: 7950.07s | Desired: 4000.00 RPM | Measured: 3833.00 RPM | Error: 167.00 RPM | PWM: 639608.63473773 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.015581
# Time: 7951.12s | Desired: 4000.00 RPM | Measured: 4176.00 RPM | Error: -176.00 RPM | PWM: -147.3735101553466 | Kp: 10.461 | Ki: 2.412 | Kd: 8.073 | Loss: 0.015974
# Time: 7952.15s | Desired: 4000.00 RPM | Measured: 4226.00 RPM | Error: -226.00 RPM | PWM: 730135.4097938538 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.016235
# Time: 7953.20s | Desired: 4000.00 RPM | Measured: 4218.00 RPM | Error: -218.00 RPM | PWM: -32.544617354811635 | Kp: 9.555 | Ki: 2.194 | Kd: 7.378 | Loss: 0.016664
# Time: 7954.25s | Desired: 4000.00 RPM | Measured: 4258.00 RPM | Error: -258.00 RPM | PWM: 662469.02784729 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.016950
# Time: 7955.29s | Desired: 4000.00 RPM | Measured: 2978.00 RPM | Error: 1022.00 RPM | PWM: 986.3647700224974 | Kp: 5.682 | Ki: 1.262 | Kd: 4.406 | Loss: 0.017441
# Time: 7956.34s | Desired: 4000.00 RPM | Measured: 3255.00 RPM | Error: 745.00 RPM | PWM: 385417.008705616 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.017786
# Time: 7957.37s | Desired: 4000.00 RPM | Measured: 4148.00 RPM | Error: -148.00 RPM | PWM: -344.1500557214313 | Kp: 11.751 | Ki: 2.721 | Kd: 9.063 | Loss: 0.018390
# Time: 7958.42s | Desired: 4000.00 RPM | Measured: 4108.00 RPM | Error: -108.00 RPM | PWM: 821541.1686046124 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.018827
# Time: 7959.45s | Desired: 4000.00 RPM | Measured: 4087.00 RPM | Error: -87.00 RPM | PWM: 28.783117276034318 | Kp: 9.355 | Ki: 2.145 | Kd: 7.224 | Loss: 0.019601
# Time: 7960.50s | Desired: 4000.00 RPM | Measured: 3715.00 RPM | Error: 285.00 RPM | PWM: 652318.5963127613 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.020210
# Time: 7961.55s | Desired: 4000.00 RPM | Measured: 3888.00 RPM | Error: 112.00 RPM | PWM: 41.295645054633496 | Kp: 9.711 | Ki: 2.229 | Kd: 7.496 | Loss: 0.021272
# Time: 7962.59s | Desired: 4000.00 RPM | Measured: 4089.00 RPM | Error: -89.00 RPM | PWM: 667725.4941520691 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.022205
# Time: 7963.62s | Desired: 4000.00 RPM | Measured: 4263.00 RPM | Error: -263.00 RPM | PWM: -121.76852619412239 | Kp: 9.851 | Ki: 2.262 | Kd: 7.604 | Loss: 0.023809
# Time: 7964.65s | Desired: 4000.00 RPM | Measured: 4268.00 RPM | Error: -268.00 RPM | PWM: 672768.6553051472 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.025111
# Time: 7965.70s | Desired: 4000.00 RPM | Measured: 4277.00 RPM | Error: -277.00 RPM | PWM: -65.69461196851626 | Kp: 9.387 | Ki: 2.149 | Kd: 7.247 | Loss: 0.027362
# Time: 7966.73s | Desired: 4000.00 RPM | Measured: 4253.00 RPM | Error: -253.00 RPM | PWM: 635406.8964972496 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.029048
# Time: 7967.78s | Desired: 4000.00 RPM | Measured: 4235.00 RPM | Error: -235.00 RPM | PWM: -37.69595536560519 | Kp: 9.244 | Ki: 2.113 | Kd: 7.136 | Loss: 0.032027
# Time: 7968.83s | Desired: 4000.00 RPM | Measured: 3928.00 RPM | Error: 72.00 RPM | PWM: 625409.5843992233 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.034012
# Time: 7969.87s | Desired: 4000.00 RPM | Measured: 3523.00 RPM | Error: 477.00 RPM | PWM: 417.1411689569941 | Kp: 7.847 | Ki: 1.776 | Kd: 6.065 | Loss: 0.037689
# Time: 7970.91s | Desired: 4000.00 RPM | Measured: 3062.00 RPM | Error: 938.00 RPM | PWM: 534027.9037103653 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.039749
# Time: 7971.96s | Desired: 4000.00 RPM | Measured: 3332.00 RPM | Error: 668.00 RPM | PWM: 243.8920025844127 | Kp: 9.420 | Ki: 2.151 | Kd: 7.270 | Loss: 0.043893
# Time: 7972.99s | Desired: 4000.00 RPM | Measured: 4126.00 RPM | Error: -126.00 RPM | PWM: 627852.122440815 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.045456
# Time: 7974.04s | Desired: 4000.00 RPM | Measured: 3527.00 RPM | Error: 473.00 RPM | PWM: 489.0888514074468 | Kp: 7.250 | Ki: 1.631 | Kd: 5.606 | Loss: 0.049328
# Time: 7975.09s | Desired: 4000.00 RPM | Measured: 4056.00 RPM | Error: -56.00 RPM | PWM: 477795.3312982321 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.049491
# Time: 7976.13s | Desired: 4000.00 RPM | Measured: 3912.00 RPM | Error: 88.00 RPM | PWM: 149.95613129611593 | Kp: 8.565 | Ki: 1.945 | Kd: 6.613 | Loss: 0.051901
# Time: 7977.17s | Desired: 4000.00 RPM | Measured: 3218.00 RPM | Error: 782.00 RPM | PWM: 584597.3757025003 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.049775
# Time: 7978.21s | Desired: 4000.00 RPM | Measured: 4059.00 RPM | Error: -59.00 RPM | PWM: -287.31318401452154 | Kp: 11.134 | Ki: 2.560 | Kd: 8.584 | Loss: 0.049544
# Time: 7979.25s | Desired: 4000.00 RPM | Measured: 4203.00 RPM | Error: -203.00 RPM | PWM: 748387.8801138401 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.044896
# Time: 7980.30s | Desired: 4000.00 RPM | Measured: 4215.00 RPM | Error: -215.00 RPM | PWM: -40.611338506656466 | Kp: 9.110 | Ki: 2.078 | Kd: 7.033 | Loss: 0.041751
# Time: 7981.33s | Desired: 4000.00 RPM | Measured: 4193.00 RPM | Error: -193.00 RPM | PWM: 606433.9311466217 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.035626
# Time: 7982.38s | Desired: 4000.00 RPM | Measured: 4214.00 RPM | Error: -214.00 RPM | PWM: -43.7083335336647 | Kp: 9.167 | Ki: 2.095 | Kd: 7.078 | Loss: 0.030845
# Time: 7983.41s | Desired: 4000.00 RPM | Measured: 4245.00 RPM | Error: -245.00 RPM | PWM: 609123.0845680237 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.025122
# Time: 7984.46s | Desired: 4000.00 RPM | Measured: 4021.00 RPM | Error: -21.00 RPM | PWM: 132.6208857056772 | Kp: 8.494 | Ki: 1.938 | Kd: 6.563 | Loss: 0.020741
# Time: 7985.49s | Desired: 4000.00 RPM | Measured: 3853.00 RPM | Error: 147.00 RPM | PWM: 566969.9971578121 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.016890
# Time: 7986.55s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 252.55822753085522 | Kp: 8.537 | Ki: 1.952 | Kd: 6.598 | Loss: 0.014262
# Time: 7987.58s | Desired: 4000.00 RPM | Measured: 3687.00 RPM | Error: 313.00 RPM | PWM: 567939.667317152 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.012585
# Time: 7988.63s | Desired: 4000.00 RPM | Measured: 3059.00 RPM | Error: 941.00 RPM | PWM: 701.5604449074017 | Kp: 7.078 | Ki: 1.603 | Kd: 5.480 | Loss: 0.011789
# Time: 7989.67s | Desired: 4000.00 RPM | Measured: 3560.00 RPM | Error: 440.00 RPM | PWM: 462900.70145606995 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.011680
# Time: 7990.72s | Desired: 4000.00 RPM | Measured: 4078.00 RPM | Error: -78.00 RPM | PWM: -174.10763115045847 | Kp: 10.536 | Ki: 2.441 | Kd: 8.135 | Loss: 0.012050
# Time: 7991.75s | Desired: 4000.00 RPM | Measured: 3890.00 RPM | Error: 110.00 RPM | PWM: 704513.7292952538 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.012764
# Time: 7992.80s | Desired: 4000.00 RPM | Measured: 4234.00 RPM | Error: -234.00 RPM | PWM: -175.92067828468862 | Kp: 10.177 | Ki: 2.356 | Kd: 7.861 | Loss: 0.013658
# Time: 7993.85s | Desired: 4000.00 RPM | Measured: 4080.00 RPM | Error: -80.00 RPM | PWM: 676753.9563646317 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.014703
# Time: 7994.89s | Desired: 4000.00 RPM | Measured: 4268.00 RPM | Error: -268.00 RPM | PWM: -131.60573533002753 | Kp: 9.797 | Ki: 2.266 | Kd: 7.570 | Loss: 0.015706
# Time: 7995.93s | Desired: 4000.00 RPM | Measured: 4290.00 RPM | Error: -290.00 RPM | PWM: 643693.8893136978 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.016817
# Time: 7996.99s | Desired: 4000.00 RPM | Measured: 4312.00 RPM | Error: -312.00 RPM | PWM: -88.27187509420037 | Kp: 9.394 | Ki: 2.170 | Kd: 7.261 | Loss: 0.017759
# Time: 7998.02s | Desired: 4000.00 RPM | Measured: 3359.00 RPM | Error: 641.00 RPM | PWM: 628132.6847310066 | Kp: 0.433 | Ki: 0.000 | Kd: 0.379 | Loss: 0.018829
# Time: 7999.06s | Desired: 4000.00 RPM | Measured: 4109.00 RPM | Error: -109.00 RPM | PWM: -276.6367697562382 | Kp: 11.176 | Ki: 2.603 | Kd: 8.630 | Loss: 0.019564
# Data saved to motor_speed_data_ANN_20250405_031459.csv
# Measured Speed plot saved to motor_speed_plot_speed_ANN_20250405_031459.pdf
# PID Gains plot saved to motor_speed_plot_gains_ANN_20250405_031459.pdf
# Loss plot saved to motor_speed_plot_loss_ANN_20250405_031459.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime
import uuid  # Import UUID for unique filenames

import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

# Define whether ANN is enabled or not
ANN_enabled = True  # Set to True if ANN is used, False otherwise

# Convert lists to NumPy arrays for performance calculations
time_stamps = np.array(times)  # Recorded time points
error = np.array(errors)
setpoints = np.array([desired_speed] * len(times))  # Setpoints stored as an array
speeds = np.array(speeds)

# Handle missing `loss_values`
if "loss_values" in globals() and len(loss_values) > 0:
    training_epochs = np.array(range(len(loss_values)))  # Training epochs for ANN
    loss_values = np.array(loss_values)
else:
    training_epochs = np.array([])  # Empty array if no loss data is available
    loss_values = np.array([])

# Compute Performance Metrics
rmse = np.sqrt(np.mean(error ** 2))
mae = np.mean(np.abs(error))
SSE = error[-1]  # Last recorded error
max_speed = max(speeds)
overshoot = max(0, ((max_speed - desired_speed) / desired_speed) * 100)

# Settling Time (Ts)
within_tolerance = np.abs(error) < (0.05 * desired_speed)  # Within ±5% of setpoint
Ts_index = np.argmax(within_tolerance) if np.any(within_tolerance) else -1
Ts = time_stamps[Ts_index] if Ts_index != -1 else None  # First time where error is within ±5%

# Generate Performance Plots and Save with explicit names
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")  # Format: YYYYMMDD_HHMMSS
identifier = "With_ANN" if ANN_enabled else "No_ANN"  # Condition-based identifier
unique_id = uuid.uuid4().hex[:8]  # Generates an 8-character unique ID

# 1. Histogram of Errors
hist_filename = f"Histogram_Errors_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.hist(error, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Error (RPM)", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(hist_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 2. RMSE & MAE Comparison
rmse_mae_filename = f"RMSE_MAE_Comparison_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["RMSE", "MAE"], [rmse, mae], color=['red', 'orange'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(rmse_mae_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 3. Overshoot & Steady-State Error
overshoot_sse_filename = f"Overshoot_SSE_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["Overshoot (%)", "SSE"], [overshoot, SSE], color=['purple', 'green'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)
plt.savefig(overshoot_sse_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 4. ANN Loss Plot (if available)
if loss_values.size > 0:
    ann_loss_filename = f"ANN_Loss_{identifier}_{current_datetime}_{unique_id}.pdf"
    plt.figure(figsize=(7, 5))
    plt.plot(training_epochs, loss_values, label="Loss", color="b", linewidth=2)
    plt.xlabel("Epochs", fontsize=16)
    plt.ylabel("Loss Value (MSE)", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.savefig(ann_loss_filename, format="pdf", bbox_inches="tight")  # Save to PDF
    plt.show()
    print(f"ANN Loss Plot saved as {ann_loss_filename}")

# Print Statistical Summary
print("\n **Statistical Evaluation:**")
print(f"RMSE: {rmse:.2f} RPM")
print(f"MAE: {mae:.2f} RPM")
print(f"Settling Time (Ts): {Ts:.2f} s" if Ts is not None else " Settling Time Not Reached")
print(f"Steady-State Error (SSE): {SSE:.2f} RPM")
print(f"Overshoot: {overshoot:.2f}%")
print(f"\nHistogram of Errors saved as {hist_filename}")
print(f"RMSE & MAE Comparison saved as {rmse_mae_filename}")
print(f"Overshoot & Steady-State Error saved as {overshoot_sse_filename}")
# Out:
# ANN Loss Plot saved as ANN_Loss_With_ANN_20250405_052847_7465142c.pdf
#
#  **Statistical Evaluation:**
# RMSE: 639.53 RPM
# MAE: 429.99 RPM
# Settling Time (Ts): 21.89 s
# Steady-State Error (SSE): -109.00 RPM
# Overshoot: 10.62%
#
# Histogram of Errors saved as Histogram_Errors_With_ANN_20250405_052847_7465142c.pdf
# RMSE & MAE Comparison saved as RMSE_MAE_Comparison_With_ANN_20250405_052847_7465142c.pdf
# Overshoot & Steady-State Error saved as Overshoot_SSE_With_ANN_20250405_052847_7465142c.pdf

# %% [markdown]
# # Arduino Code Description
#
# The Arduino code (given below) is designed to control a DC motor using an Arduino microcontroller. The microcontroller powers the DC motor through a pulse-width modulation (PWM) driver. The code uses an shaft encoder to measure the motor's speed and a servo object to apply control. Real-time speed updates are sent to a connected Python script via serial communication, while PWM reference values received from the Python script are used to dynamically control the motor's speed. Encoder pulses are tracked using interrupts to ensure accurate speed measurements, creating a seamless integration between hardware and software for efficient motor control.

# %% [markdown]
# # The Arduino Code
#
# ```cpp
# #include <Servo.h>  // Include the Servo library
#
# Servo myservo;  // Servo object for motor control
#
# // Encoder tracking
# volatile unsigned int counter = 0;
# unsigned long lastTime = 0;
# const long interval = 1000;  // Speed update every 1 second
#
# int speedValue = 0;  // Measured speed
#
# void setup() {
#     myservo.attach(9);  // Connect servo/motor control to pin 9
#     Serial.begin(115200);  // Set serial baud rate
#
#     pinMode(2, INPUT_PULLUP);  // Encoder input
#     attachInterrupt(digitalPinToInterrupt(2), countPulses, RISING);  // Interrupt for encoder
# }
#
# void loop() {
#     // Send speed to Python every second
#     if (millis() - lastTime >= interval) {
#         lastTime = millis();
#         speedValue = map(counter, 0, 400, 0, 100);  // Convert pulses per second to speed in RPM
#         Serial.println(speedValue);  // Send the speed to Python
#         counter = 0;  // Reset counter
#     }
#
#     // Read PWM value from Python
#     if (Serial.available()) {
#         int pwmValue = Serial.parseInt();
#         pwmValue = map(pwmValue, 30000, 0, 120, 140);  // Map PWM range
#         myservo.write(pwmValue);  // Apply control
#         delay(50);
#     }
# }
#
# // Interrupt function to count encoder pulses
# void countPulses() {
#     counter++;
# }
# ```

# %% [markdown]
# # Preliminary Result
#
# The ANN-tuned PID controller outperforms the classical PID, achieving lower steady-state error and better adherence to the desired speed. Moreover, ongoing investigations are addressing the electrical and mechanical issues causing drift and undesirable step response, which reduces the systems performance.
