# %% [markdown]
# # Real-time Adaptive PID Control for DC Motor Speed Regulation using Neural Network-based Self-tuning
#
# **Machine Learning (CS-5841/EE-5841) Project**
# *Mbadiwe S. Benyeogor, Mark-Anthony Agbanu, Kepha Barasa, and Joseph Alfred Sonne*
#
#
# **Instructor: Professor Sujan Kumar Roy**

# %% [markdown]
# # Introduction
# This software documentation describes the functionality of a real-time Artificial Neural Network (ANN)-tuned PID motor speed control system implemented in Python. The system uses a Proportional-Integral-Derivative (PID) controller initially, and after 20% of the total runtime, the ANN dynamically adjusts the PID gains for improved performance. The control loop is executed in real-time, interfacing with an Arduino via serial communication.
#
# # System Overview
# The system consists of:
# - A PID controller for initial motor speed regulation.
# - An ANN for self-tuning of PID gains after 20% of the runtime.
# - A serial communication interface to receive speed measurements and send control signals.
# - A CSV logging mechanism for data storage.
# - Real-time visualization of system performance using Matplotlib.
#
#
# # Experimental Setup
#
# The experimental setup displayed in Figure 1 is essential for implementing and testing the Python code provided below. Each device in the setup is a critical component of the control loop, ensuring the system operates as intended. The experiment primarily investigates the performance of an ANN-enhanced PID control system, comparing it with that of a classical PID control algorithm. This approach evaluates the advantages of integrating machine learning into traditional control methods for improved system efficiency.
#
# ![Experimental Setup](Device2.png)
#
# *Figure 1: Experimental setup showing the components of the real-time ANN-enabled PID motor speed control system.*
#
# ---
#
# ^1 The devices in the experimental setup are required for the Python code below to function correctly.

# %% [markdown]
# # Classical PID Control program without ANN-enabled Self-tuning:

# %%
import serial
import time
import csv
import matplotlib.pyplot as plt
from datetime import datetime
from matplotlib.ticker import ScalarFormatter

# PID Parameters (Tune as needed)
Kp = 1.6
Ki = 0.05
Kd = 0.5

# User Inputs
desired_speed = float(input("Enter desired motor speed (RPM): "))
runtime = float(input("Enter duration for PID control (seconds): "))

# Initialize Serial Communication (Update COM port if necessary)
ser = serial.Serial('COM3', 115200, timeout=0.2)  # Ensure COM port matches your system

# PID Variables
previous_error = 0
integral = 0

# Anti-Windup Limits
integral_min = -255
integral_max = 255

# Data Logging
times, speeds, errors, pwm_outputs = [], [], [], []
kp_values, ki_values, kd_values = [], [], []
start_time = time.time()

# Generate dynamic filenames with timestamp
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"PID_motor_data_{current_time}.csv"
pdf_filename_speed = f"PID_motor_plot_speed_{current_time}.pdf"
pdf_filename_gains = f"PID_motor_plot_gains_{current_time}.pdf"

# CSV File Setup
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Time (s)", "Desired Speed (RPM)", "Measured Speed (RPM)", "Error (RPM)", "PWM Output", "Kp", "Ki", "Kd"])  # CSV Header

def pid_control(measured_speed):
    """Compute PID control signal."""
    global previous_error, integral

    # PID computation
    error = desired_speed - measured_speed
    integral += error
    integral = max(min(integral, integral_max), integral_min)  # Anti-windup
    derivative = error - previous_error
    control_signal = (Kp * error) + (Ki * integral) + (Kd * derivative)
    previous_error = error

    return control_signal

# Main Control Loop
while time.time() - start_time < runtime:  # Run for user-defined duration
    response = ser.readline().decode().strip()
    if response:
        try:
            measured_speed = float(response)  # Measured speed in RPM
            elapsed_time = time.time() - start_time

            # Compute PID control output
            pwm_output = pid_control(measured_speed)
            ser.write(f"{pwm_output}\n".encode())  # Send PWM to Arduino

            # Store data
            times.append(elapsed_time)
            speeds.append(measured_speed)
            errors.append(desired_speed - measured_speed)
            pwm_outputs.append(pwm_output)
            kp_values.append(Kp)
            ki_values.append(Ki)
            kd_values.append(Kd)

            # Print output with current parameters
            print(f"Time: {elapsed_time:.2f}s | Desired: {desired_speed:.2f} RPM | "
                  f"Measured: {measured_speed:.2f} RPM | Error: {errors[-1]:.2f} RPM | "
                  f"PWM: {pwm_output} | Kp: {Kp} | Ki: {Ki} | Kd: {Kd}")

            # Save data to CSV
            with open(csv_filename, mode="a", newline="") as file:
                writer = csv.writer(file)
                writer.writerow([elapsed_time, desired_speed, measured_speed, errors[-1], pwm_output, Kp, Ki, Kd])

        except ValueError:
            print("Invalid data received.")

ser.close()

# Compute Settling Time (Ts)
settling_threshold = desired_speed * 0.05  # 5% threshold in RPM
Ts = next((t for t, e in zip(times, errors) if abs(e) <= settling_threshold), times[-1])

# Generate and Save Measured Speed & Error Plot
plt.figure(figsize=(7, 6))
plt.plot(times, speeds, label="Measured Speed", color="b", linewidth=2)
plt.plot(times, errors, label="Error", color="r", linewidth=2)
plt.plot(times, [desired_speed] * len(times), label="Desired Speed", color="g", linestyle="--", linewidth=2)

# Add shaded threshold region
threshold_lower = desired_speed * 0.95  # Lower bound of ±5% threshold
threshold_upper = desired_speed * 1.05  # Upper bound of ±5% threshold
plt.fill_between(times, threshold_lower, threshold_upper, color="gray", alpha=0.3, label="±5% Threshold")

# Add settling time marker
if Ts:
    plt.axvline(Ts, color="black", linestyle="--", linewidth=2, label=f"Settling Time: {Ts:.2f}s")
    #plt.text(Ts, desired_speed, f"  Ts = {Ts:.2f}s", fontsize=12, color="black", va="bottom")

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Speed (RPM)", fontsize=16)
#plt.title("Measured Speed and Error for PID Control without ANN", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Y-axis scientific notation
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)

# Add legend
plt.legend(fontsize=14)

# Save as PDF
plt.tight_layout()
plt.savefig(pdf_filename_speed, format="pdf")
plt.show()

# Generate and Save PID Gains Plot
plt.figure(figsize=(7, 6))
plt.plot(times, kp_values, label="Kp", color="m", linewidth=2)
plt.plot(times, ki_values, label="Ki", color="c", linewidth=2, alpha=0.6)
plt.plot(times, kd_values, label="Kd", color="y", linewidth=2, alpha=0.6)
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("PID Gains", fontsize=16)
#plt.title("Constant PID Gains Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(fontsize=14)

# Save as PDF
plt.tight_layout()
plt.savefig(pdf_filename_gains, format="pdf")
plt.show()

# Final Report
print(f"Data saved to {csv_filename}")
print(f"Speed plot saved to {pdf_filename_speed}")
print(f"PID gains plot saved to {pdf_filename_gains}")
# Out:
# Enter desired motor speed (RPM): 4000
# Enter duration for PID control (seconds): 2000
# Time: 1.90s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 2.93s | Desired: 4000.00 RPM | Measured: 2853.00 RPM | Error: 1147.00 RPM | PWM: 421.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 3.97s | Desired: 4000.00 RPM | Measured: 3799.00 RPM | Error: 201.00 RPM | PWM: -138.64999999999998 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 5.01s | Desired: 4000.00 RPM | Measured: 3543.00 RPM | Error: 457.00 RPM | PWM: 871.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 6.04s | Desired: 4000.00 RPM | Measured: 3656.00 RPM | Error: 344.00 RPM | PWM: 506.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7.07s | Desired: 4000.00 RPM | Measured: 3668.00 RPM | Error: 332.00 RPM | PWM: 537.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 8.11s | Desired: 4000.00 RPM | Measured: 3675.00 RPM | Error: 325.00 RPM | PWM: 529.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 9.13s | Desired: 4000.00 RPM | Measured: 3679.00 RPM | Error: 321.00 RPM | PWM: 524.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 10.18s | Desired: 4000.00 RPM | Measured: 3627.00 RPM | Error: 373.00 RPM | PWM: 635.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 11.21s | Desired: 4000.00 RPM | Measured: 3789.00 RPM | Error: 211.00 RPM | PWM: 269.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 12.24s | Desired: 4000.00 RPM | Measured: 3680.00 RPM | Error: 320.00 RPM | PWM: 579.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 13.27s | Desired: 4000.00 RPM | Measured: 3593.00 RPM | Error: 407.00 RPM | PWM: 707.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 14.30s | Desired: 4000.00 RPM | Measured: 3615.00 RPM | Error: 385.00 RPM | PWM: 617.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 15.34s | Desired: 4000.00 RPM | Measured: 3570.00 RPM | Error: 430.00 RPM | PWM: 723.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 16.37s | Desired: 4000.00 RPM | Measured: 3565.00 RPM | Error: 435.00 RPM | PWM: 711.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 17.41s | Desired: 4000.00 RPM | Measured: 3534.00 RPM | Error: 466.00 RPM | PWM: 773.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 18.44s | Desired: 4000.00 RPM | Measured: 3589.00 RPM | Error: 411.00 RPM | PWM: 642.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 19.48s | Desired: 4000.00 RPM | Measured: 3595.00 RPM | Error: 405.00 RPM | PWM: 657.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 20.51s | Desired: 4000.00 RPM | Measured: 3565.00 RPM | Error: 435.00 RPM | PWM: 723.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 21.54s | Desired: 4000.00 RPM | Measured: 3512.00 RPM | Error: 488.00 RPM | PWM: 820.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 22.59s | Desired: 4000.00 RPM | Measured: 3710.00 RPM | Error: 290.00 RPM | PWM: 377.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 23.61s | Desired: 4000.00 RPM | Measured: 3574.00 RPM | Error: 426.00 RPM | PWM: 762.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 24.65s | Desired: 4000.00 RPM | Measured: 3545.00 RPM | Error: 455.00 RPM | PWM: 755.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 25.67s | Desired: 4000.00 RPM | Measured: 3565.00 RPM | Error: 435.00 RPM | PWM: 698.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 26.71s | Desired: 4000.00 RPM | Measured: 3573.00 RPM | Error: 427.00 RPM | PWM: 691.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 27.76s | Desired: 4000.00 RPM | Measured: 3578.00 RPM | Error: 422.00 RPM | PWM: 685.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 28.79s | Desired: 4000.00 RPM | Measured: 3581.00 RPM | Error: 419.00 RPM | PWM: 681.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 29.82s | Desired: 4000.00 RPM | Measured: 3731.00 RPM | Error: 269.00 RPM | PWM: 368.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 30.86s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 336.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 31.88s | Desired: 4000.00 RPM | Measured: 3628.00 RPM | Error: 372.00 RPM | PWM: 684.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 32.91s | Desired: 4000.00 RPM | Measured: 3586.00 RPM | Error: 414.00 RPM | PWM: 696.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 33.95s | Desired: 4000.00 RPM | Measured: 3771.00 RPM | Error: 229.00 RPM | PWM: 286.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 34.99s | Desired: 4000.00 RPM | Measured: 3516.00 RPM | Error: 484.00 RPM | PWM: 914.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 36.02s | Desired: 4000.00 RPM | Measured: 3767.00 RPM | Error: 233.00 RPM | PWM: 260.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 37.05s | Desired: 4000.00 RPM | Measured: 3613.00 RPM | Error: 387.00 RPM | PWM: 708.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 38.09s | Desired: 4000.00 RPM | Measured: 3589.00 RPM | Error: 411.00 RPM | PWM: 682.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 39.12s | Desired: 4000.00 RPM | Measured: 3592.00 RPM | Error: 408.00 RPM | PWM: 664.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 40.15s | Desired: 4000.00 RPM | Measured: 3801.00 RPM | Error: 199.00 RPM | PWM: 226.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 41.19s | Desired: 4000.00 RPM | Measured: 3518.00 RPM | Error: 482.00 RPM | PWM: 925.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 42.23s | Desired: 4000.00 RPM | Measured: 3576.00 RPM | Error: 424.00 RPM | PWM: 662.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 43.26s | Desired: 4000.00 RPM | Measured: 3766.00 RPM | Error: 234.00 RPM | PWM: 292.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 44.29s | Desired: 4000.00 RPM | Measured: 3790.00 RPM | Error: 210.00 RPM | PWM: 336.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 45.33s | Desired: 4000.00 RPM | Measured: 3597.00 RPM | Error: 403.00 RPM | PWM: 754.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 46.37s | Desired: 4000.00 RPM | Measured: 3749.00 RPM | Error: 251.00 RPM | PWM: 338.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 47.40s | Desired: 4000.00 RPM | Measured: 3577.00 RPM | Error: 423.00 RPM | PWM: 775.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 48.44s | Desired: 4000.00 RPM | Measured: 3747.00 RPM | Error: 253.00 RPM | PWM: 332.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 49.47s | Desired: 4000.00 RPM | Measured: 3591.00 RPM | Error: 409.00 RPM | PWM: 745.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 50.49s | Desired: 4000.00 RPM | Measured: 3751.00 RPM | Error: 249.00 RPM | PWM: 331.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 51.53s | Desired: 4000.00 RPM | Measured: 3766.00 RPM | Error: 234.00 RPM | PWM: 379.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 52.56s | Desired: 4000.00 RPM | Measured: 3475.00 RPM | Error: 525.00 RPM | PWM: 998.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 53.60s | Desired: 4000.00 RPM | Measured: 3572.00 RPM | Error: 428.00 RPM | PWM: 649.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 54.64s | Desired: 4000.00 RPM | Measured: 3737.00 RPM | Error: 263.00 RPM | PWM: 351.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 55.66s | Desired: 4000.00 RPM | Measured: 3571.00 RPM | Error: 429.00 RPM | PWM: 782.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 56.71s | Desired: 4000.00 RPM | Measured: 3740.00 RPM | Error: 260.00 RPM | PWM: 344.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 57.74s | Desired: 4000.00 RPM | Measured: 3605.00 RPM | Error: 395.00 RPM | PWM: 712.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 58.78s | Desired: 4000.00 RPM | Measured: 3579.00 RPM | Error: 421.00 RPM | PWM: 699.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 59.82s | Desired: 4000.00 RPM | Measured: 3588.00 RPM | Error: 412.00 RPM | PWM: 667.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 60.85s | Desired: 4000.00 RPM | Measured: 3588.00 RPM | Error: 412.00 RPM | PWM: 671.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 61.88s | Desired: 4000.00 RPM | Measured: 3576.00 RPM | Error: 424.00 RPM | PWM: 697.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 62.91s | Desired: 4000.00 RPM | Measured: 3759.00 RPM | Error: 241.00 RPM | PWM: 306.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 63.95s | Desired: 4000.00 RPM | Measured: 3612.00 RPM | Error: 388.00 RPM | PWM: 707.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 64.97s | Desired: 4000.00 RPM | Measured: 3736.00 RPM | Error: 264.00 RPM | PWM: 373.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 66.01s | Desired: 4000.00 RPM | Measured: 3762.00 RPM | Error: 238.00 RPM | PWM: 380.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 67.05s | Desired: 4000.00 RPM | Measured: 3582.00 RPM | Error: 418.00 RPM | PWM: 771.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 68.09s | Desired: 4000.00 RPM | Measured: 3709.00 RPM | Error: 291.00 RPM | PWM: 414.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 69.12s | Desired: 4000.00 RPM | Measured: 3560.00 RPM | Error: 440.00 RPM | PWM: 791.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 70.15s | Desired: 4000.00 RPM | Measured: 3573.00 RPM | Error: 427.00 RPM | PWM: 689.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 71.18s | Desired: 4000.00 RPM | Measured: 3560.00 RPM | Error: 440.00 RPM | PWM: 723.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 72.23s | Desired: 4000.00 RPM | Measured: 3561.00 RPM | Error: 439.00 RPM | PWM: 714.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 73.26s | Desired: 4000.00 RPM | Measured: 3752.00 RPM | Error: 248.00 RPM | PWM: 314.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 74.29s | Desired: 4000.00 RPM | Measured: 3635.00 RPM | Error: 365.00 RPM | PWM: 655.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 75.33s | Desired: 4000.00 RPM | Measured: 3576.00 RPM | Error: 424.00 RPM | PWM: 720.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 76.35s | Desired: 4000.00 RPM | Measured: 3738.00 RPM | Error: 262.00 RPM | PWM: 350.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 77.39s | Desired: 4000.00 RPM | Measured: 3757.00 RPM | Error: 243.00 RPM | PWM: 392.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 78.43s | Desired: 4000.00 RPM | Measured: 3609.00 RPM | Error: 391.00 RPM | PWM: 712.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 79.46s | Desired: 4000.00 RPM | Measured: 3603.00 RPM | Error: 397.00 RPM | PWM: 650.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 80.51s | Desired: 4000.00 RPM | Measured: 3593.00 RPM | Error: 407.00 RPM | PWM: 668.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 81.54s | Desired: 4000.00 RPM | Measured: 3581.00 RPM | Error: 419.00 RPM | PWM: 689.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 82.58s | Desired: 4000.00 RPM | Measured: 3765.00 RPM | Error: 235.00 RPM | PWM: 296.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 83.61s | Desired: 4000.00 RPM | Measured: 3644.00 RPM | Error: 356.00 RPM | PWM: 642.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 84.63s | Desired: 4000.00 RPM | Measured: 3642.00 RPM | Error: 358.00 RPM | PWM: 586.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 85.67s | Desired: 4000.00 RPM | Measured: 3764.00 RPM | Error: 236.00 RPM | PWM: 329.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 86.70s | Desired: 4000.00 RPM | Measured: 3602.00 RPM | Error: 398.00 RPM | PWM: 730.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 87.74s | Desired: 4000.00 RPM | Measured: 3736.00 RPM | Error: 264.00 RPM | PWM: 368.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 88.78s | Desired: 4000.00 RPM | Measured: 3768.00 RPM | Error: 232.00 RPM | PWM: 367.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 89.81s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 404.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 90.84s | Desired: 4000.00 RPM | Measured: 3755.00 RPM | Error: 245.00 RPM | PWM: 406.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 91.88s | Desired: 4000.00 RPM | Measured: 3611.00 RPM | Error: 389.00 RPM | PWM: 707.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 92.91s | Desired: 4000.00 RPM | Measured: 3768.00 RPM | Error: 232.00 RPM | PWM: 305.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 93.95s | Desired: 4000.00 RPM | Measured: 3801.00 RPM | Error: 199.00 RPM | PWM: 314.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 94.98s | Desired: 4000.00 RPM | Measured: 3505.00 RPM | Error: 495.00 RPM | PWM: 952.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 96.01s | Desired: 4000.00 RPM | Measured: 3558.00 RPM | Error: 442.00 RPM | PWM: 693.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 97.05s | Desired: 4000.00 RPM | Measured: 3595.00 RPM | Error: 405.00 RPM | PWM: 642.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 98.09s | Desired: 4000.00 RPM | Measured: 3587.00 RPM | Error: 413.00 RPM | PWM: 677.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 99.11s | Desired: 4000.00 RPM | Measured: 3710.00 RPM | Error: 290.00 RPM | PWM: 415.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 100.15s | Desired: 4000.00 RPM | Measured: 3585.00 RPM | Error: 415.00 RPM | PWM: 739.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 101.18s | Desired: 4000.00 RPM | Measured: 3589.00 RPM | Error: 411.00 RPM | PWM: 668.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 102.23s | Desired: 4000.00 RPM | Measured: 3596.00 RPM | Error: 404.00 RPM | PWM: 655.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 103.26s | Desired: 4000.00 RPM | Measured: 3725.00 RPM | Error: 275.00 RPM | PWM: 388.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 104.29s | Desired: 4000.00 RPM | Measured: 3576.00 RPM | Error: 424.00 RPM | PWM: 765.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 105.33s | Desired: 4000.00 RPM | Measured: 3747.00 RPM | Error: 253.00 RPM | PWM: 332.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 106.36s | Desired: 4000.00 RPM | Measured: 3610.00 RPM | Error: 390.00 RPM | PWM: 705.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 107.38s | Desired: 4000.00 RPM | Measured: 3575.00 RPM | Error: 425.00 RPM | PWM: 710.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 108.43s | Desired: 4000.00 RPM | Measured: 3591.00 RPM | Error: 409.00 RPM | PWM: 659.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 109.46s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 316.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 110.50s | Desired: 4000.00 RPM | Measured: 3793.00 RPM | Error: 207.00 RPM | PWM: 326.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 111.53s | Desired: 4000.00 RPM | Measured: 3812.00 RPM | Error: 188.00 RPM | PWM: 304.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 112.56s | Desired: 4000.00 RPM | Measured: 3655.00 RPM | Error: 345.00 RPM | PWM: 643.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 113.60s | Desired: 4000.00 RPM | Measured: 3652.00 RPM | Error: 348.00 RPM | PWM: 571.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 114.63s | Desired: 4000.00 RPM | Measured: 3829.00 RPM | Error: 171.00 RPM | PWM: 197.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 115.66s | Desired: 4000.00 RPM | Measured: 3089.00 RPM | Error: 911.00 RPM | PWM: 1840.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 116.70s | Desired: 4000.00 RPM | Measured: 3680.00 RPM | Error: 320.00 RPM | PWM: 229.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 117.73s | Desired: 4000.00 RPM | Measured: 3696.00 RPM | Error: 304.00 RPM | PWM: 491.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 118.76s | Desired: 4000.00 RPM | Measured: 3838.00 RPM | Error: 162.00 RPM | PWM: 200.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 119.79s | Desired: 4000.00 RPM | Measured: 3708.00 RPM | Error: 292.00 RPM | PWM: 544.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 120.83s | Desired: 4000.00 RPM | Measured: 3666.00 RPM | Error: 334.00 RPM | PWM: 568.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 121.86s | Desired: 4000.00 RPM | Measured: 3491.00 RPM | Error: 509.00 RPM | PWM: 914.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 122.89s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 213.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 123.93s | Desired: 4000.00 RPM | Measured: 3865.00 RPM | Error: 135.00 RPM | PWM: 187.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 124.97s | Desired: 4000.00 RPM | Measured: 3643.00 RPM | Error: 357.00 RPM | PWM: 694.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 126.00s | Desired: 4000.00 RPM | Measured: 3638.00 RPM | Error: 362.00 RPM | PWM: 594.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 127.03s | Desired: 4000.00 RPM | Measured: 3683.00 RPM | Error: 317.00 RPM | PWM: 497.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 128.07s | Desired: 4000.00 RPM | Measured: 3832.00 RPM | Error: 168.00 RPM | PWM: 207.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 129.10s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 445.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 130.13s | Desired: 4000.00 RPM | Measured: 3679.00 RPM | Error: 321.00 RPM | PWM: 563.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 131.18s | Desired: 4000.00 RPM | Measured: 3693.00 RPM | Error: 307.00 RPM | PWM: 496.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 132.21s | Desired: 4000.00 RPM | Measured: 3817.00 RPM | Error: 183.00 RPM | PWM: 243.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 133.25s | Desired: 4000.00 RPM | Measured: 3722.00 RPM | Error: 278.00 RPM | PWM: 505.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 134.28s | Desired: 4000.00 RPM | Measured: 3693.00 RPM | Error: 307.00 RPM | PWM: 518.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 135.31s | Desired: 4000.00 RPM | Measured: 3679.00 RPM | Error: 321.00 RPM | PWM: 533.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 136.35s | Desired: 4000.00 RPM | Measured: 3699.00 RPM | Error: 301.00 RPM | PWM: 484.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 137.38s | Desired: 4000.00 RPM | Measured: 3699.00 RPM | Error: 301.00 RPM | PWM: 494.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 138.41s | Desired: 4000.00 RPM | Measured: 3681.00 RPM | Error: 319.00 RPM | PWM: 532.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 139.45s | Desired: 4000.00 RPM | Measured: 3804.00 RPM | Error: 196.00 RPM | PWM: 264.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 140.49s | Desired: 4000.00 RPM | Measured: 3703.00 RPM | Error: 297.00 RPM | PWM: 538.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 141.52s | Desired: 4000.00 RPM | Measured: 3686.00 RPM | Error: 314.00 RPM | PWM: 523.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 142.55s | Desired: 4000.00 RPM | Measured: 3798.00 RPM | Error: 202.00 RPM | PWM: 279.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 143.58s | Desired: 4000.00 RPM | Measured: 3821.00 RPM | Error: 179.00 RPM | PWM: 287.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 144.61s | Desired: 4000.00 RPM | Measured: 3528.00 RPM | Error: 472.00 RPM | PWM: 914.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 145.64s | Desired: 4000.00 RPM | Measured: 3606.00 RPM | Error: 394.00 RPM | PWM: 604.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 146.68s | Desired: 4000.00 RPM | Measured: 3795.00 RPM | Error: 205.00 RPM | PWM: 246.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 147.71s | Desired: 4000.00 RPM | Measured: 3655.00 RPM | Error: 345.00 RPM | PWM: 634.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 148.75s | Desired: 4000.00 RPM | Measured: 3592.00 RPM | Error: 408.00 RPM | PWM: 697.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 149.79s | Desired: 4000.00 RPM | Measured: 3804.00 RPM | Error: 196.00 RPM | PWM: 220.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 150.83s | Desired: 4000.00 RPM | Measured: 3334.00 RPM | Error: 666.00 RPM | PWM: 1313.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 151.86s | Desired: 4000.00 RPM | Measured: 3744.00 RPM | Error: 256.00 RPM | PWM: 217.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 152.88s | Desired: 4000.00 RPM | Measured: 3336.00 RPM | Error: 664.00 RPM | PWM: 1279.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 153.93s | Desired: 4000.00 RPM | Measured: 3592.00 RPM | Error: 408.00 RPM | PWM: 537.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 154.96s | Desired: 4000.00 RPM | Measured: 3819.00 RPM | Error: 181.00 RPM | PWM: 188.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 156.00s | Desired: 4000.00 RPM | Measured: 3071.00 RPM | Error: 929.00 RPM | PWM: 1873.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 157.04s | Desired: 4000.00 RPM | Measured: 3499.00 RPM | Error: 501.00 RPM | PWM: 600.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 158.07s | Desired: 4000.00 RPM | Measured: 3617.00 RPM | Error: 383.00 RPM | PWM: 566.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 159.10s | Desired: 4000.00 RPM | Measured: 3786.00 RPM | Error: 214.00 RPM | PWM: 270.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 160.13s | Desired: 4000.00 RPM | Measured: 3546.00 RPM | Error: 454.00 RPM | PWM: 859.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 161.17s | Desired: 4000.00 RPM | Measured: 3784.00 RPM | Error: 216.00 RPM | PWM: 239.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 162.21s | Desired: 4000.00 RPM | Measured: 3326.00 RPM | Error: 674.00 RPM | PWM: 1320.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 163.24s | Desired: 4000.00 RPM | Measured: 3581.00 RPM | Error: 419.00 RPM | PWM: 555.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 164.28s | Desired: 4000.00 RPM | Measured: 3829.00 RPM | Error: 171.00 RPM | PWM: 162.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 165.30s | Desired: 4000.00 RPM | Measured: 3338.00 RPM | Error: 662.00 RPM | PWM: 1317.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 166.34s | Desired: 4000.00 RPM | Measured: 3552.00 RPM | Error: 448.00 RPM | PWM: 622.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 167.38s | Desired: 4000.00 RPM | Measured: 3815.00 RPM | Error: 185.00 RPM | PWM: 177.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 168.40s | Desired: 4000.00 RPM | Measured: 3672.00 RPM | Error: 328.00 RPM | PWM: 609.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 169.44s | Desired: 4000.00 RPM | Measured: 3837.00 RPM | Error: 163.00 RPM | PWM: 191.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 170.48s | Desired: 4000.00 RPM | Measured: 3676.00 RPM | Error: 324.00 RPM | PWM: 611.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 171.49s | Desired: 4000.00 RPM | Measured: 3642.00 RPM | Error: 358.00 RPM | PWM: 602.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 172.54s | Desired: 4000.00 RPM | Measured: 3798.00 RPM | Error: 202.00 RPM | PWM: 257.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 173.58s | Desired: 4000.00 RPM | Measured: 3852.00 RPM | Error: 148.00 RPM | PWM: 222.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 174.60s | Desired: 4000.00 RPM | Measured: 3678.00 RPM | Error: 322.00 RPM | PWM: 614.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 175.63s | Desired: 4000.00 RPM | Measured: 3612.00 RPM | Error: 388.00 RPM | PWM: 666.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 176.67s | Desired: 4000.00 RPM | Measured: 3778.00 RPM | Error: 222.00 RPM | PWM: 284.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 177.70s | Desired: 4000.00 RPM | Measured: 3810.00 RPM | Error: 190.00 RPM | PWM: 300.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 178.73s | Desired: 4000.00 RPM | Measured: 3661.00 RPM | Error: 339.00 RPM | PWM: 629.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 179.76s | Desired: 4000.00 RPM | Measured: 3601.00 RPM | Error: 399.00 RPM | PWM: 681.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 180.81s | Desired: 4000.00 RPM | Measured: 3773.00 RPM | Error: 227.00 RPM | PWM: 289.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 181.84s | Desired: 4000.00 RPM | Measured: 3808.00 RPM | Error: 192.00 RPM | PWM: 302.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 182.88s | Desired: 4000.00 RPM | Measured: 3816.00 RPM | Error: 184.00 RPM | PWM: 303.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 183.91s | Desired: 4000.00 RPM | Measured: 3802.00 RPM | Error: 198.00 RPM | PWM: 336.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 184.93s | Desired: 4000.00 RPM | Measured: 3643.00 RPM | Error: 357.00 RPM | PWM: 663.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 185.98s | Desired: 4000.00 RPM | Measured: 3579.00 RPM | Error: 421.00 RPM | PWM: 718.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 187.01s | Desired: 4000.00 RPM | Measured: 3564.00 RPM | Error: 436.00 RPM | PWM: 717.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 188.04s | Desired: 4000.00 RPM | Measured: 3605.00 RPM | Error: 395.00 RPM | PWM: 624.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 189.07s | Desired: 4000.00 RPM | Measured: 3570.00 RPM | Error: 430.00 RPM | PWM: 718.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 190.12s | Desired: 4000.00 RPM | Measured: 3538.00 RPM | Error: 462.00 RPM | PWM: 767.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 191.15s | Desired: 4000.00 RPM | Measured: 3530.00 RPM | Error: 470.00 RPM | PWM: 768.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 192.18s | Desired: 4000.00 RPM | Measured: 3534.00 RPM | Error: 466.00 RPM | PWM: 756.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 193.23s | Desired: 4000.00 RPM | Measured: 3547.00 RPM | Error: 453.00 RPM | PWM: 731.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 194.26s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 355.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 195.30s | Desired: 4000.00 RPM | Measured: 3597.00 RPM | Error: 403.00 RPM | PWM: 723.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 196.32s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 380.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 197.36s | Desired: 4000.00 RPM | Measured: 3615.00 RPM | Error: 385.00 RPM | PWM: 685.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 198.40s | Desired: 4000.00 RPM | Measured: 3582.00 RPM | Error: 418.00 RPM | PWM: 698.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 199.43s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 320.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 200.46s | Desired: 4000.00 RPM | Measured: 3565.00 RPM | Error: 435.00 RPM | PWM: 803.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 201.50s | Desired: 4000.00 RPM | Measured: 3563.00 RPM | Error: 437.00 RPM | PWM: 712.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 202.54s | Desired: 4000.00 RPM | Measured: 3547.00 RPM | Error: 453.00 RPM | PWM: 745.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 203.57s | Desired: 4000.00 RPM | Measured: 3725.00 RPM | Error: 275.00 RPM | PWM: 363.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 204.61s | Desired: 4000.00 RPM | Measured: 3576.00 RPM | Error: 424.00 RPM | PWM: 765.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 205.64s | Desired: 4000.00 RPM | Measured: 3711.00 RPM | Error: 289.00 RPM | PWM: 407.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 206.66s | Desired: 4000.00 RPM | Measured: 3450.00 RPM | Error: 550.00 RPM | PWM: 1023.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 207.71s | Desired: 4000.00 RPM | Measured: 3525.00 RPM | Error: 475.00 RPM | PWM: 735.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 208.73s | Desired: 4000.00 RPM | Measured: 3607.00 RPM | Error: 393.00 RPM | PWM: 600.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 209.77s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 349.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 210.80s | Desired: 4000.00 RPM | Measured: 3499.00 RPM | Error: 501.00 RPM | PWM: 937.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 211.84s | Desired: 4000.00 RPM | Measured: 3571.00 RPM | Error: 429.00 RPM | PWM: 663.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 212.88s | Desired: 4000.00 RPM | Measured: 3781.00 RPM | Error: 219.00 RPM | PWM: 258.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 213.91s | Desired: 4000.00 RPM | Measured: 3811.00 RPM | Error: 189.00 RPM | PWM: 300.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 214.95s | Desired: 4000.00 RPM | Measured: 3798.00 RPM | Error: 202.00 RPM | PWM: 342.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 215.98s | Desired: 4000.00 RPM | Measured: 3814.00 RPM | Error: 186.00 RPM | PWM: 302.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 217.01s | Desired: 4000.00 RPM | Measured: 3635.00 RPM | Error: 365.00 RPM | PWM: 686.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 218.05s | Desired: 4000.00 RPM | Measured: 3587.00 RPM | Error: 413.00 RPM | PWM: 697.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 219.08s | Desired: 4000.00 RPM | Measured: 3738.00 RPM | Error: 262.00 RPM | PWM: 356.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 220.12s | Desired: 4000.00 RPM | Measured: 3781.00 RPM | Error: 219.00 RPM | PWM: 341.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 221.15s | Desired: 4000.00 RPM | Measured: 3484.00 RPM | Error: 516.00 RPM | PWM: 986.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 222.19s | Desired: 4000.00 RPM | Measured: 3599.00 RPM | Error: 401.00 RPM | PWM: 596.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 223.21s | Desired: 4000.00 RPM | Measured: 3617.00 RPM | Error: 383.00 RPM | PWM: 616.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 224.25s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 329.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 225.28s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 349.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 226.31s | Desired: 4000.00 RPM | Measured: 3609.00 RPM | Error: 391.00 RPM | PWM: 724.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 227.36s | Desired: 4000.00 RPM | Measured: 3526.00 RPM | Error: 474.00 RPM | PWM: 812.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 228.39s | Desired: 4000.00 RPM | Measured: 3737.00 RPM | Error: 263.00 RPM | PWM: 328.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 229.43s | Desired: 4000.00 RPM | Measured: 3607.00 RPM | Error: 393.00 RPM | PWM: 706.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 230.46s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 341.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 231.50s | Desired: 4000.00 RPM | Measured: 3578.00 RPM | Error: 422.00 RPM | PWM: 773.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 232.52s | Desired: 4000.00 RPM | Measured: 3549.00 RPM | Error: 451.00 RPM | PWM: 748.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 233.57s | Desired: 4000.00 RPM | Measured: 3560.00 RPM | Error: 440.00 RPM | PWM: 711.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 234.60s | Desired: 4000.00 RPM | Measured: 3578.00 RPM | Error: 422.00 RPM | PWM: 678.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 235.63s | Desired: 4000.00 RPM | Measured: 3594.00 RPM | Error: 406.00 RPM | PWM: 654.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 236.67s | Desired: 4000.00 RPM | Measured: 3585.00 RPM | Error: 415.00 RPM | PWM: 681.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 237.70s | Desired: 4000.00 RPM | Measured: 3578.00 RPM | Error: 422.00 RPM | PWM: 691.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 238.73s | Desired: 4000.00 RPM | Measured: 3591.00 RPM | Error: 409.00 RPM | PWM: 660.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 239.77s | Desired: 4000.00 RPM | Measured: 3691.00 RPM | Error: 309.00 RPM | PWM: 457.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 240.80s | Desired: 4000.00 RPM | Measured: 3715.00 RPM | Error: 285.00 RPM | PWM: 456.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 241.82s | Desired: 4000.00 RPM | Measured: 3617.00 RPM | Error: 383.00 RPM | PWM: 674.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 242.86s | Desired: 4000.00 RPM | Measured: 3717.00 RPM | Error: 283.00 RPM | PWM: 415.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 243.90s | Desired: 4000.00 RPM | Measured: 3616.00 RPM | Error: 384.00 RPM | PWM: 677.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 244.93s | Desired: 4000.00 RPM | Measured: 3698.00 RPM | Error: 302.00 RPM | PWM: 454.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 245.96s | Desired: 4000.00 RPM | Measured: 3720.00 RPM | Error: 280.00 RPM | PWM: 449.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 247.00s | Desired: 4000.00 RPM | Measured: 3590.00 RPM | Error: 410.00 RPM | PWM: 733.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 248.03s | Desired: 4000.00 RPM | Measured: 3581.00 RPM | Error: 419.00 RPM | PWM: 687.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 249.07s | Desired: 4000.00 RPM | Measured: 3716.00 RPM | Error: 284.00 RPM | PWM: 399.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 250.09s | Desired: 4000.00 RPM | Measured: 3434.00 RPM | Error: 566.00 RPM | PWM: 1059.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 251.12s | Desired: 4000.00 RPM | Measured: 3487.00 RPM | Error: 513.00 RPM | PWM: 807.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 252.16s | Desired: 4000.00 RPM | Measured: 3721.00 RPM | Error: 279.00 RPM | PWM: 342.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 253.20s | Desired: 4000.00 RPM | Measured: 3740.00 RPM | Error: 260.00 RPM | PWM: 419.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 254.23s | Desired: 4000.00 RPM | Measured: 3586.00 RPM | Error: 414.00 RPM | PWM: 752.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 255.26s | Desired: 4000.00 RPM | Measured: 3699.00 RPM | Error: 301.00 RPM | PWM: 437.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 256.29s | Desired: 4000.00 RPM | Measured: 3609.00 RPM | Error: 391.00 RPM | PWM: 683.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 257.33s | Desired: 4000.00 RPM | Measured: 3582.00 RPM | Error: 418.00 RPM | PWM: 695.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 258.36s | Desired: 4000.00 RPM | Measured: 3739.00 RPM | Error: 261.00 RPM | PWM: 351.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 259.39s | Desired: 4000.00 RPM | Measured: 3573.00 RPM | Error: 427.00 RPM | PWM: 778.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 260.42s | Desired: 4000.00 RPM | Measured: 3559.00 RPM | Error: 441.00 RPM | PWM: 725.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 261.47s | Desired: 4000.00 RPM | Measured: 3573.00 RPM | Error: 427.00 RPM | PWM: 688.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 262.50s | Desired: 4000.00 RPM | Measured: 3587.00 RPM | Error: 413.00 RPM | PWM: 666.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 263.53s | Desired: 4000.00 RPM | Measured: 3749.00 RPM | Error: 251.00 RPM | PWM: 333.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 264.56s | Desired: 4000.00 RPM | Measured: 3586.00 RPM | Error: 414.00 RPM | PWM: 756.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 265.60s | Desired: 4000.00 RPM | Measured: 3734.00 RPM | Error: 266.00 RPM | PWM: 364.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 266.63s | Desired: 4000.00 RPM | Measured: 3608.00 RPM | Error: 392.00 RPM | PWM: 702.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 267.67s | Desired: 4000.00 RPM | Measured: 3576.00 RPM | Error: 424.00 RPM | PWM: 707.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 268.70s | Desired: 4000.00 RPM | Measured: 3784.00 RPM | Error: 216.00 RPM | PWM: 254.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 269.73s | Desired: 4000.00 RPM | Measured: 3303.00 RPM | Error: 697.00 RPM | PWM: 1368.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 270.77s | Desired: 4000.00 RPM | Measured: 3501.00 RPM | Error: 499.00 RPM | PWM: 712.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 271.80s | Desired: 4000.00 RPM | Measured: 3769.00 RPM | Error: 231.00 RPM | PWM: 248.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 272.84s | Desired: 4000.00 RPM | Measured: 3261.00 RPM | Error: 739.00 RPM | PWM: 1449.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 273.87s | Desired: 4000.00 RPM | Measured: 3500.00 RPM | Error: 500.00 RPM | PWM: 693.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 274.89s | Desired: 4000.00 RPM | Measured: 3521.00 RPM | Error: 479.00 RPM | PWM: 768.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 275.93s | Desired: 4000.00 RPM | Measured: 3724.00 RPM | Error: 276.00 RPM | PWM: 352.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 276.97s | Desired: 4000.00 RPM | Measured: 3622.00 RPM | Error: 378.00 RPM | PWM: 668.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 278.00s | Desired: 4000.00 RPM | Measured: 3713.00 RPM | Error: 287.00 RPM | PWM: 426.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 279.03s | Desired: 4000.00 RPM | Measured: 3738.00 RPM | Error: 262.00 RPM | PWM: 419.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 280.06s | Desired: 4000.00 RPM | Measured: 3730.00 RPM | Error: 270.00 RPM | PWM: 448.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 281.11s | Desired: 4000.00 RPM | Measured: 3611.00 RPM | Error: 389.00 RPM | PWM: 694.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 282.14s | Desired: 4000.00 RPM | Measured: 3732.00 RPM | Error: 268.00 RPM | PWM: 381.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 283.18s | Desired: 4000.00 RPM | Measured: 3592.00 RPM | Error: 408.00 RPM | PWM: 735.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 284.21s | Desired: 4000.00 RPM | Measured: 3680.00 RPM | Error: 320.00 RPM | PWM: 480.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 285.25s | Desired: 4000.00 RPM | Measured: 3576.00 RPM | Error: 424.00 RPM | PWM: 743.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 286.28s | Desired: 4000.00 RPM | Measured: 3678.00 RPM | Error: 322.00 RPM | PWM: 476.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 287.31s | Desired: 4000.00 RPM | Measured: 3721.00 RPM | Error: 279.00 RPM | PWM: 437.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 288.35s | Desired: 4000.00 RPM | Measured: 3448.00 RPM | Error: 552.00 RPM | PWM: 1032.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 289.38s | Desired: 4000.00 RPM | Measured: 3546.00 RPM | Error: 454.00 RPM | PWM: 690.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 290.42s | Desired: 4000.00 RPM | Measured: 3717.00 RPM | Error: 283.00 RPM | PWM: 380.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 291.45s | Desired: 4000.00 RPM | Measured: 3592.00 RPM | Error: 408.00 RPM | PWM: 728.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 292.49s | Desired: 4000.00 RPM | Measured: 3735.00 RPM | Error: 265.00 RPM | PWM: 365.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 293.51s | Desired: 4000.00 RPM | Measured: 3643.00 RPM | Error: 357.00 RPM | PWM: 629.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 294.56s | Desired: 4000.00 RPM | Measured: 3597.00 RPM | Error: 403.00 RPM | PWM: 680.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 295.59s | Desired: 4000.00 RPM | Measured: 3702.00 RPM | Error: 298.00 RPM | PWM: 437.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 296.62s | Desired: 4000.00 RPM | Measured: 3586.00 RPM | Error: 414.00 RPM | PWM: 733.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 297.65s | Desired: 4000.00 RPM | Measured: 3702.00 RPM | Error: 298.00 RPM | PWM: 431.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 298.68s | Desired: 4000.00 RPM | Measured: 3625.00 RPM | Error: 375.00 RPM | PWM: 651.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 299.72s | Desired: 4000.00 RPM | Measured: 3594.00 RPM | Error: 406.00 RPM | PWM: 677.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 300.75s | Desired: 4000.00 RPM | Measured: 3594.00 RPM | Error: 406.00 RPM | PWM: 662.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 301.78s | Desired: 4000.00 RPM | Measured: 3595.00 RPM | Error: 405.00 RPM | PWM: 660.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 302.82s | Desired: 4000.00 RPM | Measured: 3612.00 RPM | Error: 388.00 RPM | PWM: 625.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 303.86s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 392.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 304.88s | Desired: 4000.00 RPM | Measured: 3615.00 RPM | Error: 385.00 RPM | PWM: 684.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 305.92s | Desired: 4000.00 RPM | Measured: 3612.00 RPM | Error: 388.00 RPM | PWM: 635.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 306.95s | Desired: 4000.00 RPM | Measured: 3737.00 RPM | Error: 263.00 RPM | PWM: 371.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 307.98s | Desired: 4000.00 RPM | Measured: 3645.00 RPM | Error: 355.00 RPM | PWM: 626.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 309.02s | Desired: 4000.00 RPM | Measured: 3617.00 RPM | Error: 383.00 RPM | PWM: 639.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 310.05s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 394.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 311.09s | Desired: 4000.00 RPM | Measured: 3631.00 RPM | Error: 369.00 RPM | PWM: 651.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 312.13s | Desired: 4000.00 RPM | Measured: 3628.00 RPM | Error: 372.00 RPM | PWM: 609.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 313.15s | Desired: 4000.00 RPM | Measured: 3624.00 RPM | Error: 376.00 RPM | PWM: 616.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 314.19s | Desired: 4000.00 RPM | Measured: 3589.00 RPM | Error: 411.00 RPM | PWM: 687.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 315.22s | Desired: 4000.00 RPM | Measured: 3607.00 RPM | Error: 393.00 RPM | PWM: 632.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 316.25s | Desired: 4000.00 RPM | Measured: 3759.00 RPM | Error: 241.00 RPM | PWM: 322.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 317.30s | Desired: 4000.00 RPM | Measured: 3685.00 RPM | Error: 315.00 RPM | PWM: 553.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 318.33s | Desired: 4000.00 RPM | Measured: 3637.00 RPM | Error: 363.00 RPM | PWM: 617.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 319.36s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 282.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 320.40s | Desired: 4000.00 RPM | Measured: 3664.00 RPM | Error: 336.00 RPM | PWM: 610.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 321.44s | Desired: 4000.00 RPM | Measured: 3635.00 RPM | Error: 365.00 RPM | PWM: 611.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 322.46s | Desired: 4000.00 RPM | Measured: 3587.00 RPM | Error: 413.00 RPM | PWM: 697.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 323.50s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 375.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 324.54s | Desired: 4000.00 RPM | Measured: 3601.00 RPM | Error: 399.00 RPM | PWM: 715.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 325.57s | Desired: 4000.00 RPM | Measured: 3732.00 RPM | Error: 268.00 RPM | PWM: 376.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 326.59s | Desired: 4000.00 RPM | Measured: 3620.00 RPM | Error: 380.00 RPM | PWM: 676.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 327.63s | Desired: 4000.00 RPM | Measured: 3585.00 RPM | Error: 415.00 RPM | PWM: 694.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 328.67s | Desired: 4000.00 RPM | Measured: 3613.00 RPM | Error: 387.00 RPM | PWM: 617.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 329.70s | Desired: 4000.00 RPM | Measured: 3582.00 RPM | Error: 418.00 RPM | PWM: 697.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 330.73s | Desired: 4000.00 RPM | Measured: 3716.00 RPM | Error: 284.00 RPM | PWM: 400.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 331.76s | Desired: 4000.00 RPM | Measured: 3740.00 RPM | Error: 260.00 RPM | PWM: 416.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 332.80s | Desired: 4000.00 RPM | Measured: 3585.00 RPM | Error: 415.00 RPM | PWM: 754.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 333.83s | Desired: 4000.00 RPM | Measured: 3568.00 RPM | Error: 432.00 RPM | PWM: 712.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 334.87s | Desired: 4000.00 RPM | Measured: 3578.00 RPM | Error: 422.00 RPM | PWM: 682.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 335.90s | Desired: 4000.00 RPM | Measured: 3568.00 RPM | Error: 432.00 RPM | PWM: 708.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 336.94s | Desired: 4000.00 RPM | Measured: 3573.00 RPM | Error: 427.00 RPM | PWM: 693.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 337.98s | Desired: 4000.00 RPM | Measured: 3574.00 RPM | Error: 426.00 RPM | PWM: 693.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 339.00s | Desired: 4000.00 RPM | Measured: 3577.00 RPM | Error: 423.00 RPM | PWM: 688.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 340.04s | Desired: 4000.00 RPM | Measured: 3726.00 RPM | Error: 274.00 RPM | PWM: 376.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 341.07s | Desired: 4000.00 RPM | Measured: 3477.00 RPM | Error: 523.00 RPM | PWM: 974.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 342.11s | Desired: 4000.00 RPM | Measured: 3706.00 RPM | Error: 294.00 RPM | PWM: 368.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 343.15s | Desired: 4000.00 RPM | Measured: 3470.00 RPM | Error: 530.00 RPM | PWM: 978.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 344.19s | Desired: 4000.00 RPM | Measured: 3578.00 RPM | Error: 422.00 RPM | PWM: 633.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 345.22s | Desired: 4000.00 RPM | Measured: 3601.00 RPM | Error: 399.00 RPM | PWM: 639.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 346.25s | Desired: 4000.00 RPM | Measured: 3744.00 RPM | Error: 256.00 RPM | PWM: 350.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 347.28s | Desired: 4000.00 RPM | Measured: 3640.00 RPM | Error: 360.00 RPM | PWM: 640.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 348.32s | Desired: 4000.00 RPM | Measured: 3609.00 RPM | Error: 391.00 RPM | PWM: 653.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 349.34s | Desired: 4000.00 RPM | Measured: 3627.00 RPM | Error: 373.00 RPM | PWM: 600.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 350.38s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 296.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 351.42s | Desired: 4000.00 RPM | Measured: 3508.00 RPM | Error: 492.00 RPM | PWM: 933.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 352.45s | Desired: 4000.00 RPM | Measured: 3622.00 RPM | Error: 378.00 RPM | PWM: 560.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 353.48s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 279.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 354.52s | Desired: 4000.00 RPM | Measured: 3795.00 RPM | Error: 205.00 RPM | PWM: 334.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 355.55s | Desired: 4000.00 RPM | Measured: 3639.00 RPM | Error: 361.00 RPM | PWM: 668.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 356.58s | Desired: 4000.00 RPM | Measured: 3663.00 RPM | Error: 337.00 RPM | PWM: 539.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 357.62s | Desired: 4000.00 RPM | Measured: 3736.00 RPM | Error: 264.00 RPM | PWM: 398.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 358.66s | Desired: 4000.00 RPM | Measured: 3597.00 RPM | Error: 403.00 RPM | PWM: 727.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 359.69s | Desired: 4000.00 RPM | Measured: 3789.00 RPM | Error: 211.00 RPM | PWM: 254.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 360.73s | Desired: 4000.00 RPM | Measured: 3302.00 RPM | Error: 698.00 RPM | PWM: 1373.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 361.75s | Desired: 4000.00 RPM | Measured: 3584.00 RPM | Error: 416.00 RPM | PWM: 537.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 362.79s | Desired: 4000.00 RPM | Measured: 3598.00 RPM | Error: 402.00 RPM | PWM: 648.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 363.83s | Desired: 4000.00 RPM | Measured: 3597.00 RPM | Error: 403.00 RPM | PWM: 658.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 364.85s | Desired: 4000.00 RPM | Measured: 3732.00 RPM | Error: 268.00 RPM | PWM: 374.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 365.90s | Desired: 4000.00 RPM | Measured: 3626.00 RPM | Error: 374.00 RPM | PWM: 664.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 366.93s | Desired: 4000.00 RPM | Measured: 3600.00 RPM | Error: 400.00 RPM | PWM: 665.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 367.95s | Desired: 4000.00 RPM | Measured: 3584.00 RPM | Error: 416.00 RPM | PWM: 686.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 369.00s | Desired: 4000.00 RPM | Measured: 3600.00 RPM | Error: 400.00 RPM | PWM: 644.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 370.03s | Desired: 4000.00 RPM | Measured: 3603.00 RPM | Error: 397.00 RPM | PWM: 646.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 371.07s | Desired: 4000.00 RPM | Measured: 3609.00 RPM | Error: 391.00 RPM | PWM: 635.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 372.10s | Desired: 4000.00 RPM | Measured: 3608.00 RPM | Error: 392.00 RPM | PWM: 640.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 373.12s | Desired: 4000.00 RPM | Measured: 3617.00 RPM | Error: 383.00 RPM | PWM: 621.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 374.17s | Desired: 4000.00 RPM | Measured: 3748.00 RPM | Error: 252.00 RPM | PWM: 350.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 375.19s | Desired: 4000.00 RPM | Measured: 3768.00 RPM | Error: 232.00 RPM | PWM: 373.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 376.22s | Desired: 4000.00 RPM | Measured: 3749.00 RPM | Error: 251.00 RPM | PWM: 423.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 377.26s | Desired: 4000.00 RPM | Measured: 3630.00 RPM | Error: 370.00 RPM | PWM: 664.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 378.29s | Desired: 4000.00 RPM | Measured: 3621.00 RPM | Error: 379.00 RPM | PWM: 623.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 379.33s | Desired: 4000.00 RPM | Measured: 3621.00 RPM | Error: 379.00 RPM | PWM: 619.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 380.36s | Desired: 4000.00 RPM | Measured: 3616.00 RPM | Error: 384.00 RPM | PWM: 629.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# ...
# Time: 1876.93s | Desired: 4000.00 RPM | Measured: 3726.00 RPM | Error: 274.00 RPM | PWM: 542.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1877.98s | Desired: 4000.00 RPM | Measured: 3870.00 RPM | Error: 130.00 RPM | PWM: 148.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1879.02s | Desired: 4000.00 RPM | Measured: 3757.00 RPM | Error: 243.00 RPM | PWM: 458.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1880.04s | Desired: 4000.00 RPM | Measured: 3694.00 RPM | Error: 306.00 RPM | PWM: 533.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1881.07s | Desired: 4000.00 RPM | Measured: 3664.00 RPM | Error: 336.00 RPM | PWM: 565.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1882.11s | Desired: 4000.00 RPM | Measured: 3667.00 RPM | Error: 333.00 RPM | PWM: 544.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1883.15s | Desired: 4000.00 RPM | Measured: 3824.00 RPM | Error: 176.00 RPM | PWM: 215.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1884.18s | Desired: 4000.00 RPM | Measured: 3099.00 RPM | Error: 901.00 RPM | PWM: 1816.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1885.21s | Desired: 4000.00 RPM | Measured: 3462.00 RPM | Error: 538.00 RPM | PWM: 692.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1886.25s | Desired: 4000.00 RPM | Measured: 3812.00 RPM | Error: 188.00 RPM | PWM: 138.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1887.28s | Desired: 4000.00 RPM | Measured: 3721.00 RPM | Error: 279.00 RPM | PWM: 504.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1888.32s | Desired: 4000.00 RPM | Measured: 3526.00 RPM | Error: 474.00 RPM | PWM: 868.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1889.35s | Desired: 4000.00 RPM | Measured: 3814.00 RPM | Error: 186.00 RPM | PWM: 166.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1890.38s | Desired: 4000.00 RPM | Measured: 3311.00 RPM | Error: 689.00 RPM | PWM: 1366.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1891.42s | Desired: 4000.00 RPM | Measured: 3595.00 RPM | Error: 405.00 RPM | PWM: 518.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1892.45s | Desired: 4000.00 RPM | Measured: 3702.00 RPM | Error: 298.00 RPM | PWM: 436.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1893.49s | Desired: 4000.00 RPM | Measured: 3673.00 RPM | Error: 327.00 RPM | PWM: 550.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1894.52s | Desired: 4000.00 RPM | Measured: 3699.00 RPM | Error: 301.00 RPM | PWM: 481.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1895.56s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 370.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1896.59s | Desired: 4000.00 RPM | Measured: 3834.00 RPM | Error: 166.00 RPM | PWM: 240.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1897.62s | Desired: 4000.00 RPM | Measured: 3337.00 RPM | Error: 663.00 RPM | PWM: 1322.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1898.65s | Desired: 4000.00 RPM | Measured: 3510.00 RPM | Error: 490.00 RPM | PWM: 710.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1899.70s | Desired: 4000.00 RPM | Measured: 3600.00 RPM | Error: 400.00 RPM | PWM: 607.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1900.73s | Desired: 4000.00 RPM | Measured: 3619.00 RPM | Error: 381.00 RPM | PWM: 612.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1901.76s | Desired: 4000.00 RPM | Measured: 3575.00 RPM | Error: 425.00 RPM | PWM: 714.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1902.79s | Desired: 4000.00 RPM | Measured: 3630.00 RPM | Error: 370.00 RPM | PWM: 577.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1903.82s | Desired: 4000.00 RPM | Measured: 3682.00 RPM | Error: 318.00 RPM | PWM: 495.54999999999995 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1904.87s | Desired: 4000.00 RPM | Measured: 2708.00 RPM | Error: 1292.00 RPM | PWM: 2566.9500000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1905.89s | Desired: 4000.00 RPM | Measured: 3363.00 RPM | Error: 637.00 RPM | PWM: 704.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1906.93s | Desired: 4000.00 RPM | Measured: 3717.00 RPM | Error: 283.00 RPM | PWM: 288.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1907.96s | Desired: 4000.00 RPM | Measured: 3719.00 RPM | Error: 281.00 RPM | PWM: 461.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1908.99s | Desired: 4000.00 RPM | Measured: 3660.00 RPM | Error: 340.00 RPM | PWM: 586.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1910.04s | Desired: 4000.00 RPM | Measured: 3668.00 RPM | Error: 332.00 RPM | PWM: 539.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1911.06s | Desired: 4000.00 RPM | Measured: 3643.00 RPM | Error: 357.00 RPM | PWM: 596.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1912.09s | Desired: 4000.00 RPM | Measured: 3649.00 RPM | Error: 351.00 RPM | PWM: 571.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1913.13s | Desired: 4000.00 RPM | Measured: 3584.00 RPM | Error: 416.00 RPM | PWM: 710.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1914.18s | Desired: 4000.00 RPM | Measured: 3551.00 RPM | Error: 449.00 RPM | PWM: 747.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1915.21s | Desired: 4000.00 RPM | Measured: 3714.00 RPM | Error: 286.00 RPM | PWM: 388.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1916.24s | Desired: 4000.00 RPM | Measured: 3565.00 RPM | Error: 435.00 RPM | PWM: 783.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1917.27s | Desired: 4000.00 RPM | Measured: 3562.00 RPM | Error: 438.00 RPM | PWM: 715.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1918.31s | Desired: 4000.00 RPM | Measured: 3735.00 RPM | Error: 265.00 RPM | PWM: 350.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1919.34s | Desired: 4000.00 RPM | Measured: 3607.00 RPM | Error: 393.00 RPM | PWM: 705.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1920.37s | Desired: 4000.00 RPM | Measured: 3732.00 RPM | Error: 268.00 RPM | PWM: 379.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1921.41s | Desired: 4000.00 RPM | Measured: 3620.00 RPM | Error: 380.00 RPM | PWM: 676.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1922.43s | Desired: 4000.00 RPM | Measured: 3576.00 RPM | Error: 424.00 RPM | PWM: 713.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1923.48s | Desired: 4000.00 RPM | Measured: 3755.00 RPM | Error: 245.00 RPM | PWM: 315.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1924.51s | Desired: 4000.00 RPM | Measured: 3630.00 RPM | Error: 370.00 RPM | PWM: 667.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1925.54s | Desired: 4000.00 RPM | Measured: 3637.00 RPM | Error: 363.00 RPM | PWM: 590.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1926.58s | Desired: 4000.00 RPM | Measured: 3756.00 RPM | Error: 244.00 RPM | PWM: 343.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1927.62s | Desired: 4000.00 RPM | Measured: 3506.00 RPM | Error: 494.00 RPM | PWM: 928.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1928.64s | Desired: 4000.00 RPM | Measured: 3756.00 RPM | Error: 244.00 RPM | PWM: 278.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1929.68s | Desired: 4000.00 RPM | Measured: 3806.00 RPM | Error: 194.00 RPM | PWM: 298.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1930.71s | Desired: 4000.00 RPM | Measured: 3779.00 RPM | Error: 221.00 RPM | PWM: 379.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1931.74s | Desired: 4000.00 RPM | Measured: 3614.00 RPM | Error: 386.00 RPM | PWM: 712.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1932.79s | Desired: 4000.00 RPM | Measured: 3577.00 RPM | Error: 423.00 RPM | PWM: 708.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1933.81s | Desired: 4000.00 RPM | Measured: 3728.00 RPM | Error: 272.00 RPM | PWM: 372.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1934.84s | Desired: 4000.00 RPM | Measured: 3790.00 RPM | Error: 210.00 RPM | PWM: 317.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1935.89s | Desired: 4000.00 RPM | Measured: 3673.00 RPM | Error: 327.00 RPM | PWM: 594.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1936.93s | Desired: 4000.00 RPM | Measured: 3691.00 RPM | Error: 309.00 RPM | PWM: 498.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1937.96s | Desired: 4000.00 RPM | Measured: 3799.00 RPM | Error: 201.00 RPM | PWM: 280.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1938.99s | Desired: 4000.00 RPM | Measured: 3662.00 RPM | Error: 338.00 RPM | PWM: 622.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1940.03s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 377.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1941.06s | Desired: 4000.00 RPM | Measured: 3821.00 RPM | Error: 179.00 RPM | PWM: 261.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1942.08s | Desired: 4000.00 RPM | Measured: 3590.00 RPM | Error: 410.00 RPM | PWM: 784.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1943.12s | Desired: 4000.00 RPM | Measured: 3673.00 RPM | Error: 327.00 RPM | PWM: 494.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1944.15s | Desired: 4000.00 RPM | Measured: 3850.00 RPM | Error: 150.00 RPM | PWM: 164.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1945.19s | Desired: 4000.00 RPM | Measured: 3759.00 RPM | Error: 241.00 RPM | PWM: 443.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1946.23s | Desired: 4000.00 RPM | Measured: 3742.00 RPM | Error: 258.00 RPM | PWM: 434.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1947.26s | Desired: 4000.00 RPM | Measured: 3735.00 RPM | Error: 265.00 RPM | PWM: 440.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1948.29s | Desired: 4000.00 RPM | Measured: 3731.00 RPM | Error: 269.00 RPM | PWM: 445.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1949.33s | Desired: 4000.00 RPM | Measured: 3880.00 RPM | Error: 120.00 RPM | PWM: 130.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1950.36s | Desired: 4000.00 RPM | Measured: 3768.00 RPM | Error: 232.00 RPM | PWM: 439.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1951.41s | Desired: 4000.00 RPM | Measured: 3882.00 RPM | Error: 118.00 RPM | PWM: 144.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1952.44s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 478.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1953.46s | Desired: 4000.00 RPM | Measured: 3711.00 RPM | Error: 289.00 RPM | PWM: 494.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1954.51s | Desired: 4000.00 RPM | Measured: 3559.00 RPM | Error: 441.00 RPM | PWM: 794.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1955.54s | Desired: 4000.00 RPM | Measured: 3739.00 RPM | Error: 261.00 RPM | PWM: 340.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1956.57s | Desired: 4000.00 RPM | Measured: 3762.00 RPM | Error: 238.00 RPM | PWM: 382.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1957.60s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 401.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1958.64s | Desired: 4000.00 RPM | Measured: 3879.00 RPM | Error: 121.00 RPM | PWM: 145.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1959.67s | Desired: 4000.00 RPM | Measured: 3143.00 RPM | Error: 857.00 RPM | PWM: 1751.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1960.70s | Desired: 4000.00 RPM | Measured: 3617.00 RPM | Error: 383.00 RPM | PWM: 388.55000000000007 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1961.74s | Desired: 4000.00 RPM | Measured: 2758.00 RPM | Error: 1242.00 RPM | PWM: 2429.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1962.77s | Desired: 4000.00 RPM | Measured: 3570.00 RPM | Error: 430.00 RPM | PWM: 294.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1963.82s | Desired: 4000.00 RPM | Measured: 3761.00 RPM | Error: 239.00 RPM | PWM: 299.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1964.84s | Desired: 4000.00 RPM | Measured: 3622.00 RPM | Error: 378.00 RPM | PWM: 687.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1965.87s | Desired: 4000.00 RPM | Measured: 3851.00 RPM | Error: 149.00 RPM | PWM: 136.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1966.91s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 389.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1967.94s | Desired: 4000.00 RPM | Measured: 3767.00 RPM | Error: 233.00 RPM | PWM: 394.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1968.98s | Desired: 4000.00 RPM | Measured: 3761.00 RPM | Error: 239.00 RPM | PWM: 398.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1970.01s | Desired: 4000.00 RPM | Measured: 3854.00 RPM | Error: 146.00 RPM | PWM: 199.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1971.05s | Desired: 4000.00 RPM | Measured: 3103.00 RPM | Error: 897.00 RPM | PWM: 1823.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1972.08s | Desired: 4000.00 RPM | Measured: 3640.00 RPM | Error: 360.00 RPM | PWM: 320.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1973.11s | Desired: 4000.00 RPM | Measured: 3786.00 RPM | Error: 214.00 RPM | PWM: 282.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1974.15s | Desired: 4000.00 RPM | Measured: 3940.00 RPM | Error: 60.00 RPM | PWM: 31.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1975.19s | Desired: 4000.00 RPM | Measured: 3809.00 RPM | Error: 191.00 RPM | PWM: 383.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1976.23s | Desired: 4000.00 RPM | Measured: 3794.00 RPM | Error: 206.00 RPM | PWM: 349.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1977.26s | Desired: 4000.00 RPM | Measured: 3813.00 RPM | Error: 187.00 RPM | PWM: 302.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1978.29s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 444.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1979.32s | Desired: 4000.00 RPM | Measured: 3796.00 RPM | Error: 204.00 RPM | PWM: 316.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1980.36s | Desired: 4000.00 RPM | Measured: 3970.00 RPM | Error: 30.00 RPM | PWM: -26.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1981.38s | Desired: 4000.00 RPM | Measured: 3847.00 RPM | Error: 153.00 RPM | PWM: 319.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1982.43s | Desired: 4000.00 RPM | Measured: 3765.00 RPM | Error: 235.00 RPM | PWM: 429.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1983.46s | Desired: 4000.00 RPM | Measured: 3756.00 RPM | Error: 244.00 RPM | PWM: 407.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1984.49s | Desired: 4000.00 RPM | Measured: 3541.00 RPM | Error: 459.00 RPM | PWM: 854.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1985.52s | Desired: 4000.00 RPM | Measured: 3821.00 RPM | Error: 179.00 RPM | PWM: 159.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1986.56s | Desired: 4000.00 RPM | Measured: 3873.00 RPM | Error: 127.00 RPM | PWM: 189.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1987.59s | Desired: 4000.00 RPM | Measured: 3865.00 RPM | Error: 135.00 RPM | PWM: 232.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1988.64s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 470.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1989.66s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 538.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1990.70s | Desired: 4000.00 RPM | Measured: 3664.00 RPM | Error: 336.00 RPM | PWM: 563.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1991.74s | Desired: 4000.00 RPM | Measured: 3665.00 RPM | Error: 335.00 RPM | PWM: 548.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1992.76s | Desired: 4000.00 RPM | Measured: 3663.00 RPM | Error: 337.00 RPM | PWM: 552.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1993.79s | Desired: 4000.00 RPM | Measured: 3676.00 RPM | Error: 324.00 RPM | PWM: 524.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1994.83s | Desired: 4000.00 RPM | Measured: 3697.00 RPM | Error: 303.00 RPM | PWM: 487.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1995.86s | Desired: 4000.00 RPM | Measured: 3777.00 RPM | Error: 223.00 RPM | PWM: 329.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1996.91s | Desired: 4000.00 RPM | Measured: 3822.00 RPM | Error: 178.00 RPM | PWM: 275.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1997.94s | Desired: 4000.00 RPM | Measured: 3828.00 RPM | Error: 172.00 RPM | PWM: 284.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 1998.98s | Desired: 4000.00 RPM | Measured: 3675.00 RPM | Error: 325.00 RPM | PWM: 609.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 2000.01s | Desired: 4000.00 RPM | Measured: 3692.00 RPM | Error: 308.00 RPM | PWM: 497.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Data saved to PID_motor_data_20250404_231328.csv
# Speed plot saved to PID_motor_plot_speed_20250404_231328.pdf
# PID gains plot saved to PID_motor_plot_gains_20250404_231328.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime
import uuid  # Import UUID for unique filenames

import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

# Define whether ANN is enabled or not
ANN_enabled = True  # Set to True if ANN is used, False otherwise

# Convert lists to NumPy arrays for performance calculations
time_stamps = np.array(times)  # Recorded time points
error = np.array(errors)
setpoints = np.array([desired_speed] * len(times))  # Setpoints stored as an array
speeds = np.array(speeds)

# Compute Performance Metrics
rmse = np.sqrt(np.mean(error ** 2))  # Root Mean Square Error
mae = np.mean(np.abs(error))  # Mean Absolute Error
SSE = error[-1]  # Last recorded steady-state error
max_speed = max(speeds)  # Maximum speed recorded
overshoot = max(0, ((max_speed - desired_speed) / desired_speed) * 100)  # Percentage overshoot

# Settling Time (Ts)
within_tolerance = np.abs(error) < (0.05 * desired_speed)  # Define ±5% tolerance band
Ts_index = np.argmax(within_tolerance) if np.any(within_tolerance) else -1
Ts = time_stamps[Ts_index] if Ts_index != -1 else None  # First time where error is within ±5%

# Print Summary of Performance Metrics
print("Performance Metrics:")
print(f"Root Mean Square Error (RMSE): {rmse:.2f} RPM")
print(f"Mean Absolute Error (MAE): {mae:.2f} RPM")
print(f"Steady-State Error (SSE): {SSE:.2f} RPM")
print(f"Maximum Speed: {max_speed:.2f} RPM")
print(f"Overshoot: {overshoot:.2f}%")
print(f"Settling Time (Ts): {Ts:.2f} seconds" if Ts else "Settling Time (Ts): Not achieved within the runtime.")

# Generate Performance Plots and Save with explicit names
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")  # Format: YYYYMMDD_HHMMSS
identifier = "With_ANN" if ANN_enabled else "No_ANN"  # Condition-based identifier
unique_id = uuid.uuid4().hex[:8]  # Generates an 8-character unique ID

# 1. Histogram of Errors
hist_filename = f"Histogram_Errors_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.hist(error, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Error (RPM)", fontsize=16)
plt.ylabel("Frequency", fontsize=16)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(hist_filename, format="pdf", bbox_inches="tight")
plt.show()

# 2. RMSE & MAE Comparison
rmse_mae_filename = f"RMSE_MAE_Comparison_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["RMSE", "MAE"], [rmse, mae], color=['red', 'orange'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(rmse_mae_filename, format="pdf", bbox_inches="tight")
plt.show()

# 3. Overshoot & Steady-State Error
overshoot_sse_filename = f"Overshoot_SSE_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["Overshoot (%)", "SSE"], [overshoot, SSE], color=['purple', 'green'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)

# Apply Scientific Notation for the Y-axis
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)
plt.savefig(overshoot_sse_filename, format="pdf", bbox_inches="tight")
plt.show()

# Print saved filenames
print(f"Histogram of Errors saved as {hist_filename}")
print(f"RMSE & MAE Comparison saved as {rmse_mae_filename}")
print(f"Overshoot & Steady-State Error saved as {overshoot_sse_filename}")
# Out:
# Performance Metrics:
# Root Mean Square Error (RMSE): 369.22 RPM
# Mean Absolute Error (MAE): 316.57 RPM
# Steady-State Error (SSE): 308.00 RPM
# Maximum Speed: 4067.00 RPM
# Overshoot: 1.68%
# Settling Time (Ts): 40.15 seconds
# Histogram of Errors saved as Histogram_Errors_With_ANN_20250404_234754_414ced7f.pdf
# RMSE & MAE Comparison saved as RMSE_MAE_Comparison_With_ANN_20250404_234754_414ced7f.pdf
# Overshoot & Steady-State Error saved as Overshoot_SSE_With_ANN_20250404_234754_414ced7f.pdf

# %% [markdown]
# # Enhanced PID Control program with ANN-enabled Self-tuning:

# %%
import serial
import time
import csv
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime

# Initialize Serial Communication (Update COM Port)
ser = serial.Serial('COM3', 115200, timeout=0.1)

# PID Initial Parameters
Kp, Ki, Kd = 1.0, 0.05, 0.5
desired_speed = float(input("Enter desired motor speed (RPM): "))
runtime = float(input("Enter duration for PID control (seconds): "))
ann_start_time = runtime * 0.2  # ANN starts optimizing after 20% of runtime

# Define ANN Model (PyTorch)
class PIDANN(nn.Module):
    def __init__(self):
        super(PIDANN, self).__init__()
        self.fc1 = nn.Linear(5, 16)  # 5 Inputs -> 16 Neurons
        self.fc2 = nn.Linear(16, 16)  # Hidden layer
        self.fc3 = nn.Linear(16, 3)  # 3 Outputs (Kp, Ki, Kd)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)  # No activation (raw values)
        return x

# Initialize ANN Model
model = PIDANN()
optimizer = optim.Adam(model.parameters(), lr=0.01)
loss_function = nn.MSELoss()

# Data Logging
times, speeds, errors, pwm_outputs = [], [], [], []
kp_values, ki_values, kd_values, loss_values = [], [], [], []
start_time = time.time()
history = []  # Training Buffer
history_size = int(runtime * 0.1)  # Keep last nth data points for ANN training--10% size of run time

# Generate dynamic filenames for CSV and PDF
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"motor_speed_data_ANN_{current_datetime}.csv"
pdf_filename_speed = f"motor_speed_plot_speed_ANN_{current_datetime}.pdf"
pdf_filename_gains = f"motor_speed_plot_gains_ANN_{current_datetime}.pdf"
pdf_filename_loss = f"motor_speed_plot_loss_ANN_{current_datetime}.pdf"

# CSV File Setup
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Time (s)", "Desired Speed (RPM)", "Measured Speed (RPM)", "Error (RPM)", 
                     "PWM Output", "Kp", "Ki", "Kd", "Loss"])  # CSV Header

def pid_control(measured_speed, elapsed_time):
    """Compute PID control signal."""
    global Kp, Ki, Kd, history

    error = desired_speed - measured_speed
    delta_error = error - errors[-1] if errors else 0
    control_signal = (Kp * error) + (Ki * sum(errors[-history_size:])) + (Kd * delta_error)

    # ANN Optimization only after 20% runtime
    if elapsed_time >= ann_start_time and len(history) > 10:
        inputs = np.array([len(errors), desired_speed, measured_speed, error, control_signal], dtype=np.float32)
        inputs_tensor = torch.tensor(inputs, dtype=torch.float32)

        with torch.no_grad():
            output_tensor = model(inputs_tensor)

        Kp, Ki, Kd = output_tensor.numpy()

        # Apply constraints
        Kp = max(0.0, min(Kp, 50.0))
        Ki = max(0.0, min(Ki, 25.0))
        Kd = max(0.0, min(Kd, 25.0))

    # Train the ANN Online only after given runtime (e.g., 20% runtime)
    if elapsed_time >= ann_start_time:
        history.append([len(errors), desired_speed, measured_speed, error, control_signal, Kp, Ki, Kd])
        if len(history) > history_size:
            history.pop(0)

        x_train = torch.tensor([h[:-3] for h in history], dtype=torch.float32)
        y_train = torch.tensor([h[-3:] for h in history], dtype=torch.float32)

        optimizer.zero_grad()
        prediction = model(x_train)
        loss = loss_function(prediction, y_train)
        loss.backward()
        optimizer.step()

        loss_value = loss.item()
        loss_values.append(loss_value)
    else:
        loss_value = 0  # Before 20% runtime, no ANN training

    return control_signal, loss_value

# Main Control Loop
while time.time() - start_time < runtime:
    response = ser.readline().decode().strip()
    if response:
        measured_speed = float(response)  # Measured speed in RPM
        elapsed_time = time.time() - start_time
        
        # Compute PID output with ANN tuning only after 20% runtime
        pwm_output, loss_value = pid_control(measured_speed, elapsed_time)
        ser.write(f"{pwm_output}\n".encode())  # Send PWM to Arduino

        # Store Data
        times.append(elapsed_time)
        speeds.append(measured_speed)
        errors.append(desired_speed - measured_speed)
        pwm_outputs.append(pwm_output)
        kp_values.append(Kp)
        ki_values.append(Ki)
        kd_values.append(Kd)

        # Save to CSV
        with open(csv_filename, mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([elapsed_time, desired_speed, measured_speed, errors[-1], pwm_output, 
                             Kp, Ki, Kd, loss_value])

        # Print data in real-time
        print(f"Time: {elapsed_time:.2f}s | Desired: {desired_speed:.2f} RPM | Measured: {measured_speed:.2f} RPM | "
              f"Error: {errors[-1]:.2f} RPM | PWM: {pwm_output} | Kp: {Kp:.3f} | Ki: {Ki:.3f} | "
              f"Kd: {Kd:.3f} | Loss: {loss_value:.6f}")

ser.close()

# Generate Measured Speed & Error Plot
plt.figure(figsize=(7, 6))
plt.plot(times, speeds, label="Measured Speed (RPM)", color="b", linewidth=2)
plt.plot(times, errors, label="Error", color="r", linewidth=2)
plt.plot(times, [desired_speed] * len(times), label="Desired Speed (RPM)", color="g", linestyle="--", linewidth=2)

# Add shaded threshold region
threshold_lower = desired_speed * 0.95  # Lower bound of ±5% threshold
threshold_upper = desired_speed * 1.05  # Upper bound of ±5% threshold
plt.fill_between(times, threshold_lower, threshold_upper, color="gray", alpha=0.3, label="±5% Threshold")

# Add settling time marker
if Ts:
    plt.axvline(Ts, color="black", linestyle="--", linewidth=2, label=f"Settling Time: {Ts:.2f}s")
    #plt.text(Ts, desired_speed, f"  Ts = {Ts:.2f}s", fontsize=12, color="black", va="bottom")

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Speed (RPM)", fontsize=16)
#plt.title("Measured Speed and Error for PID Control with ANN", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_speed, format="pdf")
plt.show()

# Generate PID Gains Plot
plt.figure(figsize=(7, 6))
plt.plot(times, kp_values, label="Kp", color="m", linewidth=2)
plt.plot(times, ki_values, label="Ki", color="c", linewidth=2, alpha=0.6)
plt.plot(times, kd_values, label="Kd", color="y", linewidth=2, alpha=0.6)

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("PID Gains", fontsize=16)
#plt.title("ANN-PID Gains Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_gains, format="pdf")
plt.show()

# Generate Loss Plot
plt.figure(figsize=(7, 6))
plt.plot(times[:len(loss_values)], loss_values, label="Loss (MSE)", color="orange", linewidth=2)

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Loss (MSE)", fontsize=16)
#plt.title("ANN Training Loss Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_loss, format="pdf")
plt.show()

# Final Outputs
print(f"Data saved to {csv_filename}")
print(f"Measured Speed plot saved to {pdf_filename_speed}")
print(f"PID Gains plot saved to {pdf_filename_gains}")
print(f"Loss plot saved to {pdf_filename_loss}")
# Out:
# Enter desired motor speed (RPM): 4000
# Enter duration for PID control (seconds): 2000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 7800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 9000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 9200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 9400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 9600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 9800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 10000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 10200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 10400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 10600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 10800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 11000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 1.22s | Desired: 4000.00 RPM | Measured: 3440.00 RPM | Error: 560.00 RPM | PWM: 6040.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 2.26s | Desired: 4000.00 RPM | Measured: 3873.00 RPM | Error: 127.00 RPM | PWM: 7138.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 3.29s | Desired: 4000.00 RPM | Measured: 3795.00 RPM | Error: 205.00 RPM | PWM: 7478.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 4.31s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 7505.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 5.36s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 7462.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 6.39s | Desired: 4000.00 RPM | Measured: 3018.00 RPM | Error: 982.00 RPM | PWM: 8631.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 7.42s | Desired: 4000.00 RPM | Measured: 3684.00 RPM | Error: 316.00 RPM | PWM: 7299.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 8.46s | Desired: 4000.00 RPM | Measured: 3033.00 RPM | Error: 967.00 RPM | PWM: 8625.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 9.49s | Desired: 4000.00 RPM | Measured: 3855.00 RPM | Error: 145.00 RPM | PWM: 7114.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 10.53s | Desired: 4000.00 RPM | Measured: 3842.00 RPM | Error: 158.00 RPM | PWM: 7552.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 11.56s | Desired: 4000.00 RPM | Measured: 3812.00 RPM | Error: 188.00 RPM | PWM: 7599.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 12.60s | Desired: 4000.00 RPM | Measured: 3969.00 RPM | Error: 31.00 RPM | PWM: 7357.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 13.64s | Desired: 4000.00 RPM | Measured: 3528.00 RPM | Error: 472.00 RPM | PWM: 8099.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 14.67s | Desired: 4000.00 RPM | Measured: 3629.00 RPM | Error: 371.00 RPM | PWM: 7751.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 15.70s | Desired: 4000.00 RPM | Measured: 3751.00 RPM | Error: 249.00 RPM | PWM: 7637.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 16.73s | Desired: 4000.00 RPM | Measured: 3749.00 RPM | Error: 251.00 RPM | PWM: 7713.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 17.77s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 7717.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 18.80s | Desired: 4000.00 RPM | Measured: 3806.00 RPM | Error: 194.00 RPM | PWM: 7654.400000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 19.84s | Desired: 4000.00 RPM | Measured: 3948.00 RPM | Error: 52.00 RPM | PWM: 7477.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 20.88s | Desired: 4000.00 RPM | Measured: 3820.00 RPM | Error: 180.00 RPM | PWM: 7742.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 21.91s | Desired: 4000.00 RPM | Measured: 3037.00 RPM | Error: 963.00 RPM | PWM: 8862.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 22.94s | Desired: 4000.00 RPM | Measured: 3685.00 RPM | Error: 315.00 RPM | PWM: 7546.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 23.99s | Desired: 4000.00 RPM | Measured: 3763.00 RPM | Error: 237.00 RPM | PWM: 7769.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 25.01s | Desired: 4000.00 RPM | Measured: 3743.00 RPM | Error: 257.00 RPM | PWM: 7850.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 26.05s | Desired: 4000.00 RPM | Measured: 3649.00 RPM | Error: 351.00 RPM | PWM: 7994.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 27.08s | Desired: 4000.00 RPM | Measured: 3724.00 RPM | Error: 276.00 RPM | PWM: 7852.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 28.13s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 7816.650000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 29.14s | Desired: 4000.00 RPM | Measured: 3947.00 RPM | Error: 53.00 RPM | PWM: 7609.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 30.19s | Desired: 4000.00 RPM | Measured: 3797.00 RPM | Error: 203.00 RPM | PWM: 7919.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 31.23s | Desired: 4000.00 RPM | Measured: 3972.00 RPM | Error: 28.00 RPM | PWM: 7591.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 32.26s | Desired: 4000.00 RPM | Measured: 3834.00 RPM | Error: 166.00 RPM | PWM: 7887.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 33.29s | Desired: 4000.00 RPM | Measured: 3780.00 RPM | Error: 220.00 RPM | PWM: 7908.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 34.33s | Desired: 4000.00 RPM | Measured: 3781.00 RPM | Error: 219.00 RPM | PWM: 7890.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 35.37s | Desired: 4000.00 RPM | Measured: 3810.00 RPM | Error: 190.00 RPM | PWM: 7858.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 36.39s | Desired: 4000.00 RPM | Measured: 3751.00 RPM | Error: 249.00 RPM | PWM: 7971.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 37.43s | Desired: 4000.00 RPM | Measured: 3906.00 RPM | Error: 94.00 RPM | PWM: 7721.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 38.46s | Desired: 4000.00 RPM | Measured: 3649.00 RPM | Error: 351.00 RPM | PWM: 8189.150000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 39.50s | Desired: 4000.00 RPM | Measured: 2963.00 RPM | Error: 1037.00 RPM | PWM: 9107.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 40.53s | Desired: 4000.00 RPM | Measured: 3611.00 RPM | Error: 389.00 RPM | PWM: 7844.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 41.56s | Desired: 4000.00 RPM | Measured: 3786.00 RPM | Error: 214.00 RPM | PWM: 7925.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 42.59s | Desired: 4000.00 RPM | Measured: 3943.00 RPM | Error: 57.00 RPM | PWM: 7787.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 43.63s | Desired: 4000.00 RPM | Measured: 3065.00 RPM | Error: 935.00 RPM | PWM: 9186.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 44.66s | Desired: 4000.00 RPM | Measured: 3664.00 RPM | Error: 336.00 RPM | PWM: 7895.299999999999 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 45.69s | Desired: 4000.00 RPM | Measured: 3958.00 RPM | Error: 42.00 RPM | PWM: 7770.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 46.73s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 8176.200000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 47.76s | Desired: 4000.00 RPM | Measured: 3922.00 RPM | Error: 78.00 RPM | PWM: 7898.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 48.80s | Desired: 4000.00 RPM | Measured: 3759.00 RPM | Error: 241.00 RPM | PWM: 8214.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 49.83s | Desired: 4000.00 RPM | Measured: 3725.00 RPM | Error: 275.00 RPM | PWM: 8196.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 50.86s | Desired: 4000.00 RPM | Measured: 3739.00 RPM | Error: 261.00 RPM | PWM: 8172.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 51.89s | Desired: 4000.00 RPM | Measured: 3736.00 RPM | Error: 264.00 RPM | PWM: 8196.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 52.92s | Desired: 4000.00 RPM | Measured: 3766.00 RPM | Error: 234.00 RPM | PWM: 8163.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 53.97s | Desired: 4000.00 RPM | Measured: 3756.00 RPM | Error: 244.00 RPM | PWM: 8205.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 55.01s | Desired: 4000.00 RPM | Measured: 3923.00 RPM | Error: 77.00 RPM | PWM: 7961.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 56.03s | Desired: 4000.00 RPM | Measured: 3042.00 RPM | Error: 958.00 RPM | PWM: 9370.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 57.08s | Desired: 4000.00 RPM | Measured: 3579.00 RPM | Error: 421.00 RPM | PWM: 8172.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 58.11s | Desired: 4000.00 RPM | Measured: 3601.00 RPM | Error: 399.00 RPM | PWM: 8429.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 59.14s | Desired: 4000.00 RPM | Measured: 3900.00 RPM | Error: 100.00 RPM | PWM: 8011.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 60.18s | Desired: 4000.00 RPM | Measured: 3668.00 RPM | Error: 332.00 RPM | PWM: 8513.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 61.21s | Desired: 4000.00 RPM | Measured: 3741.00 RPM | Error: 259.00 RPM | PWM: 8305.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 62.24s | Desired: 4000.00 RPM | Measured: 3768.00 RPM | Error: 232.00 RPM | PWM: 8314.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 63.28s | Desired: 4000.00 RPM | Measured: 3977.00 RPM | Error: 23.00 RPM | PWM: 8025.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 64.31s | Desired: 4000.00 RPM | Measured: 3777.00 RPM | Error: 223.00 RPM | PWM: 8431.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 65.34s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 8343.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 66.39s | Desired: 4000.00 RPM | Measured: 3484.00 RPM | Error: 516.00 RPM | PWM: 8792.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 67.42s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 8267.400000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 68.44s | Desired: 4000.00 RPM | Measured: 3926.00 RPM | Error: 74.00 RPM | PWM: 8156.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 69.49s | Desired: 4000.00 RPM | Measured: 3087.00 RPM | Error: 913.00 RPM | PWM: 9504.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 70.53s | Desired: 4000.00 RPM | Measured: 3336.00 RPM | Error: 664.00 RPM | PWM: 8757.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 71.56s | Desired: 4000.00 RPM | Measured: 3859.00 RPM | Error: 141.00 RPM | PWM: 8130.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 72.59s | Desired: 4000.00 RPM | Measured: 3781.00 RPM | Error: 219.00 RPM | PWM: 8516.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 73.63s | Desired: 4000.00 RPM | Measured: 3925.00 RPM | Error: 75.00 RPM | PWM: 8272.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 74.66s | Desired: 4000.00 RPM | Measured: 3779.00 RPM | Error: 221.00 RPM | PWM: 8567.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 75.69s | Desired: 4000.00 RPM | Measured: 3906.00 RPM | Error: 94.00 RPM | PWM: 8314.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 76.72s | Desired: 4000.00 RPM | Measured: 3936.00 RPM | Error: 64.00 RPM | PWM: 8337.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 77.76s | Desired: 4000.00 RPM | Measured: 3751.00 RPM | Error: 249.00 RPM | PWM: 8633.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 78.80s | Desired: 4000.00 RPM | Measured: 3692.00 RPM | Error: 308.00 RPM | PWM: 8641.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 79.83s | Desired: 4000.00 RPM | Measured: 3745.00 RPM | Error: 255.00 RPM | PWM: 8548.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 80.86s | Desired: 4000.00 RPM | Measured: 3882.00 RPM | Error: 118.00 RPM | PWM: 8382.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 81.89s | Desired: 4000.00 RPM | Measured: 2767.00 RPM | Error: 1233.00 RPM | PWM: 10128.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 82.93s | Desired: 4000.00 RPM | Measured: 3567.00 RPM | Error: 433.00 RPM | PWM: 8433.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 83.98s | Desired: 4000.00 RPM | Measured: 3740.00 RPM | Error: 260.00 RPM | PWM: 8595.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 85.00s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 8714.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 86.04s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 8686.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 87.07s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 8658.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 88.11s | Desired: 4000.00 RPM | Measured: 3764.00 RPM | Error: 236.00 RPM | PWM: 8718.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 89.14s | Desired: 4000.00 RPM | Measured: 3775.00 RPM | Error: 225.00 RPM | PWM: 8702.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 90.18s | Desired: 4000.00 RPM | Measured: 3728.00 RPM | Error: 272.00 RPM | PWM: 8790.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 91.21s | Desired: 4000.00 RPM | Measured: 3737.00 RPM | Error: 263.00 RPM | PWM: 8766.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 92.24s | Desired: 4000.00 RPM | Measured: 3241.00 RPM | Error: 759.00 RPM | PWM: 9528.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 93.28s | Desired: 4000.00 RPM | Measured: 3657.00 RPM | Error: 343.00 RPM | PWM: 8694.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 94.31s | Desired: 4000.00 RPM | Measured: 3735.00 RPM | Error: 265.00 RPM | PWM: 8802.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 95.34s | Desired: 4000.00 RPM | Measured: 3912.00 RPM | Error: 88.00 RPM | PWM: 8589.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 96.38s | Desired: 4000.00 RPM | Measured: 3945.00 RPM | Error: 55.00 RPM | PWM: 8632.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 97.41s | Desired: 4000.00 RPM | Measured: 3772.00 RPM | Error: 228.00 RPM | PWM: 8911.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 98.45s | Desired: 4000.00 RPM | Measured: 3709.00 RPM | Error: 291.00 RPM | PWM: 8930.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 99.49s | Desired: 4000.00 RPM | Measured: 3705.00 RPM | Error: 295.00 RPM | PWM: 8919.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 100.52s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 8899.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 101.55s | Desired: 4000.00 RPM | Measured: 3696.00 RPM | Error: 304.00 RPM | PWM: 8970.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 102.59s | Desired: 4000.00 RPM | Measured: 3205.00 RPM | Error: 795.00 RPM | PWM: 9707.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 103.63s | Desired: 4000.00 RPM | Measured: 3791.00 RPM | Error: 209.00 RPM | PWM: 8622.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 104.66s | Desired: 4000.00 RPM | Measured: 3752.00 RPM | Error: 248.00 RPM | PWM: 8984.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 105.69s | Desired: 4000.00 RPM | Measured: 3713.00 RPM | Error: 287.00 RPM | PWM: 9035.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 106.74s | Desired: 4000.00 RPM | Measured: 3725.00 RPM | Error: 275.00 RPM | PWM: 9012.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 107.76s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 9026.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 108.80s | Desired: 4000.00 RPM | Measured: 3753.00 RPM | Error: 247.00 RPM | PWM: 9005.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 109.84s | Desired: 4000.00 RPM | Measured: 3744.00 RPM | Error: 256.00 RPM | PWM: 9043.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 110.88s | Desired: 4000.00 RPM | Measured: 3717.00 RPM | Error: 283.00 RPM | PWM: 9092.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 111.91s | Desired: 4000.00 RPM | Measured: 3713.00 RPM | Error: 287.00 RPM | PWM: 9099.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 112.94s | Desired: 4000.00 RPM | Measured: 2819.00 RPM | Error: 1181.00 RPM | PWM: 10452.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 113.97s | Desired: 4000.00 RPM | Measured: 3547.00 RPM | Error: 453.00 RPM | PWM: 8972.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 115.02s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 9048.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 116.05s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 9114.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 117.09s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 9149.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 118.11s | Desired: 4000.00 RPM | Measured: 3957.00 RPM | Error: 43.00 RPM | PWM: 8895.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 119.14s | Desired: 4000.00 RPM | Measured: 3799.00 RPM | Error: 201.00 RPM | PWM: 9222.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 120.19s | Desired: 4000.00 RPM | Measured: 3786.00 RPM | Error: 214.00 RPM | PWM: 9172.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 121.22s | Desired: 4000.00 RPM | Measured: 3789.00 RPM | Error: 211.00 RPM | PWM: 9172.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 122.26s | Desired: 4000.00 RPM | Measured: 3800.00 RPM | Error: 200.00 RPM | PWM: 9167.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 123.28s | Desired: 4000.00 RPM | Measured: 3752.00 RPM | Error: 248.00 RPM | PWM: 9255.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 124.33s | Desired: 4000.00 RPM | Measured: 3788.00 RPM | Error: 212.00 RPM | PWM: 9189.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 125.36s | Desired: 4000.00 RPM | Measured: 3241.00 RPM | Error: 759.00 RPM | PWM: 10038.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 126.39s | Desired: 4000.00 RPM | Measured: 3711.00 RPM | Error: 289.00 RPM | PWM: 9098.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 127.43s | Desired: 4000.00 RPM | Measured: 3781.00 RPM | Error: 219.00 RPM | PWM: 9242.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 128.47s | Desired: 4000.00 RPM | Measured: 3244.00 RPM | Error: 756.00 RPM | PWM: 10094.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 129.50s | Desired: 4000.00 RPM | Measured: 3673.00 RPM | Error: 327.00 RPM | PWM: 9220.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 130.53s | Desired: 4000.00 RPM | Measured: 2773.00 RPM | Error: 1227.00 RPM | PWM: 10800.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 131.56s | Desired: 4000.00 RPM | Measured: 3536.00 RPM | Error: 464.00 RPM | PWM: 9267.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 132.60s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 9345.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 133.64s | Desired: 4000.00 RPM | Measured: 3752.00 RPM | Error: 248.00 RPM | PWM: 9469.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 134.68s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 9445.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 135.71s | Desired: 4000.00 RPM | Measured: 3789.00 RPM | Error: 211.00 RPM | PWM: 9448.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 136.74s | Desired: 4000.00 RPM | Measured: 3774.00 RPM | Error: 226.00 RPM | PWM: 9488.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 137.79s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 9489.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 138.82s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 9492.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 139.85s | Desired: 4000.00 RPM | Measured: 3773.00 RPM | Error: 227.00 RPM | PWM: 9519.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 140.89s | Desired: 4000.00 RPM | Measured: 3258.00 RPM | Error: 742.00 RPM | PWM: 10299.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 141.93s | Desired: 4000.00 RPM | Measured: 3719.00 RPM | Error: 281.00 RPM | PWM: 9387.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 142.96s | Desired: 4000.00 RPM | Measured: 3793.00 RPM | Error: 207.00 RPM | PWM: 9520.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 143.99s | Desired: 4000.00 RPM | Measured: 3291.00 RPM | Error: 709.00 RPM | PWM: 10321.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 145.02s | Desired: 4000.00 RPM | Measured: 3554.00 RPM | Error: 446.00 RPM | PWM: 9711.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 146.06s | Desired: 4000.00 RPM | Measured: 3675.00 RPM | Error: 325.00 RPM | PWM: 9683.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 147.10s | Desired: 4000.00 RPM | Measured: 3697.00 RPM | Error: 303.00 RPM | PWM: 9727.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 148.13s | Desired: 4000.00 RPM | Measured: 3753.00 RPM | Error: 247.00 RPM | PWM: 9669.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 149.15s | Desired: 4000.00 RPM | Measured: 3884.00 RPM | Error: 116.00 RPM | PWM: 9513.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 150.19s | Desired: 4000.00 RPM | Measured: 3738.00 RPM | Error: 262.00 RPM | PWM: 9803.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 151.22s | Desired: 4000.00 RPM | Measured: 3726.00 RPM | Error: 274.00 RPM | PWM: 9761.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 152.26s | Desired: 4000.00 RPM | Measured: 3836.00 RPM | Error: 164.00 RPM | PWM: 9604.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 153.30s | Desired: 4000.00 RPM | Measured: 3719.00 RPM | Error: 281.00 RPM | PWM: 9842.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 154.33s | Desired: 4000.00 RPM | Measured: 3691.00 RPM | Error: 309.00 RPM | PWM: 9840.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 155.36s | Desired: 4000.00 RPM | Measured: 3668.00 RPM | Error: 332.00 RPM | PWM: 9876.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 156.39s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 9848.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 157.43s | Desired: 4000.00 RPM | Measured: 3820.00 RPM | Error: 180.00 RPM | PWM: 9680.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 158.46s | Desired: 4000.00 RPM | Measured: 2672.00 RPM | Error: 1328.00 RPM | PWM: 11476.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 159.50s | Desired: 4000.00 RPM | Measured: 2422.00 RPM | Error: 1578.00 RPM | PWM: 11343.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 160.54s | Desired: 4000.00 RPM | Measured: 3532.00 RPM | Error: 468.00 RPM | PWM: 9632.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 161.56s | Desired: 4000.00 RPM | Measured: 3706.00 RPM | Error: 294.00 RPM | PWM: 9949.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 162.61s | Desired: 4000.00 RPM | Measured: 3695.00 RPM | Error: 305.00 RPM | PWM: 10067.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 163.64s | Desired: 4000.00 RPM | Measured: 3685.00 RPM | Error: 315.00 RPM | PWM: 10092.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 164.68s | Desired: 4000.00 RPM | Measured: 3695.00 RPM | Error: 305.00 RPM | PWM: 10088.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 165.71s | Desired: 4000.00 RPM | Measured: 3712.00 RPM | Error: 288.00 RPM | PWM: 10083.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 166.74s | Desired: 4000.00 RPM | Measured: 3682.00 RPM | Error: 318.00 RPM | PWM: 10151.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 167.77s | Desired: 4000.00 RPM | Measured: 3683.00 RPM | Error: 317.00 RPM | PWM: 10150.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 168.82s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 10072.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 169.84s | Desired: 4000.00 RPM | Measured: 3738.00 RPM | Error: 262.00 RPM | PWM: 10128.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 170.89s | Desired: 4000.00 RPM | Measured: 3940.00 RPM | Error: 60.00 RPM | PWM: 9834.650000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 171.93s | Desired: 4000.00 RPM | Measured: 3956.00 RPM | Error: 44.00 RPM | PWM: 9714.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 172.96s | Desired: 4000.00 RPM | Measured: 3823.00 RPM | Error: 177.00 RPM | PWM: 9724.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 173.99s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 9520.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 175.03s | Desired: 4000.00 RPM | Measured: 3786.00 RPM | Error: 214.00 RPM | PWM: 9314.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 176.07s | Desired: 4000.00 RPM | Measured: 3805.00 RPM | Error: 195.00 RPM | PWM: 9096.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 177.10s | Desired: 4000.00 RPM | Measured: 4015.00 RPM | Error: -15.00 RPM | PWM: 8600.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 178.13s | Desired: 4000.00 RPM | Measured: 3443.00 RPM | Error: 557.00 RPM | PWM: 9363.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 179.16s | Desired: 4000.00 RPM | Measured: 2853.00 RPM | Error: 1147.00 RPM | PWM: 9789.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 180.20s | Desired: 4000.00 RPM | Measured: 3658.00 RPM | Error: 342.00 RPM | PWM: 8144.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 181.23s | Desired: 4000.00 RPM | Measured: 3825.00 RPM | Error: 175.00 RPM | PWM: 8113.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 182.26s | Desired: 4000.00 RPM | Measured: 3791.00 RPM | Error: 209.00 RPM | PWM: 8057.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 183.29s | Desired: 4000.00 RPM | Measured: 3789.00 RPM | Error: 211.00 RPM | PWM: 7853.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 184.33s | Desired: 4000.00 RPM | Measured: 3813.00 RPM | Error: 187.00 RPM | PWM: 7627.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 185.36s | Desired: 4000.00 RPM | Measured: 3807.00 RPM | Error: 193.00 RPM | PWM: 7457.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 186.39s | Desired: 4000.00 RPM | Measured: 3674.00 RPM | Error: 326.00 RPM | PWM: 7463.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 187.44s | Desired: 4000.00 RPM | Measured: 3734.00 RPM | Error: 266.00 RPM | PWM: 7123.400000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 188.48s | Desired: 4000.00 RPM | Measured: 3946.00 RPM | Error: 54.00 RPM | PWM: 6648.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 189.50s | Desired: 4000.00 RPM | Measured: 3103.00 RPM | Error: 897.00 RPM | PWM: 7821.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 190.54s | Desired: 4000.00 RPM | Measured: 3296.00 RPM | Error: 704.00 RPM | PWM: 6955.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 191.58s | Desired: 4000.00 RPM | Measured: 3716.00 RPM | Error: 284.00 RPM | PWM: 6257.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 192.61s | Desired: 4000.00 RPM | Measured: 3603.00 RPM | Error: 397.00 RPM | PWM: 6451.150000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 193.65s | Desired: 4000.00 RPM | Measured: 2971.00 RPM | Error: 1029.00 RPM | PWM: 7162.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 194.68s | Desired: 4000.00 RPM | Measured: 3519.00 RPM | Error: 481.00 RPM | PWM: 5875.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 195.73s | Desired: 4000.00 RPM | Measured: 3878.00 RPM | Error: 122.00 RPM | PWM: 5435.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 196.75s | Desired: 4000.00 RPM | Measured: 3714.00 RPM | Error: 286.00 RPM | PWM: 5667.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 197.80s | Desired: 4000.00 RPM | Measured: 3743.00 RPM | Error: 257.00 RPM | PWM: 5355.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 198.82s | Desired: 4000.00 RPM | Measured: 3429.00 RPM | Error: 571.00 RPM | PWM: 5654.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 199.86s | Desired: 4000.00 RPM | Measured: 3680.00 RPM | Error: 320.00 RPM | PWM: 4949.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 200.89s | Desired: 4000.00 RPM | Measured: 3759.00 RPM | Error: 241.00 RPM | PWM: 4772.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 201.93s | Desired: 4000.00 RPM | Measured: 3806.00 RPM | Error: 194.00 RPM | PWM: 4553.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 202.96s | Desired: 4000.00 RPM | Measured: 3789.00 RPM | Error: 211.00 RPM | PWM: 4412.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 203.99s | Desired: 4000.00 RPM | Measured: 3748.00 RPM | Error: 252.00 RPM | PWM: 4275.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 205.03s | Desired: 4000.00 RPM | Measured: 3798.00 RPM | Error: 202.00 RPM | PWM: 3992.7000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 206.07s | Desired: 4000.00 RPM | Measured: 2770.00 RPM | Error: 1230.00 RPM | PWM: 5369.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 207.10s | Desired: 4000.00 RPM | Measured: 3618.00 RPM | Error: 382.00 RPM | PWM: 3445.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 208.13s | Desired: 4000.00 RPM | Measured: 3754.00 RPM | Error: 246.00 RPM | PWM: 3484.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 209.16s | Desired: 4000.00 RPM | Measured: 3775.00 RPM | Error: 225.00 RPM | PWM: 3505.2000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 210.19s | Desired: 4000.00 RPM | Measured: 3556.00 RPM | Error: 444.00 RPM | PWM: 3849.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 211.23s | Desired: 4000.00 RPM | Measured: 3642.00 RPM | Error: 358.00 RPM | PWM: 3622.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 212.26s | Desired: 4000.00 RPM | Measured: 3771.00 RPM | Error: 229.00 RPM | PWM: 3477.8500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 213.31s | Desired: 4000.00 RPM | Measured: 3713.00 RPM | Error: 287.00 RPM | PWM: 3629.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 214.35s | Desired: 4000.00 RPM | Measured: 3737.00 RPM | Error: 263.00 RPM | PWM: 3530.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 215.36s | Desired: 4000.00 RPM | Measured: 3799.00 RPM | Error: 201.00 RPM | PWM: 3446.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 216.41s | Desired: 4000.00 RPM | Measured: 3860.00 RPM | Error: 140.00 RPM | PWM: 3347.7000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 217.44s | Desired: 4000.00 RPM | Measured: 2870.00 RPM | Error: 1130.00 RPM | PWM: 4862.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 218.47s | Desired: 4000.00 RPM | Measured: 3831.00 RPM | Error: 169.00 RPM | PWM: 2975.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 219.51s | Desired: 4000.00 RPM | Measured: 3914.00 RPM | Error: 86.00 RPM | PWM: 3330.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 220.55s | Desired: 4000.00 RPM | Measured: 3763.00 RPM | Error: 237.00 RPM | PWM: 3600.8500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 221.58s | Desired: 4000.00 RPM | Measured: 3769.00 RPM | Error: 231.00 RPM | PWM: 3504.6000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 222.61s | Desired: 4000.00 RPM | Measured: 3076.00 RPM | Error: 924.00 RPM | PWM: 4540.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 223.64s | Desired: 4000.00 RPM | Measured: 3772.00 RPM | Error: 228.00 RPM | PWM: 3183.3500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 224.68s | Desired: 4000.00 RPM | Measured: 4064.00 RPM | Error: -64.00 RPM | PWM: 3092.2000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 225.73s | Desired: 4000.00 RPM | Measured: 3692.00 RPM | Error: 308.00 RPM | PWM: 3780.7000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 226.75s | Desired: 4000.00 RPM | Measured: 2833.00 RPM | Error: 1167.00 RPM | PWM: 4888.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 227.80s | Desired: 4000.00 RPM | Measured: 3677.00 RPM | Error: 323.00 RPM | PWM: 3249.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 228.82s | Desired: 4000.00 RPM | Measured: 3853.00 RPM | Error: 147.00 RPM | PWM: 3414.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 229.86s | Desired: 4000.00 RPM | Measured: 3867.00 RPM | Error: 133.00 RPM | PWM: 3440.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 230.90s | Desired: 4000.00 RPM | Measured: 3889.00 RPM | Error: 111.00 RPM | PWM: 3405.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 231.93s | Desired: 4000.00 RPM | Measured: 3879.00 RPM | Error: 121.00 RPM | PWM: 3425.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 232.96s | Desired: 4000.00 RPM | Measured: 3675.00 RPM | Error: 325.00 RPM | PWM: 3719.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 234.00s | Desired: 4000.00 RPM | Measured: 3794.00 RPM | Error: 206.00 RPM | PWM: 3437.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 235.03s | Desired: 4000.00 RPM | Measured: 3829.00 RPM | Error: 171.00 RPM | PWM: 3441.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 236.07s | Desired: 4000.00 RPM | Measured: 4008.00 RPM | Error: -8.00 RPM | PWM: 3187.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 237.10s | Desired: 4000.00 RPM | Measured: 3868.00 RPM | Error: 132.00 RPM | PWM: 3484.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 238.13s | Desired: 4000.00 RPM | Measured: 3714.00 RPM | Error: 286.00 RPM | PWM: 3641.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 239.16s | Desired: 4000.00 RPM | Measured: 3816.00 RPM | Error: 184.00 RPM | PWM: 3424.4500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 240.21s | Desired: 4000.00 RPM | Measured: 3959.00 RPM | Error: 41.00 RPM | PWM: 3261.8500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 241.23s | Desired: 4000.00 RPM | Measured: 3761.00 RPM | Error: 239.00 RPM | PWM: 3621.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 242.28s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 3545.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 243.31s | Desired: 4000.00 RPM | Measured: 3769.00 RPM | Error: 231.00 RPM | PWM: 3507.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 244.35s | Desired: 4000.00 RPM | Measured: 3675.00 RPM | Error: 325.00 RPM | PWM: 3658.7000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 245.38s | Desired: 4000.00 RPM | Measured: 2813.00 RPM | Error: 1187.00 RPM | PWM: 4916.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 246.41s | Desired: 4000.00 RPM | Measured: 3559.00 RPM | Error: 441.00 RPM | PWM: 3408.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 247.44s | Desired: 4000.00 RPM | Measured: 3789.00 RPM | Error: 211.00 RPM | PWM: 3406.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 248.48s | Desired: 4000.00 RPM | Measured: 3793.00 RPM | Error: 207.00 RPM | PWM: 3506.3500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 249.51s | Desired: 4000.00 RPM | Measured: 3933.00 RPM | Error: 67.00 RPM | PWM: 3298.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 250.54s | Desired: 4000.00 RPM | Measured: 3918.00 RPM | Error: 82.00 RPM | PWM: 3391.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 251.58s | Desired: 4000.00 RPM | Measured: 3940.00 RPM | Error: 60.00 RPM | PWM: 3307.8500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 252.62s | Desired: 4000.00 RPM | Measured: 3728.00 RPM | Error: 272.00 RPM | PWM: 3623.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 253.65s | Desired: 4000.00 RPM | Measured: 3735.00 RPM | Error: 265.00 RPM | PWM: 3518.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 254.68s | Desired: 4000.00 RPM | Measured: 3778.00 RPM | Error: 222.00 RPM | PWM: 3459.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 255.71s | Desired: 4000.00 RPM | Measured: 3749.00 RPM | Error: 251.00 RPM | PWM: 3531.8500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 256.75s | Desired: 4000.00 RPM | Measured: 3736.00 RPM | Error: 264.00 RPM | PWM: 3537.3500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 257.79s | Desired: 4000.00 RPM | Measured: 3971.00 RPM | Error: 29.00 RPM | PWM: 3177.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 258.82s | Desired: 4000.00 RPM | Measured: 3849.00 RPM | Error: 151.00 RPM | PWM: 3466.7000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 259.85s | Desired: 4000.00 RPM | Measured: 2843.00 RPM | Error: 1157.00 RPM | PWM: 4909.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 260.89s | Desired: 4000.00 RPM | Measured: 3687.00 RPM | Error: 313.00 RPM | PWM: 3186.2000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 261.92s | Desired: 4000.00 RPM | Measured: 3600.00 RPM | Error: 400.00 RPM | PWM: 3742.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 262.96s | Desired: 4000.00 RPM | Measured: 3799.00 RPM | Error: 201.00 RPM | PWM: 3416.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 263.98s | Desired: 4000.00 RPM | Measured: 3810.00 RPM | Error: 190.00 RPM | PWM: 3461.4500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 265.03s | Desired: 4000.00 RPM | Measured: 3965.00 RPM | Error: 35.00 RPM | PWM: 3222.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 266.05s | Desired: 4000.00 RPM | Measured: 3807.00 RPM | Error: 193.00 RPM | PWM: 3519.2000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 267.09s | Desired: 4000.00 RPM | Measured: 3567.00 RPM | Error: 433.00 RPM | PWM: 3804.8500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 268.11s | Desired: 4000.00 RPM | Measured: 3658.00 RPM | Error: 342.00 RPM | PWM: 3553.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 269.16s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 3465.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 270.19s | Desired: 4000.00 RPM | Measured: 3776.00 RPM | Error: 224.00 RPM | PWM: 3472.9500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 271.23s | Desired: 4000.00 RPM | Measured: 3636.00 RPM | Error: 364.00 RPM | PWM: 3706.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 272.26s | Desired: 4000.00 RPM | Measured: 3917.00 RPM | Error: 83.00 RPM | PWM: 3221.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 273.30s | Desired: 4000.00 RPM | Measured: 3829.00 RPM | Error: 171.00 RPM | PWM: 3487.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 274.33s | Desired: 4000.00 RPM | Measured: 3950.00 RPM | Error: 50.00 RPM | PWM: 3244.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 275.36s | Desired: 4000.00 RPM | Measured: 3848.00 RPM | Error: 152.00 RPM | PWM: 3447.9500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 276.40s | Desired: 4000.00 RPM | Measured: 3614.00 RPM | Error: 386.00 RPM | PWM: 3751.8500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 277.43s | Desired: 4000.00 RPM | Measured: 3670.00 RPM | Error: 330.00 RPM | PWM: 3524.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 278.48s | Desired: 4000.00 RPM | Measured: 3801.00 RPM | Error: 199.00 RPM | PWM: 3339.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 279.51s | Desired: 4000.00 RPM | Measured: 3792.00 RPM | Error: 208.00 RPM | PWM: 3421.2000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 280.53s | Desired: 4000.00 RPM | Measured: 3552.00 RPM | Error: 448.00 RPM | PWM: 3776.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 281.58s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 3383.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 282.61s | Desired: 4000.00 RPM | Measured: 3780.00 RPM | Error: 220.00 RPM | PWM: 3431.4500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 283.64s | Desired: 4000.00 RPM | Measured: 3950.00 RPM | Error: 50.00 RPM | PWM: 3199.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 284.68s | Desired: 4000.00 RPM | Measured: 3801.00 RPM | Error: 199.00 RPM | PWM: 3507.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 285.71s | Desired: 4000.00 RPM | Measured: 3772.00 RPM | Error: 228.00 RPM | PWM: 3474.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 286.75s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 3433.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 287.78s | Desired: 4000.00 RPM | Measured: 3823.00 RPM | Error: 177.00 RPM | PWM: 3384.4500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 288.82s | Desired: 4000.00 RPM | Measured: 3969.00 RPM | Error: 31.00 RPM | PWM: 3186.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 289.85s | Desired: 4000.00 RPM | Measured: 3828.00 RPM | Error: 172.00 RPM | PWM: 3410.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 290.88s | Desired: 4000.00 RPM | Measured: 3794.00 RPM | Error: 206.00 RPM | PWM: 3378.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 291.92s | Desired: 4000.00 RPM | Measured: 3824.00 RPM | Error: 176.00 RPM | PWM: 3313.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# ...
# Time: 1900.86s | Desired: 4000.00 RPM | Measured: 4073.00 RPM | Error: -73.00 RPM | PWM: 320137.85410785675 | Kp: 11.361 | Ki: 17.310 | Kd: 3.074 | Loss: 34.502407
# Time: 1901.89s | Desired: 4000.00 RPM | Measured: 3689.00 RPM | Error: 311.00 RPM | PWM: 341916.19425296783 | Kp: 11.269 | Ki: 16.795 | Kd: 4.833 | Loss: 34.495956
# Time: 1902.94s | Desired: 4000.00 RPM | Measured: 4047.00 RPM | Error: -47.00 RPM | PWM: 333360.01940631866 | Kp: 11.625 | Ki: 17.574 | Kd: 3.620 | Loss: 34.483986
# Time: 1903.98s | Desired: 4000.00 RPM | Measured: 4147.00 RPM | Error: -147.00 RPM | PWM: 345671.1106977463 | Kp: 12.050 | Ki: 18.168 | Kd: 3.852 | Loss: 34.471855
# Time: 1905.02s | Desired: 4000.00 RPM | Measured: 3728.00 RPM | Error: 272.00 RPM | PWM: 351683.7175426483 | Kp: 11.558 | Ki: 17.144 | Kd: 5.066 | Loss: 34.464916
# Time: 1906.06s | Desired: 4000.00 RPM | Measured: 3262.00 RPM | Error: 738.00 RPM | PWM: 340097.9724845886 | Kp: 10.609 | Ki: 15.536 | Kd: 5.695 | Loss: 34.455097
# Time: 1907.09s | Desired: 4000.00 RPM | Measured: 3066.00 RPM | Error: 934.00 RPM | PWM: 324421.48819351196 | Kp: 9.974 | Ki: 14.580 | Kd: 5.523 | Loss: 34.444748
# Time: 1908.14s | Desired: 4000.00 RPM | Measured: 3472.00 RPM | Error: 528.00 RPM | PWM: 301902.9200706482 | Kp: 10.090 | Ki: 15.134 | Kd: 3.654 | Loss: 34.433144
# Time: 1909.19s | Desired: 4000.00 RPM | Measured: 4069.00 RPM | Error: -69.00 RPM | PWM: 317064.2560172081 | Kp: 11.317 | Ki: 17.189 | Kd: 2.824 | Loss: 34.426598
# Time: 1910.22s | Desired: 4000.00 RPM | Measured: 3737.00 RPM | Error: 263.00 RPM | PWM: 370765.6225891113 | Kp: 11.997 | Ki: 17.635 | Kd: 5.719 | Loss: 34.420467
# Time: 1911.27s | Desired: 4000.00 RPM | Measured: 4074.00 RPM | Error: -74.00 RPM | PWM: 382855.17717933655 | Kp: 12.766 | Ki: 18.884 | Kd: 5.384 | Loss: 34.414314
# Time: 1912.30s | Desired: 4000.00 RPM | Measured: 3721.00 RPM | Error: 279.00 RPM | PWM: 421884.104722023 | Kp: 13.092 | Ki: 18.895 | Kd: 7.746 | Loss: 34.405991
# Time: 1913.34s | Desired: 4000.00 RPM | Measured: 4141.00 RPM | Error: -141.00 RPM | PWM: 404356.3098487854 | Kp: 13.334 | Ki: 19.618 | Kd: 6.046 | Loss: 34.389084
# Time: 1914.37s | Desired: 4000.00 RPM | Measured: 3733.00 RPM | Error: 267.00 RPM | PWM: 431172.62635326385 | Kp: 13.310 | Ki: 19.167 | Kd: 8.055 | Loss: 34.376625
# Time: 1915.42s | Desired: 4000.00 RPM | Measured: 3580.00 RPM | Error: 420.00 RPM | PWM: 432779.3728351593 | Kp: 13.115 | Ki: 18.784 | Kd: 8.466 | Loss: 34.365997
# Time: 1916.45s | Desired: 4000.00 RPM | Measured: 3679.00 RPM | Error: 321.00 RPM | PWM: 433395.85663604736 | Kp: 13.275 | Ki: 19.081 | Kd: 8.240 | Loss: 34.352989
# Time: 1917.50s | Desired: 4000.00 RPM | Measured: 4170.00 RPM | Error: -170.00 RPM | PWM: 441469.6024799347 | Kp: 14.182 | Ki: 20.663 | Kd: 7.381 | Loss: 34.332008
# Time: 1918.54s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 494322.06998348236 | Kp: 14.757 | Ki: 20.945 | Kd: 10.357 | Loss: 34.308533
# Time: 1919.57s | Desired: 4000.00 RPM | Measured: 3270.00 RPM | Error: 730.00 RPM | PWM: 523758.69284152985 | Kp: 14.633 | Ki: 20.281 | Kd: 12.705 | Loss: 34.284199
# Time: 1920.62s | Desired: 4000.00 RPM | Measured: 3221.00 RPM | Error: 779.00 RPM | PWM: 526053.1441020966 | Kp: 14.609 | Ki: 20.218 | Kd: 12.889 | Loss: 34.258579
# Time: 1921.65s | Desired: 4000.00 RPM | Measured: 3436.00 RPM | Error: 564.00 RPM | PWM: 540697.1499156952 | Kp: 15.248 | Ki: 21.208 | Kd: 12.931 | Loss: 34.232109
# Time: 1922.69s | Desired: 4000.00 RPM | Measured: 3261.00 RPM | Error: 739.00 RPM | PWM: 593375.0739269257 | Kp: 16.135 | Ki: 22.089 | Kd: 15.382 | Loss: 34.201809
# Time: 1923.73s | Desired: 4000.00 RPM | Measured: 3164.00 RPM | Error: 836.00 RPM | PWM: 638175.9019136429 | Kp: 16.966 | Ki: 22.989 | Kd: 17.335 | Loss: 34.153530
# Time: 1924.79s | Desired: 4000.00 RPM | Measured: 3685.00 RPM | Error: 315.00 RPM | PWM: 670124.0564537048 | Kp: 18.437 | Ki: 25.000 | Kd: 17.322 | Loss: 34.095802
# Time: 1925.83s | Desired: 4000.00 RPM | Measured: 3714.00 RPM | Error: 286.00 RPM | PWM: 752895.695941925 | Kp: 20.282 | Ki: 25.000 | Kd: 20.451 | Loss: 34.031796
# Time: 1926.85s | Desired: 4000.00 RPM | Measured: 3507.00 RPM | Error: 493.00 RPM | PWM: 778082.4716796875 | Kp: 20.522 | Ki: 25.000 | Kd: 21.883 | Loss: 33.995533
# Time: 1927.90s | Desired: 4000.00 RPM | Measured: 3698.00 RPM | Error: 302.00 RPM | PWM: 786643.124004364 | Kp: 20.992 | Ki: 25.000 | Kd: 21.728 | Loss: 33.969421
# Time: 1928.94s | Desired: 4000.00 RPM | Measured: 3737.00 RPM | Error: 263.00 RPM | PWM: 785148.3972110748 | Kp: 21.015 | Ki: 25.000 | Kd: 21.544 | Loss: 33.968407
# Time: 1929.99s | Desired: 4000.00 RPM | Measured: 4160.00 RPM | Error: -160.00 RPM | PWM: 766524.4606895447 | Kp: 21.235 | Ki: 25.000 | Kd: 19.794 | Loss: 33.963612
# Time: 1931.03s | Desired: 4000.00 RPM | Measured: 4245.00 RPM | Error: -245.00 RPM | PWM: 745489.8395252228 | Kp: 20.899 | Ki: 25.000 | Kd: 18.754 | Loss: 33.969406
# Time: 1932.06s | Desired: 4000.00 RPM | Measured: 3328.00 RPM | Error: 672.00 RPM | PWM: 772317.1128826141 | Kp: 20.112 | Ki: 25.000 | Kd: 21.944 | Loss: 33.931671
# Time: 1933.11s | Desired: 4000.00 RPM | Measured: 4059.00 RPM | Error: -59.00 RPM | PWM: 747347.0195217133 | Kp: 20.647 | Ki: 25.000 | Kd: 19.245 | Loss: 33.916161
# Time: 1934.14s | Desired: 4000.00 RPM | Measured: 4204.00 RPM | Error: -204.00 RPM | PWM: 763472.578453064 | Kp: 21.201 | Ki: 25.000 | Kd: 19.529 | Loss: 33.917820
# Time: 1935.18s | Desired: 4000.00 RPM | Measured: 3049.00 RPM | Error: 951.00 RPM | PWM: 815893.5902709961 | Kp: 20.609 | Ki: 25.000 | Kd: 24.292 | Loss: 33.909737
# Time: 1936.22s | Desired: 4000.00 RPM | Measured: 3402.00 RPM | Error: 598.00 RPM | PWM: 807824.3838272095 | Kp: 20.946 | Ki: 25.000 | Kd: 23.155 | Loss: 33.872807
# Time: 1937.26s | Desired: 4000.00 RPM | Measured: 3126.00 RPM | Error: 874.00 RPM | PWM: 849247.9752807617 | Kp: 21.420 | Ki: 25.000 | Kd: 25.000 | Loss: 33.783882
# Time: 1938.31s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 821812.534362793 | Kp: 21.798 | Ki: 25.000 | Kd: 22.811 | Loss: 33.690655
# Time: 1939.35s | Desired: 4000.00 RPM | Measured: 4143.00 RPM | Error: -143.00 RPM | PWM: 830912.2541751862 | Kp: 22.514 | Ki: 25.000 | Kd: 22.333 | Loss: 33.716457
# Time: 1940.37s | Desired: 4000.00 RPM | Measured: 3965.00 RPM | Error: 35.00 RPM | PWM: 848813.2398853302 | Kp: 22.631 | Ki: 25.000 | Kd: 23.450 | Loss: 33.248657
# Time: 1941.42s | Desired: 4000.00 RPM | Measured: 4181.00 RPM | Error: -181.00 RPM | PWM: 841788.5409927368 | Kp: 22.797 | Ki: 25.000 | Kd: 22.665 | Loss: 33.275711
# Time: 1942.46s | Desired: 4000.00 RPM | Measured: 4250.00 RPM | Error: -250.00 RPM | PWM: 831861.7620487213 | Kp: 22.686 | Ki: 25.000 | Kd: 22.107 | Loss: 32.980000
# Time: 1943.50s | Desired: 4000.00 RPM | Measured: 3244.00 RPM | Error: 756.00 RPM | PWM: 877015.934463501 | Kp: 22.173 | Ki: 25.000 | Kd: 25.000 | Loss: 31.626183
# Time: 1944.55s | Desired: 4000.00 RPM | Measured: 4013.00 RPM | Error: -13.00 RPM | PWM: 843811.7554588318 | Kp: 22.605 | Ki: 25.000 | Kd: 23.093 | Loss: 30.875921
# Time: 1945.59s | Desired: 4000.00 RPM | Measured: 4244.00 RPM | Error: -244.00 RPM | PWM: 859149.8746337891 | Kp: 23.290 | Ki: 25.000 | Kd: 23.117 | Loss: 29.670902
# Time: 1946.62s | Desired: 4000.00 RPM | Measured: 4240.00 RPM | Error: -240.00 RPM | PWM: 858902.9492721558 | Kp: 23.294 | Ki: 25.000 | Kd: 23.079 | Loss: 27.989275
# Time: 1947.66s | Desired: 4000.00 RPM | Measured: 3157.00 RPM | Error: 843.00 RPM | PWM: 890231.5262050629 | Kp: 22.384 | Ki: 25.000 | Kd: 25.000 | Loss: 22.783283
# Time: 1948.70s | Desired: 4000.00 RPM | Measured: 4114.00 RPM | Error: -114.00 RPM | PWM: 845248.2719650269 | Kp: 22.849 | Ki: 25.000 | Kd: 22.757 | Loss: 21.764214
# Time: 1949.74s | Desired: 4000.00 RPM | Measured: 4297.00 RPM | Error: -297.00 RPM | PWM: 854749.3659973145 | Kp: 23.347 | Ki: 25.000 | Kd: 22.643 | Loss: 16.576256
# Time: 1950.79s | Desired: 4000.00 RPM | Measured: 4286.00 RPM | Error: -286.00 RPM | PWM: 857771.7927761078 | Kp: 23.418 | Ki: 25.000 | Kd: 22.734 | Loss: 15.565022
# Time: 1951.83s | Desired: 4000.00 RPM | Measured: 4056.00 RPM | Error: -56.00 RPM | PWM: 868367.379283905 | Kp: 23.329 | Ki: 25.000 | Kd: 23.633 | Loss: 15.130405
# Time: 1952.87s | Desired: 4000.00 RPM | Measured: 3244.00 RPM | Error: 756.00 RPM | PWM: 906376.2704772949 | Kp: 22.972 | Ki: 25.000 | Kd: 25.000 | Loss: 14.109417
# Time: 1953.91s | Desired: 4000.00 RPM | Measured: 4146.00 RPM | Error: -146.00 RPM | PWM: 869471.1141586304 | Kp: 23.524 | Ki: 25.000 | Kd: 23.375 | Loss: 8.914840
# Time: 1954.94s | Desired: 4000.00 RPM | Measured: 3734.00 RPM | Error: 266.00 RPM | PWM: 914412.9967651367 | Kp: 23.907 | Ki: 25.000 | Kd: 25.000 | Loss: 3.714111
# Time: 1955.97s | Desired: 4000.00 RPM | Measured: 3434.00 RPM | Error: 566.00 RPM | PWM: 933106.1285820007 | Kp: 23.883 | Ki: 25.000 | Kd: 25.000 | Loss: 3.735252
# Time: 1957.02s | Desired: 4000.00 RPM | Measured: 3842.00 RPM | Error: 158.00 RPM | PWM: 927373.4536361694 | Kp: 24.372 | Ki: 25.000 | Kd: 25.000 | Loss: 3.587478
# Time: 1958.07s | Desired: 4000.00 RPM | Measured: 3266.00 RPM | Error: 734.00 RPM | PWM: 978014.1080093384 | Kp: 24.630 | Ki: 25.000 | Kd: 25.000 | Loss: 3.637889
# Time: 1959.10s | Desired: 4000.00 RPM | Measured: 4071.00 RPM | Error: -71.00 RPM | PWM: 936226.26653862 | Kp: 24.918 | Ki: 25.000 | Kd: 25.000 | Loss: 3.281527
# Time: 1960.14s | Desired: 4000.00 RPM | Measured: 4208.00 RPM | Error: -208.00 RPM | PWM: 954842.0978088379 | Kp: 25.530 | Ki: 25.000 | Kd: 25.000 | Loss: 3.314193
# Time: 1961.18s | Desired: 4000.00 RPM | Measured: 3126.00 RPM | Error: 874.00 RPM | PWM: 1006038.1839256287 | Kp: 25.048 | Ki: 25.000 | Kd: 25.000 | Loss: 3.182749
# Time: 1962.22s | Desired: 4000.00 RPM | Measured: 4011.00 RPM | Error: -11.00 RPM | PWM: 949924.4706745148 | Kp: 25.138 | Ki: 25.000 | Kd: 25.000 | Loss: 3.196369
# Time: 1963.26s | Desired: 4000.00 RPM | Measured: 3589.00 RPM | Error: 411.00 RPM | PWM: 999506.5198688507 | Kp: 25.595 | Ki: 25.000 | Kd: 25.000 | Loss: 3.051330
# Time: 1964.31s | Desired: 4000.00 RPM | Measured: 4114.00 RPM | Error: -114.00 RPM | PWM: 981432.1579017639 | Kp: 25.980 | Ki: 25.000 | Kd: 25.000 | Loss: 3.077435
# Time: 1965.34s | Desired: 4000.00 RPM | Measured: 4180.00 RPM | Error: -180.00 RPM | PWM: 968798.6052322388 | Kp: 25.806 | Ki: 25.000 | Kd: 25.000 | Loss: 3.044432
# Time: 1966.39s | Desired: 4000.00 RPM | Measured: 3871.00 RPM | Error: 129.00 RPM | PWM: 984978.990945816 | Kp: 25.705 | Ki: 25.000 | Kd: 25.000 | Loss: 3.067114
# Time: 1967.42s | Desired: 4000.00 RPM | Measured: 4131.00 RPM | Error: -131.00 RPM | PWM: 956407.6407623291 | Kp: 25.470 | Ki: 25.000 | Kd: 25.000 | Loss: 3.059695
# Time: 1968.45s | Desired: 4000.00 RPM | Measured: 4190.00 RPM | Error: -190.00 RPM | PWM: 941660.6751251221 | Kp: 25.238 | Ki: 25.000 | Kd: 25.000 | Loss: 3.084792
# Time: 1969.50s | Desired: 4000.00 RPM | Measured: 4185.00 RPM | Error: -185.00 RPM | PWM: 930805.9253787994 | Kp: 24.995 | Ki: 25.000 | Kd: 24.782 | Loss: 3.087639
# Time: 1970.54s | Desired: 4000.00 RPM | Measured: 4211.00 RPM | Error: -211.00 RPM | PWM: 923981.683713913 | Kp: 24.883 | Ki: 25.000 | Kd: 24.390 | Loss: 3.112495
# Time: 1971.57s | Desired: 4000.00 RPM | Measured: 4244.00 RPM | Error: -244.00 RPM | PWM: 923498.5540866852 | Kp: 24.918 | Ki: 25.000 | Kd: 24.237 | Loss: 3.122942
# Time: 1972.62s | Desired: 4000.00 RPM | Measured: 4225.00 RPM | Error: -225.00 RPM | PWM: 926403.9614067078 | Kp: 24.948 | Ki: 25.000 | Kd: 24.348 | Loss: 3.140745
# Time: 1973.66s | Desired: 4000.00 RPM | Measured: 4092.00 RPM | Error: -92.00 RPM | PWM: 934168.0895252228 | Kp: 24.915 | Ki: 25.000 | Kd: 24.925 | Loss: 3.120360
# Time: 1974.70s | Desired: 4000.00 RPM | Measured: 3040.00 RPM | Error: 960.00 RPM | PWM: 976989.4768066406 | Kp: 24.290 | Ki: 25.000 | Kd: 25.000 | Loss: 3.136303
# Time: 1975.75s | Desired: 4000.00 RPM | Measured: 4003.00 RPM | Error: -3.00 RPM | PWM: 924102.1303348541 | Kp: 24.557 | Ki: 25.000 | Kd: 24.739 | Loss: 3.104383
# Time: 1976.78s | Desired: 4000.00 RPM | Measured: 4163.00 RPM | Error: -163.00 RPM | PWM: 946639.1061344147 | Kp: 25.279 | Ki: 25.000 | Kd: 25.000 | Loss: 3.106986
# Time: 1977.81s | Desired: 4000.00 RPM | Measured: 4087.00 RPM | Error: -87.00 RPM | PWM: 957775.7418270111 | Kp: 25.411 | Ki: 25.000 | Kd: 25.000 | Loss: 3.100043
# Time: 1978.86s | Desired: 4000.00 RPM | Measured: 4133.00 RPM | Error: -133.00 RPM | PWM: 952695.3951854706 | Kp: 25.373 | Ki: 25.000 | Kd: 25.000 | Loss: 3.107477
# Time: 1979.90s | Desired: 4000.00 RPM | Measured: 4150.00 RPM | Error: -150.00 RPM | PWM: 955094.092464447 | Kp: 25.456 | Ki: 25.000 | Kd: 25.000 | Loss: 3.073647
# Time: 1980.94s | Desired: 4000.00 RPM | Measured: 4123.00 RPM | Error: -123.00 RPM | PWM: 959368.9409332275 | Kp: 25.515 | Ki: 25.000 | Kd: 25.000 | Loss: 3.087143
# Time: 1981.98s | Desired: 4000.00 RPM | Measured: 3982.00 RPM | Error: 18.00 RPM | PWM: 969634.2774391174 | Kp: 25.538 | Ki: 25.000 | Kd: 25.000 | Loss: 3.054096
# Time: 1983.02s | Desired: 4000.00 RPM | Measured: 4058.00 RPM | Error: -58.00 RPM | PWM: 969943.7932281494 | Kp: 25.664 | Ki: 25.000 | Kd: 25.000 | Loss: 3.071953
# Time: 1984.06s | Desired: 4000.00 RPM | Measured: 3919.00 RPM | Error: 81.00 RPM | PWM: 984928.7495117188 | Kp: 25.792 | Ki: 25.000 | Kd: 25.000 | Loss: 3.053586
# Time: 1985.09s | Desired: 4000.00 RPM | Measured: 3060.00 RPM | Error: 940.00 RPM | PWM: 1034669.4690704346 | Kp: 25.620 | Ki: 25.000 | Kd: 25.000 | Loss: 3.114703
# Time: 1986.14s | Desired: 4000.00 RPM | Measured: 2647.00 RPM | Error: 1353.00 RPM | PWM: 1065713.946296692 | Kp: 25.701 | Ki: 25.000 | Kd: 25.000 | Loss: 3.127041
# Time: 1987.17s | Desired: 4000.00 RPM | Measured: 2951.00 RPM | Error: 1049.00 RPM | PWM: 1056685.4132499695 | Kp: 25.970 | Ki: 25.000 | Kd: 25.000 | Loss: 3.208943
# Time: 1988.22s | Desired: 4000.00 RPM | Measured: 4005.00 RPM | Error: -5.00 RPM | PWM: 1039920.149345398 | Kp: 27.173 | Ki: 25.000 | Kd: 25.000 | Loss: 3.228602
# Time: 1989.25s | Desired: 4000.00 RPM | Measured: 4132.00 RPM | Error: -132.00 RPM | PWM: 1068263.1045379639 | Kp: 28.002 | Ki: 25.000 | Kd: 25.000 | Loss: 3.299142
# Time: 1990.29s | Desired: 4000.00 RPM | Measured: 3517.00 RPM | Error: 483.00 RPM | PWM: 1097124.801486969 | Kp: 27.757 | Ki: 25.000 | Kd: 25.000 | Loss: 3.380058
# Time: 1991.34s | Desired: 4000.00 RPM | Measured: 3984.00 RPM | Error: 16.00 RPM | PWM: 1076944.112915039 | Kp: 28.022 | Ki: 25.000 | Kd: 25.000 | Loss: 3.450851
# Time: 1992.37s | Desired: 4000.00 RPM | Measured: 4050.00 RPM | Error: -50.00 RPM | PWM: 1084273.8963127136 | Kp: 28.290 | Ki: 25.000 | Kd: 25.000 | Loss: 3.524953
# Time: 1993.42s | Desired: 4000.00 RPM | Measured: 2919.00 RPM | Error: 1081.00 RPM | PWM: 1153681.1796512604 | Kp: 28.150 | Ki: 25.000 | Kd: 25.000 | Loss: 3.695328
# Time: 1994.46s | Desired: 4000.00 RPM | Measured: 3923.00 RPM | Error: 77.00 RPM | PWM: 1090517.5443897247 | Kp: 28.234 | Ki: 25.000 | Kd: 25.000 | Loss: 3.763797
# Time: 1995.49s | Desired: 4000.00 RPM | Measured: 3355.00 RPM | Error: 645.00 RPM | PWM: 1147110.8237171173 | Kp: 28.619 | Ki: 25.000 | Kd: 25.000 | Loss: 3.900566
# Time: 1996.53s | Desired: 4000.00 RPM | Measured: 3275.00 RPM | Error: 725.00 RPM | PWM: 1144548.9875793457 | Kp: 28.429 | Ki: 25.000 | Kd: 25.000 | Loss: 3.985753
# Time: 1997.58s | Desired: 4000.00 RPM | Measured: 3991.00 RPM | Error: 9.00 RPM | PWM: 1108830.8584842682 | Kp: 28.678 | Ki: 25.000 | Kd: 25.000 | Loss: 4.069015
# Time: 1998.61s | Desired: 4000.00 RPM | Measured: 3329.00 RPM | Error: 671.00 RPM | PWM: 1147043.159072876 | Kp: 28.527 | Ki: 25.000 | Kd: 25.000 | Loss: 4.192974
# Time: 1999.64s | Desired: 4000.00 RPM | Measured: 3247.00 RPM | Error: 753.00 RPM | PWM: 1156256.1415481567 | Kp: 28.596 | Ki: 25.000 | Kd: 25.000 | Loss: 4.325926
# Data saved to motor_speed_data_ANN_20250404_235026.csv
# Measured Speed plot saved to motor_speed_plot_speed_ANN_20250404_235026.pdf
# PID Gains plot saved to motor_speed_plot_gains_ANN_20250404_235026.pdf
# Loss plot saved to motor_speed_plot_loss_ANN_20250404_235026.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime
import uuid  # Import UUID for unique filenames

import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

# Define whether ANN is enabled or not
ANN_enabled = True  # Set to True if ANN is used, False otherwise

# Convert lists to NumPy arrays for performance calculations
time_stamps = np.array(times)  # Recorded time points
error = np.array(errors)
setpoints = np.array([desired_speed] * len(times))  # Setpoints stored as an array
speeds = np.array(speeds)

# Handle missing `loss_values`
if "loss_values" in globals() and len(loss_values) > 0:
    training_epochs = np.array(range(len(loss_values)))  # Training epochs for ANN
    loss_values = np.array(loss_values)
else:
    training_epochs = np.array([])  # Empty array if no loss data is available
    loss_values = np.array([])

# Compute Performance Metrics
rmse = np.sqrt(np.mean(error ** 2))
mae = np.mean(np.abs(error))
SSE = error[-1]  # Last recorded error
max_speed = max(speeds)
overshoot = max(0, ((max_speed - desired_speed) / desired_speed) * 100)

# Settling Time (Ts)
within_tolerance = np.abs(error) < (0.05 * desired_speed)  # Within ±5% of setpoint
Ts_index = np.argmax(within_tolerance) if np.any(within_tolerance) else -1
Ts = time_stamps[Ts_index] if Ts_index != -1 else None  # First time where error is within ±5%

# Generate Performance Plots and Save with explicit names
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")  # Format: YYYYMMDD_HHMMSS
identifier = "With_ANN" if ANN_enabled else "No_ANN"  # Condition-based identifier
unique_id = uuid.uuid4().hex[:8]  # Generates an 8-character unique ID

# 1. Histogram of Errors
hist_filename = f"Histogram_Errors_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.hist(error, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Error (RPM)", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(hist_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 2. RMSE & MAE Comparison
rmse_mae_filename = f"RMSE_MAE_Comparison_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["RMSE", "MAE"], [rmse, mae], color=['red', 'orange'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(rmse_mae_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 3. Overshoot & Steady-State Error
overshoot_sse_filename = f"Overshoot_SSE_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["Overshoot (%)", "SSE"], [overshoot, SSE], color=['purple', 'green'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)
plt.savefig(overshoot_sse_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 4. ANN Loss Plot (if available)
if loss_values.size > 0:
    ann_loss_filename = f"ANN_Loss_{identifier}_{current_datetime}_{unique_id}.pdf"
    plt.figure(figsize=(7, 5))
    plt.plot(training_epochs, loss_values, label="Loss", color="b", linewidth=2)
    plt.xlabel("Epochs", fontsize=16)
    plt.ylabel("Loss Value (MSE)", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.savefig(ann_loss_filename, format="pdf", bbox_inches="tight")  # Save to PDF
    plt.show()
    print(f"ANN Loss Plot saved as {ann_loss_filename}")

# Print Statistical Summary
print("\n **Statistical Evaluation:**")
print(f"RMSE: {rmse:.2f} RPM")
print(f"MAE: {mae:.2f} RPM")
print(f"Settling Time (Ts): {Ts:.2f} s" if Ts is not None else " Settling Time Not Reached")
print(f"Steady-State Error (SSE): {SSE:.2f} RPM")
print(f"Overshoot: {overshoot:.2f}%")
print(f"\nHistogram of Errors saved as {hist_filename}")
print(f"RMSE & MAE Comparison saved as {rmse_mae_filename}")
print(f"Overshoot & Steady-State Error saved as {overshoot_sse_filename}")
# Out:
# ANN Loss Plot saved as ANN_Loss_With_ANN_20250405_002458_89a99859.pdf
#
#  **Statistical Evaluation:**
# RMSE: 758.60 RPM
# MAE: 468.85 RPM
# Settling Time (Ts): 2.26 s
# Steady-State Error (SSE): 753.00 RPM
# Overshoot: 19.48%
#
# Histogram of Errors saved as Histogram_Errors_With_ANN_20250405_002458_89a99859.pdf
# RMSE & MAE Comparison saved as RMSE_MAE_Comparison_With_ANN_20250405_002458_89a99859.pdf
# Overshoot & Steady-State Error saved as Overshoot_SSE_With_ANN_20250405_002458_89a99859.pdf

# %% [markdown]
# # Arduino Code Description
#
# The Arduino code (given below) is designed to control a DC motor using an Arduino microcontroller. The microcontroller powers the DC motor through a pulse-width modulation (PWM) driver. The code uses an shaft encoder to measure the motor's speed and a servo object to apply control. Real-time speed updates are sent to a connected Python script via serial communication, while PWM reference values received from the Python script are used to dynamically control the motor's speed. Encoder pulses are tracked using interrupts to ensure accurate speed measurements, creating a seamless integration between hardware and software for efficient motor control.

# %% [markdown]
# # The Arduino Code
#
# ```cpp
# #include <Servo.h>  // Include the Servo library
#
# Servo myservo;  // Servo object for motor control
#
# // Encoder tracking
# volatile unsigned int counter = 0;
# unsigned long lastTime = 0;
# const long interval = 1000;  // Speed update every 1 second
#
# int speedValue = 0;  // Measured speed
#
# void setup() {
#     myservo.attach(9);  // Connect servo/motor control to pin 9
#     Serial.begin(115200);  // Set serial baud rate
#
#     pinMode(2, INPUT_PULLUP);  // Encoder input
#     attachInterrupt(digitalPinToInterrupt(2), countPulses, RISING);  // Interrupt for encoder
# }
#
# void loop() {
#     // Send speed to Python every second
#     if (millis() - lastTime >= interval) {
#         lastTime = millis();
#         speedValue = map(counter, 0, 400, 0, 100);  // Convert pulses per second to speed in RPM
#         Serial.println(speedValue);  // Send the speed to Python
#         counter = 0;  // Reset counter
#     }
#
#     // Read PWM value from Python
#     if (Serial.available()) {
#         int pwmValue = Serial.parseInt();
#         pwmValue = map(pwmValue, 30000, 0, 120, 140);  // Map PWM range
#         myservo.write(pwmValue);  // Apply control
#         delay(50);
#     }
# }
#
# // Interrupt function to count encoder pulses
# void countPulses() {
#     counter++;
# }
# ```

# %% [markdown]
# # Preliminary Result
#
# The ANN-tuned PID controller outperforms the classical PID, achieving lower steady-state error and better adherence to the desired speed. Moreover, ongoing investigations are addressing the electrical and mechanical issues causing drift and undesirable step response, which reduces the systems performance.
