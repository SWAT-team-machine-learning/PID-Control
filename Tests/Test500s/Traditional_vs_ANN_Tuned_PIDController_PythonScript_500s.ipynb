# %% [markdown]
# # Real-time Adaptive PID Control for DC Motor Speed Regulation using Neural Network-based Self-tuning
#
# **Machine Learning (CS-5841/EE-5841) Project**
# *Mbadiwe S. Benyeogor, Mark-Anthony Agbanu, Kepha Barasa, and Joseph Alfred Sonne*
#
#
# **Instructor: Professor Sujan Kumar Roy**

# %% [markdown]
# # Introduction
# This software documentation describes the functionality of a real-time Artificial Neural Network (ANN)-tuned PID motor speed control system implemented in Python. The system uses a Proportional-Integral-Derivative (PID) controller initially, and after 20% of the total runtime, the ANN dynamically adjusts the PID gains for improved performance. The control loop is executed in real-time, interfacing with an Arduino via serial communication.
#
# # System Overview
# The system consists of:
# - A PID controller for initial motor speed regulation.
# - An ANN for self-tuning of PID gains after 20% of the runtime.
# - A serial communication interface to receive speed measurements and send control signals.
# - A CSV logging mechanism for data storage.
# - Real-time visualization of system performance using Matplotlib.
#
#
# # Experimental Setup
#
# The experimental setup displayed in Figure 1 is essential for implementing and testing the Python code provided below. Each device in the setup is a critical component of the control loop, ensuring the system operates as intended. The experiment primarily investigates the performance of an ANN-enhanced PID control system, comparing it with that of a classical PID control algorithm. This approach evaluates the advantages of integrating machine learning into traditional control methods for improved system efficiency.
#
# ![Experimental Setup](Device2.png)
#
# *Figure 1: Experimental setup showing the components of the real-time ANN-enabled PID motor speed control system.*
#
# ---
#
# ^1 The devices in the experimental setup are required for the Python code below to function correctly.

# %% [markdown]
# # Classical PID Control program without ANN-enabled Self-tuning:

# %%
import serial
import time
import csv
import matplotlib.pyplot as plt
from datetime import datetime
from matplotlib.ticker import ScalarFormatter

# PID Parameters (Tune as needed)
Kp = 1.6
Ki = 0.05
Kd = 0.5

# User Inputs
desired_speed = float(input("Enter desired motor speed (RPM): "))
runtime = float(input("Enter duration for PID control (seconds): "))

# Initialize Serial Communication (Update COM port if necessary)
ser = serial.Serial('COM3', 115200, timeout=0.2)  # Ensure COM port matches your system

# PID Variables
previous_error = 0
integral = 0

# Anti-Windup Limits
integral_min = -255
integral_max = 255

# Data Logging
times, speeds, errors, pwm_outputs = [], [], [], []
kp_values, ki_values, kd_values = [], [], []
start_time = time.time()

# Generate dynamic filenames with timestamp
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"PID_motor_data_{current_time}.csv"
pdf_filename_speed = f"PID_motor_plot_speed_{current_time}.pdf"
pdf_filename_gains = f"PID_motor_plot_gains_{current_time}.pdf"

# CSV File Setup
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Time (s)", "Desired Speed (RPM)", "Measured Speed (RPM)", "Error (RPM)", "PWM Output", "Kp", "Ki", "Kd"])  # CSV Header

def pid_control(measured_speed):
    """Compute PID control signal."""
    global previous_error, integral

    # PID computation
    error = desired_speed - measured_speed
    integral += error
    integral = max(min(integral, integral_max), integral_min)  # Anti-windup
    derivative = error - previous_error
    control_signal = (Kp * error) + (Ki * integral) + (Kd * derivative)
    previous_error = error

    return control_signal

# Main Control Loop
while time.time() - start_time < runtime:  # Run for user-defined duration
    response = ser.readline().decode().strip()
    if response:
        try:
            measured_speed = float(response)  # Measured speed in RPM
            elapsed_time = time.time() - start_time

            # Compute PID control output
            pwm_output = pid_control(measured_speed)
            ser.write(f"{pwm_output}\n".encode())  # Send PWM to Arduino

            # Store data
            times.append(elapsed_time)
            speeds.append(measured_speed)
            errors.append(desired_speed - measured_speed)
            pwm_outputs.append(pwm_output)
            kp_values.append(Kp)
            ki_values.append(Ki)
            kd_values.append(Kd)

            # Print output with current parameters
            print(f"Time: {elapsed_time:.2f}s | Desired: {desired_speed:.2f} RPM | "
                  f"Measured: {measured_speed:.2f} RPM | Error: {errors[-1]:.2f} RPM | "
                  f"PWM: {pwm_output} | Kp: {Kp} | Ki: {Ki} | Kd: {Kd}")

            # Save data to CSV
            with open(csv_filename, mode="a", newline="") as file:
                writer = csv.writer(file)
                writer.writerow([elapsed_time, desired_speed, measured_speed, errors[-1], pwm_output, Kp, Ki, Kd])

        except ValueError:
            print("Invalid data received.")

ser.close()

# Compute Settling Time (Ts)
settling_threshold = desired_speed * 0.05  # 5% threshold in RPM
Ts = next((t for t, e in zip(times, errors) if abs(e) <= settling_threshold), times[-1])

# Generate and Save Measured Speed & Error Plot
plt.figure(figsize=(7, 6))
plt.plot(times, speeds, label="Measured Speed", color="b", linewidth=2)
plt.plot(times, errors, label="Error", color="r", linewidth=2)
plt.plot(times, [desired_speed] * len(times), label="Desired Speed", color="g", linestyle="--", linewidth=2)

# Add shaded threshold region
threshold_lower = desired_speed * 0.95  # Lower bound of ±5% threshold
threshold_upper = desired_speed * 1.05  # Upper bound of ±5% threshold
plt.fill_between(times, threshold_lower, threshold_upper, color="gray", alpha=0.3, label="±5% Threshold")

# Add settling time marker
if Ts:
    plt.axvline(Ts, color="black", linestyle="--", linewidth=2, label=f"Settling Time: {Ts:.2f}s")
    #plt.text(Ts, desired_speed, f"  Ts = {Ts:.2f}s", fontsize=12, color="black", va="bottom")

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Speed (RPM)", fontsize=16)
#plt.title("Measured Speed and Error for PID Control without ANN", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Y-axis scientific notation
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)

# Add legend
plt.legend(fontsize=14)

# Save as PDF
plt.tight_layout()
plt.savefig(pdf_filename_speed, format="pdf")
plt.show()

# Generate and Save PID Gains Plot
plt.figure(figsize=(7, 6))
plt.plot(times, kp_values, label="Kp", color="m", linewidth=2)
plt.plot(times, ki_values, label="Ki", color="c", linewidth=2, alpha=0.6)
plt.plot(times, kd_values, label="Kd", color="y", linewidth=2, alpha=0.6)
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("PID Gains", fontsize=16)
#plt.title("Constant PID Gains Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(fontsize=14)

# Save as PDF
plt.tight_layout()
plt.savefig(pdf_filename_gains, format="pdf")
plt.show()

# Final Report
print(f"Data saved to {csv_filename}")
print(f"Speed plot saved to {pdf_filename_speed}")
print(f"PID gains plot saved to {pdf_filename_gains}")
# Out:
# Enter desired motor speed (RPM): 4000
# Enter duration for PID control (seconds): 500
# Time: 1.90s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 8412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 2.94s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 3.97s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 5.01s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 6.03s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7.06s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 8.09s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 9.14s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 6412.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 10.17s | Desired: 4000.00 RPM | Measured: 3507.00 RPM | Error: 493.00 RPM | PWM: -951.9499999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 11.21s | Desired: 4000.00 RPM | Measured: 4896.00 RPM | Error: -896.00 RPM | PWM: -2140.8500000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 12.24s | Desired: 4000.00 RPM | Measured: 4974.00 RPM | Error: -974.00 RPM | PWM: -1610.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 13.28s | Desired: 4000.00 RPM | Measured: 5073.00 RPM | Error: -1073.00 RPM | PWM: -1779.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 14.31s | Desired: 4000.00 RPM | Measured: 5295.00 RPM | Error: -1295.00 RPM | PWM: -2195.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 15.35s | Desired: 4000.00 RPM | Measured: 5191.00 RPM | Error: -1191.00 RPM | PWM: -1866.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 16.37s | Desired: 4000.00 RPM | Measured: 7022.00 RPM | Error: -3022.00 RPM | PWM: -5763.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 17.41s | Desired: 4000.00 RPM | Measured: 6918.00 RPM | Error: -2918.00 RPM | PWM: -4629.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 18.44s | Desired: 4000.00 RPM | Measured: 5217.00 RPM | Error: -1217.00 RPM | PWM: -1109.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 19.48s | Desired: 4000.00 RPM | Measured: 5127.00 RPM | Error: -1127.00 RPM | PWM: -1770.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 20.52s | Desired: 4000.00 RPM | Measured: 5135.00 RPM | Error: -1135.00 RPM | PWM: -1832.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 21.54s | Desired: 4000.00 RPM | Measured: 5118.00 RPM | Error: -1118.00 RPM | PWM: -1793.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 22.58s | Desired: 4000.00 RPM | Measured: 5278.00 RPM | Error: -1278.00 RPM | PWM: -2137.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 23.61s | Desired: 4000.00 RPM | Measured: 5125.00 RPM | Error: -1125.00 RPM | PWM: -1736.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 24.64s | Desired: 4000.00 RPM | Measured: 5144.00 RPM | Error: -1144.00 RPM | PWM: -1852.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 25.68s | Desired: 4000.00 RPM | Measured: 5084.00 RPM | Error: -1084.00 RPM | PWM: -1717.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 26.72s | Desired: 4000.00 RPM | Measured: 5107.00 RPM | Error: -1107.00 RPM | PWM: -1795.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 27.76s | Desired: 4000.00 RPM | Measured: 5119.00 RPM | Error: -1119.00 RPM | PWM: -1809.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 28.78s | Desired: 4000.00 RPM | Measured: 5095.00 RPM | Error: -1095.00 RPM | PWM: -1752.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 29.81s | Desired: 4000.00 RPM | Measured: 5072.00 RPM | Error: -1072.00 RPM | PWM: -1716.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 30.86s | Desired: 4000.00 RPM | Measured: 5104.00 RPM | Error: -1104.00 RPM | PWM: -1795.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 31.89s | Desired: 4000.00 RPM | Measured: 5118.00 RPM | Error: -1118.00 RPM | PWM: -1808.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 32.92s | Desired: 4000.00 RPM | Measured: 5277.00 RPM | Error: -1277.00 RPM | PWM: -2135.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 33.95s | Desired: 4000.00 RPM | Measured: 5141.00 RPM | Error: -1141.00 RPM | PWM: -1770.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 35.00s | Desired: 4000.00 RPM | Measured: 5284.00 RPM | Error: -1284.00 RPM | PWM: -2138.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 36.03s | Desired: 4000.00 RPM | Measured: 5170.00 RPM | Error: -1170.00 RPM | PWM: -1827.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 37.06s | Desired: 4000.00 RPM | Measured: 5107.00 RPM | Error: -1107.00 RPM | PWM: -1752.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 38.10s | Desired: 4000.00 RPM | Measured: 5103.00 RPM | Error: -1103.00 RPM | PWM: -1775.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 39.13s | Desired: 4000.00 RPM | Measured: 5295.00 RPM | Error: -1295.00 RPM | PWM: -2180.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 40.17s | Desired: 4000.00 RPM | Measured: 5145.00 RPM | Error: -1145.00 RPM | PWM: -1769.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 41.20s | Desired: 4000.00 RPM | Measured: 4172.00 RPM | Error: -172.00 RPM | PWM: 198.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 42.23s | Desired: 4000.00 RPM | Measured: 3273.00 RPM | Error: 727.00 RPM | PWM: 1625.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 43.27s | Desired: 4000.00 RPM | Measured: 3278.00 RPM | Error: 722.00 RPM | PWM: 1165.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 44.30s | Desired: 4000.00 RPM | Measured: 3268.00 RPM | Error: 732.00 RPM | PWM: 1188.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 45.34s | Desired: 4000.00 RPM | Measured: 3268.00 RPM | Error: 732.00 RPM | PWM: 1183.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 46.36s | Desired: 4000.00 RPM | Measured: 3278.00 RPM | Error: 722.00 RPM | PWM: 1162.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 47.39s | Desired: 4000.00 RPM | Measured: 4696.00 RPM | Error: -696.00 RPM | PWM: -1835.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 48.44s | Desired: 4000.00 RPM | Measured: 3564.00 RPM | Error: 436.00 RPM | PWM: 1272.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 49.48s | Desired: 4000.00 RPM | Measured: 3306.00 RPM | Error: 694.00 RPM | PWM: 1252.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 50.51s | Desired: 4000.00 RPM | Measured: 3288.00 RPM | Error: 712.00 RPM | PWM: 1160.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 51.53s | Desired: 4000.00 RPM | Measured: 3445.00 RPM | Error: 555.00 RPM | PWM: 822.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 52.58s | Desired: 4000.00 RPM | Measured: 3648.00 RPM | Error: 352.00 RPM | PWM: 474.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 53.61s | Desired: 4000.00 RPM | Measured: 3995.00 RPM | Error: 5.00 RPM | PWM: -152.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 54.64s | Desired: 4000.00 RPM | Measured: 3862.00 RPM | Error: 138.00 RPM | PWM: 300.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 55.67s | Desired: 4000.00 RPM | Measured: 3833.00 RPM | Error: 167.00 RPM | PWM: 294.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 56.71s | Desired: 4000.00 RPM | Measured: 3825.00 RPM | Error: 175.00 RPM | PWM: 296.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 57.75s | Desired: 4000.00 RPM | Measured: 3817.00 RPM | Error: 183.00 RPM | PWM: 309.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 58.77s | Desired: 4000.00 RPM | Measured: 3817.00 RPM | Error: 183.00 RPM | PWM: 305.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 59.81s | Desired: 4000.00 RPM | Measured: 3797.00 RPM | Error: 203.00 RPM | PWM: 347.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 60.84s | Desired: 4000.00 RPM | Measured: 3797.00 RPM | Error: 203.00 RPM | PWM: 337.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 61.87s | Desired: 4000.00 RPM | Measured: 3909.00 RPM | Error: 91.00 RPM | PWM: 102.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 62.91s | Desired: 4000.00 RPM | Measured: 3938.00 RPM | Error: 62.00 RPM | PWM: 97.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 63.94s | Desired: 4000.00 RPM | Measured: 3960.00 RPM | Error: 40.00 RPM | PWM: 65.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 64.98s | Desired: 4000.00 RPM | Measured: 3977.00 RPM | Error: 23.00 RPM | PWM: 41.050000000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 66.01s | Desired: 4000.00 RPM | Measured: 3752.00 RPM | Error: 248.00 RPM | PWM: 522.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 67.05s | Desired: 4000.00 RPM | Measured: 3938.00 RPM | Error: 62.00 RPM | PWM: 18.950000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 68.07s | Desired: 4000.00 RPM | Measured: 3164.00 RPM | Error: 836.00 RPM | PWM: 1737.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 69.11s | Desired: 4000.00 RPM | Measured: 4027.00 RPM | Error: -27.00 RPM | PWM: -463.3 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 70.16s | Desired: 4000.00 RPM | Measured: 3996.00 RPM | Error: 4.00 RPM | PWM: 33.5 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 71.19s | Desired: 4000.00 RPM | Measured: 3955.00 RPM | Error: 45.00 RPM | PWM: 105.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 72.22s | Desired: 4000.00 RPM | Measured: 3962.00 RPM | Error: 38.00 RPM | PWM: 70.05000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 73.26s | Desired: 4000.00 RPM | Measured: 3394.00 RPM | Error: 606.00 RPM | PWM: 1266.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 74.28s | Desired: 4000.00 RPM | Measured: 3860.00 RPM | Error: 140.00 RPM | PWM: 3.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 75.33s | Desired: 4000.00 RPM | Measured: 3964.00 RPM | Error: 36.00 RPM | PWM: 18.349999999999994 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 76.36s | Desired: 4000.00 RPM | Measured: 4162.00 RPM | Error: -162.00 RPM | PWM: -353.54999999999995 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 77.39s | Desired: 4000.00 RPM | Measured: 3070.00 RPM | Error: 930.00 RPM | PWM: 2046.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 78.43s | Desired: 4000.00 RPM | Measured: 3788.00 RPM | Error: 212.00 RPM | PWM: -7.0499999999999545 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 79.46s | Desired: 4000.00 RPM | Measured: 3594.00 RPM | Error: 406.00 RPM | PWM: 759.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 80.49s | Desired: 4000.00 RPM | Measured: 3943.00 RPM | Error: 57.00 RPM | PWM: -70.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 81.53s | Desired: 4000.00 RPM | Measured: 3997.00 RPM | Error: 3.00 RPM | PWM: -9.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 82.56s | Desired: 4000.00 RPM | Measured: 3972.00 RPM | Error: 28.00 RPM | PWM: 70.05000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 83.61s | Desired: 4000.00 RPM | Measured: 3344.00 RPM | Error: 656.00 RPM | PWM: 1376.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 84.64s | Desired: 4000.00 RPM | Measured: 4027.00 RPM | Error: -27.00 RPM | PWM: -373.3 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 85.66s | Desired: 4000.00 RPM | Measured: 3969.00 RPM | Error: 31.00 RPM | PWM: 91.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 86.70s | Desired: 4000.00 RPM | Measured: 3956.00 RPM | Error: 44.00 RPM | PWM: 89.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 87.73s | Desired: 4000.00 RPM | Measured: 3979.00 RPM | Error: 21.00 RPM | PWM: 34.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 88.77s | Desired: 4000.00 RPM | Measured: 3984.00 RPM | Error: 16.00 RPM | PWM: 35.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 89.80s | Desired: 4000.00 RPM | Measured: 3968.00 RPM | Error: 32.00 RPM | PWM: 71.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 90.83s | Desired: 4000.00 RPM | Measured: 3994.00 RPM | Error: 6.00 RPM | PWM: 9.350000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 91.86s | Desired: 4000.00 RPM | Measured: 4119.00 RPM | Error: -119.00 RPM | PWM: -246.1 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 92.90s | Desired: 4000.00 RPM | Measured: 3988.00 RPM | Error: 12.00 RPM | PWM: 92.1 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 93.93s | Desired: 4000.00 RPM | Measured: 3954.00 RPM | Error: 46.00 RPM | PWM: 100.30000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 94.97s | Desired: 4000.00 RPM | Measured: 4113.00 RPM | Error: -113.00 RPM | PWM: -256.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 96.00s | Desired: 4000.00 RPM | Measured: 3967.00 RPM | Error: 33.00 RPM | PWM: 131.5 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 97.04s | Desired: 4000.00 RPM | Measured: 3946.00 RPM | Error: 54.00 RPM | PWM: 105.30000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 98.06s | Desired: 4000.00 RPM | Measured: 4109.00 RPM | Error: -109.00 RPM | PWM: -252.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 99.11s | Desired: 4000.00 RPM | Measured: 4165.00 RPM | Error: -165.00 RPM | PWM: -297.3 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 100.14s | Desired: 4000.00 RPM | Measured: 4033.00 RPM | Error: -33.00 RPM | PWM: 6.249999999999993 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 101.18s | Desired: 4000.00 RPM | Measured: 4146.00 RPM | Error: -146.00 RPM | PWM: -302.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 102.21s | Desired: 4000.00 RPM | Measured: 4043.00 RPM | Error: -43.00 RPM | PWM: -30.049999999999997 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 103.25s | Desired: 4000.00 RPM | Measured: 3759.00 RPM | Error: 241.00 RPM | PWM: 526.9000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 104.27s | Desired: 4000.00 RPM | Measured: 4073.00 RPM | Error: -73.00 RPM | PWM: -278.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 105.30s | Desired: 4000.00 RPM | Measured: 4021.00 RPM | Error: -21.00 RPM | PWM: -13.0 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 106.34s | Desired: 4000.00 RPM | Measured: 4129.00 RPM | Error: -129.00 RPM | PWM: -272.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 107.38s | Desired: 4000.00 RPM | Measured: 4050.00 RPM | Error: -50.00 RPM | PWM: -53.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 108.41s | Desired: 4000.00 RPM | Measured: 4015.00 RPM | Error: -15.00 RPM | PWM: -19.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 109.45s | Desired: 4000.00 RPM | Measured: 4013.00 RPM | Error: -13.00 RPM | PWM: -32.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 110.48s | Desired: 4000.00 RPM | Measured: 4023.00 RPM | Error: -23.00 RPM | PWM: -54.550000000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 111.51s | Desired: 4000.00 RPM | Measured: 3192.00 RPM | Error: 808.00 RPM | PWM: 1721.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 112.55s | Desired: 4000.00 RPM | Measured: 4011.00 RPM | Error: -11.00 RPM | PWM: -414.9 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 113.59s | Desired: 4000.00 RPM | Measured: 4029.00 RPM | Error: -29.00 RPM | PWM: -44.650000000000006 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 114.61s | Desired: 4000.00 RPM | Measured: 4161.00 RPM | Error: -161.00 RPM | PWM: -320.90000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 115.66s | Desired: 4000.00 RPM | Measured: 4191.00 RPM | Error: -191.00 RPM | PWM: -327.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 116.69s | Desired: 4000.00 RPM | Measured: 4196.00 RPM | Error: -196.00 RPM | PWM: -328.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 117.72s | Desired: 4000.00 RPM | Measured: 4045.00 RPM | Error: -45.00 RPM | PWM: -9.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 118.76s | Desired: 4000.00 RPM | Measured: 4033.00 RPM | Error: -33.00 RPM | PWM: -59.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 119.80s | Desired: 4000.00 RPM | Measured: 3025.00 RPM | Error: 975.00 RPM | PWM: 2076.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 120.83s | Desired: 4000.00 RPM | Measured: 3850.00 RPM | Error: 150.00 RPM | PWM: -159.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 121.86s | Desired: 4000.00 RPM | Measured: 4049.00 RPM | Error: -49.00 RPM | PWM: -167.60000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 122.90s | Desired: 4000.00 RPM | Measured: 4183.00 RPM | Error: -183.00 RPM | PWM: -358.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 123.92s | Desired: 4000.00 RPM | Measured: 3882.00 RPM | Error: 118.00 RPM | PWM: 346.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 124.95s | Desired: 4000.00 RPM | Measured: 3985.00 RPM | Error: 15.00 RPM | PWM: -19.7 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 126.00s | Desired: 4000.00 RPM | Measured: 3992.00 RPM | Error: 8.00 RPM | PWM: 17.5 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 127.03s | Desired: 4000.00 RPM | Measured: 3986.00 RPM | Error: 14.00 RPM | PWM: 34.300000000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 128.05s | Desired: 4000.00 RPM | Measured: 4162.00 RPM | Error: -162.00 RPM | PWM: -346.4 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 129.10s | Desired: 4000.00 RPM | Measured: 4029.00 RPM | Error: -29.00 RPM | PWM: 19.449999999999996 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 130.13s | Desired: 4000.00 RPM | Measured: 3771.00 RPM | Error: 229.00 RPM | PWM: 506.20000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 131.16s | Desired: 4000.00 RPM | Measured: 3474.00 RPM | Error: 526.00 RPM | PWM: 1002.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 132.20s | Desired: 4000.00 RPM | Measured: 3870.00 RPM | Error: 130.00 RPM | PWM: 22.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 133.23s | Desired: 4000.00 RPM | Measured: 3996.00 RPM | Error: 4.00 RPM | PWM: -43.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 134.27s | Desired: 4000.00 RPM | Measured: 3983.00 RPM | Error: 17.00 RPM | PWM: 46.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 135.30s | Desired: 4000.00 RPM | Measured: 4028.00 RPM | Error: -28.00 RPM | PWM: -55.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 136.33s | Desired: 4000.00 RPM | Measured: 3975.00 RPM | Error: 25.00 RPM | PWM: 79.1 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 137.38s | Desired: 4000.00 RPM | Measured: 3989.00 RPM | Error: 11.00 RPM | PWM: 23.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 138.41s | Desired: 4000.00 RPM | Measured: 4022.00 RPM | Error: -22.00 RPM | PWM: -40.050000000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 139.45s | Desired: 4000.00 RPM | Measured: 3739.00 RPM | Error: 261.00 RPM | PWM: 571.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 140.48s | Desired: 4000.00 RPM | Measured: 3924.00 RPM | Error: 76.00 RPM | PWM: 41.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 141.52s | Desired: 4000.00 RPM | Measured: 3344.00 RPM | Error: 656.00 RPM | PWM: 1352.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 142.55s | Desired: 4000.00 RPM | Measured: 4045.00 RPM | Error: -45.00 RPM | PWM: -412.0 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 143.58s | Desired: 4000.00 RPM | Measured: 4173.00 RPM | Error: -173.00 RPM | PWM: -338.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 144.61s | Desired: 4000.00 RPM | Measured: 4012.00 RPM | Error: -12.00 RPM | PWM: 62.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 145.64s | Desired: 4000.00 RPM | Measured: 4005.00 RPM | Error: -5.00 RPM | PWM: -3.5 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 146.68s | Desired: 4000.00 RPM | Measured: 4001.00 RPM | Error: -1.00 RPM | PWM: 1.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 147.72s | Desired: 4000.00 RPM | Measured: 3955.00 RPM | Error: 45.00 RPM | PWM: 98.2 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 148.75s | Desired: 4000.00 RPM | Measured: 3955.00 RPM | Error: 45.00 RPM | PWM: 77.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 149.78s | Desired: 4000.00 RPM | Measured: 3975.00 RPM | Error: 25.00 RPM | PWM: 36.7 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 150.83s | Desired: 4000.00 RPM | Measured: 3944.00 RPM | Error: 56.00 RPM | PWM: 114.60000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 151.85s | Desired: 4000.00 RPM | Measured: 4117.00 RPM | Error: -117.00 RPM | PWM: -270.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 152.88s | Desired: 4000.00 RPM | Measured: 3977.00 RPM | Error: 23.00 RPM | PWM: 111.60000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 153.93s | Desired: 4000.00 RPM | Measured: 4131.00 RPM | Error: -131.00 RPM | PWM: -288.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 154.96s | Desired: 4000.00 RPM | Measured: 3987.00 RPM | Error: 13.00 RPM | PWM: 91.7 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 155.99s | Desired: 4000.00 RPM | Measured: 4002.00 RPM | Error: -2.00 RPM | PWM: -11.9 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 157.02s | Desired: 4000.00 RPM | Measured: 3982.00 RPM | Error: 18.00 RPM | PWM: 38.5 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 158.07s | Desired: 4000.00 RPM | Measured: 3988.00 RPM | Error: 12.00 RPM | PWM: 16.500000000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 159.10s | Desired: 4000.00 RPM | Measured: 3493.00 RPM | Error: 507.00 RPM | PWM: 1071.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 160.13s | Desired: 4000.00 RPM | Measured: 3880.00 RPM | Error: 120.00 RPM | PWM: 11.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 161.16s | Desired: 4000.00 RPM | Measured: 3932.00 RPM | Error: 68.00 RPM | PWM: 95.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 162.20s | Desired: 4000.00 RPM | Measured: 2957.00 RPM | Error: 1043.00 RPM | PWM: 2169.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 163.24s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: -53.049999999999955 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 164.26s | Desired: 4000.00 RPM | Measured: 3725.00 RPM | Error: 275.00 RPM | PWM: 481.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 165.30s | Desired: 4000.00 RPM | Measured: 3903.00 RPM | Error: 97.00 RPM | PWM: 78.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 166.34s | Desired: 4000.00 RPM | Measured: 4114.00 RPM | Error: -114.00 RPM | PWM: -280.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 167.38s | Desired: 4000.00 RPM | Measured: 3982.00 RPM | Error: 18.00 RPM | PWM: 102.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 168.41s | Desired: 4000.00 RPM | Measured: 3937.00 RPM | Error: 63.00 RPM | PWM: 134.4 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 169.43s | Desired: 4000.00 RPM | Measured: 3940.00 RPM | Error: 60.00 RPM | PWM: 107.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 170.48s | Desired: 4000.00 RPM | Measured: 3953.00 RPM | Error: 47.00 RPM | PWM: 81.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 171.51s | Desired: 4000.00 RPM | Measured: 3972.00 RPM | Error: 28.00 RPM | PWM: 48.050000000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 172.55s | Desired: 4000.00 RPM | Measured: 3719.00 RPM | Error: 281.00 RPM | PWM: 588.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 173.58s | Desired: 4000.00 RPM | Measured: 3940.00 RPM | Error: 60.00 RPM | PWM: -1.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 174.61s | Desired: 4000.00 RPM | Measured: 3961.00 RPM | Error: 39.00 RPM | PWM: 64.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 175.65s | Desired: 4000.00 RPM | Measured: 3976.00 RPM | Error: 24.00 RPM | PWM: 43.650000000000006 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 176.68s | Desired: 4000.00 RPM | Measured: 4137.00 RPM | Error: -137.00 RPM | PWM: -293.8 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 177.72s | Desired: 4000.00 RPM | Measured: 4000.00 RPM | Error: 0.00 RPM | PWM: 74.4 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 178.74s | Desired: 4000.00 RPM | Measured: 3971.00 RPM | Error: 29.00 RPM | PWM: 68.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 179.78s | Desired: 4000.00 RPM | Measured: 3995.00 RPM | Error: 5.00 RPM | PWM: 3.6000000000000014 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 180.82s | Desired: 4000.00 RPM | Measured: 4026.00 RPM | Error: -26.00 RPM | PWM: -50.8 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 181.84s | Desired: 4000.00 RPM | Measured: 4007.00 RPM | Error: -7.00 RPM | PWM: 4.249999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 182.88s | Desired: 4000.00 RPM | Measured: 4169.00 RPM | Error: -169.00 RPM | PWM: -353.90000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 183.91s | Desired: 4000.00 RPM | Measured: 4198.00 RPM | Error: -198.00 RPM | PWM: -343.7 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 184.95s | Desired: 4000.00 RPM | Measured: 4074.00 RPM | Error: -74.00 RPM | PWM: -69.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 185.99s | Desired: 4000.00 RPM | Measured: 4066.00 RPM | Error: -66.00 RPM | PWM: -114.35000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 187.02s | Desired: 4000.00 RPM | Measured: 3686.00 RPM | Error: 314.00 RPM | PWM: 695.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 188.05s | Desired: 4000.00 RPM | Measured: 3954.00 RPM | Error: 46.00 RPM | PWM: -55.14999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 189.10s | Desired: 4000.00 RPM | Measured: 4182.00 RPM | Error: -182.00 RPM | PWM: -409.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 190.13s | Desired: 4000.00 RPM | Measured: 4046.00 RPM | Error: -46.00 RPM | PWM: -11.750000000000014 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 191.16s | Desired: 4000.00 RPM | Measured: 4165.00 RPM | Error: -165.00 RPM | PWM: -336.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 192.20s | Desired: 4000.00 RPM | Measured: 4047.00 RPM | Error: -47.00 RPM | PWM: -28.950000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 193.24s | Desired: 4000.00 RPM | Measured: 3182.00 RPM | Error: 818.00 RPM | PWM: 1754.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 194.26s | Desired: 4000.00 RPM | Measured: 4029.00 RPM | Error: -29.00 RPM | PWM: -458.6 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 195.30s | Desired: 4000.00 RPM | Measured: 4073.00 RPM | Error: -73.00 RPM | PWM: -131.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 196.33s | Desired: 4000.00 RPM | Measured: 4045.00 RPM | Error: -45.00 RPM | PWM: -52.599999999999994 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 197.38s | Desired: 4000.00 RPM | Measured: 2945.00 RPM | Error: 1055.00 RPM | PWM: 2250.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 198.41s | Desired: 4000.00 RPM | Measured: 3826.00 RPM | Error: 174.00 RPM | PWM: -149.34999999999997 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 199.45s | Desired: 4000.00 RPM | Measured: 3679.00 RPM | Error: 321.00 RPM | PWM: 599.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 200.48s | Desired: 4000.00 RPM | Measured: 4044.00 RPM | Error: -44.00 RPM | PWM: -242.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 201.52s | Desired: 4000.00 RPM | Measured: 3709.00 RPM | Error: 291.00 RPM | PWM: 645.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 202.55s | Desired: 4000.00 RPM | Measured: 3975.00 RPM | Error: 25.00 RPM | PWM: -80.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 203.58s | Desired: 4000.00 RPM | Measured: 4078.00 RPM | Error: -78.00 RPM | PWM: -167.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 204.61s | Desired: 4000.00 RPM | Measured: 4215.00 RPM | Error: -215.00 RPM | PWM: -414.4 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 205.64s | Desired: 4000.00 RPM | Measured: 4081.00 RPM | Error: -81.00 RPM | PWM: -68.54999999999998 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 206.68s | Desired: 4000.00 RPM | Measured: 3083.00 RPM | Error: 917.00 RPM | PWM: 1978.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 207.71s | Desired: 4000.00 RPM | Measured: 3930.00 RPM | Error: 70.00 RPM | PWM: -298.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 208.75s | Desired: 4000.00 RPM | Measured: 4066.00 RPM | Error: -66.00 RPM | PWM: -164.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 209.79s | Desired: 4000.00 RPM | Measured: 4066.00 RPM | Error: -66.00 RPM | PWM: -99.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 210.81s | Desired: 4000.00 RPM | Measured: 4083.00 RPM | Error: -83.00 RPM | PWM: -139.3 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 211.85s | Desired: 4000.00 RPM | Measured: 4095.00 RPM | Error: -95.00 RPM | PWM: -160.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 212.88s | Desired: 4000.00 RPM | Measured: 4073.00 RPM | Error: -73.00 RPM | PWM: -112.20000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 213.91s | Desired: 4000.00 RPM | Measured: 3529.00 RPM | Error: 471.00 RPM | PWM: 1038.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 214.96s | Desired: 4000.00 RPM | Measured: 3990.00 RPM | Error: 10.00 RPM | PWM: -201.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 216.00s | Desired: 4000.00 RPM | Measured: 4071.00 RPM | Error: -71.00 RPM | PWM: -144.9 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 217.02s | Desired: 4000.00 RPM | Measured: 4066.00 RPM | Error: -66.00 RPM | PWM: -97.2 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 218.06s | Desired: 4000.00 RPM | Measured: 4054.00 RPM | Error: -54.00 RPM | PWM: -77.2 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 219.10s | Desired: 4000.00 RPM | Measured: 4087.00 RPM | Error: -87.00 RPM | PWM: -156.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 220.13s | Desired: 4000.00 RPM | Measured: 3466.00 RPM | Error: 534.00 RPM | PWM: 1177.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 221.16s | Desired: 4000.00 RPM | Measured: 3969.00 RPM | Error: 31.00 RPM | PWM: -189.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 222.20s | Desired: 4000.00 RPM | Measured: 4020.00 RPM | Error: -20.00 RPM | PWM: -45.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 223.23s | Desired: 4000.00 RPM | Measured: 4092.00 RPM | Error: -92.00 RPM | PWM: -176.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 224.26s | Desired: 4000.00 RPM | Measured: 4121.00 RPM | Error: -121.00 RPM | PWM: -207.00000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 225.30s | Desired: 4000.00 RPM | Measured: 4065.00 RPM | Error: -65.00 RPM | PWM: -78.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 226.32s | Desired: 4000.00 RPM | Measured: 4062.00 RPM | Error: -62.00 RPM | PWM: -102.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 227.36s | Desired: 4000.00 RPM | Measured: 4073.00 RPM | Error: -73.00 RPM | PWM: -131.20000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 228.40s | Desired: 4000.00 RPM | Measured: 3522.00 RPM | Error: 478.00 RPM | PWM: 1053.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 229.43s | Desired: 4000.00 RPM | Measured: 4120.00 RPM | Error: -120.00 RPM | PWM: -484.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 230.46s | Desired: 4000.00 RPM | Measured: 4118.00 RPM | Error: -118.00 RPM | PWM: -186.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 231.50s | Desired: 4000.00 RPM | Measured: 4196.00 RPM | Error: -196.00 RPM | PWM: -361.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 232.55s | Desired: 4000.00 RPM | Measured: 4094.00 RPM | Error: -94.00 RPM | PWM: -112.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 233.57s | Desired: 4000.00 RPM | Measured: 4046.00 RPM | Error: -46.00 RPM | PWM: -62.35000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 234.60s | Desired: 4000.00 RPM | Measured: 3641.00 RPM | Error: 359.00 RPM | PWM: 782.1 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 235.64s | Desired: 4000.00 RPM | Measured: 3998.00 RPM | Error: 2.00 RPM | PWM: -170.0 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 236.68s | Desired: 4000.00 RPM | Measured: 4238.00 RPM | Error: -238.00 RPM | PWM: -507.40000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 237.71s | Desired: 4000.00 RPM | Measured: 4221.00 RPM | Error: -221.00 RPM | PWM: -357.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 238.75s | Desired: 4000.00 RPM | Measured: 4066.00 RPM | Error: -66.00 RPM | PWM: -40.85000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 239.77s | Desired: 4000.00 RPM | Measured: 3397.00 RPM | Error: 603.00 RPM | PWM: 1312.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 240.82s | Desired: 4000.00 RPM | Measured: 4098.00 RPM | Error: -98.00 RPM | PWM: -499.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 241.85s | Desired: 4000.00 RPM | Measured: 4220.00 RPM | Error: -220.00 RPM | PWM: -416.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 242.88s | Desired: 4000.00 RPM | Measured: 4061.00 RPM | Error: -61.00 RPM | PWM: -24.30000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 243.91s | Desired: 4000.00 RPM | Measured: 4171.00 RPM | Error: -171.00 RPM | PWM: -341.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 244.94s | Desired: 4000.00 RPM | Measured: 4084.00 RPM | Error: -84.00 RPM | PWM: -103.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 245.98s | Desired: 4000.00 RPM | Measured: 4055.00 RPM | Error: -55.00 RPM | PWM: -86.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 247.02s | Desired: 4000.00 RPM | Measured: 4053.00 RPM | Error: -53.00 RPM | PWM: -96.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 248.05s | Desired: 4000.00 RPM | Measured: 3034.00 RPM | Error: 966.00 RPM | PWM: 2067.8500000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 249.10s | Desired: 4000.00 RPM | Measured: 3742.00 RPM | Error: 258.00 RPM | PWM: 71.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 250.13s | Desired: 4000.00 RPM | Measured: 3056.00 RPM | Error: 944.00 RPM | PWM: 1866.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 251.16s | Desired: 4000.00 RPM | Measured: 3915.00 RPM | Error: 85.00 RPM | PWM: -280.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 252.19s | Desired: 4000.00 RPM | Measured: 4048.00 RPM | Error: -48.00 RPM | PWM: -132.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 253.23s | Desired: 4000.00 RPM | Measured: 4177.00 RPM | Error: -177.00 RPM | PWM: -346.2 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 254.26s | Desired: 4000.00 RPM | Measured: 4073.00 RPM | Error: -73.00 RPM | PWM: -66.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 255.30s | Desired: 4000.00 RPM | Measured: 4197.00 RPM | Error: -197.00 RPM | PWM: -389.20000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 256.33s | Desired: 4000.00 RPM | Measured: 3583.00 RPM | Error: 417.00 RPM | PWM: 983.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 257.37s | Desired: 4000.00 RPM | Measured: 4171.00 RPM | Error: -171.00 RPM | PWM: -567.3 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 258.41s | Desired: 4000.00 RPM | Measured: 4138.00 RPM | Error: -138.00 RPM | PWM: -210.9 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 259.43s | Desired: 4000.00 RPM | Measured: 4069.00 RPM | Error: -69.00 RPM | PWM: -85.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 260.48s | Desired: 4000.00 RPM | Measured: 4083.00 RPM | Error: -83.00 RPM | PWM: -152.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 261.51s | Desired: 4000.00 RPM | Measured: 4104.00 RPM | Error: -104.00 RPM | PWM: -189.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 262.53s | Desired: 4000.00 RPM | Measured: 4119.00 RPM | Error: -119.00 RPM | PWM: -210.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 263.58s | Desired: 4000.00 RPM | Measured: 4096.00 RPM | Error: -96.00 RPM | PWM: -154.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 264.60s | Desired: 4000.00 RPM | Measured: 3480.00 RPM | Error: 520.00 RPM | PWM: 1152.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 265.65s | Desired: 4000.00 RPM | Measured: 3988.00 RPM | Error: 12.00 RPM | PWM: -222.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 266.68s | Desired: 4000.00 RPM | Measured: 4088.00 RPM | Error: -88.00 RPM | PWM: -182.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 267.72s | Desired: 4000.00 RPM | Measured: 4215.00 RPM | Error: -215.00 RPM | PWM: -409.9 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 268.74s | Desired: 4000.00 RPM | Measured: 4077.00 RPM | Error: -77.00 RPM | PWM: -60.44999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 269.78s | Desired: 4000.00 RPM | Measured: 4179.00 RPM | Error: -179.00 RPM | PWM: -350.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 270.82s | Desired: 4000.00 RPM | Measured: 4214.00 RPM | Error: -214.00 RPM | PWM: -372.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 271.85s | Desired: 4000.00 RPM | Measured: 3928.00 RPM | Error: 72.00 RPM | PWM: 249.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 272.88s | Desired: 4000.00 RPM | Measured: 4023.00 RPM | Error: -23.00 RPM | PWM: -94.60000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 273.91s | Desired: 4000.00 RPM | Measured: 4208.00 RPM | Error: -208.00 RPM | PWM: -438.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 274.96s | Desired: 4000.00 RPM | Measured: 4099.00 RPM | Error: -99.00 RPM | PWM: -116.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 275.99s | Desired: 4000.00 RPM | Measured: 4077.00 RPM | Error: -77.00 RPM | PWM: -124.94999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 277.02s | Desired: 4000.00 RPM | Measured: 4199.00 RPM | Error: -199.00 RPM | PWM: -392.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 278.05s | Desired: 4000.00 RPM | Measured: 4197.00 RPM | Error: -197.00 RPM | PWM: -326.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 279.10s | Desired: 4000.00 RPM | Measured: 4197.00 RPM | Error: -197.00 RPM | PWM: -327.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 280.13s | Desired: 4000.00 RPM | Measured: 4193.00 RPM | Error: -193.00 RPM | PWM: -319.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 281.16s | Desired: 4000.00 RPM | Measured: 4025.00 RPM | Error: -25.00 RPM | PWM: 31.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 282.20s | Desired: 4000.00 RPM | Measured: 4031.00 RPM | Error: -31.00 RPM | PWM: -65.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 283.23s | Desired: 4000.00 RPM | Measured: 4051.00 RPM | Error: -51.00 RPM | PWM: -104.35000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 284.26s | Desired: 4000.00 RPM | Measured: 3670.00 RPM | Error: 330.00 RPM | PWM: 722.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 285.30s | Desired: 4000.00 RPM | Measured: 3987.00 RPM | Error: 13.00 RPM | PWM: -133.3 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 286.34s | Desired: 4000.00 RPM | Measured: 4019.00 RPM | Error: -19.00 RPM | PWM: -42.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 287.37s | Desired: 4000.00 RPM | Measured: 4026.00 RPM | Error: -26.00 RPM | PWM: -42.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 288.40s | Desired: 4000.00 RPM | Measured: 4068.00 RPM | Error: -68.00 RPM | PWM: -131.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 289.43s | Desired: 4000.00 RPM | Measured: 4028.00 RPM | Error: -28.00 RPM | PWM: -27.450000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 290.48s | Desired: 4000.00 RPM | Measured: 3758.00 RPM | Error: 242.00 RPM | PWM: 531.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 291.52s | Desired: 4000.00 RPM | Measured: 4175.00 RPM | Error: -175.00 RPM | PWM: -487.8 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 292.54s | Desired: 4000.00 RPM | Measured: 4115.00 RPM | Error: -115.00 RPM | PWM: -159.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 293.58s | Desired: 4000.00 RPM | Measured: 4016.00 RPM | Error: -16.00 RPM | PWM: 18.049999999999997 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 294.62s | Desired: 4000.00 RPM | Measured: 3722.00 RPM | Error: 278.00 RPM | PWM: 599.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 295.65s | Desired: 4000.00 RPM | Measured: 3929.00 RPM | Error: 71.00 RPM | PWM: 21.700000000000017 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 296.67s | Desired: 4000.00 RPM | Measured: 4133.00 RPM | Error: -133.00 RPM | PWM: -309.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 297.71s | Desired: 4000.00 RPM | Measured: 3973.00 RPM | Error: 27.00 RPM | PWM: 129.5 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 298.75s | Desired: 4000.00 RPM | Measured: 3952.00 RPM | Error: 48.00 RPM | PWM: 96.00000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 299.79s | Desired: 4000.00 RPM | Measured: 3961.00 RPM | Error: 39.00 RPM | PWM: 68.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 300.82s | Desired: 4000.00 RPM | Measured: 3006.00 RPM | Error: 994.00 RPM | PWM: 2080.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 301.85s | Desired: 4000.00 RPM | Measured: 3873.00 RPM | Error: 127.00 RPM | PWM: -217.54999999999998 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 302.88s | Desired: 4000.00 RPM | Measured: 3020.00 RPM | Error: 980.00 RPM | PWM: 2007.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 303.92s | Desired: 4000.00 RPM | Measured: 3919.00 RPM | Error: 81.00 RPM | PWM: -307.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 304.96s | Desired: 4000.00 RPM | Measured: 4043.00 RPM | Error: -43.00 RPM | PWM: -120.19999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 305.98s | Desired: 4000.00 RPM | Measured: 3507.00 RPM | Error: 493.00 RPM | PWM: 1069.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 307.02s | Desired: 4000.00 RPM | Measured: 4057.00 RPM | Error: -57.00 RPM | PWM: -356.3 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 308.06s | Desired: 4000.00 RPM | Measured: 4029.00 RPM | Error: -29.00 RPM | PWM: -23.950000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 309.10s | Desired: 4000.00 RPM | Measured: 3237.00 RPM | Error: 763.00 RPM | PWM: 1629.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 310.13s | Desired: 4000.00 RPM | Measured: 3892.00 RPM | Error: 108.00 RPM | PWM: -141.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 311.17s | Desired: 4000.00 RPM | Measured: 3986.00 RPM | Error: 14.00 RPM | PWM: -11.849999999999994 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 312.19s | Desired: 4000.00 RPM | Measured: 3691.00 RPM | Error: 309.00 RPM | PWM: 654.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 313.23s | Desired: 4000.00 RPM | Measured: 4063.00 RPM | Error: -63.00 RPM | PWM: -277.20000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 314.27s | Desired: 4000.00 RPM | Measured: 3465.00 RPM | Error: 535.00 RPM | PWM: 1167.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 315.30s | Desired: 4000.00 RPM | Measured: 3837.00 RPM | Error: 163.00 RPM | PWM: 87.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 316.34s | Desired: 4000.00 RPM | Measured: 2977.00 RPM | Error: 1023.00 RPM | PWM: 2079.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 317.38s | Desired: 4000.00 RPM | Measured: 3823.00 RPM | Error: 177.00 RPM | PWM: -127.05000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 318.42s | Desired: 4000.00 RPM | Measured: 3311.00 RPM | Error: 689.00 RPM | PWM: 1371.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 319.45s | Desired: 4000.00 RPM | Measured: 3843.00 RPM | Error: 157.00 RPM | PWM: -2.0499999999999545 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 320.47s | Desired: 4000.00 RPM | Measured: 3520.00 RPM | Error: 480.00 RPM | PWM: 942.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 321.51s | Desired: 4000.00 RPM | Measured: 3895.00 RPM | Error: 105.00 RPM | PWM: -6.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 322.55s | Desired: 4000.00 RPM | Measured: 3981.00 RPM | Error: 19.00 RPM | PWM: 0.15000000000000568 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 323.58s | Desired: 4000.00 RPM | Measured: 4114.00 RPM | Error: -114.00 RPM | PWM: -241.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 324.62s | Desired: 4000.00 RPM | Measured: 3981.00 RPM | Error: 19.00 RPM | PWM: 104.9 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 325.65s | Desired: 4000.00 RPM | Measured: 3950.00 RPM | Error: 50.00 RPM | PWM: 106.0 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 326.68s | Desired: 4000.00 RPM | Measured: 4114.00 RPM | Error: -114.00 RPM | PWM: -259.6 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 327.71s | Desired: 4000.00 RPM | Measured: 3918.00 RPM | Error: 82.00 RPM | PWM: 238.10000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 328.75s | Desired: 4000.00 RPM | Measured: 4062.00 RPM | Error: -62.00 RPM | PWM: -165.4 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 329.79s | Desired: 4000.00 RPM | Measured: 3893.00 RPM | Error: 107.00 RPM | PWM: 266.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 330.82s | Desired: 4000.00 RPM | Measured: 3934.00 RPM | Error: 66.00 RPM | PWM: 97.85000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 331.85s | Desired: 4000.00 RPM | Measured: 3362.00 RPM | Error: 638.00 RPM | PWM: 1319.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 332.88s | Desired: 4000.00 RPM | Measured: 3955.00 RPM | Error: 45.00 RPM | PWM: -211.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 333.92s | Desired: 4000.00 RPM | Measured: 3837.00 RPM | Error: 163.00 RPM | PWM: 332.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 334.96s | Desired: 4000.00 RPM | Measured: 3878.00 RPM | Error: 122.00 RPM | PWM: 187.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 335.98s | Desired: 4000.00 RPM | Measured: 4057.00 RPM | Error: -57.00 RPM | PWM: -170.8 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 337.02s | Desired: 4000.00 RPM | Measured: 3913.00 RPM | Error: 87.00 RPM | PWM: 223.95000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 338.05s | Desired: 4000.00 RPM | Measured: 4101.00 RPM | Error: -101.00 RPM | PWM: -247.90000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 339.09s | Desired: 4000.00 RPM | Measured: 4106.00 RPM | Error: -106.00 RPM | PWM: -169.70000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 340.13s | Desired: 4000.00 RPM | Measured: 3102.00 RPM | Error: 898.00 RPM | PWM: 1951.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 341.17s | Desired: 4000.00 RPM | Measured: 3873.00 RPM | Error: 127.00 RPM | PWM: -169.54999999999998 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 342.20s | Desired: 4000.00 RPM | Measured: 2872.00 RPM | Error: 1128.00 RPM | PWM: 2318.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 343.23s | Desired: 4000.00 RPM | Measured: 3709.00 RPM | Error: 291.00 RPM | PWM: 59.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 344.27s | Desired: 4000.00 RPM | Measured: 3317.00 RPM | Error: 683.00 RPM | PWM: 1301.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 345.30s | Desired: 4000.00 RPM | Measured: 3834.00 RPM | Error: 166.00 RPM | PWM: 19.850000000000023 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 346.33s | Desired: 4000.00 RPM | Measured: 3640.00 RPM | Error: 360.00 RPM | PWM: 685.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 347.37s | Desired: 4000.00 RPM | Measured: 3863.00 RPM | Error: 137.00 RPM | PWM: 120.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 348.40s | Desired: 4000.00 RPM | Measured: 4075.00 RPM | Error: -75.00 RPM | PWM: -217.0 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 349.45s | Desired: 4000.00 RPM | Measured: 4080.00 RPM | Error: -80.00 RPM | PWM: -125.5 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 350.48s | Desired: 4000.00 RPM | Measured: 3937.00 RPM | Error: 63.00 RPM | PWM: 180.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 351.52s | Desired: 4000.00 RPM | Measured: 4043.00 RPM | Error: -43.00 RPM | PWM: -115.8 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 352.55s | Desired: 4000.00 RPM | Measured: 3932.00 RPM | Error: 68.00 RPM | PWM: 173.70000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 353.59s | Desired: 4000.00 RPM | Measured: 3036.00 RPM | Error: 964.00 RPM | PWM: 2003.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 354.62s | Desired: 4000.00 RPM | Measured: 3724.00 RPM | Error: 276.00 RPM | PWM: 110.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 355.65s | Desired: 4000.00 RPM | Measured: 3512.00 RPM | Error: 488.00 RPM | PWM: 899.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 356.68s | Desired: 4000.00 RPM | Measured: 4000.00 RPM | Error: 0.00 RPM | PWM: -231.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 357.72s | Desired: 4000.00 RPM | Measured: 3895.00 RPM | Error: 105.00 RPM | PWM: 233.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 358.76s | Desired: 4000.00 RPM | Measured: 3852.00 RPM | Error: 148.00 RPM | PWM: 271.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 359.78s | Desired: 4000.00 RPM | Measured: 3807.00 RPM | Error: 193.00 RPM | PWM: 344.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 360.82s | Desired: 4000.00 RPM | Measured: 3656.00 RPM | Error: 344.00 RPM | PWM: 638.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 361.85s | Desired: 4000.00 RPM | Measured: 3628.00 RPM | Error: 372.00 RPM | PWM: 621.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 362.88s | Desired: 4000.00 RPM | Measured: 3674.00 RPM | Error: 326.00 RPM | PWM: 511.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 363.93s | Desired: 4000.00 RPM | Measured: 3663.00 RPM | Error: 337.00 RPM | PWM: 557.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 364.96s | Desired: 4000.00 RPM | Measured: 3714.00 RPM | Error: 286.00 RPM | PWM: 444.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 365.99s | Desired: 4000.00 RPM | Measured: 3694.00 RPM | Error: 306.00 RPM | PWM: 512.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 367.03s | Desired: 4000.00 RPM | Measured: 3740.00 RPM | Error: 260.00 RPM | PWM: 405.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 368.07s | Desired: 4000.00 RPM | Measured: 3829.00 RPM | Error: 171.00 RPM | PWM: 241.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 369.10s | Desired: 4000.00 RPM | Measured: 3209.00 RPM | Error: 791.00 RPM | PWM: 1588.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 370.13s | Desired: 4000.00 RPM | Measured: 3899.00 RPM | Error: 101.00 RPM | PWM: -170.64999999999998 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 371.16s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 531.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 372.21s | Desired: 4000.00 RPM | Measured: 3836.00 RPM | Error: 164.00 RPM | PWM: 221.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 373.24s | Desired: 4000.00 RPM | Measured: 3687.00 RPM | Error: 313.00 RPM | PWM: 588.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 374.27s | Desired: 4000.00 RPM | Measured: 3778.00 RPM | Error: 222.00 RPM | PWM: 322.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 375.30s | Desired: 4000.00 RPM | Measured: 3978.00 RPM | Error: 22.00 RPM | PWM: -52.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 376.35s | Desired: 4000.00 RPM | Measured: 3901.00 RPM | Error: 99.00 RPM | PWM: 209.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 377.38s | Desired: 4000.00 RPM | Measured: 3878.00 RPM | Error: 122.00 RPM | PWM: 219.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 378.42s | Desired: 4000.00 RPM | Measured: 3995.00 RPM | Error: 5.00 RPM | PWM: -37.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 379.45s | Desired: 4000.00 RPM | Measured: 3662.00 RPM | Error: 338.00 RPM | PWM: 720.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 380.48s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 368.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 381.52s | Desired: 4000.00 RPM | Measured: 3721.00 RPM | Error: 279.00 RPM | PWM: 473.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 382.55s | Desired: 4000.00 RPM | Measured: 3532.00 RPM | Error: 468.00 RPM | PWM: 856.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 383.59s | Desired: 4000.00 RPM | Measured: 3779.00 RPM | Error: 221.00 RPM | PWM: 242.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 384.62s | Desired: 4000.00 RPM | Measured: 3029.00 RPM | Error: 971.00 RPM | PWM: 1941.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 385.65s | Desired: 4000.00 RPM | Measured: 3843.00 RPM | Error: 157.00 RPM | PWM: -143.04999999999995 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 386.70s | Desired: 4000.00 RPM | Measured: 3192.00 RPM | Error: 808.00 RPM | PWM: 1631.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 387.73s | Desired: 4000.00 RPM | Measured: 3795.00 RPM | Error: 205.00 RPM | PWM: 39.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 388.76s | Desired: 4000.00 RPM | Measured: 3812.00 RPM | Error: 188.00 RPM | PWM: 305.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 389.80s | Desired: 4000.00 RPM | Measured: 3767.00 RPM | Error: 233.00 RPM | PWM: 408.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 390.82s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 351.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 391.85s | Desired: 4000.00 RPM | Measured: 3904.00 RPM | Error: 96.00 RPM | PWM: 105.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 392.90s | Desired: 4000.00 RPM | Measured: 3116.00 RPM | Error: 884.00 RPM | PWM: 1821.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 393.93s | Desired: 4000.00 RPM | Measured: 3629.00 RPM | Error: 371.00 RPM | PWM: 349.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 394.97s | Desired: 4000.00 RPM | Measured: 3767.00 RPM | Error: 233.00 RPM | PWM: 316.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 396.00s | Desired: 4000.00 RPM | Measured: 3798.00 RPM | Error: 202.00 RPM | PWM: 320.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 397.03s | Desired: 4000.00 RPM | Measured: 3983.00 RPM | Error: 17.00 RPM | PWM: -52.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 398.06s | Desired: 4000.00 RPM | Measured: 3831.00 RPM | Error: 169.00 RPM | PWM: 359.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 399.10s | Desired: 4000.00 RPM | Measured: 3946.00 RPM | Error: 54.00 RPM | PWM: 41.650000000000006 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 400.14s | Desired: 4000.00 RPM | Measured: 3984.00 RPM | Error: 16.00 RPM | PWM: 19.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 401.18s | Desired: 4000.00 RPM | Measured: 3795.00 RPM | Error: 205.00 RPM | PWM: 435.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 402.20s | Desired: 4000.00 RPM | Measured: 3783.00 RPM | Error: 217.00 RPM | PWM: 365.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 403.23s | Desired: 4000.00 RPM | Measured: 3954.00 RPM | Error: 46.00 RPM | PWM: 0.8500000000000085 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 404.27s | Desired: 4000.00 RPM | Measured: 3325.00 RPM | Error: 675.00 RPM | PWM: 1407.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 405.31s | Desired: 4000.00 RPM | Measured: 3736.00 RPM | Error: 264.00 RPM | PWM: 229.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 406.34s | Desired: 4000.00 RPM | Measured: 3599.00 RPM | Error: 401.00 RPM | PWM: 722.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 407.38s | Desired: 4000.00 RPM | Measured: 3626.00 RPM | Error: 374.00 RPM | PWM: 597.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 408.41s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 476.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 409.44s | Desired: 4000.00 RPM | Measured: 3701.00 RPM | Error: 299.00 RPM | PWM: 485.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 410.48s | Desired: 4000.00 RPM | Measured: 3543.00 RPM | Error: 457.00 RPM | PWM: 822.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 411.52s | Desired: 4000.00 RPM | Measured: 3684.00 RPM | Error: 316.00 RPM | PWM: 447.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 412.54s | Desired: 4000.00 RPM | Measured: 3682.00 RPM | Error: 318.00 RPM | PWM: 522.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 413.57s | Desired: 4000.00 RPM | Measured: 3697.00 RPM | Error: 303.00 RPM | PWM: 490.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 414.61s | Desired: 4000.00 RPM | Measured: 3707.00 RPM | Error: 293.00 RPM | PWM: 476.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 415.65s | Desired: 4000.00 RPM | Measured: 3725.00 RPM | Error: 275.00 RPM | PWM: 443.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 416.69s | Desired: 4000.00 RPM | Measured: 3733.00 RPM | Error: 267.00 RPM | PWM: 435.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 417.72s | Desired: 4000.00 RPM | Measured: 3880.00 RPM | Error: 120.00 RPM | PWM: 131.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 418.74s | Desired: 4000.00 RPM | Measured: 3748.00 RPM | Error: 252.00 RPM | PWM: 481.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 419.79s | Desired: 4000.00 RPM | Measured: 3840.00 RPM | Error: 160.00 RPM | PWM: 222.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 420.82s | Desired: 4000.00 RPM | Measured: 3678.00 RPM | Error: 322.00 RPM | PWM: 608.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 421.85s | Desired: 4000.00 RPM | Measured: 3594.00 RPM | Error: 406.00 RPM | PWM: 704.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 422.88s | Desired: 4000.00 RPM | Measured: 3660.00 RPM | Error: 340.00 RPM | PWM: 523.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 423.92s | Desired: 4000.00 RPM | Measured: 3677.00 RPM | Error: 323.00 RPM | PWM: 521.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 424.95s | Desired: 4000.00 RPM | Measured: 3874.00 RPM | Error: 126.00 RPM | PWM: 115.85000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 425.99s | Desired: 4000.00 RPM | Measured: 3155.00 RPM | Error: 845.00 RPM | PWM: 1724.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 427.02s | Desired: 4000.00 RPM | Measured: 3643.00 RPM | Error: 357.00 RPM | PWM: 339.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 428.06s | Desired: 4000.00 RPM | Measured: 3879.00 RPM | Error: 121.00 RPM | PWM: 88.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 429.09s | Desired: 4000.00 RPM | Measured: 3438.00 RPM | Error: 562.00 RPM | PWM: 1132.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 430.12s | Desired: 4000.00 RPM | Measured: 3586.00 RPM | Error: 414.00 RPM | PWM: 601.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 431.15s | Desired: 4000.00 RPM | Measured: 3873.00 RPM | Error: 127.00 RPM | PWM: 72.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 432.19s | Desired: 4000.00 RPM | Measured: 3897.00 RPM | Error: 103.00 RPM | PWM: 165.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 433.23s | Desired: 4000.00 RPM | Measured: 3781.00 RPM | Error: 219.00 RPM | PWM: 421.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 434.27s | Desired: 4000.00 RPM | Measured: 3876.00 RPM | Error: 124.00 RPM | PWM: 163.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 435.29s | Desired: 4000.00 RPM | Measured: 3703.00 RPM | Error: 297.00 RPM | PWM: 574.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 436.34s | Desired: 4000.00 RPM | Measured: 3731.00 RPM | Error: 269.00 RPM | PWM: 429.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 437.37s | Desired: 4000.00 RPM | Measured: 3905.00 RPM | Error: 95.00 RPM | PWM: 77.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 438.40s | Desired: 4000.00 RPM | Measured: 3825.00 RPM | Error: 175.00 RPM | PWM: 332.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 439.44s | Desired: 4000.00 RPM | Measured: 3830.00 RPM | Error: 170.00 RPM | PWM: 282.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 440.47s | Desired: 4000.00 RPM | Measured: 3748.00 RPM | Error: 252.00 RPM | PWM: 456.95000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 441.50s | Desired: 4000.00 RPM | Measured: 3948.00 RPM | Error: 52.00 RPM | PWM: -4.049999999999997 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 442.54s | Desired: 4000.00 RPM | Measured: 3601.00 RPM | Error: 399.00 RPM | PWM: 824.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 443.57s | Desired: 4000.00 RPM | Measured: 3947.00 RPM | Error: 53.00 RPM | PWM: -75.44999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 444.61s | Desired: 4000.00 RPM | Measured: 3985.00 RPM | Error: 15.00 RPM | PWM: 17.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 445.64s | Desired: 4000.00 RPM | Measured: 3881.00 RPM | Error: 119.00 RPM | PWM: 255.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 446.67s | Desired: 4000.00 RPM | Measured: 3869.00 RPM | Error: 131.00 RPM | PWM: 228.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 447.72s | Desired: 4000.00 RPM | Measured: 3491.00 RPM | Error: 509.00 RPM | PWM: 1016.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 448.74s | Desired: 4000.00 RPM | Measured: 3935.00 RPM | Error: 65.00 RPM | PWM: -105.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 449.77s | Desired: 4000.00 RPM | Measured: 3877.00 RPM | Error: 123.00 RPM | PWM: 238.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 450.81s | Desired: 4000.00 RPM | Measured: 3861.00 RPM | Error: 139.00 RPM | PWM: 243.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 451.85s | Desired: 4000.00 RPM | Measured: 3898.00 RPM | Error: 102.00 RPM | PWM: 157.45000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 452.89s | Desired: 4000.00 RPM | Measured: 4042.00 RPM | Error: -42.00 RPM | PWM: -128.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 453.91s | Desired: 4000.00 RPM | Measured: 3917.00 RPM | Error: 83.00 RPM | PWM: 208.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 454.95s | Desired: 4000.00 RPM | Measured: 3925.00 RPM | Error: 75.00 RPM | PWM: 128.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 455.98s | Desired: 4000.00 RPM | Measured: 3921.00 RPM | Error: 79.00 RPM | PWM: 141.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 457.02s | Desired: 4000.00 RPM | Measured: 3930.00 RPM | Error: 70.00 RPM | PWM: 120.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 458.06s | Desired: 4000.00 RPM | Measured: 3942.00 RPM | Error: 58.00 RPM | PWM: 99.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 459.09s | Desired: 4000.00 RPM | Measured: 2937.00 RPM | Error: 1063.00 RPM | PWM: 2216.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 460.12s | Desired: 4000.00 RPM | Measured: 3818.00 RPM | Error: 182.00 RPM | PWM: -136.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 461.15s | Desired: 4000.00 RPM | Measured: 3969.00 RPM | Error: 31.00 RPM | PWM: -13.149999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 462.19s | Desired: 4000.00 RPM | Measured: 2878.00 RPM | Error: 1122.00 RPM | PWM: 2353.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 463.21s | Desired: 4000.00 RPM | Measured: 3616.00 RPM | Error: 384.00 RPM | PWM: 258.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 464.25s | Desired: 4000.00 RPM | Measured: 3911.00 RPM | Error: 89.00 RPM | PWM: 7.650000000000006 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 465.29s | Desired: 4000.00 RPM | Measured: 3947.00 RPM | Error: 53.00 RPM | PWM: 79.55000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 466.32s | Desired: 4000.00 RPM | Measured: 2794.00 RPM | Error: 1206.00 RPM | PWM: 2518.8500000000004 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 467.37s | Desired: 4000.00 RPM | Measured: 3475.00 RPM | Error: 525.00 RPM | PWM: 512.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 468.39s | Desired: 4000.00 RPM | Measured: 3765.00 RPM | Error: 235.00 RPM | PWM: 243.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 469.42s | Desired: 4000.00 RPM | Measured: 3756.00 RPM | Error: 244.00 RPM | PWM: 407.65000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 470.45s | Desired: 4000.00 RPM | Measured: 3640.00 RPM | Error: 360.00 RPM | PWM: 646.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 471.50s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 284.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 472.54s | Desired: 4000.00 RPM | Measured: 3779.00 RPM | Error: 221.00 RPM | PWM: 369.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 473.57s | Desired: 4000.00 RPM | Measured: 3851.00 RPM | Error: 149.00 RPM | PWM: 215.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 474.61s | Desired: 4000.00 RPM | Measured: 3811.00 RPM | Error: 189.00 RPM | PWM: 335.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 475.63s | Desired: 4000.00 RPM | Measured: 3979.00 RPM | Error: 21.00 RPM | PWM: -37.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 476.67s | Desired: 4000.00 RPM | Measured: 3939.00 RPM | Error: 61.00 RPM | PWM: 130.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 477.70s | Desired: 4000.00 RPM | Measured: 3447.00 RPM | Error: 553.00 RPM | PWM: 1143.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 478.74s | Desired: 4000.00 RPM | Measured: 3929.00 RPM | Error: 71.00 RPM | PWM: -114.64999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 479.78s | Desired: 4000.00 RPM | Measured: 3695.00 RPM | Error: 305.00 RPM | PWM: 617.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 480.81s | Desired: 4000.00 RPM | Measured: 3781.00 RPM | Error: 219.00 RPM | PWM: 320.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 481.84s | Desired: 4000.00 RPM | Measured: 3951.00 RPM | Error: 49.00 RPM | PWM: 6.150000000000006 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 482.87s | Desired: 4000.00 RPM | Measured: 3066.00 RPM | Error: 934.00 RPM | PWM: 1949.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 483.92s | Desired: 4000.00 RPM | Measured: 3684.00 RPM | Error: 316.00 RPM | PWM: 209.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 484.95s | Desired: 4000.00 RPM | Measured: 3439.00 RPM | Error: 561.00 RPM | PWM: 1032.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 485.98s | Desired: 4000.00 RPM | Measured: 3788.00 RPM | Error: 212.00 RPM | PWM: 177.45000000000005 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 487.02s | Desired: 4000.00 RPM | Measured: 3925.00 RPM | Error: 75.00 RPM | PWM: 64.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 488.05s | Desired: 4000.00 RPM | Measured: 3818.00 RPM | Error: 182.00 RPM | PWM: 357.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 489.09s | Desired: 4000.00 RPM | Measured: 3896.00 RPM | Error: 104.00 RPM | PWM: 140.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 490.12s | Desired: 4000.00 RPM | Measured: 3875.00 RPM | Error: 125.00 RPM | PWM: 223.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 491.15s | Desired: 4000.00 RPM | Measured: 3801.00 RPM | Error: 199.00 RPM | PWM: 368.15000000000003 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 492.19s | Desired: 4000.00 RPM | Measured: 3889.00 RPM | Error: 111.00 RPM | PWM: 146.35000000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 493.22s | Desired: 4000.00 RPM | Measured: 3387.00 RPM | Error: 613.00 RPM | PWM: 1244.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 494.26s | Desired: 4000.00 RPM | Measured: 3838.00 RPM | Error: 162.00 RPM | PWM: 46.44999999999999 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 495.29s | Desired: 4000.00 RPM | Measured: 3966.00 RPM | Error: 34.00 RPM | PWM: 3.1500000000000057 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 496.32s | Desired: 4000.00 RPM | Measured: 3967.00 RPM | Error: 33.00 RPM | PWM: 65.05000000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 497.35s | Desired: 4000.00 RPM | Measured: 3170.00 RPM | Error: 830.00 RPM | PWM: 1739.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 498.39s | Desired: 4000.00 RPM | Measured: 3732.00 RPM | Error: 268.00 RPM | PWM: 160.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 499.44s | Desired: 4000.00 RPM | Measured: 3827.00 RPM | Error: 173.00 RPM | PWM: 242.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Data saved to PID_motor_data_20250404_225215.csv
# Speed plot saved to PID_motor_plot_speed_20250404_225215.pdf
# PID gains plot saved to PID_motor_plot_gains_20250404_225215.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime
import uuid  # Import UUID for unique filenames

import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

# Define whether ANN is enabled or not
ANN_enabled = True  # Set to True if ANN is used, False otherwise

# Convert lists to NumPy arrays for performance calculations
time_stamps = np.array(times)  # Recorded time points
error = np.array(errors)
setpoints = np.array([desired_speed] * len(times))  # Setpoints stored as an array
speeds = np.array(speeds)

# Compute Performance Metrics
rmse = np.sqrt(np.mean(error ** 2))  # Root Mean Square Error
mae = np.mean(np.abs(error))  # Mean Absolute Error
SSE = error[-1]  # Last recorded steady-state error
max_speed = max(speeds)  # Maximum speed recorded
overshoot = max(0, ((max_speed - desired_speed) / desired_speed) * 100)  # Percentage overshoot

# Settling Time (Ts)
within_tolerance = np.abs(error) < (0.05 * desired_speed)  # Define ±5% tolerance band
Ts_index = np.argmax(within_tolerance) if np.any(within_tolerance) else -1
Ts = time_stamps[Ts_index] if Ts_index != -1 else None  # First time where error is within ±5%

# Print Summary of Performance Metrics
print("Performance Metrics:")
print(f"Root Mean Square Error (RMSE): {rmse:.2f} RPM")
print(f"Mean Absolute Error (MAE): {mae:.2f} RPM")
print(f"Steady-State Error (SSE): {SSE:.2f} RPM")
print(f"Maximum Speed: {max_speed:.2f} RPM")
print(f"Overshoot: {overshoot:.2f}%")
print(f"Settling Time (Ts): {Ts:.2f} seconds" if Ts else "Settling Time (Ts): Not achieved within the runtime.")

# Generate Performance Plots and Save with explicit names
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")  # Format: YYYYMMDD_HHMMSS
identifier = "With_ANN" if ANN_enabled else "No_ANN"  # Condition-based identifier
unique_id = uuid.uuid4().hex[:8]  # Generates an 8-character unique ID

# 1. Histogram of Errors
hist_filename = f"Histogram_Errors_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.hist(error, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Error (RPM)", fontsize=16)
plt.ylabel("Frequency", fontsize=16)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(hist_filename, format="pdf", bbox_inches="tight")
plt.show()

# 2. RMSE & MAE Comparison
rmse_mae_filename = f"RMSE_MAE_Comparison_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["RMSE", "MAE"], [rmse, mae], color=['red', 'orange'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(rmse_mae_filename, format="pdf", bbox_inches="tight")
plt.show()

# 3. Overshoot & Steady-State Error
overshoot_sse_filename = f"Overshoot_SSE_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["Overshoot (%)", "SSE"], [overshoot, SSE], color=['purple', 'green'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)

# Apply Scientific Notation for the Y-axis
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)
plt.savefig(overshoot_sse_filename, format="pdf", bbox_inches="tight")
plt.show()

# Print saved filenames
print(f"Histogram of Errors saved as {hist_filename}")
print(f"RMSE & MAE Comparison saved as {rmse_mae_filename}")
print(f"Overshoot & Steady-State Error saved as {overshoot_sse_filename}")
# Out:
# Performance Metrics:
# Root Mean Square Error (RMSE): 688.88 RPM
# Mean Absolute Error (MAE): 341.79 RPM
# Steady-State Error (SSE): 173.00 RPM
# Maximum Speed: 7022.00 RPM
# Overshoot: 75.55%
# Settling Time (Ts): 41.20 seconds
# Histogram of Errors saved as Histogram_Errors_With_ANN_20250404_230210_57ec534c.pdf
# RMSE & MAE Comparison saved as RMSE_MAE_Comparison_With_ANN_20250404_230210_57ec534c.pdf
# Overshoot & Steady-State Error saved as Overshoot_SSE_With_ANN_20250404_230210_57ec534c.pdf

# %% [markdown]
# # Enhanced PID Control program with ANN-enabled Self-tuning:

# %%
import serial
import time
import csv
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime

# Initialize Serial Communication (Update COM Port)
ser = serial.Serial('COM3', 115200, timeout=0.1)

# PID Initial Parameters
Kp, Ki, Kd = 1.0, 0.05, 0.5
desired_speed = float(input("Enter desired motor speed (RPM): "))
runtime = float(input("Enter duration for PID control (seconds): "))
ann_start_time = runtime * 0.2  # ANN starts optimizing after 20% of runtime

# Define ANN Model (PyTorch)
class PIDANN(nn.Module):
    def __init__(self):
        super(PIDANN, self).__init__()
        self.fc1 = nn.Linear(5, 16)  # 5 Inputs -> 16 Neurons
        self.fc2 = nn.Linear(16, 16)  # Hidden layer
        self.fc3 = nn.Linear(16, 3)  # 3 Outputs (Kp, Ki, Kd)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)  # No activation (raw values)
        return x

# Initialize ANN Model
model = PIDANN()
optimizer = optim.Adam(model.parameters(), lr=0.01)
loss_function = nn.MSELoss()

# Data Logging
times, speeds, errors, pwm_outputs = [], [], [], []
kp_values, ki_values, kd_values, loss_values = [], [], [], []
start_time = time.time()
history = []  # Training Buffer
history_size = int(runtime * 0.1)  # Keep last nth data points for ANN training--10% size of run time

# Generate dynamic filenames for CSV and PDF
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"motor_speed_data_ANN_{current_datetime}.csv"
pdf_filename_speed = f"motor_speed_plot_speed_ANN_{current_datetime}.pdf"
pdf_filename_gains = f"motor_speed_plot_gains_ANN_{current_datetime}.pdf"
pdf_filename_loss = f"motor_speed_plot_loss_ANN_{current_datetime}.pdf"

# CSV File Setup
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Time (s)", "Desired Speed (RPM)", "Measured Speed (RPM)", "Error (RPM)", 
                     "PWM Output", "Kp", "Ki", "Kd", "Loss"])  # CSV Header

def pid_control(measured_speed, elapsed_time):
    """Compute PID control signal."""
    global Kp, Ki, Kd, history

    error = desired_speed - measured_speed
    delta_error = error - errors[-1] if errors else 0
    control_signal = (Kp * error) + (Ki * sum(errors[-history_size:])) + (Kd * delta_error)

    # ANN Optimization only after 20% runtime
    if elapsed_time >= ann_start_time and len(history) > 10:
        inputs = np.array([len(errors), desired_speed, measured_speed, error, control_signal], dtype=np.float32)
        inputs_tensor = torch.tensor(inputs, dtype=torch.float32)

        with torch.no_grad():
            output_tensor = model(inputs_tensor)

        Kp, Ki, Kd = output_tensor.numpy()

        # Apply constraints
        Kp = max(0.0, min(Kp, 50.0))
        Ki = max(0.0, min(Ki, 25.0))
        Kd = max(0.0, min(Kd, 25.0))

    # Train the ANN Online only after given runtime (e.g., 20% runtime)
    if elapsed_time >= ann_start_time:
        history.append([len(errors), desired_speed, measured_speed, error, control_signal, Kp, Ki, Kd])
        if len(history) > history_size:
            history.pop(0)

        x_train = torch.tensor([h[:-3] for h in history], dtype=torch.float32)
        y_train = torch.tensor([h[-3:] for h in history], dtype=torch.float32)

        optimizer.zero_grad()
        prediction = model(x_train)
        loss = loss_function(prediction, y_train)
        loss.backward()
        optimizer.step()

        loss_value = loss.item()
        loss_values.append(loss_value)
    else:
        loss_value = 0  # Before 20% runtime, no ANN training

    return control_signal, loss_value

# Main Control Loop
while time.time() - start_time < runtime:
    response = ser.readline().decode().strip()
    if response:
        measured_speed = float(response)  # Measured speed in RPM
        elapsed_time = time.time() - start_time
        
        # Compute PID output with ANN tuning only after 20% runtime
        pwm_output, loss_value = pid_control(measured_speed, elapsed_time)
        ser.write(f"{pwm_output}\n".encode())  # Send PWM to Arduino

        # Store Data
        times.append(elapsed_time)
        speeds.append(measured_speed)
        errors.append(desired_speed - measured_speed)
        pwm_outputs.append(pwm_output)
        kp_values.append(Kp)
        ki_values.append(Ki)
        kd_values.append(Kd)

        # Save to CSV
        with open(csv_filename, mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([elapsed_time, desired_speed, measured_speed, errors[-1], pwm_output, 
                             Kp, Ki, Kd, loss_value])

        # Print data in real-time
        print(f"Time: {elapsed_time:.2f}s | Desired: {desired_speed:.2f} RPM | Measured: {measured_speed:.2f} RPM | "
              f"Error: {errors[-1]:.2f} RPM | PWM: {pwm_output} | Kp: {Kp:.3f} | Ki: {Ki:.3f} | "
              f"Kd: {Kd:.3f} | Loss: {loss_value:.6f}")

ser.close()

# Generate Measured Speed & Error Plot
plt.figure(figsize=(7, 6))
plt.plot(times, speeds, label="Measured Speed (RPM)", color="b", linewidth=2)
plt.plot(times, errors, label="Error", color="r", linewidth=2)
plt.plot(times, [desired_speed] * len(times), label="Desired Speed (RPM)", color="g", linestyle="--", linewidth=2)

# Add shaded threshold region
threshold_lower = desired_speed * 0.95  # Lower bound of ±5% threshold
threshold_upper = desired_speed * 1.05  # Upper bound of ±5% threshold
plt.fill_between(times, threshold_lower, threshold_upper, color="gray", alpha=0.3, label="±5% Threshold")

# Add settling time marker
if Ts:
    plt.axvline(Ts, color="black", linestyle="--", linewidth=2, label=f"Settling Time: {Ts:.2f}s")
    #plt.text(Ts, desired_speed, f"  Ts = {Ts:.2f}s", fontsize=12, color="black", va="bottom")

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Speed (RPM)", fontsize=16)
#plt.title("Measured Speed and Error for PID Control with ANN", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_speed, format="pdf")
plt.show()

# Generate PID Gains Plot
plt.figure(figsize=(7, 6))
plt.plot(times, kp_values, label="Kp", color="m", linewidth=2)
plt.plot(times, ki_values, label="Ki", color="c", linewidth=2, alpha=0.6)
plt.plot(times, kd_values, label="Kd", color="y", linewidth=2, alpha=0.6)

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("PID Gains", fontsize=16)
#plt.title("ANN-PID Gains Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_gains, format="pdf")
plt.show()

# Generate Loss Plot
plt.figure(figsize=(7, 6))
plt.plot(times[:len(loss_values)], loss_values, label="Loss (MSE)", color="orange", linewidth=2)

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Loss (MSE)", fontsize=16)
#plt.title("ANN Training Loss Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_loss, format="pdf")
plt.show()

# Final Outputs
print(f"Data saved to {csv_filename}")
print(f"Measured Speed plot saved to {pdf_filename_speed}")
print(f"PID Gains plot saved to {pdf_filename_gains}")
print(f"Loss plot saved to {pdf_filename_loss}")
# Out:
# Enter desired motor speed (RPM): 4000
# Enter duration for PID control (seconds): 500
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 4800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 4000.00 RPM | Measured: 0.00 RPM | Error: 4000.00 RPM | PWM: 5200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 1.16s | Desired: 4000.00 RPM | Measured: 3600.00 RPM | Error: 400.00 RPM | PWM: 0.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 2.18s | Desired: 4000.00 RPM | Measured: 3818.00 RPM | Error: 182.00 RPM | PWM: 1493.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 3.22s | Desired: 4000.00 RPM | Measured: 3834.00 RPM | Error: 166.00 RPM | PWM: 1587.1000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 4.25s | Desired: 4000.00 RPM | Measured: 3567.00 RPM | Error: 433.00 RPM | PWM: 2003.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 5.29s | Desired: 4000.00 RPM | Measured: 3706.00 RPM | Error: 294.00 RPM | PWM: 1683.5500000000002 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 6.33s | Desired: 4000.00 RPM | Measured: 3833.00 RPM | Error: 167.00 RPM | PWM: 1577.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 7.35s | Desired: 4000.00 RPM | Measured: 3726.00 RPM | Error: 274.00 RPM | PWM: 1809.6000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 8.39s | Desired: 4000.00 RPM | Measured: 2908.00 RPM | Error: 1092.00 RPM | PWM: 2996.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 9.43s | Desired: 4000.00 RPM | Measured: 3603.00 RPM | Error: 397.00 RPM | PWM: 1599.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 10.46s | Desired: 4000.00 RPM | Measured: 3757.00 RPM | Error: 243.00 RPM | PWM: 1736.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 11.50s | Desired: 4000.00 RPM | Measured: 3690.00 RPM | Error: 310.00 RPM | PWM: 1925.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 12.53s | Desired: 4000.00 RPM | Measured: 3707.00 RPM | Error: 293.00 RPM | PWM: 1882.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 13.57s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 1875.5500000000002 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 14.59s | Desired: 4000.00 RPM | Measured: 3848.00 RPM | Error: 152.00 RPM | PWM: 1717.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 15.64s | Desired: 4000.00 RPM | Measured: 3749.00 RPM | Error: 251.00 RPM | PWM: 1934.3000000000002 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 16.68s | Desired: 4000.00 RPM | Measured: 3387.00 RPM | Error: 613.00 RPM | PWM: 2440.3500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 17.70s | Desired: 4000.00 RPM | Measured: 3803.00 RPM | Error: 197.00 RPM | PWM: 1666.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 18.74s | Desired: 4000.00 RPM | Measured: 3908.00 RPM | Error: 92.00 RPM | PWM: 1726.3500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 19.77s | Desired: 4000.00 RPM | Measured: 3885.00 RPM | Error: 115.00 RPM | PWM: 1817.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 20.80s | Desired: 4000.00 RPM | Measured: 3784.00 RPM | Error: 216.00 RPM | PWM: 1963.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 21.84s | Desired: 4000.00 RPM | Measured: 3729.00 RPM | Error: 271.00 RPM | PWM: 2006.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 22.89s | Desired: 4000.00 RPM | Measured: 3731.00 RPM | Error: 269.00 RPM | PWM: 1989.5500000000002 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 23.90s | Desired: 4000.00 RPM | Measured: 3853.00 RPM | Error: 147.00 RPM | PWM: 1821.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 24.94s | Desired: 4000.00 RPM | Measured: 3885.00 RPM | Error: 115.00 RPM | PWM: 1841.3500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 25.98s | Desired: 4000.00 RPM | Measured: 3897.00 RPM | Error: 103.00 RPM | PWM: 1845.1000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 27.02s | Desired: 4000.00 RPM | Measured: 3620.00 RPM | Error: 380.00 RPM | PWM: 2271.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 28.05s | Desired: 4000.00 RPM | Measured: 3709.00 RPM | Error: 291.00 RPM | PWM: 2018.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 29.09s | Desired: 4000.00 RPM | Measured: 3711.00 RPM | Error: 289.00 RPM | PWM: 2074.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 30.11s | Desired: 4000.00 RPM | Measured: 3656.00 RPM | Error: 344.00 RPM | PWM: 2172.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 31.15s | Desired: 4000.00 RPM | Measured: 3659.00 RPM | Error: 341.00 RPM | PWM: 2157.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 32.19s | Desired: 4000.00 RPM | Measured: 3680.00 RPM | Error: 320.00 RPM | PWM: 2145.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 33.22s | Desired: 4000.00 RPM | Measured: 3806.00 RPM | Error: 194.00 RPM | PWM: 1982.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 34.25s | Desired: 4000.00 RPM | Measured: 3700.00 RPM | Error: 300.00 RPM | PWM: 2214.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 35.30s | Desired: 4000.00 RPM | Measured: 3686.00 RPM | Error: 314.00 RPM | PWM: 2197.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 36.32s | Desired: 4000.00 RPM | Measured: 3682.00 RPM | Error: 318.00 RPM | PWM: 2211.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 37.36s | Desired: 4000.00 RPM | Measured: 3684.00 RPM | Error: 316.00 RPM | PWM: 2222.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 38.40s | Desired: 4000.00 RPM | Measured: 3703.00 RPM | Error: 297.00 RPM | PWM: 2211.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 39.44s | Desired: 4000.00 RPM | Measured: 3550.00 RPM | Error: 450.00 RPM | PWM: 2464.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 40.47s | Desired: 4000.00 RPM | Measured: 3669.00 RPM | Error: 331.00 RPM | PWM: 2232.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 41.49s | Desired: 4000.00 RPM | Measured: 3717.00 RPM | Error: 283.00 RPM | PWM: 2236.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 42.53s | Desired: 4000.00 RPM | Measured: 3765.00 RPM | Error: 235.00 RPM | PWM: 2202.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 43.57s | Desired: 4000.00 RPM | Measured: 3768.00 RPM | Error: 232.00 RPM | PWM: 2233.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 44.61s | Desired: 4000.00 RPM | Measured: 3707.00 RPM | Error: 293.00 RPM | PWM: 2338.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 45.63s | Desired: 4000.00 RPM | Measured: 3697.00 RPM | Error: 303.00 RPM | PWM: 2337.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 46.67s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 2074.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 47.71s | Desired: 4000.00 RPM | Measured: 3739.00 RPM | Error: 261.00 RPM | PWM: 1922.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 48.74s | Desired: 4000.00 RPM | Measured: 3846.00 RPM | Error: 154.00 RPM | PWM: 1571.0500000000002 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 49.77s | Desired: 4000.00 RPM | Measured: 3873.00 RPM | Error: 127.00 RPM | PWM: 1391.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 50.80s | Desired: 4000.00 RPM | Measured: 3739.00 RPM | Error: 261.00 RPM | PWM: 1412.6000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 51.84s | Desired: 4000.00 RPM | Measured: 2881.00 RPM | Error: 1119.00 RPM | PWM: 2445.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 52.87s | Desired: 4000.00 RPM | Measured: 3578.00 RPM | Error: 422.00 RPM | PWM: 827.0999999999999 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 53.92s | Desired: 4000.00 RPM | Measured: 3577.00 RPM | Error: 423.00 RPM | PWM: 1178.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 54.94s | Desired: 4000.00 RPM | Measured: 3691.00 RPM | Error: 309.00 RPM | PWM: 1018.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 55.97s | Desired: 4000.00 RPM | Measured: 3734.00 RPM | Error: 266.00 RPM | PWM: 1018.4000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 57.02s | Desired: 4000.00 RPM | Measured: 3233.00 RPM | Error: 767.00 RPM | PWM: 1783.0500000000002 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 58.04s | Desired: 4000.00 RPM | Measured: 3765.00 RPM | Error: 235.00 RPM | PWM: 758.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 59.08s | Desired: 4000.00 RPM | Measured: 3750.00 RPM | Error: 250.00 RPM | PWM: 1050.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 60.12s | Desired: 4000.00 RPM | Measured: 3712.00 RPM | Error: 288.00 RPM | PWM: 1098.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 61.16s | Desired: 4000.00 RPM | Measured: 3746.00 RPM | Error: 254.00 RPM | PWM: 988.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 62.19s | Desired: 4000.00 RPM | Measured: 3741.00 RPM | Error: 259.00 RPM | PWM: 1005.5500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 63.22s | Desired: 4000.00 RPM | Measured: 3876.00 RPM | Error: 124.00 RPM | PWM: 801.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 64.25s | Desired: 4000.00 RPM | Measured: 3764.00 RPM | Error: 236.00 RPM | PWM: 1027.5500000000002 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 65.29s | Desired: 4000.00 RPM | Measured: 3920.00 RPM | Error: 80.00 RPM | PWM: 734.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 66.33s | Desired: 4000.00 RPM | Measured: 3821.00 RPM | Error: 179.00 RPM | PWM: 951.5500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 67.36s | Desired: 4000.00 RPM | Measured: 3919.00 RPM | Error: 81.00 RPM | PWM: 756.4000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 68.40s | Desired: 4000.00 RPM | Measured: 3256.00 RPM | Error: 744.00 RPM | PWM: 1791.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 69.43s | Desired: 4000.00 RPM | Measured: 3722.00 RPM | Error: 278.00 RPM | PWM: 767.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 70.47s | Desired: 4000.00 RPM | Measured: 3762.00 RPM | Error: 238.00 RPM | PWM: 944.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 71.49s | Desired: 4000.00 RPM | Measured: 3755.00 RPM | Error: 245.00 RPM | PWM: 982.3000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 72.52s | Desired: 4000.00 RPM | Measured: 3423.00 RPM | Error: 577.00 RPM | PWM: 1483.3000000000002 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 73.56s | Desired: 4000.00 RPM | Measured: 3354.00 RPM | Error: 646.00 RPM | PWM: 1438.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 74.60s | Desired: 4000.00 RPM | Measured: 3699.00 RPM | Error: 301.00 RPM | PWM: 905.5999999999999 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 75.63s | Desired: 4000.00 RPM | Measured: 2926.00 RPM | Error: 1074.00 RPM | PWM: 2239.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 76.67s | Desired: 4000.00 RPM | Measured: 3626.00 RPM | Error: 374.00 RPM | PWM: 849.0500000000002 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 77.70s | Desired: 4000.00 RPM | Measured: 3919.00 RPM | Error: 81.00 RPM | PWM: 772.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 78.74s | Desired: 4000.00 RPM | Measured: 3808.00 RPM | Error: 192.00 RPM | PWM: 1084.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 79.77s | Desired: 4000.00 RPM | Measured: 3761.00 RPM | Error: 239.00 RPM | PWM: 1090.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 80.81s | Desired: 4000.00 RPM | Measured: 3869.00 RPM | Error: 131.00 RPM | PWM: 901.9000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 81.84s | Desired: 4000.00 RPM | Measured: 3873.00 RPM | Error: 127.00 RPM | PWM: 942.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 82.87s | Desired: 4000.00 RPM | Measured: 3887.00 RPM | Error: 113.00 RPM | PWM: 912.1500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 83.90s | Desired: 4000.00 RPM | Measured: 3881.00 RPM | Error: 119.00 RPM | PWM: 916.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 84.95s | Desired: 4000.00 RPM | Measured: 3700.00 RPM | Error: 300.00 RPM | PWM: 1175.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 85.97s | Desired: 4000.00 RPM | Measured: 3695.00 RPM | Error: 305.00 RPM | PWM: 1097.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 87.00s | Desired: 4000.00 RPM | Measured: 3709.00 RPM | Error: 291.00 RPM | PWM: 1074.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 88.05s | Desired: 4000.00 RPM | Measured: 3707.00 RPM | Error: 293.00 RPM | PWM: 1083.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 89.08s | Desired: 4000.00 RPM | Measured: 3684.00 RPM | Error: 316.00 RPM | PWM: 1115.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 90.10s | Desired: 4000.00 RPM | Measured: 3686.00 RPM | Error: 314.00 RPM | PWM: 1100.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 91.14s | Desired: 4000.00 RPM | Measured: 3707.00 RPM | Error: 293.00 RPM | PWM: 1071.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 92.17s | Desired: 4000.00 RPM | Measured: 3748.00 RPM | Error: 252.00 RPM | PWM: 1012.3499999999999 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 93.21s | Desired: 4000.00 RPM | Measured: 3871.00 RPM | Error: 129.00 RPM | PWM: 844.4000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 94.24s | Desired: 4000.00 RPM | Measured: 3261.00 RPM | Error: 739.00 RPM | PWM: 1813.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 95.29s | Desired: 4000.00 RPM | Measured: 3654.00 RPM | Error: 346.00 RPM | PWM: 943.9000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 96.32s | Desired: 4000.00 RPM | Measured: 3900.00 RPM | Error: 100.00 RPM | PWM: 777.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 97.35s | Desired: 4000.00 RPM | Measured: 3793.00 RPM | Error: 207.00 RPM | PWM: 1050.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 98.38s | Desired: 4000.00 RPM | Measured: 3814.00 RPM | Error: 186.00 RPM | PWM: 961.1500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 99.42s | Desired: 4000.00 RPM | Measured: 3916.00 RPM | Error: 84.00 RPM | PWM: 815.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 100.46s | Desired: 4000.00 RPM | Measured: 3801.00 RPM | Error: 199.00 RPM | PWM: 1029.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 35097.449219
# Time: 101.49s | Desired: 4000.00 RPM | Measured: 3815.00 RPM | Error: 185.00 RPM | PWM: 953.6500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 1468.374390
# Time: 102.52s | Desired: 4000.00 RPM | Measured: 3945.00 RPM | Error: 55.00 RPM | PWM: 768.5500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 10234.261719
# Time: 103.56s | Desired: 4000.00 RPM | Measured: 3968.00 RPM | Error: 32.00 RPM | PWM: 788.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 14791.887695
# Time: 104.60s | Desired: 4000.00 RPM | Measured: 3856.00 RPM | Error: 144.00 RPM | PWM: 913.9000000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 9958.780273
# Time: 105.64s | Desired: 4000.00 RPM | Measured: 3936.00 RPM | Error: 64.00 RPM | PWM: 724.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 3911.108154
# Time: 106.67s | Desired: 4000.00 RPM | Measured: 3958.00 RPM | Error: 42.00 RPM | PWM: 713.0500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 891.637085
# Time: 107.72s | Desired: 4000.00 RPM | Measured: 3944.00 RPM | Error: 56.00 RPM | PWM: 731.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 1521.431763
# Time: 108.75s | Desired: 4000.00 RPM | Measured: 3806.00 RPM | Error: 194.00 RPM | PWM: 921.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 3803.962646
# Time: 109.79s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 855.0500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 5203.566895
# Time: 110.82s | Desired: 4000.00 RPM | Measured: 3909.00 RPM | Error: 91.00 RPM | PWM: 657.5500000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 4777.207031
# Time: 111.86s | Desired: 4000.00 RPM | Measured: 3950.00 RPM | Error: 50.00 RPM | PWM: 650.1 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 3072.712646
# Time: 112.91s | Desired: 4000.00 RPM | Measured: 3825.00 RPM | Error: 175.00 RPM | PWM: 0.0 | Kp: 0.000 | Ki: 0.000 | Kd: 20.800 | Loss: 1271.237915
# Time: 113.95s | Desired: 4000.00 RPM | Measured: 3955.00 RPM | Error: 45.00 RPM | PWM: -2703.952293395996 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 739.063660
# Time: 114.97s | Desired: 4000.00 RPM | Measured: 3727.00 RPM | Error: 273.00 RPM | PWM: 19350.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 4167.035645
# Time: 116.02s | Desired: 4000.00 RPM | Measured: 3928.00 RPM | Error: 72.00 RPM | PWM: 0.0 | Kp: 32.034 | Ki: 0.000 | Kd: 25.000 | Loss: 1575.489380
# Time: 117.05s | Desired: 4000.00 RPM | Measured: 3974.00 RPM | Error: 26.00 RPM | PWM: -317.10904693603516 | Kp: 46.685 | Ki: 0.000 | Kd: 25.000 | Loss: 2486.816650
# Time: 118.10s | Desired: 4000.00 RPM | Measured: 2872.00 RPM | Error: 1128.00 RPM | PWM: 80210.51803588867 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 9990.283203
# Time: 119.14s | Desired: 4000.00 RPM | Measured: 3495.00 RPM | Error: 505.00 RPM | PWM: 328700.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 137049.375000
# Time: 120.17s | Desired: 4000.00 RPM | Measured: 3932.00 RPM | Error: 68.00 RPM | PWM: 0.0 | Kp: 44.546 | Ki: 9.443 | Kd: 25.000 | Loss: 182461.281250
# Time: 121.22s | Desired: 4000.00 RPM | Measured: 3965.00 RPM | Error: 35.00 RPM | PWM: 118855.33665943146 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 120873.289062
# Time: 122.26s | Desired: 4000.00 RPM | Measured: 3972.00 RPM | Error: 28.00 RPM | PWM: 306475.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 66203.109375
# Time: 123.31s | Desired: 4000.00 RPM | Measured: 3971.00 RPM | Error: 29.00 RPM | PWM: 0.0 | Kp: 34.582 | Ki: 0.000 | Kd: 0.000 | Loss: 126780.187500
# Time: 124.35s | Desired: 4000.00 RPM | Measured: 3985.00 RPM | Error: 15.00 RPM | PWM: 518.7346458435059 | Kp: 17.580 | Ki: 0.000 | Kd: 0.000 | Loss: 25309.275391
# Time: 125.37s | Desired: 4000.00 RPM | Measured: 3980.00 RPM | Error: 20.00 RPM | PWM: 351.5910339355469 | Kp: 12.240 | Ki: 0.000 | Kd: 0.000 | Loss: 107843.304688
# Time: 126.42s | Desired: 4000.00 RPM | Measured: 3962.00 RPM | Error: 38.00 RPM | PWM: 465.1179256439209 | Kp: 11.772 | Ki: 0.000 | Kd: 0.000 | Loss: 12763.082031
# Time: 127.46s | Desired: 4000.00 RPM | Measured: 3342.00 RPM | Error: 658.00 RPM | PWM: 7745.906551361084 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 65586.218750
# Time: 128.51s | Desired: 4000.00 RPM | Measured: 3841.00 RPM | Error: 159.00 RPM | PWM: 236850.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 51698.742188
# Time: 129.53s | Desired: 4000.00 RPM | Measured: 3983.00 RPM | Error: 17.00 RPM | PWM: 0.0 | Kp: 4.419 | Ki: 0.000 | Kd: 15.556 | Loss: 28259.001953
# Time: 130.57s | Desired: 4000.00 RPM | Measured: 3989.00 RPM | Error: 11.00 RPM | PWM: -44.728623390197754 | Kp: 8.318 | Ki: 0.000 | Kd: 25.000 | Loss: 59891.062500
# Time: 131.61s | Desired: 4000.00 RPM | Measured: 3760.00 RPM | Error: 240.00 RPM | PWM: 7721.374664306641 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 20678.605469
# Time: 132.66s | Desired: 4000.00 RPM | Measured: 3986.00 RPM | Error: 14.00 RPM | PWM: 232200.0 | Kp: 50.000 | Ki: 0.000 | Kd: 0.000 | Loss: 36592.179688
# Time: 133.69s | Desired: 4000.00 RPM | Measured: 4018.00 RPM | Error: -18.00 RPM | PWM: -900.0 | Kp: 31.368 | Ki: 0.000 | Kd: 25.000 | Loss: 77547.007812
# Time: 134.74s | Desired: 4000.00 RPM | Measured: 4003.00 RPM | Error: -3.00 RPM | PWM: 280.8972473144531 | Kp: 8.739 | Ki: 0.000 | Kd: 25.000 | Loss: 7390.901367
# Time: 135.76s | Desired: 4000.00 RPM | Measured: 3693.00 RPM | Error: 307.00 RPM | PWM: 10433.01655960083 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 62449.660156
# Time: 136.81s | Desired: 4000.00 RPM | Measured: 3942.00 RPM | Error: 58.00 RPM | PWM: 226875.0 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 32859.031250
# Time: 137.84s | Desired: 4000.00 RPM | Measured: 4006.00 RPM | Error: -6.00 RPM | PWM: 225150.0 | Kp: 0.000 | Ki: 16.851 | Kd: 0.000 | Loss: 19993.248047
# Time: 138.87s | Desired: 4000.00 RPM | Measured: 3989.00 RPM | Error: 11.00 RPM | PWM: 147799.6678352356 | Kp: 0.000 | Ki: 18.557 | Kd: 0.000 | Loss: 53785.417969
# Time: 139.93s | Desired: 4000.00 RPM | Measured: 3975.00 RPM | Error: 25.00 RPM | PWM: 157570.86507987976 | Kp: 50.000 | Ki: 25.000 | Kd: 7.761 | Loss: 2889.607178
# Time: 140.96s | Desired: 4000.00 RPM | Measured: 3573.00 RPM | Error: 427.00 RPM | PWM: 230044.869348526 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 46760.191406
# Time: 142.00s | Desired: 4000.00 RPM | Measured: 3420.00 RPM | Error: 580.00 RPM | PWM: 241175.0 | Kp: 36.985 | Ki: 2.484 | Kd: 25.000 | Loss: 12693.001953
# Time: 143.03s | Desired: 4000.00 RPM | Measured: 3942.00 RPM | Error: 58.00 RPM | PWM: 10458.911680221558 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 27415.046875
# Time: 144.07s | Desired: 4000.00 RPM | Measured: 3501.00 RPM | Error: 499.00 RPM | PWM: 220150.0 | Kp: 0.000 | Ki: 5.493 | Kd: 0.000 | Loss: 24862.335938
# Time: 145.11s | Desired: 4000.00 RPM | Measured: 3908.00 RPM | Error: 92.00 RPM | PWM: 47301.60563468933 | Kp: 21.403 | Ki: 25.000 | Kd: 25.000 | Loss: 13070.430664
# Time: 146.16s | Desired: 4000.00 RPM | Measured: 3483.00 RPM | Error: 517.00 RPM | PWM: 236065.33713150024 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 28278.017578
# Time: 147.19s | Desired: 4000.00 RPM | Measured: 3978.00 RPM | Error: 22.00 RPM | PWM: 197550.0 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 8694.354492
# Time: 148.22s | Desired: 4000.00 RPM | Measured: 4065.00 RPM | Error: -65.00 RPM | PWM: -2175.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 22478.087891
# Time: 149.27s | Desired: 4000.00 RPM | Measured: 4057.00 RPM | Error: -57.00 RPM | PWM: -2650.0 | Kp: 50.000 | Ki: 2.501 | Kd: 25.000 | Loss: 9947.321289
# Time: 150.31s | Desired: 4000.00 RPM | Measured: 4044.00 RPM | Error: -44.00 RPM | PWM: 17130.307292938232 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 13752.644531
# Time: 151.35s | Desired: 4000.00 RPM | Measured: 3641.00 RPM | Error: 359.00 RPM | PWM: 194325.0 | Kp: 16.230 | Ki: 0.000 | Kd: 25.000 | Loss: 12486.468750
# Time: 152.39s | Desired: 4000.00 RPM | Measured: 3962.00 RPM | Error: 38.00 RPM | PWM: -7408.261756896973 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 8705.510742
# Time: 153.43s | Desired: 4000.00 RPM | Measured: 3328.00 RPM | Error: 672.00 RPM | PWM: 220700.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 12154.039062
# Time: 154.47s | Desired: 4000.00 RPM | Measured: 3912.00 RPM | Error: 88.00 RPM | PWM: 199275.0 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 7683.340820
# Time: 155.50s | Desired: 4000.00 RPM | Measured: 4028.00 RPM | Error: -28.00 RPM | PWM: 195800.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 10358.736328
# Time: 156.54s | Desired: 4000.00 RPM | Measured: 4036.00 RPM | Error: -36.00 RPM | PWM: -2000.0 | Kp: 49.801 | Ki: 0.000 | Kd: 25.000 | Loss: 6882.027832
# Time: 157.59s | Desired: 4000.00 RPM | Measured: 4056.00 RPM | Error: -56.00 RPM | PWM: -3288.833282470703 | Kp: 50.000 | Ki: 0.000 | Kd: 0.000 | Loss: 7784.641602
# Time: 158.63s | Desired: 4000.00 RPM | Measured: 2952.00 RPM | Error: 1048.00 RPM | PWM: 52400.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 6859.356934
# Time: 159.66s | Desired: 4000.00 RPM | Measured: 3879.00 RPM | Error: 121.00 RPM | PWM: 216250.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 5285.541504
# Time: 160.69s | Desired: 4000.00 RPM | Measured: 4008.00 RPM | Error: -8.00 RPM | PWM: -3625.0 | Kp: 50.000 | Ki: 0.000 | Kd: 11.395 | Loss: 6594.668457
# Time: 161.73s | Desired: 4000.00 RPM | Measured: 4052.00 RPM | Error: -52.00 RPM | PWM: -3101.3895874023438 | Kp: 50.000 | Ki: 3.105 | Kd: 7.208 | Loss: 3897.227051
# Time: 162.76s | Desired: 4000.00 RPM | Measured: 4019.00 RPM | Error: -19.00 RPM | PWM: 24890.887898921967 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 5438.077148
# Time: 163.81s | Desired: 4000.00 RPM | Measured: 3112.00 RPM | Error: 888.00 RPM | PWM: 226075.0 | Kp: 0.000 | Ki: 0.000 | Kd: 15.954 | Loss: 3753.623291
# Time: 164.84s | Desired: 4000.00 RPM | Measured: 3893.00 RPM | Error: 107.00 RPM | PWM: -12459.941046714783 | Kp: 43.642 | Ki: 25.000 | Kd: 25.000 | Loss: 4178.783203
# Time: 165.89s | Desired: 4000.00 RPM | Measured: 3238.00 RPM | Error: 762.00 RPM | PWM: 272280.0224761963 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 3293.028564
# Time: 166.93s | Desired: 4000.00 RPM | Measured: 3886.00 RPM | Error: 114.00 RPM | PWM: 246275.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 4023.086670
# Time: 167.96s | Desired: 4000.00 RPM | Measured: 4018.00 RPM | Error: -18.00 RPM | PWM: 236600.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 3162.635742
# Time: 169.00s | Desired: 4000.00 RPM | Measured: 4025.00 RPM | Error: -25.00 RPM | PWM: -1425.0 | Kp: 41.284 | Ki: 0.000 | Kd: 25.000 | Loss: 3051.353271
# Time: 170.04s | Desired: 4000.00 RPM | Measured: 4040.00 RPM | Error: -40.00 RPM | PWM: -2026.3677978515625 | Kp: 46.515 | Ki: 1.809 | Kd: 20.005 | Loss: 2960.752441
# Time: 171.07s | Desired: 4000.00 RPM | Measured: 3173.00 RPM | Error: 827.00 RPM | PWM: 70566.27054262161 | Kp: 0.000 | Ki: 17.068 | Kd: 0.000 | Loss: 1176.889160
# Time: 172.11s | Desired: 4000.00 RPM | Measured: 3143.00 RPM | Error: 857.00 RPM | PWM: 144687.57698059082 | Kp: 0.000 | Ki: 2.516 | Kd: 25.000 | Loss: 3012.372559
# Time: 173.16s | Desired: 4000.00 RPM | Measured: 3956.00 RPM | Error: 44.00 RPM | PWM: 2991.8484377861023 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 574.087891
# Time: 174.19s | Desired: 4000.00 RPM | Measured: 3796.00 RPM | Error: 204.00 RPM | PWM: 235875.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 2453.370361
# Time: 175.24s | Desired: 4000.00 RPM | Measured: 4068.00 RPM | Error: -68.00 RPM | PWM: 236275.0 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 698.501648
# Time: 176.27s | Desired: 4000.00 RPM | Measured: 4128.00 RPM | Error: -128.00 RPM | PWM: 225950.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1819.897339
# Time: 177.32s | Desired: 4000.00 RPM | Measured: 4125.00 RPM | Error: -125.00 RPM | PWM: -6175.0 | Kp: 46.897 | Ki: 0.000 | Kd: 4.164 | Loss: 1267.662964
# Time: 178.34s | Desired: 4000.00 RPM | Measured: 4145.00 RPM | Error: -145.00 RPM | PWM: -6883.368043899536 | Kp: 42.705 | Ki: 0.000 | Kd: 7.108 | Loss: 1334.610718
# Time: 179.40s | Desired: 4000.00 RPM | Measured: 3636.00 RPM | Error: 364.00 RPM | PWM: 19162.552824497223 | Kp: 0.000 | Ki: 15.469 | Kd: 25.000 | Loss: 1041.396362
# Time: 180.42s | Desired: 4000.00 RPM | Measured: 3114.00 RPM | Error: 886.00 RPM | PWM: 145912.08487415314 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 1063.943970
# Time: 181.47s | Desired: 4000.00 RPM | Measured: 4039.00 RPM | Error: -39.00 RPM | PWM: 0.0 | Kp: 20.622 | Ki: 4.743 | Kd: 5.210 | Loss: 1127.332520
# Time: 182.50s | Desired: 4000.00 RPM | Measured: 4235.00 RPM | Error: -235.00 RPM | PWM: 38048.37092590332 | Kp: 25.880 | Ki: 17.695 | Kd: 25.000 | Loss: 484.155823
# Time: 183.54s | Desired: 4000.00 RPM | Measured: 4083.00 RPM | Error: -83.00 RPM | PWM: 161157.7877292633 | Kp: 28.250 | Ki: 0.000 | Kd: 25.000 | Loss: 1323.238281
# Time: 184.59s | Desired: 4000.00 RPM | Measured: 4177.00 RPM | Error: -177.00 RPM | PWM: -7350.310430526733 | Kp: 48.576 | Ki: 5.496 | Kd: 0.415 | Loss: 523.247131
# Time: 185.62s | Desired: 4000.00 RPM | Measured: 4199.00 RPM | Error: -199.00 RPM | PWM: 37037.89167356491 | Kp: 25.327 | Ki: 16.769 | Kd: 25.000 | Loss: 831.648132
# Time: 186.65s | Desired: 4000.00 RPM | Measured: 4212.00 RPM | Error: -212.00 RPM | PWM: 133804.17197227478 | Kp: 22.590 | Ki: 0.000 | Kd: 25.000 | Loss: 772.419006
# Time: 187.71s | Desired: 4000.00 RPM | Measured: 4228.00 RPM | Error: -228.00 RPM | PWM: -5550.549606323242 | Kp: 47.819 | Ki: 0.000 | Kd: 0.000 | Loss: 610.610352
# Time: 188.74s | Desired: 4000.00 RPM | Measured: 4192.00 RPM | Error: -192.00 RPM | PWM: -9181.3095703125 | Kp: 50.000 | Ki: 8.318 | Kd: 0.000 | Loss: 614.040955
# Time: 189.78s | Desired: 4000.00 RPM | Measured: 4202.00 RPM | Error: -202.00 RPM | PWM: 50832.87658691406 | Kp: 19.626 | Ki: 5.955 | Kd: 25.000 | Loss: 562.777161
# Time: 190.81s | Desired: 4000.00 RPM | Measured: 3085.00 RPM | Error: 915.00 RPM | PWM: 88339.58298015594 | Kp: 0.000 | Ki: 0.000 | Kd: 7.308 | Loss: 561.326538
# Time: 191.86s | Desired: 4000.00 RPM | Measured: 3607.00 RPM | Error: 393.00 RPM | PWM: -3814.7056045532227 | Kp: 29.017 | Ki: 18.039 | Kd: 25.000 | Loss: 393.571106
# Time: 192.89s | Desired: 4000.00 RPM | Measured: 3164.00 RPM | Error: 836.00 RPM | PWM: 186881.59697914124 | Kp: 0.000 | Ki: 11.779 | Kd: 0.000 | Loss: 567.202454
# Time: 193.93s | Desired: 4000.00 RPM | Measured: 3939.00 RPM | Error: 61.00 RPM | PWM: 103773.58061790466 | Kp: 18.841 | Ki: 7.041 | Kd: 25.000 | Loss: 282.212372
# Time: 194.97s | Desired: 4000.00 RPM | Measured: 4177.00 RPM | Error: -177.00 RPM | PWM: 49092.80012655258 | Kp: 26.149 | Ki: 4.113 | Kd: 25.000 | Loss: 481.906250
# Time: 196.01s | Desired: 4000.00 RPM | Measured: 3648.00 RPM | Error: 352.00 RPM | PWM: 55560.815883636475 | Kp: 0.000 | Ki: 0.825 | Kd: 25.000 | Loss: 284.867615
# Time: 197.06s | Desired: 4000.00 RPM | Measured: 3327.00 RPM | Error: 673.00 RPM | PWM: 14552.603946566582 | Kp: 0.000 | Ki: 1.392 | Kd: 14.274 | Loss: 376.138580
# Time: 198.08s | Desired: 4000.00 RPM | Measured: 3252.00 RPM | Error: 748.00 RPM | PWM: 12884.4278383255 | Kp: 0.000 | Ki: 1.018 | Kd: 11.486 | Loss: 291.828552
# Time: 199.13s | Desired: 4000.00 RPM | Measured: 3904.00 RPM | Error: 96.00 RPM | PWM: 1391.2168003320694 | Kp: 2.194 | Ki: 0.290 | Kd: 0.000 | Loss: 293.677124
# Time: 200.17s | Desired: 4000.00 RPM | Measured: 3159.00 RPM | Error: 841.00 RPM | PWM: 4393.298283189535 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 281.420715
# Time: 201.20s | Desired: 4000.00 RPM | Measured: 3161.00 RPM | Error: 839.00 RPM | PWM: 242475.0 | Kp: 0.144 | Ki: 25.000 | Kd: 0.000 | Loss: 288.914032
# Time: 202.25s | Desired: 4000.00 RPM | Measured: 3917.00 RPM | Error: 83.00 RPM | PWM: 264936.98271779716 | Kp: 50.000 | Ki: 25.000 | Kd: 21.215 | Loss: 259.188995
# Time: 203.28s | Desired: 4000.00 RPM | Measured: 3165.00 RPM | Error: 835.00 RPM | PWM: 325803.4750061035 | Kp: 14.835 | Ki: 0.000 | Kd: 0.000 | Loss: 275.768707
# Time: 204.32s | Desired: 4000.00 RPM | Measured: 3398.00 RPM | Error: 602.00 RPM | PWM: 8930.625816345215 | Kp: 0.000 | Ki: 0.000 | Kd: 16.335 | Loss: 227.335968
# Time: 205.37s | Desired: 4000.00 RPM | Measured: 3968.00 RPM | Error: 32.00 RPM | PWM: -9311.12886428833 | Kp: 49.789 | Ki: 13.152 | Kd: 4.420 | Loss: 280.783112
# Time: 206.41s | Desired: 4000.00 RPM | Measured: 3350.00 RPM | Error: 650.00 RPM | PWM: 181394.40634822845 | Kp: 0.000 | Ki: 6.433 | Kd: 0.000 | Loss: 203.838959
# Time: 207.44s | Desired: 4000.00 RPM | Measured: 3404.00 RPM | Error: 596.00 RPM | PWM: 75174.83540439606 | Kp: 0.000 | Ki: 0.000 | Kd: 12.389 | Loss: 246.568665
# Time: 208.49s | Desired: 4000.00 RPM | Measured: 4008.00 RPM | Error: -8.00 RPM | PWM: -7483.183490753174 | Kp: 46.649 | Ki: 0.000 | Kd: 5.254 | Loss: 213.235672
# Time: 209.53s | Desired: 4000.00 RPM | Measured: 4103.00 RPM | Error: -103.00 RPM | PWM: -5304.003289222717 | Kp: 38.767 | Ki: 1.766 | Kd: 8.435 | Loss: 220.442703
# Time: 210.56s | Desired: 4000.00 RPM | Measured: 4112.00 RPM | Error: -112.00 RPM | PWM: 17287.93782901764 | Kp: 12.597 | Ki: 0.000 | Kd: 25.000 | Loss: 199.668228
# Time: 211.61s | Desired: 4000.00 RPM | Measured: 4104.00 RPM | Error: -104.00 RPM | PWM: -1110.1188583374023 | Kp: 35.645 | Ki: 3.808 | Kd: 23.588 | Loss: 204.516830
# Time: 212.65s | Desired: 4000.00 RPM | Measured: 4111.00 RPM | Error: -111.00 RPM | PWM: 37409.30438184738 | Kp: 17.054 | Ki: 0.000 | Kd: 25.000 | Loss: 197.760498
# Time: 213.68s | Desired: 4000.00 RPM | Measured: 4126.00 RPM | Error: -126.00 RPM | PWM: -2523.78560256958 | Kp: 47.754 | Ki: 5.394 | Kd: 4.999 | Loss: 218.441147
# Time: 214.72s | Desired: 4000.00 RPM | Measured: 3140.00 RPM | Error: 860.00 RPM | PWM: 103871.16202878952 | Kp: 0.000 | Ki: 0.141 | Kd: 0.000 | Loss: 174.828094
# Time: 215.76s | Desired: 4000.00 RPM | Measured: 3140.00 RPM | Error: 860.00 RPM | PWM: 1636.8041384220123 | Kp: 50.000 | Ki: 0.000 | Kd: 0.000 | Loss: 223.260178
# Time: 216.79s | Desired: 4000.00 RPM | Measured: 3956.00 RPM | Error: 44.00 RPM | PWM: 2200.0 | Kp: 0.000 | Ki: 9.223 | Kd: 0.000 | Loss: 191.713379
# Time: 217.84s | Desired: 4000.00 RPM | Measured: 4047.00 RPM | Error: -47.00 RPM | PWM: 106224.73488807678 | Kp: 20.872 | Ki: 4.319 | Kd: 25.000 | Loss: 191.070358
# Time: 218.88s | Desired: 4000.00 RPM | Measured: 3501.00 RPM | Error: 499.00 RPM | PWM: 70308.47807693481 | Kp: 0.000 | Ki: 0.000 | Kd: 13.038 | Loss: 156.908875
# Time: 219.93s | Desired: 4000.00 RPM | Measured: 3961.00 RPM | Error: 39.00 RPM | PWM: -5997.550239562988 | Kp: 34.848 | Ki: 8.103 | Kd: 16.145 | Loss: 171.864655
# Time: 220.96s | Desired: 4000.00 RPM | Measured: 3023.00 RPM | Error: 977.00 RPM | PWM: 139537.28908538818 | Kp: 0.000 | Ki: 1.719 | Kd: 0.000 | Loss: 151.298920
# Time: 221.99s | Desired: 4000.00 RPM | Measured: 3083.00 RPM | Error: 917.00 RPM | PWM: 20891.02179145813 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 160.256805
# Time: 223.04s | Desired: 4000.00 RPM | Measured: 3429.00 RPM | Error: 571.00 RPM | PWM: 0.0 | Kp: 29.417 | Ki: 0.000 | Kd: 25.000 | Loss: 152.387207
# Time: 224.08s | Desired: 4000.00 RPM | Measured: 3989.00 RPM | Error: 11.00 RPM | PWM: -13676.40817642212 | Kp: 50.000 | Ki: 11.194 | Kd: 0.000 | Loss: 139.371567
# Time: 225.11s | Desired: 4000.00 RPM | Measured: 4026.00 RPM | Error: -26.00 RPM | PWM: 133107.67776966095 | Kp: 24.700 | Ki: 1.471 | Kd: 25.000 | Loss: 137.665909
# Time: 226.16s | Desired: 4000.00 RPM | Measured: 2887.00 RPM | Error: 1113.00 RPM | PWM: 73523.68797624111 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 126.777252
# Time: 227.19s | Desired: 4000.00 RPM | Measured: 2611.00 RPM | Error: 1389.00 RPM | PWM: 0.0 | Kp: 4.202 | Ki: 0.000 | Kd: 25.000 | Loss: 135.987335
# Time: 228.24s | Desired: 4000.00 RPM | Measured: 3777.00 RPM | Error: 223.00 RPM | PWM: -28212.91494369507 | Kp: 32.861 | Ki: 25.000 | Kd: 25.000 | Loss: 128.733551
# Time: 229.28s | Desired: 4000.00 RPM | Measured: 3214.00 RPM | Error: 786.00 RPM | PWM: 406253.5541534424 | Kp: 21.629 | Ki: 22.743 | Kd: 0.000 | Loss: 189.622345
# Time: 230.32s | Desired: 4000.00 RPM | Measured: 3461.00 RPM | Error: 539.00 RPM | PWM: 365650.1236934662 | Kp: 30.640 | Ki: 10.607 | Kd: 0.000 | Loss: 1610.655151
# Time: 231.35s | Desired: 4000.00 RPM | Measured: 3507.00 RPM | Error: 493.00 RPM | PWM: 187457.6111240387 | Kp: 18.923 | Ki: 5.577 | Kd: 3.118 | Loss: 3470.094482
# Time: 232.39s | Desired: 4000.00 RPM | Measured: 3446.00 RPM | Error: 554.00 RPM | PWM: 102019.85405278206 | Kp: 0.000 | Ki: 4.565 | Kd: 13.036 | Loss: 298.473083
# Time: 233.44s | Desired: 4000.00 RPM | Measured: 3439.00 RPM | Error: 561.00 RPM | PWM: 73336.6920413971 | Kp: 2.013 | Ki: 0.000 | Kd: 8.474 | Loss: 2678.496826
# Time: 234.47s | Desired: 4000.00 RPM | Measured: 3478.00 RPM | Error: 522.00 RPM | PWM: 720.0729246139526 | Kp: 27.965 | Ki: 0.000 | Kd: 8.042 | Loss: 278.554688
# Time: 235.51s | Desired: 4000.00 RPM | Measured: 3740.00 RPM | Error: 260.00 RPM | PWM: 5164.067501068115 | Kp: 5.938 | Ki: 25.000 | Kd: 25.000 | Loss: 1868.821899
# Time: 236.56s | Desired: 4000.00 RPM | Measured: 3944.00 RPM | Error: 56.00 RPM | PWM: 438882.5340461731 | Kp: 50.000 | Ki: 19.243 | Kd: 0.108 | Loss: 642.767212
# Time: 237.59s | Desired: 4000.00 RPM | Measured: 3952.00 RPM | Error: 48.00 RPM | PWM: 348363.1685194373 | Kp: 22.559 | Ki: 22.903 | Kd: 25.000 | Loss: 796.548950
# Time: 238.63s | Desired: 4000.00 RPM | Measured: 3788.00 RPM | Error: 212.00 RPM | PWM: 426309.78009033203 | Kp: 50.000 | Ki: 0.000 | Kd: 0.000 | Loss: 1398.114014
# Time: 239.67s | Desired: 4000.00 RPM | Measured: 3004.00 RPM | Error: 996.00 RPM | PWM: 49800.0 | Kp: 0.000 | Ki: 2.615 | Kd: 2.130 | Loss: 1830.264526
# Time: 240.71s | Desired: 4000.00 RPM | Measured: 3782.00 RPM | Error: 218.00 RPM | PWM: 50311.77447938919 | Kp: 50.000 | Ki: 0.000 | Kd: 0.000 | Loss: 17541.974609
# Time: 241.74s | Desired: 4000.00 RPM | Measured: 3971.00 RPM | Error: 29.00 RPM | PWM: 1450.0 | Kp: 4.522 | Ki: 14.600 | Kd: 0.000 | Loss: 157567.671875
# Time: 242.77s | Desired: 4000.00 RPM | Measured: 3984.00 RPM | Error: 16.00 RPM | PWM: 299593.2187986374 | Kp: 50.000 | Ki: 0.000 | Kd: 0.000 | Loss: 915521.687500
# Time: 243.83s | Desired: 4000.00 RPM | Measured: 3854.00 RPM | Error: 146.00 RPM | PWM: 7300.0 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 1083746.875000
# Time: 244.87s | Desired: 4000.00 RPM | Measured: 3975.00 RPM | Error: 25.00 RPM | PWM: 481200.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 132196.703125
# Time: 245.91s | Desired: 4000.00 RPM | Measured: 3991.00 RPM | Error: 9.00 RPM | PWM: 0.0 | Kp: 35.943 | Ki: 3.906 | Kd: 2.798 | Loss: 987609.375000
# Time: 246.95s | Desired: 4000.00 RPM | Measured: 3993.00 RPM | Error: 7.00 RPM | PWM: 72522.82700634003 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 153045.703125
# Time: 247.98s | Desired: 4000.00 RPM | Measured: 4008.00 RPM | Error: -8.00 RPM | PWM: 466475.0 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 736695.875000
# Time: 249.01s | Desired: 4000.00 RPM | Measured: 3991.00 RPM | Error: 9.00 RPM | PWM: 458675.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 200629.656250
# Time: 250.06s | Desired: 4000.00 RPM | Measured: 3980.00 RPM | Error: 20.00 RPM | PWM: 0.0 | Kp: 23.372 | Ki: 12.633 | Kd: 10.703 | Loss: 564861.375000
# Time: 251.09s | Desired: 4000.00 RPM | Measured: 4001.00 RPM | Error: -1.00 RPM | PWM: 213722.21700191498 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 186233.828125
# Time: 252.14s | Desired: 4000.00 RPM | Measured: 3996.00 RPM | Error: 4.00 RPM | PWM: 421350.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 366010.937500
# Time: 253.18s | Desired: 4000.00 RPM | Measured: 4033.00 RPM | Error: -33.00 RPM | PWM: 400100.0 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 232352.312500
# Time: 254.23s | Desired: 4000.00 RPM | Measured: 4004.00 RPM | Error: -4.00 RPM | PWM: 725.0 | Kp: 25.812 | Ki: 10.800 | Kd: 0.000 | Loss: 180510.734375
# Time: 255.26s | Desired: 4000.00 RPM | Measured: 3992.00 RPM | Error: 8.00 RPM | PWM: 162697.08737277985 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 260738.953125
# Time: 256.30s | Desired: 4000.00 RPM | Measured: 3243.00 RPM | Error: 757.00 RPM | PWM: 393300.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 96537.234375
# Time: 257.34s | Desired: 4000.00 RPM | Measured: 3810.00 RPM | Error: 190.00 RPM | PWM: 368825.0 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 184463.281250
# Time: 258.38s | Desired: 4000.00 RPM | Measured: 3938.00 RPM | Error: 62.00 RPM | PWM: 360075.0 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 165251.078125
# Time: 259.41s | Desired: 4000.00 RPM | Measured: 3954.00 RPM | Error: 46.00 RPM | PWM: -400.0 | Kp: 29.996 | Ki: 8.675 | Kd: 15.399 | Loss: 57718.964844
# Time: 260.46s | Desired: 4000.00 RPM | Measured: 3954.00 RPM | Error: 46.00 RPM | PWM: 117561.13828086853 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 190602.046875
# Time: 261.49s | Desired: 4000.00 RPM | Measured: 3950.00 RPM | Error: 50.00 RPM | PWM: 338675.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 38979.421875
# Time: 262.54s | Desired: 4000.00 RPM | Measured: 3951.00 RPM | Error: 49.00 RPM | PWM: 342450.0 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 113608.625000
# Time: 263.57s | Desired: 4000.00 RPM | Measured: 3977.00 RPM | Error: 23.00 RPM | PWM: -650.0 | Kp: 28.579 | Ki: 11.119 | Kd: 25.000 | Loss: 97395.007812
# Time: 264.61s | Desired: 4000.00 RPM | Measured: 4001.00 RPM | Error: -1.00 RPM | PWM: 153785.31796073914 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 22201.005859
# Time: 265.66s | Desired: 4000.00 RPM | Measured: 4014.00 RPM | Error: -14.00 RPM | PWM: 348925.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 118361.281250
# Time: 266.70s | Desired: 4000.00 RPM | Measured: 3971.00 RPM | Error: 29.00 RPM | PWM: 354200.0 | Kp: 50.000 | Ki: 0.000 | Kd: 0.000 | Loss: 19530.386719
# Time: 267.74s | Desired: 4000.00 RPM | Measured: 3975.00 RPM | Error: 25.00 RPM | PWM: 1250.0 | Kp: 12.464 | Ki: 11.393 | Kd: 0.000 | Loss: 66962.984375
# Time: 268.78s | Desired: 4000.00 RPM | Measured: 3974.00 RPM | Error: 26.00 RPM | PWM: 142103.74512290955 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 59909.320312
# Time: 269.81s | Desired: 4000.00 RPM | Measured: 3215.00 RPM | Error: 785.00 RPM | PWM: 18975.0 | Kp: 0.000 | Ki: 22.334 | Kd: 25.000 | Loss: 15128.434570
# Time: 270.86s | Desired: 4000.00 RPM | Measured: 3871.00 RPM | Error: 129.00 RPM | PWM: 279707.7074127197 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 66453.187500
# Time: 271.89s | Desired: 4000.00 RPM | Measured: 4010.00 RPM | Error: -10.00 RPM | PWM: 321700.0 | Kp: 50.000 | Ki: 12.347 | Kd: 25.000 | Loss: 20286.439453
# Time: 272.94s | Desired: 4000.00 RPM | Measured: 4040.00 RPM | Error: -40.00 RPM | PWM: 155779.51380825043 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 29907.500000
# Time: 273.97s | Desired: 4000.00 RPM | Measured: 3544.00 RPM | Error: 456.00 RPM | PWM: 12400.0 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 46753.566406
# Time: 275.01s | Desired: 4000.00 RPM | Measured: 3971.00 RPM | Error: 29.00 RPM | PWM: 273350.0 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 1764.592041
# Time: 276.05s | Desired: 4000.00 RPM | Measured: 4079.00 RPM | Error: -79.00 RPM | PWM: 263825.0 | Kp: 50.000 | Ki: 0.000 | Kd: 0.000 | Loss: 44574.433594
# Time: 277.10s | Desired: 4000.00 RPM | Measured: 4085.00 RPM | Error: -85.00 RPM | PWM: -4250.0 | Kp: 50.000 | Ki: 5.458 | Kd: 0.457 | Loss: 12536.610352
# Time: 278.13s | Desired: 4000.00 RPM | Measured: 4028.00 RPM | Error: -28.00 RPM | PWM: 56866.412143558264 | Kp: 0.000 | Ki: 22.300 | Kd: 25.000 | Loss: 16068.195312
# Time: 279.18s | Desired: 4000.00 RPM | Measured: 4009.00 RPM | Error: -9.00 RPM | PWM: 212973.32849121094 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 28243.755859
# Time: 280.21s | Desired: 4000.00 RPM | Measured: 3994.00 RPM | Error: 6.00 RPM | PWM: 375.0 | Kp: 23.486 | Ki: 15.677 | Kd: 4.745 | Loss: 5322.776855
# Time: 281.24s | Desired: 4000.00 RPM | Measured: 3983.00 RPM | Error: 17.00 RPM | PWM: 124521.81979942322 | Kp: 50.000 | Ki: 25.000 | Kd: 24.901 | Loss: 18904.001953
# Time: 282.29s | Desired: 4000.00 RPM | Measured: 3985.00 RPM | Error: 15.00 RPM | PWM: 179325.1985244751 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 14397.493164
# Time: 283.32s | Desired: 4000.00 RPM | Measured: 2819.00 RPM | Error: 1181.00 RPM | PWM: 224575.0 | Kp: 0.000 | Ki: 4.391 | Kd: 25.000 | Loss: 3257.072998
# Time: 284.36s | Desired: 4000.00 RPM | Measured: 3839.00 RPM | Error: 161.00 RPM | PWM: 6592.155052661896 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 17923.210938
# Time: 285.39s | Desired: 4000.00 RPM | Measured: 3983.00 RPM | Error: 17.00 RPM | PWM: 169300.0 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 4483.230957
# Time: 286.44s | Desired: 4000.00 RPM | Measured: 4006.00 RPM | Error: -6.00 RPM | PWM: -575.0 | Kp: 31.638 | Ki: 12.040 | Kd: 21.733 | Loss: 7351.345703
# Time: 287.46s | Desired: 4000.00 RPM | Measured: 3987.00 RPM | Error: 13.00 RPM | PWM: 71185.89191246033 | Kp: 12.274 | Ki: 25.000 | Kd: 25.000 | Loss: 11525.412109
# Time: 288.51s | Desired: 4000.00 RPM | Measured: 3026.00 RPM | Error: 974.00 RPM | PWM: 175904.96347808838 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 1946.004150
# Time: 289.56s | Desired: 4000.00 RPM | Measured: 3830.00 RPM | Error: 170.00 RPM | PWM: 0.0 | Kp: 23.645 | Ki: 7.510 | Kd: 19.201 | Loss: 7767.291016
# Time: 290.59s | Desired: 4000.00 RPM | Measured: 4088.00 RPM | Error: -88.00 RPM | PWM: 42810.42432165146 | Kp: 0.000 | Ki: 1.930 | Kd: 25.000 | Loss: 6346.023926
# Time: 291.63s | Desired: 4000.00 RPM | Measured: 2845.00 RPM | Error: 1155.00 RPM | PWM: 43303.46821439266 | Kp: 0.000 | Ki: 0.909 | Kd: 12.236 | Loss: 1560.691895
# Time: 292.67s | Desired: 4000.00 RPM | Measured: 2485.00 RPM | Error: 1515.00 RPM | PWM: 10311.706480026245 | Kp: 0.000 | Ki: 16.694 | Kd: 0.000 | Loss: 5602.277832
# Time: 293.71s | Desired: 4000.00 RPM | Measured: 3677.00 RPM | Error: 323.00 RPM | PWM: 130099.599111557 | Kp: 43.182 | Ki: 16.279 | Kd: 25.000 | Loss: 4804.580078
# Time: 294.74s | Desired: 4000.00 RPM | Measured: 3894.00 RPM | Error: 106.00 RPM | PWM: 130803.74102401733 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 881.312195
# Time: 295.77s | Desired: 4000.00 RPM | Measured: 3917.00 RPM | Error: 83.00 RPM | PWM: -575.0 | Kp: 32.547 | Ki: 5.526 | Kd: 25.000 | Loss: 4742.359375
# Time: 296.82s | Desired: 4000.00 RPM | Measured: 3927.00 RPM | Error: 73.00 RPM | PWM: 46963.898882865906 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 3116.807129
# Time: 297.86s | Desired: 4000.00 RPM | Measured: 3703.00 RPM | Error: 297.00 RPM | PWM: 5600.0 | Kp: 0.697 | Ki: 21.490 | Kd: 25.000 | Loss: 789.409058
# Time: 298.89s | Desired: 4000.00 RPM | Measured: 3892.00 RPM | Error: 108.00 RPM | PWM: 176938.94017219543 | Kp: 50.000 | Ki: 13.089 | Kd: 21.496 | Loss: 3181.554443
# Time: 299.94s | Desired: 4000.00 RPM | Measured: 3936.00 RPM | Error: 64.00 RPM | PWM: 114177.27261924744 | Kp: 25.290 | Ki: 5.829 | Kd: 24.116 | Loss: 2228.225342
# Time: 300.98s | Desired: 4000.00 RPM | Measured: 3953.00 RPM | Error: 47.00 RPM | PWM: 51044.15555667877 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 624.771118
# Time: 302.02s | Desired: 4000.00 RPM | Measured: 3944.00 RPM | Error: 56.00 RPM | PWM: 225.0 | Kp: 24.161 | Ki: 11.193 | Kd: 8.954 | Loss: 1694.173706
# Time: 303.06s | Desired: 4000.00 RPM | Measured: 3942.00 RPM | Error: 58.00 RPM | PWM: 98761.79551792145 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1754.570190
# Time: 304.10s | Desired: 4000.00 RPM | Measured: 3787.00 RPM | Error: 213.00 RPM | PWM: 3875.0 | Kp: 32.069 | Ki: 5.211 | Kd: 0.000 | Loss: 866.869568
# Time: 305.13s | Desired: 4000.00 RPM | Measured: 3853.00 RPM | Error: 147.00 RPM | PWM: 51428.30285310745 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 602.020813
# Time: 306.18s | Desired: 4000.00 RPM | Measured: 3437.00 RPM | Error: 563.00 RPM | PWM: 10400.0 | Kp: 0.000 | Ki: 15.041 | Kd: 15.675 | Loss: 1228.506470
# Time: 307.21s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 140622.8862991333 | Kp: 24.549 | Ki: 25.000 | Kd: 14.476 | Loss: 1242.754761
# Time: 308.24s | Desired: 4000.00 RPM | Measured: 3877.00 RPM | Error: 123.00 RPM | PWM: 249662.79060173035 | Kp: 35.322 | Ki: 25.000 | Kd: 0.000 | Loss: 519.361084
# Time: 309.30s | Desired: 4000.00 RPM | Measured: 3929.00 RPM | Error: 71.00 RPM | PWM: 234632.85946273804 | Kp: 1.501 | Ki: 0.000 | Kd: 13.713 | Loss: 512.701721
# Time: 310.33s | Desired: 4000.00 RPM | Measured: 3644.00 RPM | Error: 356.00 RPM | PWM: 4442.560933589935 | Kp: 30.275 | Ki: 13.640 | Kd: 10.011 | Loss: 935.381958
# ...
# Time: 398.68s | Desired: 4000.00 RPM | Measured: 3982.00 RPM | Error: 18.00 RPM | PWM: 170254.9272289276 | Kp: 15.257 | Ki: 0.000 | Kd: 22.699 | Loss: 56.996883
# Time: 399.71s | Desired: 4000.00 RPM | Measured: 3987.00 RPM | Error: 13.00 RPM | PWM: 84.85057640075684 | Kp: 23.051 | Ki: 16.728 | Kd: 12.970 | Loss: 56.210300
# Time: 400.76s | Desired: 4000.00 RPM | Measured: 3684.00 RPM | Error: 316.00 RPM | PWM: 207299.25071907043 | Kp: 15.508 | Ki: 2.798 | Kd: 10.435 | Loss: 55.689175
# Time: 401.80s | Desired: 4000.00 RPM | Measured: 3904.00 RPM | Error: 96.00 RPM | PWM: 32905.10398864746 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 58.470573
# Time: 402.84s | Desired: 4000.00 RPM | Measured: 3691.00 RPM | Error: 309.00 RPM | PWM: 5325.0 | Kp: 7.774 | Ki: 18.313 | Kd: 20.771 | Loss: 57.634380
# Time: 403.88s | Desired: 4000.00 RPM | Measured: 3924.00 RPM | Error: 76.00 RPM | PWM: 212607.8925266266 | Kp: 22.232 | Ki: 4.076 | Kd: 15.563 | Loss: 56.607578
# Time: 404.91s | Desired: 4000.00 RPM | Measured: 3975.00 RPM | Error: 25.00 RPM | PWM: 48285.26601600647 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 58.275558
# Time: 405.96s | Desired: 4000.00 RPM | Measured: 3480.00 RPM | Error: 520.00 RPM | PWM: 12375.0 | Kp: 0.000 | Ki: 7.954 | Kd: 25.000 | Loss: 58.038151
# Time: 406.98s | Desired: 4000.00 RPM | Measured: 3917.00 RPM | Error: 83.00 RPM | PWM: 82652.6094174385 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 58.268856
# Time: 408.03s | Desired: 4000.00 RPM | Measured: 3985.00 RPM | Error: 15.00 RPM | PWM: -1700.0 | Kp: 43.298 | Ki: 6.835 | Kd: 25.000 | Loss: 56.810246
# Time: 409.06s | Desired: 4000.00 RPM | Measured: 4006.00 RPM | Error: -6.00 RPM | PWM: 70422.77998161316 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 57.816021
# Time: 410.10s | Desired: 4000.00 RPM | Measured: 2792.00 RPM | Error: 1208.00 RPM | PWM: 30350.0 | Kp: 0.000 | Ki: 0.000 | Kd: 6.451 | Loss: 69.693893
# Time: 411.13s | Desired: 4000.00 RPM | Measured: 3722.00 RPM | Error: 278.00 RPM | PWM: -5999.242172241211 | Kp: 31.170 | Ki: 8.013 | Kd: 0.094 | Loss: 68.260170
# Time: 412.18s | Desired: 4000.00 RPM | Measured: 3632.00 RPM | Error: 368.00 RPM | PWM: 106873.44598399103 | Kp: 0.000 | Ki: 0.000 | Kd: 16.758 | Loss: 68.328194
# Time: 413.21s | Desired: 4000.00 RPM | Measured: 3960.00 RPM | Error: 40.00 RPM | PWM: -5496.656341552734 | Kp: 41.065 | Ki: 3.053 | Kd: 0.000 | Loss: 68.021362
# Time: 414.26s | Desired: 4000.00 RPM | Measured: 3269.00 RPM | Error: 731.00 RPM | PWM: 68209.61706256866 | Kp: 0.000 | Ki: 0.000 | Kd: 13.324 | Loss: 69.099037
# Time: 415.29s | Desired: 4000.00 RPM | Measured: 3899.00 RPM | Error: 101.00 RPM | PWM: -8394.40320968628 | Kp: 34.472 | Ki: 5.818 | Kd: 0.000 | Loss: 65.743187
# Time: 416.34s | Desired: 4000.00 RPM | Measured: 3579.00 RPM | Error: 421.00 RPM | PWM: 88183.76109313965 | Kp: 0.000 | Ki: 0.000 | Kd: 18.684 | Loss: 62.494888
# Time: 417.38s | Desired: 4000.00 RPM | Measured: 3911.00 RPM | Error: 89.00 RPM | PWM: -6203.015182495117 | Kp: 37.982 | Ki: 4.661 | Kd: 0.000 | Loss: 62.132904
# Time: 418.41s | Desired: 4000.00 RPM | Measured: 2865.00 RPM | Error: 1135.00 RPM | PWM: 104813.06122779846 | Kp: 0.000 | Ki: 0.000 | Kd: 0.035 | Loss: 61.804016
# Time: 419.46s | Desired: 4000.00 RPM | Measured: 3257.00 RPM | Error: 743.00 RPM | PWM: -13.815301597118378 | Kp: 22.456 | Ki: 1.634 | Kd: 25.000 | Loss: 61.647736
# Time: 420.50s | Desired: 4000.00 RPM | Measured: 3983.00 RPM | Error: 17.00 RPM | PWM: 7188.320359826088 | Kp: 2.682 | Ki: 12.405 | Kd: 25.000 | Loss: 60.966763
# Time: 421.54s | Desired: 4000.00 RPM | Measured: 3920.00 RPM | Error: 80.00 RPM | PWM: 193794.79869651794 | Kp: 22.263 | Ki: 6.217 | Kd: 14.218 | Loss: 59.719128
# Time: 422.57s | Desired: 4000.00 RPM | Measured: 3576.00 RPM | Error: 424.00 RPM | PWM: 111573.50350952148 | Kp: 0.000 | Ki: 0.000 | Kd: 15.625 | Loss: 57.589283
# Time: 423.61s | Desired: 4000.00 RPM | Measured: 3973.00 RPM | Error: 27.00 RPM | PWM: -6203.091303825378 | Kp: 40.701 | Ki: 3.351 | Kd: 0.000 | Loss: 53.799728
# Time: 424.67s | Desired: 4000.00 RPM | Measured: 4044.00 RPM | Error: -44.00 RPM | PWM: 48878.7804851532 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 55.737396
# Time: 425.70s | Desired: 4000.00 RPM | Measured: 4040.00 RPM | Error: -40.00 RPM | PWM: 100.0 | Kp: 24.337 | Ki: 17.541 | Kd: 6.553 | Loss: 53.671494
# Time: 426.74s | Desired: 4000.00 RPM | Measured: 4033.00 RPM | Error: -33.00 RPM | PWM: 263142.1912474632 | Kp: 41.167 | Ki: 21.780 | Kd: 7.388 | Loss: 53.334148
# Time: 427.78s | Desired: 4000.00 RPM | Measured: 3790.00 RPM | Error: 210.00 RPM | PWM: 337332.48326826096 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 51.911987
# Time: 428.81s | Desired: 4000.00 RPM | Measured: 3957.00 RPM | Error: 43.00 RPM | PWM: 382625.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 52.720604
# Time: 429.86s | Desired: 4000.00 RPM | Measured: 3997.00 RPM | Error: 3.00 RPM | PWM: 369700.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 51.147480
# Time: 430.89s | Desired: 4000.00 RPM | Measured: 3987.00 RPM | Error: 13.00 RPM | PWM: 347650.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 49.279861
# Time: 431.93s | Desired: 4000.00 RPM | Measured: 3960.00 RPM | Error: 40.00 RPM | PWM: 345875.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.799 | Loss: 46.473248
# Time: 432.98s | Desired: 4000.00 RPM | Measured: 3984.00 RPM | Error: 16.00 RPM | PWM: 327030.81907987595 | Kp: 44.628 | Ki: 21.422 | Kd: 3.809 | Loss: 46.316254
# Time: 434.01s | Desired: 4000.00 RPM | Measured: 3971.00 RPM | Error: 29.00 RPM | PWM: 278828.4647843838 | Kp: 34.864 | Ki: 15.297 | Kd: 7.947 | Loss: 46.023392
# Time: 435.06s | Desired: 4000.00 RPM | Measured: 2839.00 RPM | Error: 1161.00 RPM | PWM: 248626.62514400482 | Kp: 6.338 | Ki: 9.853 | Kd: 0.000 | Loss: 45.230900
# Time: 436.09s | Desired: 4000.00 RPM | Measured: 3490.00 RPM | Error: 510.00 RPM | PWM: 143220.93078517914 | Kp: 2.497 | Ki: 0.000 | Kd: 10.834 | Loss: 44.872231
# Time: 437.14s | Desired: 4000.00 RPM | Measured: 2780.00 RPM | Error: 1220.00 RPM | PWM: 10738.72745513916 | Kp: 0.000 | Ki: 5.573 | Kd: 2.638 | Loss: 48.456211
# Time: 438.17s | Desired: 4000.00 RPM | Measured: 2584.00 RPM | Error: 1416.00 RPM | PWM: 89694.58895015717 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 49.038586
# Time: 439.22s | Desired: 4000.00 RPM | Measured: 3747.00 RPM | Error: 253.00 RPM | PWM: 0.0 | Kp: 23.577 | Ki: 11.598 | Kd: 23.704 | Loss: 47.626125
# Time: 440.26s | Desired: 4000.00 RPM | Measured: 3968.00 RPM | Error: 32.00 RPM | PWM: 175567.9853515625 | Kp: 17.881 | Ki: 1.646 | Kd: 18.282 | Loss: 47.210209
# Time: 441.29s | Desired: 4000.00 RPM | Measured: 3965.00 RPM | Error: 35.00 RPM | PWM: 25371.667360424995 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 51.287144
# Time: 442.34s | Desired: 4000.00 RPM | Measured: 3962.00 RPM | Error: 38.00 RPM | PWM: 75.0 | Kp: 23.949 | Ki: 16.008 | Kd: 9.918 | Loss: 50.341301
# Time: 443.38s | Desired: 4000.00 RPM | Measured: 3933.00 RPM | Error: 67.00 RPM | PWM: 236611.69253253937 | Kp: 29.882 | Ki: 10.388 | Kd: 10.685 | Loss: 49.645187
# Time: 444.41s | Desired: 4000.00 RPM | Measured: 3926.00 RPM | Error: 74.00 RPM | PWM: 154654.6014585495 | Kp: 14.937 | Ki: 0.000 | Kd: 19.052 | Loss: 49.039623
# Time: 445.46s | Desired: 4000.00 RPM | Measured: 3187.00 RPM | Error: 813.00 RPM | PWM: 26222.93625354767 | Kp: 0.000 | Ki: 0.000 | Kd: 16.794 | Loss: 55.435944
# Time: 446.50s | Desired: 4000.00 RPM | Measured: 3713.00 RPM | Error: 287.00 RPM | PWM: -8833.419597625732 | Kp: 27.640 | Ki: 8.957 | Kd: 1.086 | Loss: 54.395710
# Time: 447.54s | Desired: 4000.00 RPM | Measured: 3903.00 RPM | Error: 97.00 RPM | PWM: 134969.40939569473 | Kp: 9.549 | Ki: 0.000 | Kd: 20.601 | Loss: 54.013035
# Time: 448.57s | Desired: 4000.00 RPM | Measured: 3251.00 RPM | Error: 749.00 RPM | PWM: 20584.04447555542 | Kp: 0.000 | Ki: 0.000 | Kd: 21.093 | Loss: 59.641224
# Time: 449.61s | Desired: 4000.00 RPM | Measured: 2960.00 RPM | Error: 1040.00 RPM | PWM: 6138.068670272827 | Kp: 5.693 | Ki: 7.415 | Kd: 13.498 | Loss: 59.215931
# Time: 450.67s | Desired: 4000.00 RPM | Measured: 3279.00 RPM | Error: 721.00 RPM | PWM: 112180.90730524063 | Kp: 0.000 | Ki: 0.000 | Kd: 9.866 | Loss: 59.340111
# Time: 451.70s | Desired: 4000.00 RPM | Measured: 3848.00 RPM | Error: 152.00 RPM | PWM: -5613.8051080703735 | Kp: 36.348 | Ki: 5.328 | Kd: 0.000 | Loss: 59.034081
# Time: 452.74s | Desired: 4000.00 RPM | Measured: 3425.00 RPM | Error: 575.00 RPM | PWM: 106139.43952846527 | Kp: 0.000 | Ki: 0.000 | Kd: 13.176 | Loss: 59.141830
# Time: 453.79s | Desired: 4000.00 RPM | Measured: 3273.00 RPM | Error: 727.00 RPM | PWM: 2002.825584411621 | Kp: 14.305 | Ki: 0.000 | Kd: 0.000 | Loss: 56.967949
# Time: 454.82s | Desired: 4000.00 RPM | Measured: 2926.00 RPM | Error: 1074.00 RPM | PWM: 15363.213890075684 | Kp: 0.000 | Ki: 5.301 | Kd: 23.580 | Loss: 59.760891
# Time: 455.86s | Desired: 4000.00 RPM | Measured: 3844.00 RPM | Error: 156.00 RPM | PWM: 71924.49178552628 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 60.296574
# Time: 456.90s | Desired: 4000.00 RPM | Measured: 3545.00 RPM | Error: 455.00 RPM | PWM: 7475.0 | Kp: 0.000 | Ki: 11.211 | Kd: 14.135 | Loss: 58.059875
# Time: 457.94s | Desired: 4000.00 RPM | Measured: 3906.00 RPM | Error: 94.00 RPM | PWM: 198518.1339378357 | Kp: 22.169 | Ki: 5.288 | Kd: 13.716 | Loss: 56.285221
# Time: 458.98s | Desired: 4000.00 RPM | Measured: 3258.00 RPM | Error: 742.00 RPM | PWM: 119121.71885490417 | Kp: 0.000 | Ki: 0.000 | Kd: 8.791 | Loss: 55.728947
# Time: 460.01s | Desired: 4000.00 RPM | Measured: 3830.00 RPM | Error: 170.00 RPM | PWM: -5028.191459655762 | Kp: 36.128 | Ki: 5.502 | Kd: 0.000 | Loss: 55.459206
# Time: 461.05s | Desired: 4000.00 RPM | Measured: 3948.00 RPM | Error: 52.00 RPM | PWM: 103940.78673171997 | Kp: 5.966 | Ki: 0.000 | Kd: 24.601 | Loss: 54.356941
# Time: 462.09s | Desired: 4000.00 RPM | Measured: 3078.00 RPM | Error: 922.00 RPM | PWM: 26903.68728351593 | Kp: 0.000 | Ki: 0.000 | Kd: 15.663 | Loss: 52.302643
# Time: 463.13s | Desired: 4000.00 RPM | Measured: 2829.00 RPM | Error: 1171.00 RPM | PWM: 3900.0770530700684 | Kp: 7.049 | Ki: 16.230 | Kd: 5.484 | Loss: 51.809196
# Time: 464.18s | Desired: 4000.00 RPM | Measured: 2550.00 RPM | Error: 1450.00 RPM | PWM: 323624.4473028183 | Kp: 18.266 | Ki: 19.831 | Kd: 0.000 | Loss: 56.319557
# Time: 465.22s | Desired: 4000.00 RPM | Measured: 3784.00 RPM | Error: 216.00 RPM | PWM: 406478.76725006104 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 57.280800
# Time: 466.26s | Desired: 4000.00 RPM | Measured: 3977.00 RPM | Error: 23.00 RPM | PWM: 513000.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 66.255005
# Time: 467.29s | Desired: 4000.00 RPM | Measured: 3960.00 RPM | Error: 40.00 RPM | PWM: 496150.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 70.447021
# Time: 468.34s | Desired: 4000.00 RPM | Measured: 3973.00 RPM | Error: 27.00 RPM | PWM: 493975.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 73.259819
# Time: 469.38s | Desired: 4000.00 RPM | Measured: 3967.00 RPM | Error: 33.00 RPM | PWM: 484425.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 77.794800
# Time: 470.41s | Desired: 4000.00 RPM | Measured: 3972.00 RPM | Error: 28.00 RPM | PWM: 482775.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 74.034531
# Time: 471.45s | Desired: 4000.00 RPM | Measured: 4010.00 RPM | Error: -10.00 RPM | PWM: 453200.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 75.262848
# Time: 472.50s | Desired: 4000.00 RPM | Measured: 3977.00 RPM | Error: 23.00 RPM | PWM: 436025.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 73.474304
# Time: 473.53s | Desired: 4000.00 RPM | Measured: 3981.00 RPM | Error: 19.00 RPM | PWM: 435975.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 73.149956
# Time: 474.57s | Desired: 4000.00 RPM | Measured: 3977.00 RPM | Error: 23.00 RPM | PWM: 434650.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.611 | Loss: 72.194649
# Time: 475.61s | Desired: 4000.00 RPM | Measured: 3992.00 RPM | Error: 8.00 RPM | PWM: 423865.83485513926 | Kp: 50.000 | Ki: 24.099 | Kd: 0.000 | Loss: 73.672707
# Time: 476.65s | Desired: 4000.00 RPM | Measured: 3986.00 RPM | Error: 14.00 RPM | PWM: 408457.8066253662 | Kp: 50.000 | Ki: 25.000 | Kd: 6.620 | Loss: 80.659203
# Time: 477.70s | Desired: 4000.00 RPM | Measured: 3321.00 RPM | Error: 679.00 RPM | PWM: 462802.1569132805 | Kp: 43.853 | Ki: 11.675 | Kd: 0.000 | Loss: 149.968002
# Time: 478.73s | Desired: 4000.00 RPM | Measured: 3597.00 RPM | Error: 403.00 RPM | PWM: 224278.14477539062 | Kp: 14.866 | Ki: 21.852 | Kd: 25.000 | Loss: 680.168152
# Time: 479.78s | Desired: 4000.00 RPM | Measured: 3923.00 RPM | Error: 77.00 RPM | PWM: 389244.3153219223 | Kp: 42.099 | Ki: 0.000 | Kd: 0.000 | Loss: 4947.589844
# Time: 480.81s | Desired: 4000.00 RPM | Measured: 3209.00 RPM | Error: 791.00 RPM | PWM: 33300.66428375244 | Kp: 0.000 | Ki: 3.536 | Kd: 25.000 | Loss: 39211.671875
# Time: 481.85s | Desired: 4000.00 RPM | Measured: 3841.00 RPM | Error: 159.00 RPM | PWM: 50499.972767829895 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 267733.937500
# Time: 482.89s | Desired: 4000.00 RPM | Measured: 3543.00 RPM | Error: 457.00 RPM | PWM: 0.0 | Kp: 22.369 | Ki: 15.354 | Kd: 25.000 | Loss: 1270469.000000
# Time: 483.92s | Desired: 4000.00 RPM | Measured: 3882.00 RPM | Error: 118.00 RPM | PWM: 291240.31395721436 | Kp: 29.941 | Ki: 0.000 | Kd: 0.000 | Loss: 2018728.375000
# Time: 484.97s | Desired: 4000.00 RPM | Measured: 3954.00 RPM | Error: 46.00 RPM | PWM: 1377.276699066162 | Kp: 10.248 | Ki: 19.600 | Kd: 0.000 | Loss: 234922.031250
# Time: 486.00s | Desired: 4000.00 RPM | Measured: 3944.00 RPM | Error: 56.00 RPM | PWM: 381912.7010345459 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 946462.500000
# Time: 487.05s | Desired: 4000.00 RPM | Measured: 2984.00 RPM | Error: 1016.00 RPM | PWM: 511075.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 488940.281250
# Time: 488.08s | Desired: 4000.00 RPM | Measured: 3817.00 RPM | Error: 183.00 RPM | PWM: 0.0 | Kp: 25.739 | Ki: 5.464 | Kd: 7.096 | Loss: 415160.375000
# Time: 489.12s | Desired: 4000.00 RPM | Measured: 3893.00 RPM | Error: 107.00 RPM | PWM: 106087.89276313782 | Kp: 19.767 | Ki: 25.000 | Kd: 25.000 | Loss: 449256.156250
# Time: 490.16s | Desired: 4000.00 RPM | Measured: 2790.00 RPM | Error: 1210.00 RPM | PWM: 498942.9825401306 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 344670.718750
# Time: 491.20s | Desired: 4000.00 RPM | Measured: 3710.00 RPM | Error: 290.00 RPM | PWM: 419300.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 331878.718750
# Time: 492.23s | Desired: 4000.00 RPM | Measured: 3826.00 RPM | Error: 174.00 RPM | PWM: 0.0 | Kp: 27.150 | Ki: 5.223 | Kd: 5.760 | Loss: 284171.187500
# Time: 493.28s | Desired: 4000.00 RPM | Measured: 3833.00 RPM | Error: 167.00 RPM | PWM: 97833.70317602158 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 178852.906250
# Time: 494.31s | Desired: 4000.00 RPM | Measured: 2715.00 RPM | Error: 1285.00 RPM | PWM: 542275.0 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 322170.125000
# Time: 495.35s | Desired: 4000.00 RPM | Measured: 3621.00 RPM | Error: 379.00 RPM | PWM: 458600.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 76504.898438
# Time: 496.39s | Desired: 4000.00 RPM | Measured: 3869.00 RPM | Error: 131.00 RPM | PWM: 0.0 | Kp: 26.651 | Ki: 4.518 | Kd: 1.285 | Loss: 299977.843750
# Time: 497.43s | Desired: 4000.00 RPM | Measured: 3889.00 RPM | Error: 111.00 RPM | PWM: 91562.96134710312 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 28113.707031
# Time: 498.47s | Desired: 4000.00 RPM | Measured: 3267.00 RPM | Error: 733.00 RPM | PWM: 52200.0 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 233401.359375
# Time: 499.51s | Desired: 4000.00 RPM | Measured: 3785.00 RPM | Error: 215.00 RPM | PWM: 471125.0 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 59684.058594
# Data saved to motor_speed_data_ANN_20250404_230235.csv
# Measured Speed plot saved to motor_speed_plot_speed_ANN_20250404_230235.pdf
# PID Gains plot saved to motor_speed_plot_gains_ANN_20250404_230235.pdf
# Loss plot saved to motor_speed_plot_loss_ANN_20250404_230235.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime
import uuid  # Import UUID for unique filenames

import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

# Define whether ANN is enabled or not
ANN_enabled = True  # Set to True if ANN is used, False otherwise

# Convert lists to NumPy arrays for performance calculations
time_stamps = np.array(times)  # Recorded time points
error = np.array(errors)
setpoints = np.array([desired_speed] * len(times))  # Setpoints stored as an array
speeds = np.array(speeds)

# Handle missing `loss_values`
if "loss_values" in globals() and len(loss_values) > 0:
    training_epochs = np.array(range(len(loss_values)))  # Training epochs for ANN
    loss_values = np.array(loss_values)
else:
    training_epochs = np.array([])  # Empty array if no loss data is available
    loss_values = np.array([])

# Compute Performance Metrics
rmse = np.sqrt(np.mean(error ** 2))
mae = np.mean(np.abs(error))
SSE = error[-1]  # Last recorded error
max_speed = max(speeds)
overshoot = max(0, ((max_speed - desired_speed) / desired_speed) * 100)

# Settling Time (Ts)
within_tolerance = np.abs(error) < (0.05 * desired_speed)  # Within ±5% of setpoint
Ts_index = np.argmax(within_tolerance) if np.any(within_tolerance) else -1
Ts = time_stamps[Ts_index] if Ts_index != -1 else None  # First time where error is within ±5%

# Generate Performance Plots and Save with explicit names
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")  # Format: YYYYMMDD_HHMMSS
identifier = "With_ANN" if ANN_enabled else "No_ANN"  # Condition-based identifier
unique_id = uuid.uuid4().hex[:8]  # Generates an 8-character unique ID

# 1. Histogram of Errors
hist_filename = f"Histogram_Errors_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.hist(error, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Error (RPM)", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(hist_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 2. RMSE & MAE Comparison
rmse_mae_filename = f"RMSE_MAE_Comparison_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["RMSE", "MAE"], [rmse, mae], color=['red', 'orange'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(rmse_mae_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 3. Overshoot & Steady-State Error
overshoot_sse_filename = f"Overshoot_SSE_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(7, 5))
plt.bar(["Overshoot (%)", "SSE"], [overshoot, SSE], color=['purple', 'green'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)
plt.savefig(overshoot_sse_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 4. ANN Loss Plot (if available)
if loss_values.size > 0:
    ann_loss_filename = f"ANN_Loss_{identifier}_{current_datetime}_{unique_id}.pdf"
    plt.figure(figsize=(7, 5))
    plt.plot(training_epochs, loss_values, label="Loss", color="b", linewidth=2)
    plt.xlabel("Epochs", fontsize=16)
    plt.ylabel("Loss Value (MSE)", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.savefig(ann_loss_filename, format="pdf", bbox_inches="tight")  # Save to PDF
    plt.show()
    print(f"ANN Loss Plot saved as {ann_loss_filename}")

# Print Statistical Summary
print("\n **Statistical Evaluation:**")
print(f"RMSE: {rmse:.2f} RPM")
print(f"MAE: {mae:.2f} RPM")
print(f"Settling Time (Ts): {Ts:.2f} s" if Ts is not None else " Settling Time Not Reached")
print(f"Steady-State Error (SSE): {SSE:.2f} RPM")
print(f"Overshoot: {overshoot:.2f}%")
print(f"\nHistogram of Errors saved as {hist_filename}")
print(f"RMSE & MAE Comparison saved as {rmse_mae_filename}")
print(f"Overshoot & Steady-State Error saved as {overshoot_sse_filename}")
# Out:
# ANN Loss Plot saved as ANN_Loss_With_ANN_20250404_222136_0936973e.pdf
#
#  **Statistical Evaluation:**
# RMSE: 1842.37 RPM
# MAE: 1365.44 RPM
#  Settling Time Not Reached
# Steady-State Error (SSE): 1882.00 RPM
# Overshoot: 0.00%
#
# Histogram of Errors saved as Histogram_Errors_With_ANN_20250404_222136_0936973e.pdf
# RMSE & MAE Comparison saved as RMSE_MAE_Comparison_With_ANN_20250404_222136_0936973e.pdf
# Overshoot & Steady-State Error saved as Overshoot_SSE_With_ANN_20250404_222136_0936973e.pdf

# %% [markdown]
# # Arduino Code Description
#
# The Arduino code (given below) is designed to control a DC motor using an Arduino microcontroller. The microcontroller powers the DC motor through a pulse-width modulation (PWM) driver. The code uses an shaft encoder to measure the motor's speed and a servo object to apply control. Real-time speed updates are sent to a connected Python script via serial communication, while PWM reference values received from the Python script are used to dynamically control the motor's speed. Encoder pulses are tracked using interrupts to ensure accurate speed measurements, creating a seamless integration between hardware and software for efficient motor control.

# %% [markdown]
# # The Arduino Code
#
# ```cpp
# #include <Servo.h>  // Include the Servo library
#
# Servo myservo;  // Servo object for motor control
#
# // Encoder tracking
# volatile unsigned int counter = 0;
# unsigned long lastTime = 0;
# const long interval = 1000;  // Speed update every 1 second
#
# int speedValue = 0;  // Measured speed
#
# void setup() {
#     myservo.attach(9);  // Connect servo/motor control to pin 9
#     Serial.begin(115200);  // Set serial baud rate
#
#     pinMode(2, INPUT_PULLUP);  // Encoder input
#     attachInterrupt(digitalPinToInterrupt(2), countPulses, RISING);  // Interrupt for encoder
# }
#
# void loop() {
#     // Send speed to Python every second
#     if (millis() - lastTime >= interval) {
#         lastTime = millis();
#         speedValue = map(counter, 0, 400, 0, 100);  // Convert pulses per second to speed in RPM
#         Serial.println(speedValue);  // Send the speed to Python
#         counter = 0;  // Reset counter
#     }
#
#     // Read PWM value from Python
#     if (Serial.available()) {
#         int pwmValue = Serial.parseInt();
#         pwmValue = map(pwmValue, 30000, 0, 120, 140);  // Map PWM range
#         myservo.write(pwmValue);  // Apply control
#         delay(50);
#     }
# }
#
# // Interrupt function to count encoder pulses
# void countPulses() {
#     counter++;
# }
# ```

# %% [markdown]
# # Preliminary Result
#
# The ANN-tuned PID controller outperforms the classical PID, achieving lower steady-state error and better adherence to the desired speed. Moreover, ongoing investigations are addressing the electrical and mechanical issues causing drift and undesirable step response, which reduces the systems performance.
