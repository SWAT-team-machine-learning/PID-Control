# %% [markdown]
# # Real-time Adaptive PID Control for DC Motor Speed Regulation using Neural Network-based Self-tuning
#
# **Machine Learning (CS-5841/EE-5841) Project**
# *Mbadiwe S. Benyeogor, Mark-Anthony Agbanu, Kepha Barasa, and Joseph Alfred Sonne*
#
#
# **Instructor: Professor Sujan Kumar Roy**

# %% [markdown]
# # Introduction
# This software documentation describes the functionality of a real-time Artificial Neural Network (ANN)-tuned PID motor speed control system implemented in Python. The system uses a Proportional-Integral-Derivative (PID) controller initially, and after 20% of the total runtime, the ANN dynamically adjusts the PID gains for improved performance. The control loop is executed in real-time, interfacing with an Arduino via serial communication.
#
# # System Overview
# The system consists of:
# - A PID controller for initial motor speed regulation.
# - An ANN for self-tuning of PID gains after 20% of the runtime.
# - A serial communication interface to receive speed measurements and send control signals.
# - A CSV logging mechanism for data storage.
# - Real-time visualization of system performance using Matplotlib.
#
#
# # Experimental Setup
#
# The experimental setup displayed in Figure 1 is essential for implementing and testing the Python code provided below. Each device in the setup is a critical component of the control loop, ensuring the system operates as intended. The experiment primarily investigates the performance of an ANN-enhanced PID control system, comparing it with that of a classical PID control algorithm. This approach evaluates the advantages of integrating machine learning into traditional control methods for improved system efficiency.
#
# ![Experimental Setup](Device2.png)
#
# *Figure 1: Experimental setup showing the components of the real-time ANN-enabled PID motor speed control system.*
#
# ---
#
# ^1 The devices in the experimental setup are required for the Python code below to function correctly.

# %% [markdown]
# # Classical PID Control program without ANN-enabled Self-tuning:

# %%
import serial
import time
import csv
import matplotlib.pyplot as plt
from datetime import datetime
from matplotlib.ticker import ScalarFormatter

# PID Parameters (Tune as needed)
Kp = 1.6
Ki = 0.05
Kd = 0.5

# User Inputs
desired_speed = float(input("Enter desired motor speed (RPM): "))
runtime = float(input("Enter duration for PID control (seconds): "))

# Initialize Serial Communication (Update COM port if necessary)
ser = serial.Serial('COM3', 115200, timeout=0.2)  # Ensure COM port matches your system

# PID Variables
previous_error = 0
integral = 0

# Anti-Windup Limits
integral_min = -255
integral_max = 255

# Data Logging
times, speeds, errors, pwm_outputs = [], [], [], []
kp_values, ki_values, kd_values = [], [], []
start_time = time.time()

# Generate dynamic filenames with timestamp
current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"PID_motor_data_{current_time}.csv"
pdf_filename_speed = f"PID_motor_plot_speed_{current_time}.pdf"
pdf_filename_gains = f"PID_motor_plot_gains_{current_time}.pdf"

# CSV File Setup
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Time (s)", "Desired Speed (RPM)", "Measured Speed (RPM)", "Error (RPM)", "PWM Output", "Kp", "Ki", "Kd"])  # CSV Header

def pid_control(measured_speed):
    """Compute PID control signal."""
    global previous_error, integral

    # PID computation
    error = desired_speed - measured_speed
    integral += error
    integral = max(min(integral, integral_max), integral_min)  # Anti-windup
    derivative = error - previous_error
    control_signal = (Kp * error) + (Ki * integral) + (Kd * derivative)
    previous_error = error

    return control_signal

# Main Control Loop
while time.time() - start_time < runtime:  # Run for user-defined duration
    response = ser.readline().decode().strip()
    if response:
        try:
            measured_speed = float(response)  # Measured speed in RPM
            elapsed_time = time.time() - start_time

            # Compute PID control output
            pwm_output = pid_control(measured_speed)
            ser.write(f"{pwm_output}\n".encode())  # Send PWM to Arduino

            # Store data
            times.append(elapsed_time)
            speeds.append(measured_speed)
            errors.append(desired_speed - measured_speed)
            pwm_outputs.append(pwm_output)
            kp_values.append(Kp)
            ki_values.append(Ki)
            kd_values.append(Kd)

            # Print output with current parameters
            print(f"Time: {elapsed_time:.2f}s | Desired: {desired_speed:.2f} RPM | "
                  f"Measured: {measured_speed:.2f} RPM | Error: {errors[-1]:.2f} RPM | "
                  f"PWM: {pwm_output} | Kp: {Kp} | Ki: {Ki} | Kd: {Kd}")

            # Save data to CSV
            with open(csv_filename, mode="a", newline="") as file:
                writer = csv.writer(file)
                writer.writerow([elapsed_time, desired_speed, measured_speed, errors[-1], pwm_output, Kp, Ki, Kd])

        except ValueError:
            print("Invalid data received.")

ser.close()

# Compute Settling Time (Ts)
settling_threshold = desired_speed * 0.05  # 5% threshold in RPM
Ts = next((t for t, e in zip(times, errors) if abs(e) <= settling_threshold), times[-1])

# Generate and Save Measured Speed & Error Plot
plt.figure(figsize=(7, 6))
plt.plot(times, speeds, label="Measured Speed", color="b", linewidth=2)
plt.plot(times, errors, label="Error", color="r", linewidth=2)
plt.plot(times, [desired_speed] * len(times), label="Desired Speed", color="g", linestyle="--", linewidth=2)

# Add shaded threshold region
threshold_lower = desired_speed * 0.95  # Lower bound of ±5% threshold
threshold_upper = desired_speed * 1.05  # Upper bound of ±5% threshold
plt.fill_between(times, threshold_lower, threshold_upper, color="gray", alpha=0.3, label="±5% Threshold")

# Add settling time marker
if Ts:
    plt.axvline(Ts, color="black", linestyle="--", linewidth=2, label=f"Settling Time: {Ts:.2f}s")
    #plt.text(Ts, desired_speed, f"  Ts = {Ts:.2f}s", fontsize=12, color="black", va="bottom")

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Speed (RPM)", fontsize=16)
#plt.title("Measured Speed and Error for PID Control without ANN", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Y-axis scientific notation
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)

# Add legend
plt.legend(fontsize=14)

# Save as PDF
plt.tight_layout()
plt.savefig(pdf_filename_speed, format="pdf")
plt.show()

# Generate and Save PID Gains Plot
plt.figure(figsize=(7, 6))
plt.plot(times, kp_values, label="Kp", color="m", linewidth=2)
plt.plot(times, ki_values, label="Ki", color="c", linewidth=2, alpha=0.6)
plt.plot(times, kd_values, label="Kd", color="y", linewidth=2, alpha=0.3)
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("PID Gains", fontsize=16)
#plt.title("Constant PID Gains Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(fontsize=14)

# Save as PDF
plt.tight_layout()
plt.savefig(pdf_filename_gains, format="pdf")
plt.show()

# Final Report
print(f"Data saved to {csv_filename}")
print(f"Speed plot saved to {pdf_filename_speed}")
print(f"PID gains plot saved to {pdf_filename_gains}")
# Out:
# Enter desired motor speed (RPM): 6000
# Enter duration for PID control (seconds): 500
# Time: 1.90s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 12612.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 2.94s | Desired: 6000.00 RPM | Measured: 4045.00 RPM | Error: 1955.00 RPM | PWM: 1118.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 3.96s | Desired: 6000.00 RPM | Measured: 5102.00 RPM | Error: 898.00 RPM | PWM: 921.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 5.01s | Desired: 6000.00 RPM | Measured: 5255.00 RPM | Error: 745.00 RPM | PWM: 1128.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 6.04s | Desired: 6000.00 RPM | Measured: 5119.00 RPM | Error: 881.00 RPM | PWM: 1490.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 7.07s | Desired: 6000.00 RPM | Measured: 5247.00 RPM | Error: 753.00 RPM | PWM: 1153.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 8.11s | Desired: 6000.00 RPM | Measured: 5119.00 RPM | Error: 881.00 RPM | PWM: 1486.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 9.15s | Desired: 6000.00 RPM | Measured: 5267.00 RPM | Error: 733.00 RPM | PWM: 1111.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 10.17s | Desired: 6000.00 RPM | Measured: 5127.00 RPM | Error: 873.00 RPM | PWM: 1479.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 11.21s | Desired: 6000.00 RPM | Measured: 5259.00 RPM | Error: 741.00 RPM | PWM: 1132.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 12.24s | Desired: 6000.00 RPM | Measured: 5273.00 RPM | Error: 727.00 RPM | PWM: 1168.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 13.28s | Desired: 6000.00 RPM | Measured: 5136.00 RPM | Error: 864.00 RPM | PWM: 1463.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 14.31s | Desired: 6000.00 RPM | Measured: 5101.00 RPM | Error: 899.00 RPM | PWM: 1468.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 15.35s | Desired: 6000.00 RPM | Measured: 5061.00 RPM | Error: 939.00 RPM | PWM: 1535.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 16.37s | Desired: 6000.00 RPM | Measured: 5083.00 RPM | Error: 917.00 RPM | PWM: 1468.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 17.41s | Desired: 6000.00 RPM | Measured: 5105.00 RPM | Error: 895.00 RPM | PWM: 1433.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 18.45s | Desired: 6000.00 RPM | Measured: 5094.00 RPM | Error: 906.00 RPM | PWM: 1467.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 19.49s | Desired: 6000.00 RPM | Measured: 4985.00 RPM | Error: 1015.00 RPM | PWM: 1691.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 20.52s | Desired: 6000.00 RPM | Measured: 5102.00 RPM | Error: 898.00 RPM | PWM: 1391.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 21.56s | Desired: 6000.00 RPM | Measured: 5270.00 RPM | Error: 730.00 RPM | PWM: 1096.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 22.59s | Desired: 6000.00 RPM | Measured: 5099.00 RPM | Error: 901.00 RPM | PWM: 1539.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 23.63s | Desired: 6000.00 RPM | Measured: 4984.00 RPM | Error: 1016.00 RPM | PWM: 1695.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 24.67s | Desired: 6000.00 RPM | Measured: 5020.00 RPM | Error: 980.00 RPM | PWM: 1562.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 25.69s | Desired: 6000.00 RPM | Measured: 5112.00 RPM | Error: 888.00 RPM | PWM: 1387.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 26.73s | Desired: 6000.00 RPM | Measured: 5302.00 RPM | Error: 698.00 RPM | PWM: 1034.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 27.77s | Desired: 6000.00 RPM | Measured: 5143.00 RPM | Error: 857.00 RPM | PWM: 1463.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 28.80s | Desired: 6000.00 RPM | Measured: 5105.00 RPM | Error: 895.00 RPM | PWM: 1463.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 29.84s | Desired: 6000.00 RPM | Measured: 5121.00 RPM | Error: 879.00 RPM | PWM: 1411.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 30.87s | Desired: 6000.00 RPM | Measured: 5114.00 RPM | Error: 886.00 RPM | PWM: 1433.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 31.90s | Desired: 6000.00 RPM | Measured: 4982.00 RPM | Error: 1018.00 RPM | PWM: 1707.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 32.92s | Desired: 6000.00 RPM | Measured: 5233.00 RPM | Error: 767.00 RPM | PWM: 1114.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 33.97s | Desired: 6000.00 RPM | Measured: 5120.00 RPM | Error: 880.00 RPM | PWM: 1477.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 35.01s | Desired: 6000.00 RPM | Measured: 5133.00 RPM | Error: 867.00 RPM | PWM: 1393.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 36.04s | Desired: 6000.00 RPM | Measured: 5095.00 RPM | Error: 905.00 RPM | PWM: 1479.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 37.07s | Desired: 6000.00 RPM | Measured: 5076.00 RPM | Error: 924.00 RPM | PWM: 1500.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 38.10s | Desired: 6000.00 RPM | Measured: 5072.00 RPM | Error: 928.00 RPM | PWM: 1499.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 39.14s | Desired: 6000.00 RPM | Measured: 5234.00 RPM | Error: 766.00 RPM | PWM: 1157.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 40.17s | Desired: 6000.00 RPM | Measured: 5267.00 RPM | Error: 733.00 RPM | PWM: 1169.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 41.21s | Desired: 6000.00 RPM | Measured: 5062.00 RPM | Error: 938.00 RPM | PWM: 1616.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 42.25s | Desired: 6000.00 RPM | Measured: 5206.00 RPM | Error: 794.00 RPM | PWM: 1211.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 43.28s | Desired: 6000.00 RPM | Measured: 5072.00 RPM | Error: 928.00 RPM | PWM: 1564.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 44.31s | Desired: 6000.00 RPM | Measured: 5240.00 RPM | Error: 760.00 RPM | PWM: 1144.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 45.34s | Desired: 6000.00 RPM | Measured: 5070.00 RPM | Error: 930.00 RPM | PWM: 1585.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 46.36s | Desired: 6000.00 RPM | Measured: 5015.00 RPM | Error: 985.00 RPM | PWM: 1616.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 47.42s | Desired: 6000.00 RPM | Measured: 5030.00 RPM | Error: 970.00 RPM | PWM: 1557.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 48.45s | Desired: 6000.00 RPM | Measured: 5065.00 RPM | Error: 935.00 RPM | PWM: 1491.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 49.47s | Desired: 6000.00 RPM | Measured: 5076.00 RPM | Error: 924.00 RPM | PWM: 1485.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 50.50s | Desired: 6000.00 RPM | Measured: 5096.00 RPM | Error: 904.00 RPM | PWM: 1449.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 51.55s | Desired: 6000.00 RPM | Measured: 5094.00 RPM | Error: 906.00 RPM | PWM: 1463.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 52.59s | Desired: 6000.00 RPM | Measured: 5328.00 RPM | Error: 672.00 RPM | PWM: 970.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 53.63s | Desired: 6000.00 RPM | Measured: 5148.00 RPM | Error: 852.00 RPM | PWM: 1465.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 54.66s | Desired: 6000.00 RPM | Measured: 5113.00 RPM | Error: 887.00 RPM | PWM: 1449.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 55.70s | Desired: 6000.00 RPM | Measured: 5120.00 RPM | Error: 880.00 RPM | PWM: 1417.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 56.72s | Desired: 6000.00 RPM | Measured: 5077.00 RPM | Error: 923.00 RPM | PWM: 1511.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 57.75s | Desired: 6000.00 RPM | Measured: 5286.00 RPM | Error: 714.00 RPM | PWM: 1050.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 58.79s | Desired: 6000.00 RPM | Measured: 5136.00 RPM | Error: 864.00 RPM | PWM: 1470.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 59.82s | Desired: 6000.00 RPM | Measured: 5114.00 RPM | Error: 886.00 RPM | PWM: 1441.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 60.86s | Desired: 6000.00 RPM | Measured: 5294.00 RPM | Error: 706.00 RPM | PWM: 1052.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 61.89s | Desired: 6000.00 RPM | Measured: 5344.00 RPM | Error: 656.00 RPM | PWM: 1037.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 62.93s | Desired: 6000.00 RPM | Measured: 5330.00 RPM | Error: 670.00 RPM | PWM: 1091.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 63.97s | Desired: 6000.00 RPM | Measured: 5154.00 RPM | Error: 846.00 RPM | PWM: 1454.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 65.01s | Desired: 6000.00 RPM | Measured: 5308.00 RPM | Error: 692.00 RPM | PWM: 1042.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 66.04s | Desired: 6000.00 RPM | Measured: 5137.00 RPM | Error: 863.00 RPM | PWM: 1479.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 67.07s | Desired: 6000.00 RPM | Measured: 5285.00 RPM | Error: 715.00 RPM | PWM: 1082.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 68.11s | Desired: 6000.00 RPM | Measured: 5165.00 RPM | Error: 835.00 RPM | PWM: 1408.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 69.13s | Desired: 6000.00 RPM | Measured: 5122.00 RPM | Error: 878.00 RPM | PWM: 1439.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 70.17s | Desired: 6000.00 RPM | Measured: 5285.00 RPM | Error: 715.00 RPM | PWM: 1075.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 71.21s | Desired: 6000.00 RPM | Measured: 5113.00 RPM | Error: 887.00 RPM | PWM: 1517.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 72.24s | Desired: 6000.00 RPM | Measured: 5082.00 RPM | Error: 918.00 RPM | PWM: 1497.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 73.27s | Desired: 6000.00 RPM | Measured: 5294.00 RPM | Error: 706.00 RPM | PWM: 1036.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 74.31s | Desired: 6000.00 RPM | Measured: 5318.00 RPM | Error: 682.00 RPM | PWM: 1091.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 75.34s | Desired: 6000.00 RPM | Measured: 5147.00 RPM | Error: 853.00 RPM | PWM: 1463.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 76.37s | Desired: 6000.00 RPM | Measured: 5260.00 RPM | Error: 740.00 RPM | PWM: 1140.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 77.41s | Desired: 6000.00 RPM | Measured: 5151.00 RPM | Error: 849.00 RPM | PWM: 1425.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 78.45s | Desired: 6000.00 RPM | Measured: 5115.00 RPM | Error: 885.00 RPM | PWM: 1446.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 79.47s | Desired: 6000.00 RPM | Measured: 5124.00 RPM | Error: 876.00 RPM | PWM: 1409.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 80.50s | Desired: 6000.00 RPM | Measured: 5035.00 RPM | Error: 965.00 RPM | PWM: 1601.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 81.54s | Desired: 6000.00 RPM | Measured: 5115.00 RPM | Error: 885.00 RPM | PWM: 1388.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 82.57s | Desired: 6000.00 RPM | Measured: 5155.00 RPM | Error: 845.00 RPM | PWM: 1344.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 83.61s | Desired: 6000.00 RPM | Measured: 5137.00 RPM | Error: 863.00 RPM | PWM: 1402.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 84.64s | Desired: 6000.00 RPM | Measured: 5320.00 RPM | Error: 680.00 RPM | PWM: 1009.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 85.68s | Desired: 6000.00 RPM | Measured: 5131.00 RPM | Error: 869.00 RPM | PWM: 1497.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 86.71s | Desired: 6000.00 RPM | Measured: 5127.00 RPM | Error: 873.00 RPM | PWM: 1411.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 87.75s | Desired: 6000.00 RPM | Measured: 5336.00 RPM | Error: 664.00 RPM | PWM: 970.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 88.78s | Desired: 6000.00 RPM | Measured: 5358.00 RPM | Error: 642.00 RPM | PWM: 1028.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 89.82s | Desired: 6000.00 RPM | Measured: 5165.00 RPM | Error: 835.00 RPM | PWM: 1445.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 90.85s | Desired: 6000.00 RPM | Measured: 5150.00 RPM | Error: 850.00 RPM | PWM: 1380.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 91.89s | Desired: 6000.00 RPM | Measured: 5132.00 RPM | Error: 868.00 RPM | PWM: 1410.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 92.92s | Desired: 6000.00 RPM | Measured: 5319.00 RPM | Error: 681.00 RPM | PWM: 1008.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 93.96s | Desired: 6000.00 RPM | Measured: 5094.00 RPM | Error: 906.00 RPM | PWM: 1574.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 94.99s | Desired: 6000.00 RPM | Measured: 5012.00 RPM | Error: 988.00 RPM | PWM: 1634.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 96.02s | Desired: 6000.00 RPM | Measured: 5295.00 RPM | Error: 705.00 RPM | PWM: 999.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 97.06s | Desired: 6000.00 RPM | Measured: 5145.00 RPM | Error: 855.00 RPM | PWM: 1455.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 98.10s | Desired: 6000.00 RPM | Measured: 5091.00 RPM | Error: 909.00 RPM | PWM: 1494.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 99.13s | Desired: 6000.00 RPM | Measured: 5123.00 RPM | Error: 877.00 RPM | PWM: 1399.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 100.17s | Desired: 6000.00 RPM | Measured: 5154.00 RPM | Error: 846.00 RPM | PWM: 1350.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 101.19s | Desired: 6000.00 RPM | Measured: 5112.00 RPM | Error: 888.00 RPM | PWM: 1454.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 102.23s | Desired: 6000.00 RPM | Measured: 5341.00 RPM | Error: 659.00 RPM | PWM: 952.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 103.26s | Desired: 6000.00 RPM | Measured: 5348.00 RPM | Error: 652.00 RPM | PWM: 1052.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 104.30s | Desired: 6000.00 RPM | Measured: 5158.00 RPM | Error: 842.00 RPM | PWM: 1454.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 105.34s | Desired: 6000.00 RPM | Measured: 5128.00 RPM | Error: 872.00 RPM | PWM: 1422.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 106.36s | Desired: 6000.00 RPM | Measured: 5116.00 RPM | Error: 884.00 RPM | PWM: 1433.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 107.40s | Desired: 6000.00 RPM | Measured: 5126.00 RPM | Error: 874.00 RPM | PWM: 1406.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 108.44s | Desired: 6000.00 RPM | Measured: 5191.00 RPM | Error: 809.00 RPM | PWM: 1274.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 109.47s | Desired: 6000.00 RPM | Measured: 5244.00 RPM | Error: 756.00 RPM | PWM: 1195.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 110.50s | Desired: 6000.00 RPM | Measured: 5119.00 RPM | Error: 881.00 RPM | PWM: 1484.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 111.54s | Desired: 6000.00 RPM | Measured: 5124.00 RPM | Error: 876.00 RPM | PWM: 1411.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 112.57s | Desired: 6000.00 RPM | Measured: 5117.00 RPM | Error: 883.00 RPM | PWM: 1429.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 113.61s | Desired: 6000.00 RPM | Measured: 5388.00 RPM | Error: 612.00 RPM | PWM: 856.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 114.63s | Desired: 6000.00 RPM | Measured: 5249.00 RPM | Error: 751.00 RPM | PWM: 1283.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 115.67s | Desired: 6000.00 RPM | Measured: 5135.00 RPM | Error: 865.00 RPM | PWM: 1453.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 116.70s | Desired: 6000.00 RPM | Measured: 5172.00 RPM | Error: 828.00 RPM | PWM: 1319.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 117.74s | Desired: 6000.00 RPM | Measured: 5385.00 RPM | Error: 615.00 RPM | PWM: 890.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 118.78s | Desired: 6000.00 RPM | Measured: 5174.00 RPM | Error: 826.00 RPM | PWM: 1439.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 119.81s | Desired: 6000.00 RPM | Measured: 5105.00 RPM | Error: 895.00 RPM | PWM: 1479.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 120.84s | Desired: 6000.00 RPM | Measured: 5131.00 RPM | Error: 869.00 RPM | PWM: 1390.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 121.87s | Desired: 6000.00 RPM | Measured: 5157.00 RPM | Error: 843.00 RPM | PWM: 1348.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 122.91s | Desired: 6000.00 RPM | Measured: 5359.00 RPM | Error: 641.00 RPM | PWM: 937.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 123.94s | Desired: 6000.00 RPM | Measured: 5390.00 RPM | Error: 610.00 RPM | PWM: 973.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 124.98s | Desired: 6000.00 RPM | Measured: 5157.00 RPM | Error: 843.00 RPM | PWM: 1478.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 126.01s | Desired: 6000.00 RPM | Measured: 5340.00 RPM | Error: 660.00 RPM | PWM: 977.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 127.04s | Desired: 6000.00 RPM | Measured: 5186.00 RPM | Error: 814.00 RPM | PWM: 1392.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 128.08s | Desired: 6000.00 RPM | Measured: 5178.00 RPM | Error: 822.00 RPM | PWM: 1331.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 129.11s | Desired: 6000.00 RPM | Measured: 5188.00 RPM | Error: 812.00 RPM | PWM: 1306.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 130.14s | Desired: 6000.00 RPM | Measured: 5166.00 RPM | Error: 834.00 RPM | PWM: 1358.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 131.17s | Desired: 6000.00 RPM | Measured: 5195.00 RPM | Error: 805.00 RPM | PWM: 1286.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 132.21s | Desired: 6000.00 RPM | Measured: 5209.00 RPM | Error: 791.00 RPM | PWM: 1271.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 133.25s | Desired: 6000.00 RPM | Measured: 5360.00 RPM | Error: 640.00 RPM | PWM: 961.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 134.28s | Desired: 6000.00 RPM | Measured: 5213.00 RPM | Error: 787.00 RPM | PWM: 1345.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 135.31s | Desired: 6000.00 RPM | Measured: 5151.00 RPM | Error: 849.00 RPM | PWM: 1402.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 136.33s | Desired: 6000.00 RPM | Measured: 5157.00 RPM | Error: 843.00 RPM | PWM: 1358.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 137.38s | Desired: 6000.00 RPM | Measured: 5301.00 RPM | Error: 699.00 RPM | PWM: 1059.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 138.40s | Desired: 6000.00 RPM | Measured: 5173.00 RPM | Error: 827.00 RPM | PWM: 1399.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 139.44s | Desired: 6000.00 RPM | Measured: 5115.00 RPM | Error: 885.00 RPM | PWM: 1457.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 140.47s | Desired: 6000.00 RPM | Measured: 5164.00 RPM | Error: 836.00 RPM | PWM: 1325.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 141.51s | Desired: 6000.00 RPM | Measured: 5092.00 RPM | Error: 908.00 RPM | PWM: 1501.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 142.55s | Desired: 6000.00 RPM | Measured: 5365.00 RPM | Error: 635.00 RPM | PWM: 892.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 143.57s | Desired: 6000.00 RPM | Measured: 5236.00 RPM | Error: 764.00 RPM | PWM: 1299.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 144.61s | Desired: 6000.00 RPM | Measured: 5196.00 RPM | Error: 804.00 RPM | PWM: 1319.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 145.66s | Desired: 6000.00 RPM | Measured: 5227.00 RPM | Error: 773.00 RPM | PWM: 1234.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 146.68s | Desired: 6000.00 RPM | Measured: 5351.00 RPM | Error: 649.00 RPM | PWM: 989.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 147.72s | Desired: 6000.00 RPM | Measured: 5389.00 RPM | Error: 611.00 RPM | PWM: 971.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 148.76s | Desired: 6000.00 RPM | Measured: 5324.00 RPM | Error: 676.00 RPM | PWM: 1126.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 149.80s | Desired: 6000.00 RPM | Measured: 5102.00 RPM | Error: 898.00 RPM | PWM: 1560.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 150.82s | Desired: 6000.00 RPM | Measured: 5326.00 RPM | Error: 674.00 RPM | PWM: 979.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 151.87s | Desired: 6000.00 RPM | Measured: 5371.00 RPM | Error: 629.00 RPM | PWM: 996.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 152.91s | Desired: 6000.00 RPM | Measured: 5385.00 RPM | Error: 615.00 RPM | PWM: 989.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 153.94s | Desired: 6000.00 RPM | Measured: 5205.00 RPM | Error: 795.00 RPM | PWM: 1374.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 154.97s | Desired: 6000.00 RPM | Measured: 5151.00 RPM | Error: 849.00 RPM | PWM: 1398.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 156.00s | Desired: 6000.00 RPM | Measured: 5166.00 RPM | Error: 834.00 RPM | PWM: 1339.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 157.04s | Desired: 6000.00 RPM | Measured: 5204.00 RPM | Error: 796.00 RPM | PWM: 1267.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 158.07s | Desired: 6000.00 RPM | Measured: 5386.00 RPM | Error: 614.00 RPM | PWM: 904.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 159.11s | Desired: 6000.00 RPM | Measured: 5427.00 RPM | Error: 573.00 RPM | PWM: 909.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 160.14s | Desired: 6000.00 RPM | Measured: 5443.00 RPM | Error: 557.00 RPM | PWM: 895.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 161.16s | Desired: 6000.00 RPM | Measured: 5207.00 RPM | Error: 793.00 RPM | PWM: 1399.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 162.21s | Desired: 6000.00 RPM | Measured: 5376.00 RPM | Error: 624.00 RPM | PWM: 926.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 163.25s | Desired: 6000.00 RPM | Measured: 5439.00 RPM | Error: 561.00 RPM | PWM: 878.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 164.28s | Desired: 6000.00 RPM | Measured: 5229.00 RPM | Error: 771.00 RPM | PWM: 1351.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 165.31s | Desired: 6000.00 RPM | Measured: 5349.00 RPM | Error: 651.00 RPM | PWM: 994.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 166.33s | Desired: 6000.00 RPM | Measured: 5417.00 RPM | Error: 583.00 RPM | PWM: 911.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 167.38s | Desired: 6000.00 RPM | Measured: 5392.00 RPM | Error: 608.00 RPM | PWM: 998.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 168.40s | Desired: 6000.00 RPM | Measured: 5335.00 RPM | Error: 665.00 RPM | PWM: 1105.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 169.43s | Desired: 6000.00 RPM | Measured: 5185.00 RPM | Error: 815.00 RPM | PWM: 1391.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 170.47s | Desired: 6000.00 RPM | Measured: 5187.00 RPM | Error: 813.00 RPM | PWM: 1312.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 171.51s | Desired: 6000.00 RPM | Measured: 5430.00 RPM | Error: 570.00 RPM | PWM: 803.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 172.54s | Desired: 6000.00 RPM | Measured: 5268.00 RPM | Error: 732.00 RPM | PWM: 1264.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 173.57s | Desired: 6000.00 RPM | Measured: 5257.00 RPM | Error: 743.00 RPM | PWM: 1207.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 174.62s | Desired: 6000.00 RPM | Measured: 5248.00 RPM | Error: 752.00 RPM | PWM: 1220.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 175.65s | Desired: 6000.00 RPM | Measured: 5288.00 RPM | Error: 712.00 RPM | PWM: 1131.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 176.69s | Desired: 6000.00 RPM | Measured: 5261.00 RPM | Error: 739.00 RPM | PWM: 1208.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 177.72s | Desired: 6000.00 RPM | Measured: 5273.00 RPM | Error: 727.00 RPM | PWM: 1169.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 178.76s | Desired: 6000.00 RPM | Measured: 5150.00 RPM | Error: 850.00 RPM | PWM: 1434.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 179.79s | Desired: 6000.00 RPM | Measured: 5170.00 RPM | Error: 830.00 RPM | PWM: 1330.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 180.83s | Desired: 6000.00 RPM | Measured: 5183.00 RPM | Error: 817.00 RPM | PWM: 1313.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 181.86s | Desired: 6000.00 RPM | Measured: 5149.00 RPM | Error: 851.00 RPM | PWM: 1391.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 182.89s | Desired: 6000.00 RPM | Measured: 5310.00 RPM | Error: 690.00 RPM | PWM: 1036.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 183.92s | Desired: 6000.00 RPM | Measured: 5185.00 RPM | Error: 815.00 RPM | PWM: 1379.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 184.95s | Desired: 6000.00 RPM | Measured: 5172.00 RPM | Error: 828.00 RPM | PWM: 1344.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 185.99s | Desired: 6000.00 RPM | Measured: 5375.00 RPM | Error: 625.00 RPM | PWM: 911.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 187.02s | Desired: 6000.00 RPM | Measured: 5288.00 RPM | Error: 712.00 RPM | PWM: 1195.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 188.06s | Desired: 6000.00 RPM | Measured: 5242.00 RPM | Error: 758.00 RPM | PWM: 1248.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 189.09s | Desired: 6000.00 RPM | Measured: 5241.00 RPM | Error: 759.00 RPM | PWM: 1227.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 190.11s | Desired: 6000.00 RPM | Measured: 5255.00 RPM | Error: 745.00 RPM | PWM: 1197.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 191.16s | Desired: 6000.00 RPM | Measured: 5295.00 RPM | Error: 705.00 RPM | PWM: 1120.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 192.19s | Desired: 6000.00 RPM | Measured: 5281.00 RPM | Error: 719.00 RPM | PWM: 1170.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 193.22s | Desired: 6000.00 RPM | Measured: 5253.00 RPM | Error: 747.00 RPM | PWM: 1221.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 194.25s | Desired: 6000.00 RPM | Measured: 5289.00 RPM | Error: 711.00 RPM | PWM: 1132.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 195.29s | Desired: 6000.00 RPM | Measured: 5448.00 RPM | Error: 552.00 RPM | PWM: 816.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 196.33s | Desired: 6000.00 RPM | Measured: 5288.00 RPM | Error: 712.00 RPM | PWM: 1231.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 197.36s | Desired: 6000.00 RPM | Measured: 5275.00 RPM | Error: 725.00 RPM | PWM: 1179.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 198.40s | Desired: 6000.00 RPM | Measured: 5301.00 RPM | Error: 699.00 RPM | PWM: 1118.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 199.43s | Desired: 6000.00 RPM | Measured: 5273.00 RPM | Error: 727.00 RPM | PWM: 1189.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 200.46s | Desired: 6000.00 RPM | Measured: 5283.00 RPM | Error: 717.00 RPM | PWM: 1154.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 201.50s | Desired: 6000.00 RPM | Measured: 5289.00 RPM | Error: 711.00 RPM | PWM: 1147.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 202.53s | Desired: 6000.00 RPM | Measured: 5469.00 RPM | Error: 531.00 RPM | PWM: 772.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 203.57s | Desired: 6000.00 RPM | Measured: 5357.00 RPM | Error: 643.00 RPM | PWM: 1097.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 204.60s | Desired: 6000.00 RPM | Measured: 5322.00 RPM | Error: 678.00 RPM | PWM: 1115.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 205.62s | Desired: 6000.00 RPM | Measured: 5347.00 RPM | Error: 653.00 RPM | PWM: 1045.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 206.66s | Desired: 6000.00 RPM | Measured: 5352.00 RPM | Error: 648.00 RPM | PWM: 1047.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 207.71s | Desired: 6000.00 RPM | Measured: 5393.00 RPM | Error: 607.00 RPM | PWM: 963.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 208.74s | Desired: 6000.00 RPM | Measured: 5370.00 RPM | Error: 630.00 RPM | PWM: 1032.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 209.76s | Desired: 6000.00 RPM | Measured: 5353.00 RPM | Error: 647.00 RPM | PWM: 1056.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 210.81s | Desired: 6000.00 RPM | Measured: 5384.00 RPM | Error: 616.00 RPM | PWM: 982.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 211.83s | Desired: 6000.00 RPM | Measured: 5373.00 RPM | Error: 627.00 RPM | PWM: 1021.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 212.86s | Desired: 6000.00 RPM | Measured: 5319.00 RPM | Error: 681.00 RPM | PWM: 1129.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 213.90s | Desired: 6000.00 RPM | Measured: 5425.00 RPM | Error: 575.00 RPM | PWM: 879.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 214.93s | Desired: 6000.00 RPM | Measured: 5280.00 RPM | Error: 720.00 RPM | PWM: 1237.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 215.97s | Desired: 6000.00 RPM | Measured: 5224.00 RPM | Error: 776.00 RPM | PWM: 1282.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 217.00s | Desired: 6000.00 RPM | Measured: 5439.00 RPM | Error: 561.00 RPM | PWM: 802.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 218.04s | Desired: 6000.00 RPM | Measured: 5274.00 RPM | Error: 726.00 RPM | PWM: 1256.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 219.07s | Desired: 6000.00 RPM | Measured: 5236.00 RPM | Error: 764.00 RPM | PWM: 1254.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 220.11s | Desired: 6000.00 RPM | Measured: 5280.00 RPM | Error: 720.00 RPM | PWM: 1142.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 221.14s | Desired: 6000.00 RPM | Measured: 5265.00 RPM | Error: 735.00 RPM | PWM: 1196.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 222.17s | Desired: 6000.00 RPM | Measured: 5283.00 RPM | Error: 717.00 RPM | PWM: 1150.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 223.20s | Desired: 6000.00 RPM | Measured: 5295.00 RPM | Error: 705.00 RPM | PWM: 1134.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 224.23s | Desired: 6000.00 RPM | Measured: 5264.00 RPM | Error: 736.00 RPM | PWM: 1205.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 225.28s | Desired: 6000.00 RPM | Measured: 5236.00 RPM | Error: 764.00 RPM | PWM: 1249.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 226.31s | Desired: 6000.00 RPM | Measured: 5301.00 RPM | Error: 699.00 RPM | PWM: 1098.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 227.35s | Desired: 6000.00 RPM | Measured: 5260.00 RPM | Error: 740.00 RPM | PWM: 1217.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 228.37s | Desired: 6000.00 RPM | Measured: 5298.00 RPM | Error: 702.00 RPM | PWM: 1116.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 229.41s | Desired: 6000.00 RPM | Measured: 5289.00 RPM | Error: 711.00 RPM | PWM: 1154.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 230.45s | Desired: 6000.00 RPM | Measured: 5286.00 RPM | Error: 714.00 RPM | PWM: 1156.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 231.48s | Desired: 6000.00 RPM | Measured: 5131.00 RPM | Error: 869.00 RPM | PWM: 1480.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 232.51s | Desired: 6000.00 RPM | Measured: 5053.00 RPM | Error: 947.00 RPM | PWM: 1566.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 233.54s | Desired: 6000.00 RPM | Measured: 5093.00 RPM | Error: 907.00 RPM | PWM: 1443.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 234.58s | Desired: 6000.00 RPM | Measured: 5115.00 RPM | Error: 885.00 RPM | PWM: 1417.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 235.62s | Desired: 6000.00 RPM | Measured: 5157.00 RPM | Error: 843.00 RPM | PWM: 1340.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 236.65s | Desired: 6000.00 RPM | Measured: 5273.00 RPM | Error: 727.00 RPM | PWM: 1117.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 237.68s | Desired: 6000.00 RPM | Measured: 5166.00 RPM | Error: 834.00 RPM | PWM: 1400.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 238.71s | Desired: 6000.00 RPM | Measured: 5139.00 RPM | Error: 861.00 RPM | PWM: 1403.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 239.75s | Desired: 6000.00 RPM | Measured: 5022.00 RPM | Error: 978.00 RPM | PWM: 1636.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 240.78s | Desired: 6000.00 RPM | Measured: 5262.00 RPM | Error: 738.00 RPM | PWM: 1073.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 241.81s | Desired: 6000.00 RPM | Measured: 5125.00 RPM | Error: 875.00 RPM | PWM: 1481.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 242.85s | Desired: 6000.00 RPM | Measured: 5065.00 RPM | Error: 935.00 RPM | PWM: 1538.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 243.88s | Desired: 6000.00 RPM | Measured: 5152.00 RPM | Error: 848.00 RPM | PWM: 1326.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 244.92s | Desired: 6000.00 RPM | Measured: 5304.00 RPM | Error: 696.00 RPM | PWM: 1050.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 245.94s | Desired: 6000.00 RPM | Measured: 5314.00 RPM | Error: 686.00 RPM | PWM: 1105.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 246.98s | Desired: 6000.00 RPM | Measured: 5311.00 RPM | Error: 689.00 RPM | PWM: 1116.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 248.01s | Desired: 6000.00 RPM | Measured: 5137.00 RPM | Error: 863.00 RPM | PWM: 1480.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 249.06s | Desired: 6000.00 RPM | Measured: 5301.00 RPM | Error: 699.00 RPM | PWM: 1049.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 250.09s | Desired: 6000.00 RPM | Measured: 5135.00 RPM | Error: 865.00 RPM | PWM: 1479.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 251.12s | Desired: 6000.00 RPM | Measured: 5109.00 RPM | Error: 891.00 RPM | PWM: 1451.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 252.15s | Desired: 6000.00 RPM | Measured: 5314.00 RPM | Error: 686.00 RPM | PWM: 1007.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 253.19s | Desired: 6000.00 RPM | Measured: 5088.00 RPM | Error: 912.00 RPM | PWM: 1584.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 254.23s | Desired: 6000.00 RPM | Measured: 5140.00 RPM | Error: 860.00 RPM | PWM: 1362.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 255.25s | Desired: 6000.00 RPM | Measured: 5103.00 RPM | Error: 897.00 RPM | PWM: 1466.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 256.28s | Desired: 6000.00 RPM | Measured: 5101.00 RPM | Error: 899.00 RPM | PWM: 1452.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 257.32s | Desired: 6000.00 RPM | Measured: 5119.00 RPM | Error: 881.00 RPM | PWM: 1413.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 258.36s | Desired: 6000.00 RPM | Measured: 5333.00 RPM | Error: 667.00 RPM | PWM: 972.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 259.39s | Desired: 6000.00 RPM | Measured: 5141.00 RPM | Error: 859.00 RPM | PWM: 1483.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 260.42s | Desired: 6000.00 RPM | Measured: 5148.00 RPM | Error: 852.00 RPM | PWM: 1372.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 261.46s | Desired: 6000.00 RPM | Measured: 5077.00 RPM | Error: 923.00 RPM | PWM: 1525.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 262.50s | Desired: 6000.00 RPM | Measured: 5308.00 RPM | Error: 692.00 RPM | PWM: 1004.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 263.53s | Desired: 6000.00 RPM | Measured: 5182.00 RPM | Error: 818.00 RPM | PWM: 1384.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 264.57s | Desired: 6000.00 RPM | Measured: 5324.00 RPM | Error: 676.00 RPM | PWM: 1023.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 265.60s | Desired: 6000.00 RPM | Measured: 5375.00 RPM | Error: 625.00 RPM | PWM: 987.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 266.64s | Desired: 6000.00 RPM | Measured: 5255.00 RPM | Error: 745.00 RPM | PWM: 1264.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 267.66s | Desired: 6000.00 RPM | Measured: 5158.00 RPM | Error: 842.00 RPM | PWM: 1408.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 268.70s | Desired: 6000.00 RPM | Measured: 5111.00 RPM | Error: 889.00 RPM | PWM: 1458.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 269.74s | Desired: 6000.00 RPM | Measured: 5137.00 RPM | Error: 863.00 RPM | PWM: 1380.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 270.76s | Desired: 6000.00 RPM | Measured: 5303.00 RPM | Error: 697.00 RPM | PWM: 1044.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 271.81s | Desired: 6000.00 RPM | Measured: 5146.00 RPM | Error: 854.00 RPM | PWM: 1457.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 272.84s | Desired: 6000.00 RPM | Measured: 5121.00 RPM | Error: 879.00 RPM | PWM: 1431.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 273.87s | Desired: 6000.00 RPM | Measured: 5133.00 RPM | Error: 867.00 RPM | PWM: 1393.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 274.90s | Desired: 6000.00 RPM | Measured: 5145.00 RPM | Error: 855.00 RPM | PWM: 1374.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 275.94s | Desired: 6000.00 RPM | Measured: 5122.00 RPM | Error: 878.00 RPM | PWM: 1429.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 276.97s | Desired: 6000.00 RPM | Measured: 5309.00 RPM | Error: 691.00 RPM | PWM: 1024.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 278.01s | Desired: 6000.00 RPM | Measured: 5070.00 RPM | Error: 930.00 RPM | PWM: 1620.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 279.04s | Desired: 6000.00 RPM | Measured: 5136.00 RPM | Error: 864.00 RPM | PWM: 1362.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 280.08s | Desired: 6000.00 RPM | Measured: 5125.00 RPM | Error: 875.00 RPM | PWM: 1418.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 281.10s | Desired: 6000.00 RPM | Measured: 5122.00 RPM | Error: 878.00 RPM | PWM: 1419.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 282.14s | Desired: 6000.00 RPM | Measured: 5281.00 RPM | Error: 719.00 RPM | PWM: 1083.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 283.17s | Desired: 6000.00 RPM | Measured: 5156.00 RPM | Error: 844.00 RPM | PWM: 1425.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 284.21s | Desired: 6000.00 RPM | Measured: 5114.00 RPM | Error: 886.00 RPM | PWM: 1451.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 285.25s | Desired: 6000.00 RPM | Measured: 5323.00 RPM | Error: 677.00 RPM | PWM: 991.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 286.28s | Desired: 6000.00 RPM | Measured: 5180.00 RPM | Error: 820.00 RPM | PWM: 1396.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 287.32s | Desired: 6000.00 RPM | Measured: 5102.00 RPM | Error: 898.00 RPM | PWM: 1488.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 288.35s | Desired: 6000.00 RPM | Measured: 5333.00 RPM | Error: 667.00 RPM | PWM: 964.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 289.39s | Desired: 6000.00 RPM | Measured: 5165.00 RPM | Error: 835.00 RPM | PWM: 1432.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 290.42s | Desired: 6000.00 RPM | Measured: 5140.00 RPM | Error: 860.00 RPM | PWM: 1401.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 291.46s | Desired: 6000.00 RPM | Measured: 5146.00 RPM | Error: 854.00 RPM | PWM: 1376.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 292.50s | Desired: 6000.00 RPM | Measured: 5133.00 RPM | Error: 867.00 RPM | PWM: 1406.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 293.51s | Desired: 6000.00 RPM | Measured: 5135.00 RPM | Error: 865.00 RPM | PWM: 1395.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 294.56s | Desired: 6000.00 RPM | Measured: 5152.00 RPM | Error: 848.00 RPM | PWM: 1361.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 295.59s | Desired: 6000.00 RPM | Measured: 5360.00 RPM | Error: 640.00 RPM | PWM: 932.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 296.62s | Desired: 6000.00 RPM | Measured: 5251.00 RPM | Error: 749.00 RPM | PWM: 1265.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 297.66s | Desired: 6000.00 RPM | Measured: 5209.00 RPM | Error: 791.00 RPM | PWM: 1299.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 298.69s | Desired: 6000.00 RPM | Measured: 5362.00 RPM | Error: 638.00 RPM | PWM: 957.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 299.72s | Desired: 6000.00 RPM | Measured: 5397.00 RPM | Error: 603.00 RPM | PWM: 960.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 300.77s | Desired: 6000.00 RPM | Measured: 5401.00 RPM | Error: 599.00 RPM | PWM: 969.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 301.81s | Desired: 6000.00 RPM | Measured: 5421.00 RPM | Error: 579.00 RPM | PWM: 929.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 302.83s | Desired: 6000.00 RPM | Measured: 5414.00 RPM | Error: 586.00 RPM | PWM: 953.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 303.87s | Desired: 6000.00 RPM | Measured: 5176.00 RPM | Error: 824.00 RPM | PWM: 1450.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 304.89s | Desired: 6000.00 RPM | Measured: 5150.00 RPM | Error: 850.00 RPM | PWM: 1385.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 305.94s | Desired: 6000.00 RPM | Measured: 5116.00 RPM | Error: 884.00 RPM | PWM: 1444.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 306.97s | Desired: 6000.00 RPM | Measured: 5169.00 RPM | Error: 831.00 RPM | PWM: 1315.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 307.99s | Desired: 6000.00 RPM | Measured: 5096.00 RPM | Error: 904.00 RPM | PWM: 1495.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 309.02s | Desired: 6000.00 RPM | Measured: 5150.00 RPM | Error: 850.00 RPM | PWM: 1345.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 310.07s | Desired: 6000.00 RPM | Measured: 5148.00 RPM | Error: 852.00 RPM | PWM: 1376.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 311.11s | Desired: 6000.00 RPM | Measured: 5082.00 RPM | Error: 918.00 RPM | PWM: 1514.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 312.14s | Desired: 6000.00 RPM | Measured: 5327.00 RPM | Error: 673.00 RPM | PWM: 967.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 313.17s | Desired: 6000.00 RPM | Measured: 5210.00 RPM | Error: 790.00 RPM | PWM: 1335.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 314.21s | Desired: 6000.00 RPM | Measured: 5179.00 RPM | Error: 821.00 RPM | PWM: 1341.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 315.25s | Desired: 6000.00 RPM | Measured: 5069.00 RPM | Error: 931.00 RPM | PWM: 1557.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 316.27s | Desired: 6000.00 RPM | Measured: 5321.00 RPM | Error: 679.00 RPM | PWM: 973.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 317.31s | Desired: 6000.00 RPM | Measured: 5366.00 RPM | Error: 634.00 RPM | PWM: 1004.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 318.34s | Desired: 6000.00 RPM | Measured: 5346.00 RPM | Error: 654.00 RPM | PWM: 1069.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 319.38s | Desired: 6000.00 RPM | Measured: 5147.00 RPM | Error: 853.00 RPM | PWM: 1477.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 320.41s | Desired: 6000.00 RPM | Measured: 5307.00 RPM | Error: 693.00 RPM | PWM: 1041.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 321.44s | Desired: 6000.00 RPM | Measured: 5172.00 RPM | Error: 828.00 RPM | PWM: 1405.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 322.48s | Desired: 6000.00 RPM | Measured: 5336.00 RPM | Error: 664.00 RPM | PWM: 993.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 323.51s | Desired: 6000.00 RPM | Measured: 5385.00 RPM | Error: 615.00 RPM | PWM: 972.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 324.55s | Desired: 6000.00 RPM | Measured: 5173.00 RPM | Error: 827.00 RPM | PWM: 1441.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 325.58s | Desired: 6000.00 RPM | Measured: 5122.00 RPM | Error: 878.00 RPM | PWM: 1443.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 326.62s | Desired: 6000.00 RPM | Measured: 5314.00 RPM | Error: 686.00 RPM | PWM: 1014.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 327.65s | Desired: 6000.00 RPM | Measured: 5371.00 RPM | Error: 629.00 RPM | PWM: 990.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 328.69s | Desired: 6000.00 RPM | Measured: 5343.00 RPM | Error: 657.00 RPM | PWM: 1077.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 329.72s | Desired: 6000.00 RPM | Measured: 5161.00 RPM | Error: 839.00 RPM | PWM: 1446.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 330.75s | Desired: 6000.00 RPM | Measured: 5113.00 RPM | Error: 887.00 RPM | PWM: 1455.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 331.79s | Desired: 6000.00 RPM | Measured: 5118.00 RPM | Error: 882.00 RPM | PWM: 1421.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 332.82s | Desired: 6000.00 RPM | Measured: 5147.00 RPM | Error: 853.00 RPM | PWM: 1363.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 333.85s | Desired: 6000.00 RPM | Measured: 5308.00 RPM | Error: 692.00 RPM | PWM: 1039.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 334.88s | Desired: 6000.00 RPM | Measured: 5158.00 RPM | Error: 842.00 RPM | PWM: 1434.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 335.91s | Desired: 6000.00 RPM | Measured: 5110.00 RPM | Error: 890.00 RPM | PWM: 1460.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 336.96s | Desired: 6000.00 RPM | Measured: 5118.00 RPM | Error: 882.00 RPM | PWM: 1419.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 337.98s | Desired: 6000.00 RPM | Measured: 5120.00 RPM | Error: 880.00 RPM | PWM: 1419.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 339.02s | Desired: 6000.00 RPM | Measured: 5130.00 RPM | Error: 870.00 RPM | PWM: 1399.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 340.06s | Desired: 6000.00 RPM | Measured: 5137.00 RPM | Error: 863.00 RPM | PWM: 1390.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 341.09s | Desired: 6000.00 RPM | Measured: 5322.00 RPM | Error: 678.00 RPM | PWM: 1005.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 342.12s | Desired: 6000.00 RPM | Measured: 5193.00 RPM | Error: 807.00 RPM | PWM: 1368.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 343.16s | Desired: 6000.00 RPM | Measured: 5174.00 RPM | Error: 826.00 RPM | PWM: 1343.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 344.19s | Desired: 6000.00 RPM | Measured: 5051.00 RPM | Error: 949.00 RPM | PWM: 1592.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 345.23s | Desired: 6000.00 RPM | Measured: 5116.00 RPM | Error: 884.00 RPM | PWM: 1394.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 346.27s | Desired: 6000.00 RPM | Measured: 5091.00 RPM | Error: 909.00 RPM | PWM: 1479.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 347.30s | Desired: 6000.00 RPM | Measured: 5105.00 RPM | Error: 895.00 RPM | PWM: 1437.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 348.33s | Desired: 6000.00 RPM | Measured: 5098.00 RPM | Error: 902.00 RPM | PWM: 1459.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 349.37s | Desired: 6000.00 RPM | Measured: 5126.00 RPM | Error: 874.00 RPM | PWM: 1397.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 350.40s | Desired: 6000.00 RPM | Measured: 5141.00 RPM | Error: 859.00 RPM | PWM: 1379.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 351.44s | Desired: 6000.00 RPM | Measured: 5131.00 RPM | Error: 869.00 RPM | PWM: 1408.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 352.47s | Desired: 6000.00 RPM | Measured: 5139.00 RPM | Error: 861.00 RPM | PWM: 1386.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 353.51s | Desired: 6000.00 RPM | Measured: 5304.00 RPM | Error: 696.00 RPM | PWM: 1043.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 354.55s | Desired: 6000.00 RPM | Measured: 5080.00 RPM | Error: 920.00 RPM | PWM: 1596.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 355.58s | Desired: 6000.00 RPM | Measured: 5069.00 RPM | Error: 931.00 RPM | PWM: 1507.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 356.60s | Desired: 6000.00 RPM | Measured: 5026.00 RPM | Error: 974.00 RPM | PWM: 1592.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 357.65s | Desired: 6000.00 RPM | Measured: 5112.00 RPM | Error: 888.00 RPM | PWM: 1390.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 358.68s | Desired: 6000.00 RPM | Measured: 5318.00 RPM | Error: 682.00 RPM | PWM: 1000.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 359.72s | Desired: 6000.00 RPM | Measured: 5187.00 RPM | Error: 813.00 RPM | PWM: 1379.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 360.75s | Desired: 6000.00 RPM | Measured: 5340.00 RPM | Error: 660.00 RPM | PWM: 992.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 361.79s | Desired: 6000.00 RPM | Measured: 5179.00 RPM | Error: 821.00 RPM | PWM: 1406.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 362.82s | Desired: 6000.00 RPM | Measured: 5086.00 RPM | Error: 914.00 RPM | PWM: 1521.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 363.86s | Desired: 6000.00 RPM | Measured: 5170.00 RPM | Error: 830.00 RPM | PWM: 1298.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 364.88s | Desired: 6000.00 RPM | Measured: 5146.00 RPM | Error: 854.00 RPM | PWM: 1391.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 365.91s | Desired: 6000.00 RPM | Measured: 5162.00 RPM | Error: 838.00 RPM | PWM: 1345.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 366.96s | Desired: 6000.00 RPM | Measured: 5356.00 RPM | Error: 644.00 RPM | PWM: 946.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 367.98s | Desired: 6000.00 RPM | Measured: 5384.00 RPM | Error: 616.00 RPM | PWM: 984.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 369.02s | Desired: 6000.00 RPM | Measured: 5213.00 RPM | Error: 787.00 RPM | PWM: 1357.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 370.05s | Desired: 6000.00 RPM | Measured: 5189.00 RPM | Error: 811.00 RPM | PWM: 1322.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 371.09s | Desired: 6000.00 RPM | Measured: 5384.00 RPM | Error: 616.00 RPM | PWM: 900.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 372.12s | Desired: 6000.00 RPM | Measured: 5213.00 RPM | Error: 787.00 RPM | PWM: 1357.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 373.15s | Desired: 6000.00 RPM | Measured: 5205.00 RPM | Error: 795.00 RPM | PWM: 1288.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 374.19s | Desired: 6000.00 RPM | Measured: 5242.00 RPM | Error: 758.00 RPM | PWM: 1207.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 375.22s | Desired: 6000.00 RPM | Measured: 5228.00 RPM | Error: 772.00 RPM | PWM: 1254.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 376.27s | Desired: 6000.00 RPM | Measured: 5246.00 RPM | Error: 754.00 RPM | PWM: 1210.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 377.30s | Desired: 6000.00 RPM | Measured: 5229.00 RPM | Error: 771.00 RPM | PWM: 1254.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 378.33s | Desired: 6000.00 RPM | Measured: 5127.00 RPM | Error: 873.00 RPM | PWM: 1460.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 379.37s | Desired: 6000.00 RPM | Measured: 5404.00 RPM | Error: 596.00 RPM | PWM: 827.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 380.40s | Desired: 6000.00 RPM | Measured: 5288.00 RPM | Error: 712.00 RPM | PWM: 1209.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 381.44s | Desired: 6000.00 RPM | Measured: 5239.00 RPM | Error: 761.00 RPM | PWM: 1254.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 382.45s | Desired: 6000.00 RPM | Measured: 5134.00 RPM | Error: 866.00 RPM | PWM: 1450.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 383.50s | Desired: 6000.00 RPM | Measured: 5124.00 RPM | Error: 876.00 RPM | PWM: 1419.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 384.54s | Desired: 6000.00 RPM | Measured: 5406.00 RPM | Error: 594.00 RPM | PWM: 822.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 385.56s | Desired: 6000.00 RPM | Measured: 5450.00 RPM | Error: 550.00 RPM | PWM: 870.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 386.59s | Desired: 6000.00 RPM | Measured: 5277.00 RPM | Error: 723.00 RPM | PWM: 1256.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 387.63s | Desired: 6000.00 RPM | Measured: 5249.00 RPM | Error: 751.00 RPM | PWM: 1228.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 388.68s | Desired: 6000.00 RPM | Measured: 5443.00 RPM | Error: 557.00 RPM | PWM: 806.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 389.71s | Desired: 6000.00 RPM | Measured: 5274.00 RPM | Error: 726.00 RPM | PWM: 1258.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 390.73s | Desired: 6000.00 RPM | Measured: 5178.00 RPM | Error: 822.00 RPM | PWM: 1375.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 391.78s | Desired: 6000.00 RPM | Measured: 5224.00 RPM | Error: 776.00 RPM | PWM: 1231.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 392.80s | Desired: 6000.00 RPM | Measured: 5442.00 RPM | Error: 558.00 RPM | PWM: 796.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 393.84s | Desired: 6000.00 RPM | Measured: 5450.00 RPM | Error: 550.00 RPM | PWM: 888.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 394.87s | Desired: 6000.00 RPM | Measured: 5212.00 RPM | Error: 788.00 RPM | PWM: 1392.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 395.91s | Desired: 6000.00 RPM | Measured: 5389.00 RPM | Error: 611.00 RPM | PWM: 901.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 396.95s | Desired: 6000.00 RPM | Measured: 5203.00 RPM | Error: 797.00 RPM | PWM: 1380.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 397.98s | Desired: 6000.00 RPM | Measured: 5207.00 RPM | Error: 793.00 RPM | PWM: 1279.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 399.01s | Desired: 6000.00 RPM | Measured: 5363.00 RPM | Error: 637.00 RPM | PWM: 953.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 400.05s | Desired: 6000.00 RPM | Measured: 5210.00 RPM | Error: 790.00 RPM | PWM: 1353.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 401.08s | Desired: 6000.00 RPM | Measured: 5211.00 RPM | Error: 789.00 RPM | PWM: 1274.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 402.12s | Desired: 6000.00 RPM | Measured: 5216.00 RPM | Error: 784.00 RPM | PWM: 1264.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 403.15s | Desired: 6000.00 RPM | Measured: 5202.00 RPM | Error: 798.00 RPM | PWM: 1296.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 404.19s | Desired: 6000.00 RPM | Measured: 5349.00 RPM | Error: 651.00 RPM | PWM: 980.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 405.23s | Desired: 6000.00 RPM | Measured: 5161.00 RPM | Error: 839.00 RPM | PWM: 1449.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 406.27s | Desired: 6000.00 RPM | Measured: 5188.00 RPM | Error: 812.00 RPM | PWM: 1298.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 407.29s | Desired: 6000.00 RPM | Measured: 5202.00 RPM | Error: 798.00 RPM | PWM: 1282.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 408.33s | Desired: 6000.00 RPM | Measured: 5382.00 RPM | Error: 618.00 RPM | PWM: 911.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 409.36s | Desired: 6000.00 RPM | Measured: 5417.00 RPM | Error: 583.00 RPM | PWM: 928.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 410.40s | Desired: 6000.00 RPM | Measured: 5440.00 RPM | Error: 560.00 RPM | PWM: 897.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 411.43s | Desired: 6000.00 RPM | Measured: 5240.00 RPM | Error: 760.00 RPM | PWM: 1328.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 412.45s | Desired: 6000.00 RPM | Measured: 5220.00 RPM | Error: 780.00 RPM | PWM: 1270.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 413.49s | Desired: 6000.00 RPM | Measured: 5199.00 RPM | Error: 801.00 RPM | PWM: 1304.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 414.52s | Desired: 6000.00 RPM | Measured: 5145.00 RPM | Error: 855.00 RPM | PWM: 1407.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 415.57s | Desired: 6000.00 RPM | Measured: 5205.00 RPM | Error: 795.00 RPM | PWM: 1254.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 416.59s | Desired: 6000.00 RPM | Measured: 5230.00 RPM | Error: 770.00 RPM | PWM: 1232.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 417.62s | Desired: 6000.00 RPM | Measured: 5211.00 RPM | Error: 789.00 RPM | PWM: 1284.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 418.67s | Desired: 6000.00 RPM | Measured: 5224.00 RPM | Error: 776.00 RPM | PWM: 1247.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 419.70s | Desired: 6000.00 RPM | Measured: 5166.00 RPM | Error: 834.00 RPM | PWM: 1376.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 420.73s | Desired: 6000.00 RPM | Measured: 5246.00 RPM | Error: 754.00 RPM | PWM: 1179.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 421.77s | Desired: 6000.00 RPM | Measured: 5228.00 RPM | Error: 772.00 RPM | PWM: 1256.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 422.80s | Desired: 6000.00 RPM | Measured: 5255.00 RPM | Error: 745.00 RPM | PWM: 1191.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 423.84s | Desired: 6000.00 RPM | Measured: 5266.00 RPM | Error: 734.00 RPM | PWM: 1181.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 424.87s | Desired: 6000.00 RPM | Measured: 5224.00 RPM | Error: 776.00 RPM | PWM: 1275.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 425.91s | Desired: 6000.00 RPM | Measured: 5429.00 RPM | Error: 571.00 RPM | PWM: 823.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 426.94s | Desired: 6000.00 RPM | Measured: 5257.00 RPM | Error: 743.00 RPM | PWM: 1287.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 427.98s | Desired: 6000.00 RPM | Measured: 5213.00 RPM | Error: 787.00 RPM | PWM: 1293.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 429.01s | Desired: 6000.00 RPM | Measured: 5180.00 RPM | Error: 820.00 RPM | PWM: 1341.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 430.05s | Desired: 6000.00 RPM | Measured: 5204.00 RPM | Error: 796.00 RPM | PWM: 1274.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 431.08s | Desired: 6000.00 RPM | Measured: 5390.00 RPM | Error: 610.00 RPM | PWM: 895.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 432.11s | Desired: 6000.00 RPM | Measured: 5253.00 RPM | Error: 747.00 RPM | PWM: 1276.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 433.15s | Desired: 6000.00 RPM | Measured: 5222.00 RPM | Error: 778.00 RPM | PWM: 1273.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 434.18s | Desired: 6000.00 RPM | Measured: 5387.00 RPM | Error: 613.00 RPM | PWM: 911.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 435.22s | Desired: 6000.00 RPM | Measured: 5431.00 RPM | Error: 569.00 RPM | PWM: 901.1500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 436.25s | Desired: 6000.00 RPM | Measured: 5416.00 RPM | Error: 584.00 RPM | PWM: 954.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 437.29s | Desired: 6000.00 RPM | Measured: 5430.00 RPM | Error: 570.00 RPM | PWM: 917.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 438.32s | Desired: 6000.00 RPM | Measured: 5239.00 RPM | Error: 761.00 RPM | PWM: 1325.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 439.36s | Desired: 6000.00 RPM | Measured: 5132.00 RPM | Error: 868.00 RPM | PWM: 1455.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 440.40s | Desired: 6000.00 RPM | Measured: 5448.00 RPM | Error: 552.00 RPM | PWM: 737.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 441.42s | Desired: 6000.00 RPM | Measured: 5338.00 RPM | Error: 662.00 RPM | PWM: 1126.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 442.46s | Desired: 6000.00 RPM | Measured: 5286.00 RPM | Error: 714.00 RPM | PWM: 1181.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 443.50s | Desired: 6000.00 RPM | Measured: 5285.00 RPM | Error: 715.00 RPM | PWM: 1157.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 444.53s | Desired: 6000.00 RPM | Measured: 5292.00 RPM | Error: 708.00 RPM | PWM: 1142.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 445.57s | Desired: 6000.00 RPM | Measured: 5280.00 RPM | Error: 720.00 RPM | PWM: 1170.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 446.60s | Desired: 6000.00 RPM | Measured: 5305.00 RPM | Error: 695.00 RPM | PWM: 1112.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 447.63s | Desired: 6000.00 RPM | Measured: 5275.00 RPM | Error: 725.00 RPM | PWM: 1187.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 448.66s | Desired: 6000.00 RPM | Measured: 5287.00 RPM | Error: 713.00 RPM | PWM: 1147.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 449.69s | Desired: 6000.00 RPM | Measured: 5288.00 RPM | Error: 712.00 RPM | PWM: 1151.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 450.73s | Desired: 6000.00 RPM | Measured: 5239.00 RPM | Error: 761.00 RPM | PWM: 1254.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 451.76s | Desired: 6000.00 RPM | Measured: 5151.00 RPM | Error: 849.00 RPM | PWM: 1415.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 452.80s | Desired: 6000.00 RPM | Measured: 5183.00 RPM | Error: 817.00 RPM | PWM: 1303.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 453.83s | Desired: 6000.00 RPM | Measured: 5222.00 RPM | Error: 778.00 RPM | PWM: 1238.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 454.86s | Desired: 6000.00 RPM | Measured: 5399.00 RPM | Error: 601.00 RPM | PWM: 885.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 455.89s | Desired: 6000.00 RPM | Measured: 5260.00 RPM | Error: 740.00 RPM | PWM: 1266.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 456.94s | Desired: 6000.00 RPM | Measured: 5255.00 RPM | Error: 745.00 RPM | PWM: 1207.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 457.98s | Desired: 6000.00 RPM | Measured: 5239.00 RPM | Error: 761.00 RPM | PWM: 1238.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 459.01s | Desired: 6000.00 RPM | Measured: 5414.00 RPM | Error: 586.00 RPM | PWM: 862.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 460.05s | Desired: 6000.00 RPM | Measured: 5273.00 RPM | Error: 727.00 RPM | PWM: 1246.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 461.08s | Desired: 6000.00 RPM | Measured: 5212.00 RPM | Error: 788.00 RPM | PWM: 1304.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 462.12s | Desired: 6000.00 RPM | Measured: 5405.00 RPM | Error: 595.00 RPM | PWM: 868.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 463.15s | Desired: 6000.00 RPM | Measured: 5213.00 RPM | Error: 787.00 RPM | PWM: 1367.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 464.17s | Desired: 6000.00 RPM | Measured: 5185.00 RPM | Error: 815.00 RPM | PWM: 1330.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 465.21s | Desired: 6000.00 RPM | Measured: 5207.00 RPM | Error: 793.00 RPM | PWM: 1270.5500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 466.24s | Desired: 6000.00 RPM | Measured: 5403.00 RPM | Error: 597.00 RPM | PWM: 869.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 467.29s | Desired: 6000.00 RPM | Measured: 5286.00 RPM | Error: 714.00 RPM | PWM: 1213.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 468.31s | Desired: 6000.00 RPM | Measured: 5272.00 RPM | Error: 728.00 RPM | PWM: 1184.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 469.34s | Desired: 6000.00 RPM | Measured: 5282.00 RPM | Error: 718.00 RPM | PWM: 1156.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 470.38s | Desired: 6000.00 RPM | Measured: 5330.00 RPM | Error: 670.00 RPM | PWM: 1060.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 471.41s | Desired: 6000.00 RPM | Measured: 5352.00 RPM | Error: 648.00 RPM | PWM: 1038.55 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 472.44s | Desired: 6000.00 RPM | Measured: 5313.00 RPM | Error: 687.00 RPM | PWM: 1131.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 473.48s | Desired: 6000.00 RPM | Measured: 5303.00 RPM | Error: 697.00 RPM | PWM: 1132.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 474.52s | Desired: 6000.00 RPM | Measured: 5332.00 RPM | Error: 668.00 RPM | PWM: 1067.05 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 475.56s | Desired: 6000.00 RPM | Measured: 5381.00 RPM | Error: 619.00 RPM | PWM: 978.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 476.59s | Desired: 6000.00 RPM | Measured: 5472.00 RPM | Error: 528.00 RPM | PWM: 812.0500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 477.62s | Desired: 6000.00 RPM | Measured: 5460.00 RPM | Error: 540.00 RPM | PWM: 882.75 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 478.65s | Desired: 6000.00 RPM | Measured: 5318.00 RPM | Error: 682.00 RPM | PWM: 1174.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 479.69s | Desired: 6000.00 RPM | Measured: 5319.00 RPM | Error: 681.00 RPM | PWM: 1101.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 480.73s | Desired: 6000.00 RPM | Measured: 5194.00 RPM | Error: 806.00 RPM | PWM: 1364.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 481.76s | Desired: 6000.00 RPM | Measured: 5187.00 RPM | Error: 813.00 RPM | PWM: 1317.0500000000002 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 482.79s | Desired: 6000.00 RPM | Measured: 5416.00 RPM | Error: 584.00 RPM | PWM: 832.6500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 483.83s | Desired: 6000.00 RPM | Measured: 5472.00 RPM | Error: 528.00 RPM | PWM: 829.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 484.87s | Desired: 6000.00 RPM | Measured: 5482.00 RPM | Error: 518.00 RPM | PWM: 836.5500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 485.90s | Desired: 6000.00 RPM | Measured: 5434.00 RPM | Error: 566.00 RPM | PWM: 942.35 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 486.93s | Desired: 6000.00 RPM | Measured: 5259.00 RPM | Error: 741.00 RPM | PWM: 1285.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 487.96s | Desired: 6000.00 RPM | Measured: 5126.00 RPM | Error: 874.00 RPM | PWM: 1477.65 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 489.00s | Desired: 6000.00 RPM | Measured: 5216.00 RPM | Error: 784.00 RPM | PWM: 1222.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 490.02s | Desired: 6000.00 RPM | Measured: 5239.00 RPM | Error: 761.00 RPM | PWM: 1218.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 491.07s | Desired: 6000.00 RPM | Measured: 5144.00 RPM | Error: 856.00 RPM | PWM: 1429.8500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 492.10s | Desired: 6000.00 RPM | Measured: 5103.00 RPM | Error: 897.00 RPM | PWM: 1468.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 493.14s | Desired: 6000.00 RPM | Measured: 5220.00 RPM | Error: 780.00 RPM | PWM: 1202.25 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 494.17s | Desired: 6000.00 RPM | Measured: 5264.00 RPM | Error: 736.00 RPM | PWM: 1168.3500000000001 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 495.19s | Desired: 6000.00 RPM | Measured: 5409.00 RPM | Error: 591.00 RPM | PWM: 885.85 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 496.24s | Desired: 6000.00 RPM | Measured: 5241.00 RPM | Error: 759.00 RPM | PWM: 1311.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 497.28s | Desired: 6000.00 RPM | Measured: 5248.00 RPM | Error: 752.00 RPM | PWM: 1212.45 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 498.30s | Desired: 6000.00 RPM | Measured: 5236.00 RPM | Error: 764.00 RPM | PWM: 1241.15 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Time: 499.34s | Desired: 6000.00 RPM | Measured: 5238.00 RPM | Error: 762.00 RPM | PWM: 1230.95 | Kp: 1.6 | Ki: 0.05 | Kd: 0.5
# Data saved to PID_motor_data_20250404_214620.csv
# Speed plot saved to PID_motor_plot_speed_20250404_214620.pdf
# PID gains plot saved to PID_motor_plot_gains_20250404_214620.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime
import uuid  # Import UUID for unique filenames

import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

# Define whether ANN is enabled or not
ANN_enabled = True  # Set to True if ANN is used, False otherwise

# Convert lists to NumPy arrays for performance calculations
time_stamps = np.array(times)  # Recorded time points
error = np.array(errors)
setpoints = np.array([desired_speed] * len(times))  # Setpoints stored as an array
speeds = np.array(speeds)

# Compute Performance Metrics
rmse = np.sqrt(np.mean(error ** 2))  # Root Mean Square Error
mae = np.mean(np.abs(error))  # Mean Absolute Error
SSE = error[-1]  # Last recorded steady-state error
max_speed = max(speeds)  # Maximum speed recorded
overshoot = max(0, ((max_speed - desired_speed) / desired_speed) * 100)  # Percentage overshoot

# Settling Time (Ts)
within_tolerance = np.abs(error) < (0.05 * desired_speed)  # Define ±5% tolerance band
Ts_index = np.argmax(within_tolerance) if np.any(within_tolerance) else -1
Ts = time_stamps[Ts_index] if Ts_index != -1 else None  # First time where error is within ±5%

# Print Summary of Performance Metrics
print("Performance Metrics:")
print(f"Root Mean Square Error (RMSE): {rmse:.2f} RPM")
print(f"Mean Absolute Error (MAE): {mae:.2f} RPM")
print(f"Steady-State Error (SSE): {SSE:.2f} RPM")
print(f"Maximum Speed: {max_speed:.2f} RPM")
print(f"Overshoot: {overshoot:.2f}%")
print(f"Settling Time (Ts): {Ts:.2f} seconds" if Ts else "Settling Time (Ts): Not achieved within the runtime.")

# Generate Performance Plots and Save with explicit names
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")  # Format: YYYYMMDD_HHMMSS
identifier = "With_ANN" if ANN_enabled else "No_ANN"  # Condition-based identifier
unique_id = uuid.uuid4().hex[:8]  # Generates an 8-character unique ID

# 1. Histogram of Errors
hist_filename = f"Histogram_Errors_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(8, 5))
plt.hist(error, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Error (RPM)", fontsize=16)
plt.ylabel("Frequency", fontsize=16)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(hist_filename, format="pdf", bbox_inches="tight")
plt.show()

# 2. RMSE & MAE Comparison
rmse_mae_filename = f"RMSE_MAE_Comparison_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(8, 5))
plt.bar(["RMSE", "MAE"], [rmse, mae], color=['red', 'orange'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(rmse_mae_filename, format="pdf", bbox_inches="tight")
plt.show()

# 3. Overshoot & Steady-State Error
overshoot_sse_filename = f"Overshoot_SSE_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(8, 5))
plt.bar(["Overshoot (%)", "SSE"], [overshoot, SSE], color=['purple', 'green'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)

# Apply Scientific Notation for the Y-axis
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)
plt.savefig(overshoot_sse_filename, format="pdf", bbox_inches="tight")
plt.show()

# Print saved filenames
print(f"Histogram of Errors saved as {hist_filename}")
print(f"RMSE & MAE Comparison saved as {rmse_mae_filename}")
print(f"Overshoot & Steady-State Error saved as {overshoot_sse_filename}")
# Out:
# Performance Metrics:
# Root Mean Square Error (RMSE): 830.17 RPM
# Mean Absolute Error (MAE): 786.22 RPM
# Steady-State Error (SSE): 762.00 RPM
# Maximum Speed: 5482.00 RPM
# Overshoot: 0.00%
# Settling Time (Ts): Not achieved within the runtime.
# Histogram of Errors saved as Histogram_Errors_With_ANN_20250404_220656_5f7f03c1.pdf
# RMSE & MAE Comparison saved as RMSE_MAE_Comparison_With_ANN_20250404_220656_5f7f03c1.pdf
# Overshoot & Steady-State Error saved as Overshoot_SSE_With_ANN_20250404_220656_5f7f03c1.pdf

# %% [markdown]
# # Enhanced PID Control program with ANN-enabled Self-tuning:

# %%
import serial
import time
import csv
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime

# Initialize Serial Communication (Update COM Port)
ser = serial.Serial('COM3', 115200, timeout=0.1)

# PID Initial Parameters
Kp, Ki, Kd = 1.0, 0.05, 0.5
desired_speed = float(input("Enter desired motor speed (RPM): "))
runtime = float(input("Enter duration for PID control (seconds): "))
ann_start_time = runtime * 0.2  # ANN starts optimizing after 20% of runtime

# Define ANN Model (PyTorch)
class PIDANN(nn.Module):
    def __init__(self):
        super(PIDANN, self).__init__()
        self.fc1 = nn.Linear(5, 16)  # 5 Inputs -> 16 Neurons
        self.fc2 = nn.Linear(16, 16)  # Hidden layer
        self.fc3 = nn.Linear(16, 3)  # 3 Outputs (Kp, Ki, Kd)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)  # No activation (raw values)
        return x

# Initialize ANN Model
model = PIDANN()
optimizer = optim.Adam(model.parameters(), lr=0.01)
loss_function = nn.MSELoss()

# Data Logging
times, speeds, errors, pwm_outputs = [], [], [], []
kp_values, ki_values, kd_values, loss_values = [], [], [], []
start_time = time.time()
history = []  # Training Buffer
history_size = int(runtime * 0.1)  # Keep last nth data points for ANN training--10% size of run time

# Generate dynamic filenames for CSV and PDF
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
csv_filename = f"motor_speed_data_ANN_{current_datetime}.csv"
pdf_filename_speed = f"motor_speed_plot_speed_ANN_{current_datetime}.pdf"
pdf_filename_gains = f"motor_speed_plot_gains_ANN_{current_datetime}.pdf"
pdf_filename_loss = f"motor_speed_plot_loss_ANN_{current_datetime}.pdf"

# CSV File Setup
with open(csv_filename, mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Time (s)", "Desired Speed (RPM)", "Measured Speed (RPM)", "Error (RPM)", 
                     "PWM Output", "Kp", "Ki", "Kd", "Loss"])  # CSV Header

def pid_control(measured_speed, elapsed_time):
    """Compute PID control signal."""
    global Kp, Ki, Kd, history

    error = desired_speed - measured_speed
    delta_error = error - errors[-1] if errors else 0
    control_signal = (Kp * error) + (Ki * sum(errors[-history_size:])) + (Kd * delta_error)

    # ANN Optimization only after 20% runtime
    if elapsed_time >= ann_start_time and len(history) > 10:
        inputs = np.array([len(errors), desired_speed, measured_speed, error, control_signal], dtype=np.float32)
        inputs_tensor = torch.tensor(inputs, dtype=torch.float32)

        with torch.no_grad():
            output_tensor = model(inputs_tensor)

        Kp, Ki, Kd = output_tensor.numpy()

        # Apply constraints
        Kp = max(0.0, min(Kp, 50.0))
        Ki = max(0.0, min(Ki, 25.0))
        Kd = max(0.0, min(Kd, 25.0))

    # Train the ANN Online only after given runtime (e.g., 20% runtime)
    if elapsed_time >= ann_start_time:
        history.append([len(errors), desired_speed, measured_speed, error, control_signal, Kp, Ki, Kd])
        if len(history) > history_size:
            history.pop(0)

        x_train = torch.tensor([h[:-3] for h in history], dtype=torch.float32)
        y_train = torch.tensor([h[-3:] for h in history], dtype=torch.float32)

        optimizer.zero_grad()
        prediction = model(x_train)
        loss = loss_function(prediction, y_train)
        loss.backward()
        optimizer.step()

        loss_value = loss.item()
        loss_values.append(loss_value)
    else:
        loss_value = 0  # Before 20% runtime, no ANN training

    return control_signal, loss_value

# Main Control Loop
while time.time() - start_time < runtime:
    response = ser.readline().decode().strip()
    if response:
        measured_speed = float(response)  # Measured speed in RPM
        elapsed_time = time.time() - start_time
        
        # Compute PID output with ANN tuning only after 20% runtime
        pwm_output, loss_value = pid_control(measured_speed, elapsed_time)
        ser.write(f"{pwm_output}\n".encode())  # Send PWM to Arduino

        # Store Data
        times.append(elapsed_time)
        speeds.append(measured_speed)
        errors.append(desired_speed - measured_speed)
        pwm_outputs.append(pwm_output)
        kp_values.append(Kp)
        ki_values.append(Ki)
        kd_values.append(Kd)

        # Save to CSV
        with open(csv_filename, mode="a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([elapsed_time, desired_speed, measured_speed, errors[-1], pwm_output, 
                             Kp, Ki, Kd, loss_value])

        # Print data in real-time
        print(f"Time: {elapsed_time:.2f}s | Desired: {desired_speed:.2f} RPM | Measured: {measured_speed:.2f} RPM | "
              f"Error: {errors[-1]:.2f} RPM | PWM: {pwm_output} | Kp: {Kp:.3f} | Ki: {Ki:.3f} | "
              f"Kd: {Kd:.3f} | Loss: {loss_value:.6f}")

ser.close()

# Generate Measured Speed & Error Plot
plt.figure(figsize=(7, 6))
plt.plot(times, speeds, label="Measured Speed (RPM)", color="b", linewidth=2)
plt.plot(times, errors, label="Error", color="r", linewidth=2)
plt.plot(times, [desired_speed] * len(times), label="Desired Speed (RPM)", color="g", linestyle="--", linewidth=2)

# Add shaded threshold region
threshold_lower = desired_speed * 0.95  # Lower bound of ±5% threshold
threshold_upper = desired_speed * 1.05  # Upper bound of ±5% threshold
plt.fill_between(times, threshold_lower, threshold_upper, color="gray", alpha=0.3, label="±5% Threshold")

# Add settling time marker
if Ts:
    plt.axvline(Ts, color="black", linestyle="--", linewidth=2, label=f"Settling Time: {Ts:.2f}s")
    #plt.text(Ts, desired_speed, f"  Ts = {Ts:.2f}s", fontsize=12, color="black", va="bottom")

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Speed (RPM)", fontsize=16)
#plt.title("Measured Speed and Error for PID Control with ANN", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_speed, format="pdf")
plt.show()

# Generate PID Gains Plot
plt.figure(figsize=(7, 6))
plt.plot(times, kp_values, label="Kp", color="m", linewidth=2)
plt.plot(times, ki_values, label="Ki", color="c", linewidth=2, alpha=0.6)
plt.plot(times, kd_values, label="Kd", color="y", linewidth=2, alpha=0.3)

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("PID Gains", fontsize=16)
#plt.title("ANN-PID Gains Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_gains, format="pdf")
plt.show()

# Generate Loss Plot
plt.figure(figsize=(7, 6))
plt.plot(times[:len(loss_values)], loss_values, label="Loss (MSE)", color="orange", linewidth=2)

# Add legend
plt.legend(fontsize=14)

# Add labels, title, and grid
plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Loss (MSE)", fontsize=16)
#plt.title("ANN Training Loss Over Time", fontsize=18)
plt.grid(True, linestyle="--", alpha=0.6)

# Save plot
plt.tight_layout()
plt.savefig(pdf_filename_loss, format="pdf")
plt.show()

# Final Outputs
print(f"Data saved to {csv_filename}")
print(f"Measured Speed plot saved to {pdf_filename_speed}")
print(f"PID Gains plot saved to {pdf_filename_gains}")
print(f"Loss plot saved to {pdf_filename_loss}")
# Out:
# Enter desired motor speed (RPM): 6000
# Enter duration for PID control (seconds): 500
# Time: 0.00s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 6000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 6300.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 6600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 6900.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 7200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.00s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 7500.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 7800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 8100.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 8400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 8700.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 9000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 9300.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 9600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 9900.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 10200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 10500.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 10800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 11100.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 11400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.02s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 11700.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 12000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 12300.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 12600.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 12900.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 13200.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 13500.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 13800.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 14100.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 14400.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 14700.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 0.03s | Desired: 6000.00 RPM | Measured: 0.00 RPM | Error: 6000.00 RPM | PWM: 15000.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 1.20s | Desired: 6000.00 RPM | Measured: 4931.00 RPM | Error: 1069.00 RPM | PWM: 7903.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 2.23s | Desired: 6000.00 RPM | Measured: 5098.00 RPM | Error: 902.00 RPM | PWM: 10171.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 3.27s | Desired: 6000.00 RPM | Measured: 5054.00 RPM | Error: 946.00 RPM | PWM: 10366.550000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 4.29s | Desired: 6000.00 RPM | Measured: 5210.00 RPM | Error: 790.00 RPM | PWM: 10157.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 5.33s | Desired: 6000.00 RPM | Measured: 5069.00 RPM | Error: 931.00 RPM | PWM: 10486.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 6.37s | Desired: 6000.00 RPM | Measured: 5030.00 RPM | Error: 970.00 RPM | PWM: 10521.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 7.40s | Desired: 6000.00 RPM | Measured: 5080.00 RPM | Error: 920.00 RPM | PWM: 10475.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 8.43s | Desired: 6000.00 RPM | Measured: 5059.00 RPM | Error: 941.00 RPM | PWM: 10577.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 9.48s | Desired: 6000.00 RPM | Measured: 5042.00 RPM | Error: 958.00 RPM | PWM: 10639.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 10.51s | Desired: 6000.00 RPM | Measured: 5056.00 RPM | Error: 944.00 RPM | PWM: 10658.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 11.54s | Desired: 6000.00 RPM | Measured: 5065.00 RPM | Error: 935.00 RPM | PWM: 10699.050000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 12.58s | Desired: 6000.00 RPM | Measured: 3898.00 RPM | Error: 2102.00 RPM | PWM: 12500.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 13.62s | Desired: 6000.00 RPM | Measured: 4139.00 RPM | Error: 1861.00 RPM | PWM: 11660.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 14.66s | Desired: 6000.00 RPM | Measured: 4564.00 RPM | Error: 1436.00 RPM | PWM: 11236.95 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 15.68s | Desired: 6000.00 RPM | Measured: 5066.00 RPM | Error: 934.00 RPM | PWM: 10768.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 16.71s | Desired: 6000.00 RPM | Measured: 5113.00 RPM | Error: 887.00 RPM | PWM: 10995.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 17.76s | Desired: 6000.00 RPM | Measured: 5102.00 RPM | Error: 898.00 RPM | PWM: 11079.800000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 18.79s | Desired: 6000.00 RPM | Measured: 4547.00 RPM | Error: 1453.00 RPM | PWM: 11951.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 19.82s | Desired: 6000.00 RPM | Measured: 5003.00 RPM | Error: 997.00 RPM | PWM: 11062.85 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 20.87s | Desired: 6000.00 RPM | Measured: 5049.00 RPM | Error: 951.00 RPM | PWM: 11271.7 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 21.89s | Desired: 6000.00 RPM | Measured: 5083.00 RPM | Error: 917.00 RPM | PWM: 10991.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 22.93s | Desired: 6000.00 RPM | Measured: 5059.00 RPM | Error: 941.00 RPM | PWM: 10790.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 23.97s | Desired: 6000.00 RPM | Measured: 5064.00 RPM | Error: 936.00 RPM | PWM: 10517.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 25.00s | Desired: 6000.00 RPM | Measured: 5013.00 RPM | Error: 987.00 RPM | PWM: 10343.45 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 26.04s | Desired: 6000.00 RPM | Measured: 5061.00 RPM | Error: 939.00 RPM | PWM: 9995.300000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 27.07s | Desired: 6000.00 RPM | Measured: 5130.00 RPM | Error: 870.00 RPM | PWM: 9662.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 28.11s | Desired: 6000.00 RPM | Measured: 4930.00 RPM | Error: 1070.00 RPM | PWM: 9740.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 29.14s | Desired: 6000.00 RPM | Measured: 4890.00 RPM | Error: 1110.00 RPM | PWM: 9454.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 30.17s | Desired: 6000.00 RPM | Measured: 4930.00 RPM | Error: 1070.00 RPM | PWM: 9129.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 31.20s | Desired: 6000.00 RPM | Measured: 4931.00 RPM | Error: 1069.00 RPM | PWM: 8901.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 32.25s | Desired: 6000.00 RPM | Measured: 4940.00 RPM | Error: 1060.00 RPM | PWM: 8642.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 33.28s | Desired: 6000.00 RPM | Measured: 4919.00 RPM | Error: 1081.00 RPM | PWM: 8431.2 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 34.31s | Desired: 6000.00 RPM | Measured: 4886.00 RPM | Error: 1114.00 RPM | PWM: 8224.25 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 35.34s | Desired: 6000.00 RPM | Measured: 4947.00 RPM | Error: 1053.00 RPM | PWM: 7871.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 36.39s | Desired: 6000.00 RPM | Measured: 5120.00 RPM | Error: 880.00 RPM | PWM: 7395.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 37.42s | Desired: 6000.00 RPM | Measured: 4970.00 RPM | Error: 1030.00 RPM | PWM: 7451.1 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 38.45s | Desired: 6000.00 RPM | Measured: 4920.00 RPM | Error: 1080.00 RPM | PWM: 7202.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 39.49s | Desired: 6000.00 RPM | Measured: 4956.00 RPM | Error: 1044.00 RPM | PWM: 6877.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 40.53s | Desired: 6000.00 RPM | Measured: 4962.00 RPM | Error: 1038.00 RPM | PWM: 6638.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 41.56s | Desired: 6000.00 RPM | Measured: 4938.00 RPM | Error: 1062.00 RPM | PWM: 6429.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 42.59s | Desired: 6000.00 RPM | Measured: 4083.00 RPM | Error: 1917.00 RPM | PWM: 7453.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 43.62s | Desired: 6000.00 RPM | Measured: 4762.00 RPM | Error: 1238.00 RPM | PWM: 5803.150000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 44.66s | Desired: 6000.00 RPM | Measured: 4111.00 RPM | Error: 1889.00 RPM | PWM: 6881.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 45.68s | Desired: 6000.00 RPM | Measured: 4792.00 RPM | Error: 1208.00 RPM | PWM: 5328.5 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 46.72s | Desired: 6000.00 RPM | Measured: 4919.00 RPM | Error: 1081.00 RPM | PWM: 5238.900000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 47.75s | Desired: 6000.00 RPM | Measured: 4620.00 RPM | Error: 1380.00 RPM | PWM: 5504.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 48.78s | Desired: 6000.00 RPM | Measured: 5055.00 RPM | Error: 945.00 RPM | PWM: 4471.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 49.82s | Desired: 6000.00 RPM | Measured: 5155.00 RPM | Error: 845.00 RPM | PWM: 4286.700000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 50.87s | Desired: 6000.00 RPM | Measured: 4166.00 RPM | Error: 1834.00 RPM | PWM: 5562.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 51.90s | Desired: 6000.00 RPM | Measured: 4735.00 RPM | Error: 1265.00 RPM | PWM: 4006.1499999999996 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 52.94s | Desired: 6000.00 RPM | Measured: 5106.00 RPM | Error: 894.00 RPM | PWM: 3497.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 53.97s | Desired: 6000.00 RPM | Measured: 4985.00 RPM | Error: 1015.00 RPM | PWM: 3855.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 55.00s | Desired: 6000.00 RPM | Measured: 4919.00 RPM | Error: 1081.00 RPM | PWM: 3899.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 56.03s | Desired: 6000.00 RPM | Measured: 4910.00 RPM | Error: 1090.00 RPM | PWM: 3887.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 57.07s | Desired: 6000.00 RPM | Measured: 4941.00 RPM | Error: 1059.00 RPM | PWM: 3851.05 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 58.11s | Desired: 6000.00 RPM | Measured: 4941.00 RPM | Error: 1059.00 RPM | PWM: 3872.9500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 59.14s | Desired: 6000.00 RPM | Measured: 4729.00 RPM | Error: 1271.00 RPM | PWM: 4195.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 60.17s | Desired: 6000.00 RPM | Measured: 4904.00 RPM | Error: 1096.00 RPM | PWM: 3844.4500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 61.20s | Desired: 6000.00 RPM | Measured: 5118.00 RPM | Error: 882.00 RPM | PWM: 3618.7000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 62.23s | Desired: 6000.00 RPM | Measured: 3974.00 RPM | Error: 2026.00 RPM | PWM: 5437.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 63.26s | Desired: 6000.00 RPM | Measured: 4792.00 RPM | Error: 1208.00 RPM | PWM: 3693.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 64.30s | Desired: 6000.00 RPM | Measured: 5080.00 RPM | Error: 920.00 RPM | PWM: 3683.65 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 65.34s | Desired: 6000.00 RPM | Measured: 4966.00 RPM | Error: 1034.00 RPM | PWM: 3939.55 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 66.37s | Desired: 6000.00 RPM | Measured: 4972.00 RPM | Error: 1028.00 RPM | PWM: 3832.2000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 67.40s | Desired: 6000.00 RPM | Measured: 4694.00 RPM | Error: 1306.00 RPM | PWM: 4231.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 68.43s | Desired: 6000.00 RPM | Measured: 4909.00 RPM | Error: 1091.00 RPM | PWM: 3788.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 69.47s | Desired: 6000.00 RPM | Measured: 4956.00 RPM | Error: 1044.00 RPM | PWM: 3836.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 70.51s | Desired: 6000.00 RPM | Measured: 4805.00 RPM | Error: 1195.00 RPM | PWM: 4093.4 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 71.54s | Desired: 6000.00 RPM | Measured: 4931.00 RPM | Error: 1069.00 RPM | PWM: 3816.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 72.58s | Desired: 6000.00 RPM | Measured: 5102.00 RPM | Error: 898.00 RPM | PWM: 3626.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 73.62s | Desired: 6000.00 RPM | Measured: 4793.00 RPM | Error: 1207.00 RPM | PWM: 4172.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 74.65s | Desired: 6000.00 RPM | Measured: 4751.00 RPM | Error: 1249.00 RPM | PWM: 4095.4500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 75.68s | Desired: 6000.00 RPM | Measured: 5102.00 RPM | Error: 898.00 RPM | PWM: 3563.3500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 76.72s | Desired: 6000.00 RPM | Measured: 5152.00 RPM | Error: 848.00 RPM | PWM: 3661.9500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 77.75s | Desired: 6000.00 RPM | Measured: 4776.00 RPM | Error: 1224.00 RPM | PWM: 4244.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 78.79s | Desired: 6000.00 RPM | Measured: 5079.00 RPM | Error: 921.00 RPM | PWM: 3615.75 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 79.82s | Desired: 6000.00 RPM | Measured: 5014.00 RPM | Error: 986.00 RPM | PWM: 3867.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 80.86s | Desired: 6000.00 RPM | Measured: 4970.00 RPM | Error: 1030.00 RPM | PWM: 3896.6000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 81.90s | Desired: 6000.00 RPM | Measured: 4116.00 RPM | Error: 1884.00 RPM | PWM: 5151.6 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 82.94s | Desired: 6000.00 RPM | Measured: 4869.00 RPM | Error: 1131.00 RPM | PWM: 3635.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 83.97s | Desired: 6000.00 RPM | Measured: 5004.00 RPM | Error: 996.00 RPM | PWM: 3812.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 85.00s | Desired: 6000.00 RPM | Measured: 4957.00 RPM | Error: 1043.00 RPM | PWM: 3947.7000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 86.03s | Desired: 6000.00 RPM | Measured: 3926.00 RPM | Error: 2074.00 RPM | PWM: 5468.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 87.07s | Desired: 6000.00 RPM | Measured: 4759.00 RPM | Error: 1241.00 RPM | PWM: 3751.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 88.11s | Desired: 6000.00 RPM | Measured: 4965.00 RPM | Error: 1035.00 RPM | PWM: 3868.7000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 89.14s | Desired: 6000.00 RPM | Measured: 3927.00 RPM | Error: 2073.00 RPM | PWM: 5536.450000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 90.17s | Desired: 6000.00 RPM | Measured: 4654.00 RPM | Error: 1346.00 RPM | PWM: 3979.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 91.21s | Desired: 6000.00 RPM | Measured: 4762.00 RPM | Error: 1238.00 RPM | PWM: 4193.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 92.24s | Desired: 6000.00 RPM | Measured: 4905.00 RPM | Error: 1095.00 RPM | PWM: 4043.1000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 93.27s | Desired: 6000.00 RPM | Measured: 4770.00 RPM | Error: 1230.00 RPM | PWM: 4319.950000000001 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 94.31s | Desired: 6000.00 RPM | Measured: 5053.00 RPM | Error: 947.00 RPM | PWM: 3836.3500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 95.34s | Desired: 6000.00 RPM | Measured: 5091.00 RPM | Error: 909.00 RPM | PWM: 3872.3500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 96.38s | Desired: 6000.00 RPM | Measured: 5107.00 RPM | Error: 893.00 RPM | PWM: 3850.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 97.41s | Desired: 6000.00 RPM | Measured: 4944.00 RPM | Error: 1056.00 RPM | PWM: 4053.6000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 98.45s | Desired: 6000.00 RPM | Measured: 4051.00 RPM | Error: 1949.00 RPM | PWM: 5304.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 99.48s | Desired: 6000.00 RPM | Measured: 4899.00 RPM | Error: 1101.00 RPM | PWM: 3628.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 0.000000
# Time: 100.51s | Desired: 6000.00 RPM | Measured: 4957.00 RPM | Error: 1043.00 RPM | PWM: 3951.9500000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 14185.511719
# Time: 101.56s | Desired: 6000.00 RPM | Measured: 4816.00 RPM | Error: 1184.00 RPM | PWM: 4197.35 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 544.428101
# Time: 102.60s | Desired: 6000.00 RPM | Measured: 4939.00 RPM | Error: 1061.00 RPM | PWM: 3959.3 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 7055.216797
# Time: 103.63s | Desired: 6000.00 RPM | Measured: 4971.00 RPM | Error: 1029.00 RPM | PWM: 3934.15 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 5523.623535
# Time: 104.67s | Desired: 6000.00 RPM | Measured: 4961.00 RPM | Error: 1039.00 RPM | PWM: 3953.3500000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 2365.319092
# Time: 105.70s | Desired: 6000.00 RPM | Measured: 5131.00 RPM | Error: 869.00 RPM | PWM: 3700.6000000000004 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 1384.125977
# Time: 106.74s | Desired: 6000.00 RPM | Measured: 4076.00 RPM | Error: 1924.00 RPM | PWM: 5360.8 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 1505.702148
# Time: 107.78s | Desired: 6000.00 RPM | Measured: 4741.00 RPM | Error: 1259.00 RPM | PWM: 3877.9500000000007 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 893.949158
# Time: 108.81s | Desired: 6000.00 RPM | Measured: 4719.00 RPM | Error: 1281.00 RPM | PWM: 4251.9 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 1336.132202
# Time: 109.84s | Desired: 6000.00 RPM | Measured: 4917.00 RPM | Error: 1083.00 RPM | PWM: 3955.0 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 2056.453857
# Time: 110.89s | Desired: 6000.00 RPM | Measured: 5121.00 RPM | Error: 879.00 RPM | PWM: 3749.2000000000003 | Kp: 1.000 | Ki: 0.050 | Kd: 0.500 | Loss: 1969.619507
# Time: 111.91s | Desired: 6000.00 RPM | Measured: 4685.00 RPM | Error: 1315.00 RPM | PWM: 4485.6 | Kp: 41.378 | Ki: 0.000 | Kd: 25.000 | Loss: 1083.829712
# Time: 112.95s | Desired: 6000.00 RPM | Measured: 4931.00 RPM | Error: 1069.00 RPM | PWM: 38083.589977264404 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 22731.769531
# Time: 113.99s | Desired: 6000.00 RPM | Measured: 5122.00 RPM | Error: 878.00 RPM | PWM: -4775.0 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 5648.832520
# Time: 115.04s | Desired: 6000.00 RPM | Measured: 5152.00 RPM | Error: 848.00 RPM | PWM: -750.0 | Kp: 0.000 | Ki: 0.000 | Kd: 7.944 | Loss: 13388.472656
# Time: 116.07s | Desired: 6000.00 RPM | Measured: 5134.00 RPM | Error: 866.00 RPM | PWM: 142.99859619140625 | Kp: 16.355 | Ki: 0.000 | Kd: 0.000 | Loss: 16233.210938
# Time: 117.11s | Desired: 6000.00 RPM | Measured: 4326.00 RPM | Error: 1674.00 RPM | PWM: 27378.106395721436 | Kp: 50.000 | Ki: 17.895 | Kd: 0.000 | Loss: 8920.280273
# Time: 118.14s | Desired: 6000.00 RPM | Measured: 4983.00 RPM | Error: 1017.00 RPM | PWM: 1098369.7222137451 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 1668944.125000
# Time: 119.19s | Desired: 6000.00 RPM | Measured: 4813.00 RPM | Error: 1187.00 RPM | PWM: 1463125.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 11107408.000000
# Time: 120.22s | Desired: 6000.00 RPM | Measured: 5086.00 RPM | Error: 914.00 RPM | PWM: 38875.0 | Kp: 46.646 | Ki: 0.000 | Kd: 25.000 | Loss: 1069963.750000
# Time: 121.26s | Desired: 6000.00 RPM | Measured: 5168.00 RPM | Error: 832.00 RPM | PWM: 36759.6591796875 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 9808519.000000
# Time: 122.30s | Desired: 6000.00 RPM | Measured: 5154.00 RPM | Error: 846.00 RPM | PWM: 1450425.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 3735701.750000
# Time: 123.34s | Desired: 6000.00 RPM | Measured: 5121.00 RPM | Error: 879.00 RPM | PWM: 1441700.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 7360765.000000
# Time: 124.37s | Desired: 6000.00 RPM | Measured: 5207.00 RPM | Error: 793.00 RPM | PWM: 37500.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 4685577.500000
# Time: 125.41s | Desired: 6000.00 RPM | Measured: 5210.00 RPM | Error: 790.00 RPM | PWM: 39425.0 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1194938.500000
# Time: 126.44s | Desired: 6000.00 RPM | Measured: 5186.00 RPM | Error: 814.00 RPM | PWM: 600.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 5977718.000000
# Time: 127.49s | Desired: 6000.00 RPM | Measured: 5204.00 RPM | Error: 796.00 RPM | PWM: 1452825.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 1732686.000000
# Time: 128.53s | Desired: 6000.00 RPM | Measured: 5181.00 RPM | Error: 819.00 RPM | PWM: 1410475.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 2614135.500000
# Time: 129.56s | Desired: 6000.00 RPM | Measured: 5125.00 RPM | Error: 875.00 RPM | PWM: 45150.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 3807518.250000
# Time: 130.60s | Desired: 6000.00 RPM | Measured: 5120.00 RPM | Error: 880.00 RPM | PWM: 44125.0 | Kp: 30.781 | Ki: 0.000 | Kd: 25.000 | Loss: 45451.613281
# Time: 131.63s | Desired: 6000.00 RPM | Measured: 5102.00 RPM | Error: 898.00 RPM | PWM: 28090.892795562744 | Kp: 18.396 | Ki: 0.000 | Kd: 17.704 | Loss: 3114830.500000
# Time: 132.67s | Desired: 6000.00 RPM | Measured: 4586.00 RPM | Error: 1414.00 RPM | PWM: 35147.52741241455 | Kp: 0.000 | Ki: 0.000 | Kd: 20.204 | Loss: 1697277.000000
# Time: 133.71s | Desired: 6000.00 RPM | Measured: 3834.00 RPM | Error: 2166.00 RPM | PWM: 15193.366760253906 | Kp: 0.000 | Ki: 0.000 | Kd: 5.775 | Loss: 154583.218750
# Time: 134.75s | Desired: 6000.00 RPM | Measured: 3878.00 RPM | Error: 2122.00 RPM | PWM: -254.08416366577148 | Kp: 42.481 | Ki: 25.000 | Kd: 11.132 | Loss: 2161262.500000
# Time: 135.79s | Desired: 6000.00 RPM | Measured: 4194.00 RPM | Error: 1806.00 RPM | PWM: 1512427.718597412 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1011226.562500
# Time: 136.84s | Desired: 6000.00 RPM | Measured: 4989.00 RPM | Error: 1011.00 RPM | PWM: 30675.0 | Kp: 40.320 | Ki: 0.000 | Kd: 0.000 | Loss: 404901.406250
# Time: 137.87s | Desired: 6000.00 RPM | Measured: 5115.00 RPM | Error: 885.00 RPM | PWM: 35683.48331451416 | Kp: 12.504 | Ki: 0.000 | Kd: 0.000 | Loss: 1593963.000000
# Time: 138.92s | Desired: 6000.00 RPM | Measured: 4023.00 RPM | Error: 1977.00 RPM | PWM: 24720.37160396576 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 253408.187500
# Time: 139.95s | Desired: 6000.00 RPM | Measured: 4917.00 RPM | Error: 1083.00 RPM | PWM: 0.0 | Kp: 38.491 | Ki: 17.279 | Kd: 19.826 | Loss: 438971.031250
# Time: 141.00s | Desired: 6000.00 RPM | Measured: 5121.00 RPM | Error: 879.00 RPM | PWM: 1030958.2904205322 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1098917.500000
# Time: 142.04s | Desired: 6000.00 RPM | Measured: 5129.00 RPM | Error: 871.00 RPM | PWM: 43350.0 | Kp: 38.266 | Ki: 0.000 | Kd: 25.000 | Loss: 129986.210938
# Time: 143.08s | Desired: 6000.00 RPM | Measured: 5136.00 RPM | Error: 864.00 RPM | PWM: 32886.519775390625 | Kp: 40.671 | Ki: 0.000 | Kd: 18.391 | Loss: 357192.500000
# Time: 144.10s | Desired: 6000.00 RPM | Measured: 4873.00 RPM | Error: 1127.00 RPM | PWM: 50673.13916015625 | Kp: 17.680 | Ki: 0.000 | Kd: 0.000 | Loss: 766194.000000
# Time: 145.15s | Desired: 6000.00 RPM | Measured: 5083.00 RPM | Error: 917.00 RPM | PWM: 16212.21222114563 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 152440.328125
# Time: 146.18s | Desired: 6000.00 RPM | Measured: 5124.00 RPM | Error: 876.00 RPM | PWM: 0.0 | Kp: 37.243 | Ki: 22.958 | Kd: 25.000 | Loss: 145115.968750
# Time: 147.24s | Desired: 6000.00 RPM | Measured: 5138.00 RPM | Error: 862.00 RPM | PWM: 1306997.9471378326 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 572324.000000
# Time: 148.28s | Desired: 6000.00 RPM | Measured: 5143.00 RPM | Error: 857.00 RPM | PWM: 42725.0 | Kp: 36.930 | Ki: 0.000 | Kd: 25.000 | Loss: 177017.890625
# Time: 149.30s | Desired: 6000.00 RPM | Measured: 5162.00 RPM | Error: 838.00 RPM | PWM: 30472.202796936035 | Kp: 38.774 | Ki: 0.000 | Kd: 25.000 | Loss: 68710.609375
# Time: 150.36s | Desired: 6000.00 RPM | Measured: 5079.00 RPM | Error: 921.00 RPM | PWM: 37785.48701095581 | Kp: 34.980 | Ki: 0.000 | Kd: 25.000 | Loss: 388958.750000
# Time: 151.39s | Desired: 6000.00 RPM | Measured: 5127.00 RPM | Error: 873.00 RPM | PWM: 29337.27984237671 | Kp: 21.681 | Ki: 0.000 | Kd: 25.000 | Loss: 198343.859375
# Time: 152.42s | Desired: 6000.00 RPM | Measured: 5125.00 RPM | Error: 875.00 RPM | PWM: 19021.226930618286 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 12400.860352
# Time: 153.46s | Desired: 6000.00 RPM | Measured: 3900.00 RPM | Error: 2100.00 RPM | PWM: 30625.0 | Kp: 33.520 | Ki: 0.000 | Kd: 25.000 | Loss: 239611.328125
# Time: 154.50s | Desired: 6000.00 RPM | Measured: 4957.00 RPM | Error: 1043.00 RPM | PWM: 8536.710605621338 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 203880.984375
# Time: 155.53s | Desired: 6000.00 RPM | Measured: 4350.00 RPM | Error: 1650.00 RPM | PWM: 15175.0 | Kp: 0.000 | Ki: 0.000 | Kd: 25.000 | Loss: 10987.622070
# Time: 156.57s | Desired: 6000.00 RPM | Measured: 5031.00 RPM | Error: 969.00 RPM | PWM: -17025.0 | Kp: 50.000 | Ki: 25.000 | Kd: 10.510 | Loss: 131848.765625
# Time: 157.63s | Desired: 6000.00 RPM | Measured: 5145.00 RPM | Error: 855.00 RPM | PWM: 1423326.8248577118 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 201969.015625
# Time: 158.66s | Desired: 6000.00 RPM | Measured: 4379.00 RPM | Error: 1621.00 RPM | PWM: 1381425.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 21378.732422
# Time: 159.70s | Desired: 6000.00 RPM | Measured: 5001.00 RPM | Error: 999.00 RPM | PWM: 1373850.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 131687.843750
# Time: 160.74s | Desired: 6000.00 RPM | Measured: 5126.00 RPM | Error: 874.00 RPM | PWM: 40575.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 148760.859375
# Time: 161.77s | Desired: 6000.00 RPM | Measured: 5123.00 RPM | Error: 877.00 RPM | PWM: 43925.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 13430.314453
# Time: 162.82s | Desired: 6000.00 RPM | Measured: 5123.00 RPM | Error: 877.00 RPM | PWM: 43850.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 130978.718750
# Time: 163.85s | Desired: 6000.00 RPM | Measured: 5090.00 RPM | Error: 910.00 RPM | PWM: 46325.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 66162.757812
# Time: 164.88s | Desired: 6000.00 RPM | Measured: 5046.00 RPM | Error: 954.00 RPM | PWM: 48800.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 24255.876953
# Time: 165.92s | Desired: 6000.00 RPM | Measured: 5085.00 RPM | Error: 915.00 RPM | PWM: 44775.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 112190.000000
# Time: 166.96s | Desired: 6000.00 RPM | Measured: 5117.00 RPM | Error: 883.00 RPM | PWM: 43350.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 27051.810547
# Time: 168.00s | Desired: 6000.00 RPM | Measured: 5102.00 RPM | Error: 898.00 RPM | PWM: 45275.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 53237.234375
# Time: 169.05s | Desired: 6000.00 RPM | Measured: 5153.00 RPM | Error: 847.00 RPM | PWM: 41075.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 78712.101562
# Time: 170.08s | Desired: 6000.00 RPM | Measured: 5201.00 RPM | Error: 799.00 RPM | PWM: 38750.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 11046.783203
# Time: 171.12s | Desired: 6000.00 RPM | Measured: 5199.00 RPM | Error: 801.00 RPM | PWM: 40100.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 51411.589844
# Time: 172.16s | Desired: 6000.00 RPM | Measured: 5206.00 RPM | Error: 794.00 RPM | PWM: 39525.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 43263.320312
# Time: 173.19s | Desired: 6000.00 RPM | Measured: 5189.00 RPM | Error: 811.00 RPM | PWM: 40975.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 7372.674805
# Time: 174.24s | Desired: 6000.00 RPM | Measured: 5178.00 RPM | Error: 822.00 RPM | PWM: 41375.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 40075.015625
# Time: 175.27s | Desired: 6000.00 RPM | Measured: 5232.00 RPM | Error: 768.00 RPM | PWM: 37050.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 28306.886719
# Time: 176.31s | Desired: 6000.00 RPM | Measured: 5259.00 RPM | Error: 741.00 RPM | PWM: 36375.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 6183.304688
# Time: 177.36s | Desired: 6000.00 RPM | Measured: 5294.00 RPM | Error: 706.00 RPM | PWM: 34425.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 19949.658203
# Time: 178.39s | Desired: 6000.00 RPM | Measured: 5253.00 RPM | Error: 747.00 RPM | PWM: 38375.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 25485.169922
# Time: 179.44s | Desired: 6000.00 RPM | Measured: 5236.00 RPM | Error: 764.00 RPM | PWM: 38625.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 7372.858398
# Time: 180.47s | Desired: 6000.00 RPM | Measured: 5222.00 RPM | Error: 778.00 RPM | PWM: 39250.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 7459.166504
# Time: 181.52s | Desired: 6000.00 RPM | Measured: 5207.00 RPM | Error: 793.00 RPM | PWM: 40025.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 18487.054688
# Time: 182.55s | Desired: 6000.00 RPM | Measured: 5227.00 RPM | Error: 773.00 RPM | PWM: 38150.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 13099.296875
# Time: 183.59s | Desired: 6000.00 RPM | Measured: 5225.00 RPM | Error: 775.00 RPM | PWM: 38800.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 4155.275391
# Time: 184.63s | Desired: 6000.00 RPM | Measured: 5212.00 RPM | Error: 788.00 RPM | PWM: 39725.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 6661.260254
# Time: 185.67s | Desired: 6000.00 RPM | Measured: 5184.00 RPM | Error: 816.00 RPM | PWM: 41500.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 13045.250000
# Time: 186.71s | Desired: 6000.00 RPM | Measured: 5168.00 RPM | Error: 832.00 RPM | PWM: 42000.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 7526.109863
# Time: 187.74s | Desired: 6000.00 RPM | Measured: 5149.00 RPM | Error: 851.00 RPM | PWM: 43025.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 2497.111572
# Time: 188.77s | Desired: 6000.00 RPM | Measured: 5141.00 RPM | Error: 859.00 RPM | PWM: 43150.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 4964.729004
# Time: 189.82s | Desired: 6000.00 RPM | Measured: 5149.00 RPM | Error: 851.00 RPM | PWM: 42350.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 8424.851562
# Time: 190.86s | Desired: 6000.00 RPM | Measured: 5189.00 RPM | Error: 811.00 RPM | PWM: 39550.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 5516.316895
# Time: 191.89s | Desired: 6000.00 RPM | Measured: 5174.00 RPM | Error: 826.00 RPM | PWM: 41675.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1842.845459
# Time: 192.94s | Desired: 6000.00 RPM | Measured: 5173.00 RPM | Error: 827.00 RPM | PWM: 41375.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 2430.924072
# Time: 193.98s | Desired: 6000.00 RPM | Measured: 5199.00 RPM | Error: 801.00 RPM | PWM: 39400.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 4956.711426
# Time: 195.02s | Desired: 6000.00 RPM | Measured: 5172.00 RPM | Error: 828.00 RPM | PWM: 42075.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 4628.832031
# Time: 196.05s | Desired: 6000.00 RPM | Measured: 5201.00 RPM | Error: 799.00 RPM | PWM: 39225.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1823.243164
# Time: 197.09s | Desired: 6000.00 RPM | Measured: 5090.00 RPM | Error: 910.00 RPM | PWM: 48275.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 932.952698
# Time: 198.13s | Desired: 6000.00 RPM | Measured: 5079.00 RPM | Error: 921.00 RPM | PWM: 46325.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 2348.719238
# Time: 199.17s | Desired: 6000.00 RPM | Measured: 5089.00 RPM | Error: 911.00 RPM | PWM: 45300.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 2555.391602
# Time: 200.20s | Desired: 6000.00 RPM | Measured: 5096.00 RPM | Error: 904.00 RPM | PWM: 45025.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1863.685669
# Time: 201.25s | Desired: 6000.00 RPM | Measured: 5079.00 RPM | Error: 921.00 RPM | PWM: 46475.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 714.701782
# Time: 202.29s | Desired: 6000.00 RPM | Measured: 5095.00 RPM | Error: 905.00 RPM | PWM: 44850.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 511.570831
# Time: 203.33s | Desired: 6000.00 RPM | Measured: 5101.00 RPM | Error: 899.00 RPM | PWM: 44800.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1039.822754
# Time: 204.37s | Desired: 6000.00 RPM | Measured: 5059.00 RPM | Error: 941.00 RPM | PWM: 48100.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1402.839966
# Time: 205.41s | Desired: 6000.00 RPM | Measured: 5055.00 RPM | Error: 945.00 RPM | PWM: 47350.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 1032.051147
# Time: 206.44s | Desired: 6000.00 RPM | Measured: 5064.00 RPM | Error: 936.00 RPM | PWM: 46575.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 329.641174
# Time: 207.48s | Desired: 6000.00 RPM | Measured: 5054.00 RPM | Error: 946.00 RPM | PWM: 47550.0 | Kp: 47.804 | Ki: 0.000 | Kd: 25.000 | Loss: 155.878906
# Time: 208.52s | Desired: 6000.00 RPM | Measured: 5080.00 RPM | Error: 920.00 RPM | PWM: 43329.64569091797 | Kp: 48.504 | Ki: 0.000 | Kd: 25.000 | Loss: 524.789246
# Time: 209.56s | Desired: 6000.00 RPM | Measured: 4656.00 RPM | Error: 1344.00 RPM | PWM: 75789.79858398438 | Kp: 35.607 | Ki: 0.000 | Kd: 25.000 | Loss: 527.638428
# Time: 210.59s | Desired: 6000.00 RPM | Measured: 3864.00 RPM | Error: 2136.00 RPM | PWM: 95856.10052490234 | Kp: 20.056 | Ki: 0.000 | Kd: 25.000 | Loss: 314.283691
# Time: 211.62s | Desired: 6000.00 RPM | Measured: 4930.00 RPM | Error: 1070.00 RPM | PWM: -5190.153732299805 | Kp: 40.314 | Ki: 0.000 | Kd: 0.000 | Loss: 47.158409
# Time: 212.68s | Desired: 6000.00 RPM | Measured: 5099.00 RPM | Error: 901.00 RPM | PWM: 36323.32913970947 | Kp: 50.000 | Ki: 2.760 | Kd: 25.000 | Loss: 47.131443
# Time: 213.71s | Desired: 6000.00 RPM | Measured: 4176.00 RPM | Error: 1824.00 RPM | PWM: 236894.16255569458 | Kp: 32.482 | Ki: 0.000 | Kd: 25.000 | Loss: 69.870247
# Time: 214.76s | Desired: 6000.00 RPM | Measured: 4044.00 RPM | Error: 1956.00 RPM | PWM: 66835.49034118652 | Kp: 31.799 | Ki: 0.000 | Kd: 25.000 | Loss: 82.804962
# Time: 215.79s | Desired: 6000.00 RPM | Measured: 4286.00 RPM | Error: 1714.00 RPM | PWM: 48452.6487197876 | Kp: 37.792 | Ki: 0.000 | Kd: 25.000 | Loss: 88.562714
# Time: 216.84s | Desired: 6000.00 RPM | Measured: 4994.00 RPM | Error: 1006.00 RPM | PWM: 20318.29898071289 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 120.417542
# Time: 217.88s | Desired: 6000.00 RPM | Measured: 4145.00 RPM | Error: 1855.00 RPM | PWM: 0.0 | Kp: 47.874 | Ki: 25.000 | Kd: 15.097 | Loss: 122.422119
# Time: 218.92s | Desired: 6000.00 RPM | Measured: 4971.00 RPM | Error: 1029.00 RPM | PWM: 1243141.7243328094 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 211.967224
# Time: 219.96s | Desired: 6000.00 RPM | Measured: 4065.00 RPM | Error: 1935.00 RPM | PWM: 1306750.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 209.680176
# Time: 220.99s | Desired: 6000.00 RPM | Measured: 4916.00 RPM | Error: 1084.00 RPM | PWM: 1290125.0 | Kp: 50.000 | Ki: 9.044 | Kd: 0.000 | Loss: 130.947662
# Time: 222.03s | Desired: 6000.00 RPM | Measured: 5076.00 RPM | Error: 924.00 RPM | PWM: 495476.0367050171 | Kp: 10.377 | Ki: 0.000 | Kd: 25.000 | Loss: 265.925018
# Time: 223.07s | Desired: 6000.00 RPM | Measured: 5048.00 RPM | Error: 952.00 RPM | PWM: 10578.865730285645 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 242.246933
# Time: 224.10s | Desired: 6000.00 RPM | Measured: 5031.00 RPM | Error: 969.00 RPM | PWM: 0.0 | Kp: 50.000 | Ki: 25.000 | Kd: 16.731 | Loss: 202.208160
# Time: 225.14s | Desired: 6000.00 RPM | Measured: 5044.00 RPM | Error: 956.00 RPM | PWM: 1300707.4975585938 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 322.465179
# Time: 226.19s | Desired: 6000.00 RPM | Measured: 3990.00 RPM | Error: 2010.00 RPM | PWM: 1357250.0 | Kp: 39.702 | Ki: 25.000 | Kd: 0.000 | Loss: 190.872818
# Time: 227.22s | Desired: 6000.00 RPM | Measured: 4882.00 RPM | Error: 1118.00 RPM | PWM: 1330836.3835525513 | Kp: 0.000 | Ki: 5.737 | Kd: 0.000 | Loss: 331.419708
# Time: 228.25s | Desired: 6000.00 RPM | Measured: 3889.00 RPM | Error: 2111.00 RPM | PWM: 297209.08114624023 | Kp: 20.802 | Ki: 0.000 | Kd: 25.000 | Loss: 237.782455
# Time: 229.31s | Desired: 6000.00 RPM | Measured: 3807.00 RPM | Error: 2193.00 RPM | PWM: 47668.982692718506 | Kp: 25.502 | Ki: 0.000 | Kd: 25.000 | Loss: 319.008453
# Time: 230.35s | Desired: 6000.00 RPM | Measured: 4950.00 RPM | Error: 1050.00 RPM | PWM: -1797.7849960327148 | Kp: 50.000 | Ki: 25.000 | Kd: 15.532 | Loss: 283.874725
# Time: 231.37s | Desired: 6000.00 RPM | Measured: 5158.00 RPM | Error: 842.00 RPM | PWM: 1413069.416091919 | Kp: 24.371 | Ki: 22.214 | Kd: 0.000 | Loss: 251.146042
# Time: 232.43s | Desired: 6000.00 RPM | Measured: 4847.00 RPM | Error: 1153.00 RPM | PWM: 1250873.8787899017 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 348.523376
# Time: 233.46s | Desired: 6000.00 RPM | Measured: 5044.00 RPM | Error: 956.00 RPM | PWM: 1433325.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 324.817902
# Time: 234.50s | Desired: 6000.00 RPM | Measured: 5067.00 RPM | Error: 933.00 RPM | PWM: 1389600.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.112 | Loss: 266.160706
# Time: 235.54s | Desired: 6000.00 RPM | Measured: 5090.00 RPM | Error: 910.00 RPM | PWM: 1439097.422939524 | Kp: 33.928 | Ki: 17.335 | Kd: 0.000 | Loss: 250.226120
# Time: 236.57s | Desired: 6000.00 RPM | Measured: 5089.00 RPM | Error: 911.00 RPM | PWM: 999574.2093524933 | Kp: 38.585 | Ki: 0.000 | Kd: 15.577 | Loss: 236.175491
# Time: 237.61s | Desired: 6000.00 RPM | Measured: 5046.00 RPM | Error: 954.00 RPM | PWM: 37479.570152282715 | Kp: 48.449 | Ki: 9.514 | Kd: 19.436 | Loss: 240.369171
# Time: 238.65s | Desired: 6000.00 RPM | Measured: 4017.00 RPM | Error: 1983.00 RPM | PWM: 650194.6742401123 | Kp: 23.800 | Ki: 0.000 | Kd: 25.000 | Loss: 240.256302
# Time: 239.69s | Desired: 6000.00 RPM | Measured: 4994.00 RPM | Error: 1006.00 RPM | PWM: -482.52888107299805 | Kp: 50.000 | Ki: 25.000 | Kd: 18.295 | Loss: 248.949875
# Time: 240.72s | Desired: 6000.00 RPM | Measured: 4610.00 RPM | Error: 1390.00 RPM | PWM: 1512675.1196289062 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 324.713867
# Time: 241.77s | Desired: 6000.00 RPM | Measured: 5071.00 RPM | Error: 929.00 RPM | PWM: 1495875.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 1214.645020
# Time: 242.81s | Desired: 6000.00 RPM | Measured: 5196.00 RPM | Error: 804.00 RPM | PWM: 0.0 | Kp: 50.000 | Ki: 25.000 | Kd: 17.524 | Loss: 15097.193359
# Time: 243.84s | Desired: 6000.00 RPM | Measured: 5145.00 RPM | Error: 855.00 RPM | PWM: 1494843.7269268036 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 260399.281250
# Time: 244.89s | Desired: 6000.00 RPM | Measured: 4582.00 RPM | Error: 1418.00 RPM | PWM: 0.0 | Kp: 50.000 | Ki: 25.000 | Kd: 17.602 | Loss: 4533968.000000
# Time: 245.93s | Desired: 6000.00 RPM | Measured: 5011.00 RPM | Error: 989.00 RPM | PWM: 1508598.6293888092 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 25840198.000000
# Time: 246.96s | Desired: 6000.00 RPM | Measured: 4792.00 RPM | Error: 1208.00 RPM | PWM: 0.0 | Kp: 50.000 | Ki: 25.000 | Kd: 17.990 | Loss: 20906224.000000
# Time: 248.00s | Desired: 6000.00 RPM | Measured: 5089.00 RPM | Error: 911.00 RPM | PWM: 1521107.0114212036 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 5527939.500000
# Time: 249.04s | Desired: 6000.00 RPM | Measured: 5108.00 RPM | Error: 892.00 RPM | PWM: 1528300.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 22901582.000000
# Time: 250.08s | Desired: 6000.00 RPM | Measured: 5084.00 RPM | Error: 916.00 RPM | PWM: 0.0 | Kp: 50.000 | Ki: 25.000 | Kd: 16.571 | Loss: 1617479.875000
# Time: 251.12s | Desired: 6000.00 RPM | Measured: 5092.00 RPM | Error: 908.00 RPM | PWM: 1528392.4308166504 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 18213360.000000
# Time: 252.16s | Desired: 6000.00 RPM | Measured: 4011.00 RPM | Error: 1989.00 RPM | PWM: 1609525.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 2760212.500000
# Time: 253.19s | Desired: 6000.00 RPM | Measured: 4986.00 RPM | Error: 1014.00 RPM | PWM: 1560875.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 11838133.000000
# Time: 254.24s | Desired: 6000.00 RPM | Measured: 5126.00 RPM | Error: 874.00 RPM | PWM: 0.0 | Kp: 50.000 | Ki: 25.000 | Kd: 17.246 | Loss: 5493867.000000
# Time: 255.27s | Desired: 6000.00 RPM | Measured: 5130.00 RPM | Error: 870.00 RPM | PWM: 1555156.0176467896 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 4808746.000000
# Time: 256.32s | Desired: 6000.00 RPM | Measured: 5130.00 RPM | Error: 870.00 RPM | PWM: 1554500.0 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 7181485.000000
# Time: 257.36s | Desired: 6000.00 RPM | Measured: 5120.00 RPM | Error: 880.00 RPM | PWM: 1553225.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 2789655.500000
# Time: 258.39s | Desired: 6000.00 RPM | Measured: 5130.00 RPM | Error: 870.00 RPM | PWM: 1507600.0 | Kp: 0.000 | Ki: 0.000 | Kd: 16.196 | Loss: 5769506.500000
# Time: 259.44s | Desired: 6000.00 RPM | Measured: 5132.00 RPM | Error: 868.00 RPM | PWM: -32.39167785644531 | Kp: 50.000 | Ki: 25.000 | Kd: 19.866 | Loss: 2370578.250000
# Time: 260.47s | Desired: 6000.00 RPM | Measured: 4605.00 RPM | Error: 1395.00 RPM | PWM: 1584219.368522644 | Kp: 50.000 | Ki: 25.000 | Kd: 0.000 | Loss: 4761130.000000
# Time: 261.52s | Desired: 6000.00 RPM | Measured: 4485.00 RPM | Error: 1515.00 RPM | PWM: 1591625.0 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 1396368.750000
# Time: 262.55s | Desired: 6000.00 RPM | Measured: 5046.00 RPM | Error: 954.00 RPM | PWM: 1553825.0 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 3867833.250000
# Time: 263.59s | Desired: 6000.00 RPM | Measured: 5128.00 RPM | Error: 872.00 RPM | PWM: 1488550.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 2299184.250000
# Time: 264.65s | Desired: 6000.00 RPM | Measured: 5123.00 RPM | Error: 877.00 RPM | PWM: 0.0 | Kp: 49.925 | Ki: 25.000 | Kd: 20.981 | Loss: 1000127.375000
# Time: 265.68s | Desired: 6000.00 RPM | Measured: 5106.00 RPM | Error: 894.00 RPM | PWM: 1530039.8893623352 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 3652953.500000
# Time: 266.72s | Desired: 6000.00 RPM | Measured: 5127.00 RPM | Error: 873.00 RPM | PWM: 1504925.0 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 402818.343750
# Time: 267.76s | Desired: 6000.00 RPM | Measured: 5141.00 RPM | Error: 859.00 RPM | PWM: 1477325.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 1717526.000000
# Time: 268.79s | Desired: 6000.00 RPM | Measured: 5130.00 RPM | Error: 870.00 RPM | PWM: 0.0 | Kp: 45.758 | Ki: 25.000 | Kd: 19.687 | Loss: 2103365.000000
# Time: 269.83s | Desired: 6000.00 RPM | Measured: 5124.00 RPM | Error: 876.00 RPM | PWM: 1450151.7642669678 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 221007.734375
# Time: 270.88s | Desired: 6000.00 RPM | Measured: 5133.00 RPM | Error: 867.00 RPM | PWM: 1385250.0 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 1445436.375000
# Time: 271.91s | Desired: 6000.00 RPM | Measured: 5135.00 RPM | Error: 865.00 RPM | PWM: 1424625.0 | Kp: 50.000 | Ki: 0.000 | Kd: 0.000 | Loss: 1097894.625000
# Time: 272.94s | Desired: 6000.00 RPM | Measured: 5137.00 RPM | Error: 863.00 RPM | PWM: 43150.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 507757.906250
# Time: 273.98s | Desired: 6000.00 RPM | Measured: 5143.00 RPM | Error: 857.00 RPM | PWM: 0.0 | Kp: 45.511 | Ki: 25.000 | Kd: 18.082 | Loss: 737959.812500
# Time: 275.02s | Desired: 6000.00 RPM | Measured: 5139.00 RPM | Error: 861.00 RPM | PWM: 1386732.5390434265 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 754308.125000
# Time: 276.07s | Desired: 6000.00 RPM | Measured: 3874.00 RPM | Error: 2126.00 RPM | PWM: 1376825.0 | Kp: 13.803 | Ki: 25.000 | Kd: 0.000 | Loss: 686889.125000
# Time: 277.09s | Desired: 6000.00 RPM | Measured: 4951.00 RPM | Error: 1049.00 RPM | PWM: 1388604.4215021133 | Kp: 50.000 | Ki: 25.000 | Kd: 25.000 | Loss: 183981.687500
# Time: 278.14s | Desired: 6000.00 RPM | Measured: 4781.00 RPM | Error: 1219.00 RPM | PWM: 1441650.0 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 661512.187500
# Time: 279.17s | Desired: 6000.00 RPM | Measured: 5129.00 RPM | Error: 871.00 RPM | PWM: 34850.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 577711.937500
# Time: 280.23s | Desired: 6000.00 RPM | Measured: 5183.00 RPM | Error: 817.00 RPM | PWM: 0.0 | Kp: 47.741 | Ki: 25.000 | Kd: 18.633 | Loss: 29546.396484
# Time: 281.25s | Desired: 6000.00 RPM | Measured: 5177.00 RPM | Error: 823.00 RPM | PWM: 1357552.9639968872 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 423328.843750
# Time: 282.30s | Desired: 6000.00 RPM | Measured: 4478.00 RPM | Error: 1522.00 RPM | PWM: 1301375.0 | Kp: 0.000 | Ki: 25.000 | Kd: 25.000 | Loss: 479153.125000
# Time: 283.33s | Desired: 6000.00 RPM | Measured: 5026.00 RPM | Error: 974.00 RPM | PWM: 1282000.0 | Kp: 0.000 | Ki: 25.000 | Kd: 0.000 | Loss: 64442.933594
# Time: 284.37s | Desired: 6000.00 RPM | Measured: 5159.00 RPM | Error: 841.00 RPM | PWM: 1299000.0 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 266246.625000
# Time: 285.41s | Desired: 6000.00 RPM | Measured: 5189.00 RPM | Error: 811.00 RPM | PWM: 0.0 | Kp: 49.567 | Ki: 25.000 | Kd: 19.602 | Loss: 258143.578125
# Time: 286.44s | Desired: 6000.00 RPM | Measured: 5173.00 RPM | Error: 827.00 RPM | PWM: 1328880.7180023193 | Kp: 50.000 | Ki: 0.000 | Kd: 25.000 | Loss: 185971.625000
# Time: 287.49s | Desired: 6000.00 RPM | Measured: 3947.00 RPM | Error: 2053.00 RPM | PWM: 133300.0 | Kp: 50.000 | Ki: 16.073 | Kd: 25.000 | Loss: 142197.234375
# ...
# Time: 400.81s | Desired: 6000.00 RPM | Measured: 4027.00 RPM | Error: 1973.00 RPM | PWM: 6176.855584740639 | Kp: 18.683 | Ki: 15.325 | Kd: 16.814 | Loss: 294.181549
# Time: 401.84s | Desired: 6000.00 RPM | Measured: 4805.00 RPM | Error: 1195.00 RPM | PWM: 788493.4723739624 | Kp: 13.403 | Ki: 0.000 | Kd: 25.000 | Loss: 299.404388
# Time: 402.89s | Desired: 6000.00 RPM | Measured: 5282.00 RPM | Error: 718.00 RPM | PWM: -2301.820695877075 | Kp: 50.000 | Ki: 25.000 | Kd: 7.926 | Loss: 197.905731
# Time: 403.93s | Desired: 6000.00 RPM | Measured: 4667.00 RPM | Error: 1333.00 RPM | PWM: 1347249.3152928352 | Kp: 24.369 | Ki: 25.000 | Kd: 0.000 | Loss: 274.136139
# Time: 404.97s | Desired: 6000.00 RPM | Measured: 5290.00 RPM | Error: 710.00 RPM | PWM: 1295277.092552185 | Kp: 29.915 | Ki: 25.000 | Kd: 0.000 | Loss: 217.697311
# Time: 406.00s | Desired: 6000.00 RPM | Measured: 4797.00 RPM | Error: 1203.00 RPM | PWM: 1314037.8424720764 | Kp: 29.186 | Ki: 25.000 | Kd: 17.806 | Loss: 183.787247
# Time: 407.04s | Desired: 6000.00 RPM | Measured: 4993.00 RPM | Error: 1007.00 RPM | PWM: 1318900.5321121216 | Kp: 29.812 | Ki: 25.000 | Kd: 25.000 | Loss: 236.391693
# Time: 408.08s | Desired: 6000.00 RPM | Measured: 5326.00 RPM | Error: 674.00 RPM | PWM: 1314893.3678894043 | Kp: 31.035 | Ki: 25.000 | Kd: 17.695 | Loss: 183.301971
# Time: 409.12s | Desired: 6000.00 RPM | Measured: 4151.00 RPM | Error: 1849.00 RPM | PWM: 1383001.2564086914 | Kp: 27.114 | Ki: 25.000 | Kd: 2.186 | Loss: 180.408340
# Time: 410.16s | Desired: 6000.00 RPM | Measured: 5204.00 RPM | Error: 796.00 RPM | PWM: 1346306.2461903095 | Kp: 27.663 | Ki: 25.000 | Kd: 0.000 | Loss: 205.991776
# Time: 411.20s | Desired: 6000.00 RPM | Measured: 5382.00 RPM | Error: 618.00 RPM | PWM: 1347995.5949745178 | Kp: 24.402 | Ki: 25.000 | Kd: 2.508 | Loss: 156.356857
# Time: 412.23s | Desired: 6000.00 RPM | Measured: 5380.00 RPM | Error: 620.00 RPM | PWM: 1346609.289405346 | Kp: 22.473 | Ki: 25.000 | Kd: 19.294 | Loss: 184.934875
# Time: 413.28s | Desired: 6000.00 RPM | Measured: 5426.00 RPM | Error: 574.00 RPM | PWM: 1312387.1770515442 | Kp: 24.454 | Ki: 25.000 | Kd: 15.535 | Loss: 167.049500
# Time: 414.30s | Desired: 6000.00 RPM | Measured: 5457.00 RPM | Error: 543.00 RPM | PWM: 1306747.1421079636 | Kp: 28.258 | Ki: 25.000 | Kd: 0.000 | Loss: 162.412781
# Time: 415.35s | Desired: 6000.00 RPM | Measured: 5498.00 RPM | Error: 502.00 RPM | PWM: 1294510.3175086975 | Kp: 29.838 | Ki: 25.000 | Kd: 0.000 | Loss: 172.945465
# Time: 416.40s | Desired: 6000.00 RPM | Measured: 5492.00 RPM | Error: 508.00 RPM | PWM: 1280482.805404663 | Kp: 28.448 | Ki: 22.826 | Kd: 8.565 | Loss: 144.899963
# Time: 417.43s | Desired: 6000.00 RPM | Measured: 4209.00 RPM | Error: 1791.00 RPM | PWM: 1213159.4993982315 | Kp: 21.873 | Ki: 17.985 | Kd: 25.000 | Loss: 162.925842
# Time: 418.48s | Desired: 6000.00 RPM | Measured: 4883.00 RPM | Error: 1117.00 RPM | PWM: 935151.1579971313 | Kp: 21.845 | Ki: 4.768 | Kd: 16.436 | Loss: 121.544594
# Time: 419.51s | Desired: 6000.00 RPM | Measured: 4208.00 RPM | Error: 1792.00 RPM | PWM: 298295.6494503021 | Kp: 14.374 | Ki: 0.000 | Kd: 25.000 | Loss: 141.460846
# Time: 420.55s | Desired: 6000.00 RPM | Measured: 4375.00 RPM | Error: 1625.00 RPM | PWM: 19183.24680328369 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 176.083542
# Time: 421.59s | Desired: 6000.00 RPM | Measured: 5165.00 RPM | Error: 835.00 RPM | PWM: 0.0 | Kp: 46.751 | Ki: 24.422 | Kd: 22.686 | Loss: 174.128510
# Time: 422.63s | Desired: 6000.00 RPM | Measured: 5255.00 RPM | Error: 745.00 RPM | PWM: 1358023.8825435638 | Kp: 22.654 | Ki: 25.000 | Kd: 16.068 | Loss: 172.998703
# Time: 423.67s | Desired: 6000.00 RPM | Measured: 4032.00 RPM | Error: 1968.00 RPM | PWM: 1408684.3186969757 | Kp: 21.492 | Ki: 25.000 | Kd: 11.548 | Loss: 156.295807
# Time: 424.71s | Desired: 6000.00 RPM | Measured: 4120.00 RPM | Error: 1880.00 RPM | PWM: 1380564.1135101318 | Kp: 24.859 | Ki: 25.000 | Kd: 4.773 | Loss: 166.429092
# Time: 425.75s | Desired: 6000.00 RPM | Measured: 4429.00 RPM | Error: 1571.00 RPM | PWM: 1382028.6302423477 | Kp: 27.672 | Ki: 25.000 | Kd: 11.261 | Loss: 151.741821
# Time: 426.79s | Desired: 6000.00 RPM | Measured: 4104.00 RPM | Error: 1896.00 RPM | PWM: 1418400.8389692307 | Kp: 27.290 | Ki: 25.000 | Kd: 22.737 | Loss: 162.933167
# Time: 427.82s | Desired: 6000.00 RPM | Measured: 5073.00 RPM | Error: 927.00 RPM | PWM: 1395341.0977249146 | Kp: 30.182 | Ki: 25.000 | Kd: 11.894 | Loss: 117.380173
# Time: 428.87s | Desired: 6000.00 RPM | Measured: 5225.00 RPM | Error: 775.00 RPM | PWM: 1418632.9761676788 | Kp: 29.666 | Ki: 25.000 | Kd: 0.358 | Loss: 120.804413
# Time: 429.91s | Desired: 6000.00 RPM | Measured: 4235.00 RPM | Error: 1765.00 RPM | PWM: 1453190.123771429 | Kp: 23.578 | Ki: 25.000 | Kd: 8.148 | Loss: 114.144196
# Time: 430.95s | Desired: 6000.00 RPM | Measured: 5035.00 RPM | Error: 965.00 RPM | PWM: 1444559.5944404602 | Kp: 23.273 | Ki: 25.000 | Kd: 13.175 | Loss: 115.208046
# Time: 431.98s | Desired: 6000.00 RPM | Measured: 4195.00 RPM | Error: 1805.00 RPM | PWM: 1489099.5156002045 | Kp: 20.948 | Ki: 25.000 | Kd: 18.342 | Loss: 110.637291
# Time: 433.01s | Desired: 6000.00 RPM | Measured: 3990.00 RPM | Error: 2010.00 RPM | PWM: 1510191.3812351227 | Kp: 24.244 | Ki: 25.000 | Kd: 9.128 | Loss: 102.740547
# Time: 434.06s | Desired: 6000.00 RPM | Measured: 5105.00 RPM | Error: 895.00 RPM | PWM: 1509321.2370872498 | Kp: 31.282 | Ki: 25.000 | Kd: 1.107 | Loss: 97.724884
# Time: 435.11s | Desired: 6000.00 RPM | Measured: 5319.00 RPM | Error: 681.00 RPM | PWM: 1514166.3936812878 | Kp: 32.485 | Ki: 25.000 | Kd: 9.149 | Loss: 94.695053
# Time: 436.14s | Desired: 6000.00 RPM | Measured: 5318.00 RPM | Error: 682.00 RPM | PWM: 1507213.6726579666 | Kp: 31.467 | Ki: 25.000 | Kd: 9.855 | Loss: 94.534203
# Time: 437.17s | Desired: 6000.00 RPM | Measured: 4056.00 RPM | Error: 1944.00 RPM | PWM: 1542508.4214839935 | Kp: 26.190 | Ki: 25.000 | Kd: 9.037 | Loss: 89.088150
# Time: 438.21s | Desired: 6000.00 RPM | Measured: 4105.00 RPM | Error: 1895.00 RPM | PWM: 1544436.7474479675 | Kp: 24.261 | Ki: 25.000 | Kd: 9.741 | Loss: 87.750526
# Time: 439.27s | Desired: 6000.00 RPM | Measured: 5107.00 RPM | Error: 893.00 RPM | PWM: 1510679.2774353027 | Kp: 25.965 | Ki: 25.000 | Kd: 11.365 | Loss: 91.081932
# Time: 440.31s | Desired: 6000.00 RPM | Measured: 4542.00 RPM | Error: 1458.00 RPM | PWM: 1543653.68211174 | Kp: 25.499 | Ki: 25.000 | Kd: 11.170 | Loss: 81.259750
# Time: 441.35s | Desired: 6000.00 RPM | Measured: 5103.00 RPM | Error: 897.00 RPM | PWM: 1533881.4587955475 | Kp: 29.385 | Ki: 25.000 | Kd: 2.364 | Loss: 82.816673
# Time: 442.38s | Desired: 6000.00 RPM | Measured: 5235.00 RPM | Error: 765.00 RPM | PWM: 1523017.6239004135 | Kp: 30.301 | Ki: 25.000 | Kd: 7.394 | Loss: 80.689301
# Time: 443.42s | Desired: 6000.00 RPM | Measured: 5255.00 RPM | Error: 745.00 RPM | PWM: 1503951.4783096313 | Kp: 30.397 | Ki: 25.000 | Kd: 8.492 | Loss: 79.091927
# Time: 444.46s | Desired: 6000.00 RPM | Measured: 4585.00 RPM | Error: 1415.00 RPM | PWM: 1527500.9351348877 | Kp: 28.231 | Ki: 25.000 | Kd: 6.139 | Loss: 78.322914
# Time: 445.50s | Desired: 6000.00 RPM | Measured: 4414.00 RPM | Error: 1586.00 RPM | PWM: 1541323.9297680855 | Kp: 25.622 | Ki: 25.000 | Kd: 11.764 | Loss: 72.958656
# Time: 446.54s | Desired: 6000.00 RPM | Measured: 4223.00 RPM | Error: 1777.00 RPM | PWM: 1565153.0795431137 | Kp: 23.788 | Ki: 25.000 | Kd: 15.489 | Loss: 76.110855
# Time: 447.59s | Desired: 6000.00 RPM | Measured: 4207.00 RPM | Error: 1793.00 RPM | PWM: 1579148.839794159 | Kp: 25.306 | Ki: 25.000 | Kd: 8.659 | Loss: 73.851227
# Time: 448.62s | Desired: 6000.00 RPM | Measured: 4535.00 RPM | Error: 1465.00 RPM | PWM: 1586983.3364925385 | Kp: 27.748 | Ki: 25.000 | Kd: 9.644 | Loss: 70.785294
# Time: 449.66s | Desired: 6000.00 RPM | Measured: 5221.00 RPM | Error: 779.00 RPM | PWM: 1554325.1721515656 | Kp: 30.104 | Ki: 25.000 | Kd: 8.939 | Loss: 72.939674
# Time: 450.70s | Desired: 6000.00 RPM | Measured: 4650.00 RPM | Error: 1350.00 RPM | PWM: 1567419.5771017075 | Kp: 28.231 | Ki: 25.000 | Kd: 6.187 | Loss: 71.472458
# Time: 451.74s | Desired: 6000.00 RPM | Measured: 5250.00 RPM | Error: 750.00 RPM | PWM: 1543535.8639717102 | Kp: 28.495 | Ki: 25.000 | Kd: 6.610 | Loss: 68.233139
# Time: 452.79s | Desired: 6000.00 RPM | Measured: 5297.00 RPM | Error: 703.00 RPM | PWM: 1521221.0239768028 | Kp: 28.118 | Ki: 25.000 | Kd: 7.368 | Loss: 68.657829
# Time: 453.82s | Desired: 6000.00 RPM | Measured: 5307.00 RPM | Error: 693.00 RPM | PWM: 1489161.8486299515 | Kp: 28.825 | Ki: 25.000 | Kd: 3.554 | Loss: 69.050629
# Time: 454.85s | Desired: 6000.00 RPM | Measured: 5458.00 RPM | Error: 542.00 RPM | PWM: 1472286.3954446316 | Kp: 29.188 | Ki: 24.319 | Kd: 7.776 | Loss: 68.300926
# Time: 455.90s | Desired: 6000.00 RPM | Measured: 5163.00 RPM | Error: 837.00 RPM | PWM: 1439972.2364974022 | Kp: 28.625 | Ki: 23.597 | Kd: 6.497 | Loss: 66.199333
# Time: 456.94s | Desired: 6000.00 RPM | Measured: 5367.00 RPM | Error: 633.00 RPM | PWM: 1376344.4702033997 | Kp: 28.500 | Ki: 20.382 | Kd: 7.882 | Loss: 64.246483
# Time: 457.98s | Desired: 6000.00 RPM | Measured: 4365.00 RPM | Error: 1635.00 RPM | PWM: 1227250.1321353912 | Kp: 22.981 | Ki: 15.114 | Kd: 17.549 | Loss: 64.075363
# Time: 459.03s | Desired: 6000.00 RPM | Measured: 4439.00 RPM | Error: 1561.00 RPM | PWM: 910769.6609354019 | Kp: 20.199 | Ki: 0.023 | Kd: 18.724 | Loss: 62.789928
# Time: 460.06s | Desired: 6000.00 RPM | Measured: 5176.00 RPM | Error: 824.00 RPM | PWM: 4165.557950086892 | Kp: 34.293 | Ki: 17.516 | Kd: 25.000 | Loss: 61.281029
# Time: 461.11s | Desired: 6000.00 RPM | Measured: 5294.00 RPM | Error: 706.00 RPM | PWM: 1049037.06325531 | Kp: 24.846 | Ki: 4.586 | Kd: 11.662 | Loss: 59.382343
# Time: 462.14s | Desired: 6000.00 RPM | Measured: 5278.00 RPM | Error: 722.00 RPM | PWM: 281971.54974746704 | Kp: 17.656 | Ki: 0.000 | Kd: 23.612 | Loss: 65.019257
# Time: 463.18s | Desired: 6000.00 RPM | Measured: 4960.00 RPM | Error: 1040.00 RPM | PWM: 25870.474796295166 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 83.366035
# Time: 464.22s | Desired: 6000.00 RPM | Measured: 5277.00 RPM | Error: 723.00 RPM | PWM: 0.0 | Kp: 47.504 | Ki: 22.098 | Kd: 21.831 | Loss: 81.814217
# Time: 465.26s | Desired: 6000.00 RPM | Measured: 5351.00 RPM | Error: 649.00 RPM | PWM: 1310512.2300987244 | Kp: 26.776 | Ki: 16.557 | Kd: 8.794 | Loss: 80.084808
# Time: 466.29s | Desired: 6000.00 RPM | Measured: 4581.00 RPM | Error: 1419.00 RPM | PWM: 1006024.6410198212 | Kp: 21.850 | Ki: 3.362 | Kd: 17.999 | Loss: 78.896561
# Time: 467.33s | Desired: 6000.00 RPM | Measured: 5232.00 RPM | Error: 768.00 RPM | PWM: 203172.39001464844 | Kp: 16.699 | Ki: 0.000 | Kd: 25.000 | Loss: 86.048630
# Time: 468.37s | Desired: 6000.00 RPM | Measured: 4921.00 RPM | Error: 1079.00 RPM | PWM: 25793.292388916016 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 103.580261
# Time: 469.42s | Desired: 6000.00 RPM | Measured: 5274.00 RPM | Error: 726.00 RPM | PWM: 0.0 | Kp: 48.015 | Ki: 22.633 | Kd: 22.450 | Loss: 102.164795
# Time: 470.45s | Desired: 6000.00 RPM | Measured: 5379.00 RPM | Error: 621.00 RPM | PWM: 1356130.0176067352 | Kp: 27.411 | Ki: 18.217 | Kd: 7.322 | Loss: 101.509148
# Time: 471.49s | Desired: 6000.00 RPM | Measured: 5439.00 RPM | Error: 561.00 RPM | PWM: 1075355.1392326355 | Kp: 25.025 | Ki: 4.704 | Kd: 11.995 | Loss: 94.947838
# Time: 472.53s | Desired: 6000.00 RPM | Measured: 4914.00 RPM | Error: 1086.00 RPM | PWM: 301526.7612147331 | Kp: 16.358 | Ki: 0.000 | Kd: 25.000 | Loss: 64.369202
# Time: 473.57s | Desired: 6000.00 RPM | Measured: 5053.00 RPM | Error: 947.00 RPM | PWM: 12015.870473861694 | Kp: 8.768 | Ki: 25.000 | Kd: 25.000 | Loss: 70.273949
# Time: 474.60s | Desired: 6000.00 RPM | Measured: 5238.00 RPM | Error: 762.00 RPM | PWM: 1415856.595796585 | Kp: 28.052 | Ki: 20.840 | Kd: 8.590 | Loss: 67.213943
# Time: 475.65s | Desired: 6000.00 RPM | Measured: 5091.00 RPM | Error: 909.00 RPM | PWM: 1205672.6433506012 | Kp: 25.404 | Ki: 11.418 | Kd: 11.205 | Loss: 64.861328
# Time: 476.68s | Desired: 6000.00 RPM | Measured: 5486.00 RPM | Error: 514.00 RPM | PWM: 642464.8902053833 | Kp: 21.343 | Ki: 0.000 | Kd: 17.750 | Loss: 63.759285
# Time: 477.73s | Desired: 6000.00 RPM | Measured: 5546.00 RPM | Error: 454.00 RPM | PWM: 8624.5054397583 | Kp: 30.686 | Ki: 25.000 | Kd: 25.000 | Loss: 64.854645
# Time: 478.77s | Desired: 6000.00 RPM | Measured: 5588.00 RPM | Error: 412.00 RPM | PWM: 1337267.5246810913 | Kp: 28.568 | Ki: 16.867 | Kd: 6.339 | Loss: 63.588848
# Time: 479.81s | Desired: 6000.00 RPM | Measured: 5597.00 RPM | Error: 403.00 RPM | PWM: 880815.0133938789 | Kp: 24.005 | Ki: 0.000 | Kd: 13.439 | Loss: 63.420071
# Time: 480.86s | Desired: 6000.00 RPM | Measured: 5601.00 RPM | Error: 399.00 RPM | PWM: 9524.118434906006 | Kp: 27.376 | Ki: 25.000 | Kd: 25.000 | Loss: 63.951244
# Time: 481.89s | Desired: 6000.00 RPM | Measured: 4892.00 RPM | Error: 1108.00 RPM | PWM: 1314132.4298706055 | Kp: 25.415 | Ki: 16.492 | Kd: 11.738 | Loss: 63.891499
# Time: 482.94s | Desired: 6000.00 RPM | Measured: 5155.00 RPM | Error: 845.00 RPM | PWM: 842745.842587471 | Kp: 22.064 | Ki: 0.000 | Kd: 17.308 | Loss: 63.623306
# Time: 483.96s | Desired: 6000.00 RPM | Measured: 5519.00 RPM | Error: 481.00 RPM | PWM: 4313.006906509399 | Kp: 39.450 | Ki: 17.074 | Kd: 25.000 | Loss: 62.881027
# Time: 485.01s | Desired: 6000.00 RPM | Measured: 5571.00 RPM | Error: 429.00 RPM | PWM: 844446.7162132263 | Kp: 23.651 | Ki: 0.000 | Kd: 14.100 | Loss: 62.105350
# Time: 486.04s | Desired: 6000.00 RPM | Measured: 4287.00 RPM | Error: 1713.00 RPM | PWM: 58619.20261001587 | Kp: 7.418 | Ki: 2.383 | Kd: 25.000 | Loss: 63.207287
# Time: 487.09s | Desired: 6000.00 RPM | Measured: 4240.00 RPM | Error: 1760.00 RPM | PWM: 128107.16809415817 | Kp: 22.154 | Ki: 0.000 | Kd: 25.000 | Loss: 64.271683
# Time: 488.12s | Desired: 6000.00 RPM | Measured: 4553.00 RPM | Error: 1447.00 RPM | PWM: 24231.516876220703 | Kp: 0.000 | Ki: 0.000 | Kd: 0.000 | Loss: 84.492722
# Time: 489.17s | Desired: 6000.00 RPM | Measured: 4661.00 RPM | Error: 1339.00 RPM | PWM: 0.0 | Kp: 43.351 | Ki: 23.482 | Kd: 20.959 | Loss: 83.892479
# Time: 490.21s | Desired: 6000.00 RPM | Measured: 5390.00 RPM | Error: 610.00 RPM | PWM: 1162182.0781326294 | Kp: 25.300 | Ki: 8.574 | Kd: 11.624 | Loss: 83.389343
# Time: 491.25s | Desired: 6000.00 RPM | Measured: 5120.00 RPM | Error: 880.00 RPM | PWM: 434667.1629371643 | Kp: 17.973 | Ki: 0.000 | Kd: 23.815 | Loss: 86.733795
# Time: 492.28s | Desired: 6000.00 RPM | Measured: 4780.00 RPM | Error: 1220.00 RPM | PWM: 30023.6580657959 | Kp: 0.000 | Ki: 2.321 | Kd: 0.000 | Loss: 92.829567
# Time: 493.31s | Desired: 6000.00 RPM | Measured: 5405.00 RPM | Error: 595.00 RPM | PWM: 110219.14160966873 | Kp: 34.882 | Ki: 6.197 | Kd: 25.000 | Loss: 95.403496
# Time: 494.36s | Desired: 6000.00 RPM | Measured: 4935.00 RPM | Error: 1065.00 RPM | PWM: 341282.62886047363 | Kp: 16.518 | Ki: 0.000 | Kd: 25.000 | Loss: 100.313614
# Time: 495.39s | Desired: 6000.00 RPM | Measured: 5400.00 RPM | Error: 600.00 RPM | PWM: -1714.0731811523438 | Kp: 50.000 | Ki: 25.000 | Kd: 8.944 | Loss: 99.699821
# Time: 496.44s | Desired: 6000.00 RPM | Measured: 5535.00 RPM | Error: 465.00 RPM | PWM: 1205417.6204776764 | Kp: 26.567 | Ki: 11.648 | Kd: 8.523 | Loss: 99.172836
# Time: 497.49s | Desired: 6000.00 RPM | Measured: 4512.00 RPM | Error: 1488.00 RPM | PWM: 588564.9539871216 | Kp: 17.231 | Ki: 0.000 | Kd: 25.000 | Loss: 99.931801
# Time: 498.52s | Desired: 6000.00 RPM | Measured: 5410.00 RPM | Error: 590.00 RPM | PWM: -12283.88614654541 | Kp: 0.000 | Ki: 0.057 | Kd: 0.036 | Loss: 99.125801
# Time: 499.57s | Desired: 6000.00 RPM | Measured: 4118.00 RPM | Error: 1882.00 RPM | PWM: 2607.01852761209 | Kp: 28.752 | Ki: 15.986 | Kd: 22.185 | Loss: 97.774567
# Data saved to motor_speed_data_ANN_20250404_221040.csv
# Measured Speed plot saved to motor_speed_plot_speed_ANN_20250404_221040.pdf
# PID Gains plot saved to motor_speed_plot_gains_ANN_20250404_221040.pdf
# Loss plot saved to motor_speed_plot_loss_ANN_20250404_221040.pdf

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from datetime import datetime
import uuid  # Import UUID for unique filenames

import matplotlib 
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16)

# Define whether ANN is enabled or not
ANN_enabled = True  # Set to True if ANN is used, False otherwise

# Convert lists to NumPy arrays for performance calculations
time_stamps = np.array(times)  # Recorded time points
error = np.array(errors)
setpoints = np.array([desired_speed] * len(times))  # Setpoints stored as an array
speeds = np.array(speeds)

# Handle missing `loss_values`
if "loss_values" in globals() and len(loss_values) > 0:
    training_epochs = np.array(range(len(loss_values)))  # Training epochs for ANN
    loss_values = np.array(loss_values)
else:
    training_epochs = np.array([])  # Empty array if no loss data is available
    loss_values = np.array([])

# Compute Performance Metrics
rmse = np.sqrt(np.mean(error ** 2))
mae = np.mean(np.abs(error))
SSE = error[-1]  # Last recorded error
max_speed = max(speeds)
overshoot = max(0, ((max_speed - desired_speed) / desired_speed) * 100)

# Settling Time (Ts)
within_tolerance = np.abs(error) < (0.05 * desired_speed)  # Within ±5% of setpoint
Ts_index = np.argmax(within_tolerance) if np.any(within_tolerance) else -1
Ts = time_stamps[Ts_index] if Ts_index != -1 else None  # First time where error is within ±5%

# Generate Performance Plots and Save with explicit names
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")  # Format: YYYYMMDD_HHMMSS
identifier = "With_ANN" if ANN_enabled else "No_ANN"  # Condition-based identifier
unique_id = uuid.uuid4().hex[:8]  # Generates an 8-character unique ID

# 1. Histogram of Errors
hist_filename = f"Histogram_Errors_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(8, 5))
plt.hist(error, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Error (RPM)", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.grid(True, linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(hist_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 2. RMSE & MAE Comparison
rmse_mae_filename = f"RMSE_MAE_Comparison_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(8, 5))
plt.bar(["RMSE", "MAE"], [rmse, mae], color=['red', 'orange'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
plt.savefig(rmse_mae_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 3. Overshoot & Steady-State Error
overshoot_sse_filename = f"Overshoot_SSE_{identifier}_{current_datetime}_{unique_id}.pdf"
plt.figure(figsize=(8, 5))
plt.bar(["Overshoot (%)", "SSE"], [overshoot, SSE], color=['purple', 'green'], alpha=0.7)
plt.ylabel("Value (RPM)", fontsize=16)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tick_params(axis='both', labelsize=12)
formatter = ScalarFormatter(useMathText=True)
formatter.set_powerlimits((3, 3))  # Enforce scientific notation
plt.gca().yaxis.set_major_formatter(formatter)
plt.savefig(overshoot_sse_filename, format="pdf", bbox_inches="tight")  # Save to PDF
plt.show()

# 4. ANN Loss Plot (if available)
if loss_values.size > 0:
    ann_loss_filename = f"ANN_Loss_{identifier}_{current_datetime}_{unique_id}.pdf"
    plt.figure(figsize=(8, 5))
    plt.plot(training_epochs, loss_values, label="Loss", color="b", linewidth=2)
    plt.xlabel("Epochs", fontsize=16)
    plt.ylabel("Loss Value (MSE)", fontsize=16)
    plt.legend(fontsize=12)
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.savefig(ann_loss_filename, format="pdf", bbox_inches="tight")  # Save to PDF
    plt.show()
    print(f"ANN Loss Plot saved as {ann_loss_filename}")

# Print Statistical Summary
print("\n **Statistical Evaluation:**")
print(f"RMSE: {rmse:.2f} RPM")
print(f"MAE: {mae:.2f} RPM")
print(f"Settling Time (Ts): {Ts:.2f} s" if Ts is not None else " Settling Time Not Reached")
print(f"Steady-State Error (SSE): {SSE:.2f} RPM")
print(f"Overshoot: {overshoot:.2f}%")
print(f"\nHistogram of Errors saved as {hist_filename}")
print(f"RMSE & MAE Comparison saved as {rmse_mae_filename}")
print(f"Overshoot & Steady-State Error saved as {overshoot_sse_filename}")
# Out:
# ANN Loss Plot saved as ANN_Loss_With_ANN_20250404_222136_0936973e.pdf
#
#  **Statistical Evaluation:**
# RMSE: 1842.37 RPM
# MAE: 1365.44 RPM
#  Settling Time Not Reached
# Steady-State Error (SSE): 1882.00 RPM
# Overshoot: 0.00%
#
# Histogram of Errors saved as Histogram_Errors_With_ANN_20250404_222136_0936973e.pdf
# RMSE & MAE Comparison saved as RMSE_MAE_Comparison_With_ANN_20250404_222136_0936973e.pdf
# Overshoot & Steady-State Error saved as Overshoot_SSE_With_ANN_20250404_222136_0936973e.pdf

# %% [markdown]
# # Arduino Code Description
#
# The Arduino code (given below) is designed to control a DC motor using an Arduino microcontroller. The microcontroller powers the DC motor through a pulse-width modulation (PWM) driver. The code uses an shaft encoder to measure the motor's speed and a servo object to apply control. Real-time speed updates are sent to a connected Python script via serial communication, while PWM reference values received from the Python script are used to dynamically control the motor's speed. Encoder pulses are tracked using interrupts to ensure accurate speed measurements, creating a seamless integration between hardware and software for efficient motor control.

# %% [markdown]
# # The Arduino Code
#
# ```cpp
# #include <Servo.h>  // Include the Servo library
#
# Servo myservo;  // Servo object for motor control
#
# // Encoder tracking
# volatile unsigned int counter = 0;
# unsigned long lastTime = 0;
# const long interval = 1000;  // Speed update every 1 second
#
# int speedValue = 0;  // Measured speed
#
# void setup() {
#     myservo.attach(9);  // Connect servo/motor control to pin 9
#     Serial.begin(115200);  // Set serial baud rate
#
#     pinMode(2, INPUT_PULLUP);  // Encoder input
#     attachInterrupt(digitalPinToInterrupt(2), countPulses, RISING);  // Interrupt for encoder
# }
#
# void loop() {
#     // Send speed to Python every second
#     if (millis() - lastTime >= interval) {
#         lastTime = millis();
#         speedValue = map(counter, 0, 400, 0, 100);  // Convert pulses per second to speed in RPM
#         Serial.println(speedValue);  // Send the speed to Python
#         counter = 0;  // Reset counter
#     }
#
#     // Read PWM value from Python
#     if (Serial.available()) {
#         int pwmValue = Serial.parseInt();
#         pwmValue = map(pwmValue, 30000, 0, 120, 140);  // Map PWM range
#         myservo.write(pwmValue);  // Apply control
#         delay(50);
#     }
# }
#
# // Interrupt function to count encoder pulses
# void countPulses() {
#     counter++;
# }
# ```

# %% [markdown]
# # Preliminary Result
#
# The ANN-tuned PID controller outperforms the classical PID, achieving lower steady-state error and better adherence to the desired speed. Moreover, ongoing investigations are addressing the electrical and mechanical issues causing drift and undesirable step response, which reduces the systems performance.
